# %% [markdown]
# # Mini_proyecto_EDA
#
# # Ejercicio Práctico: Carga, Exploración, Limpieza y Visualización Básica de un Dataset
#
# ## 1. Objetivo del ejercicio
# El propósito de este ejercicio es aprender a realizar un flujo completo y ordenado de análisis exploratorio inicial (EDA) sobre un dataset real. El objetivo no es realizar análisis estadísticos avanzados, sino dominar las fases fundamentales que permiten comprender y describir datos antes de cualquier modelado.
#
# Al finalizar el ejercicio, el alumno deberá ser capaz de:
#
# ### 1.1 Exploración
# - Identificar la estructura del dataset: dimensiones, columnas, tipos de datos.
# - Evaluar la calidad del dataset respondiendo preguntas como:
#   - ¿Qué tipos de datos tengo? (numéricos, categóricos, fechas, texto libre...)
#       - Tenemos datos int, float y object
#   - ¿Cuál es el dominio del dataset? ¿Conozco el contexto de las variables?
#       - Los datasets proceden de https://archive.ics.uci.edu/ y el significado de las variables está explicado antes de comenzar el análisis
#   - ¿La fuente de datos es fiable y completa?
#   - ¿Los datos están agregados o son individuales (nivel de granularidad)?
#       - Los datos no están agregados
#   - ¿Hay valores perdidos? ¿Cuál es su proporción?
#       - Hay valores nulos
#   - ¿Existen duplicados o registros anómalos?
#       - No
#   - ¿Las variables tienen una distribución razonable? ¿Existen outliers?
#     - Aproximadamente lógica la distribución
#   - ¿Los formatos (fechas, categorías) están normalizados?
#       - No estaban normalizadas pero yo he generado una columna fecha para generar una columna 'datetime
#   - ¿Existen incoherencias entre columnas?
#       - No
#
#       https://catalog.data.gov/dataset/crime-data-from-2020-to-present
#
# ### 1.2 Limpieza
# - Corregir tipos de datos.
# - Gestionar valores nulos de forma justificada.
# - Eliminar o tratar duplicados.
# - Normalizar formatos y categorías.
# - Corregir incoherencias detectadas.
#
# ### 1.3 Visualización básica
# Generar visualizaciones sencillas que ayuden a explicar el dataset, respondiendo a preguntas como:
# - ¿Cómo se distribuye una variable numérica relevante?
# - ¿Cuáles son las categorías más frecuentes?
# - ¿Existen diferencias visuales entre grupos?
# - ¿Cómo varían los valores a lo largo del tiempo (si aplica)?
# - ¿Qué patrones básicos se detectan tras la limpieza?
#
# ### 1.4 Documentación y repositorio
# - Explicar con claridad el trabajo realizado.
# - Organizar un repositorio en GitHub con estructura ordenada.
# - Entregar el enlace a través de **Google Classroom**.
#
# ---
#
# ## 2. Descripción general del ejercicio
# El alumno trabajará con un dataset **elegido libremente** de una fuente fiable (Kaggle, datos públicos, open data, repositorios gubernamentales, etc.).
#
# El trabajo consistirá en cargar los datos, explorarlos, limpiarlos y generar visualizaciones básicas que permitan entender sus características principales.
#
# El foco está en:
# - Calidad del proceso.
# - Claridad del análisis.
# - Documentación.
# - Organización del repositorio.
#
# ---
#
# ## 3. Tareas obligatorias
#
# ### 3.1 Carga del dataset
# - Importar el dataset.
# - Revisar dimensiones y primeras filas.
# - Inspeccionar tipos de datos.
#
# ### 3.2 Exploración del dataset
# - Valores nulos.
# - Duplicados.
# - Rango de las variables.
# - Incoherencias.
# - Distribución inicial de columnas.
#
# ### 3.3 Limpieza y normalización
# - Corrección de tipos.
# - Tratamiento de nulos.
# - Eliminación o tratamiento de duplicados.
# - Normalización de categorías y fechas.
# - Justificación de cada decisión.
#
# ### 3.4 Visualizaciones básicas
# Debe incluir, como mínimo:
# - Un histograma.
# - Una gráfica de barras.
# - Una visualización adicional que aporte información relevante.
#
# ### 3.5 Conclusiones exploratorias
# - Resumen claro de las características del dataset.
# - Principales hallazgos.
# - Cambios aplicados durante la limpieza.
#
# ---
#
# ## 4. Entregables
# La entrega se realizará por **Google Classroom**, incluyendo un enlace a un repositorio público de GitHub.
#
# ### 4.1 Estructura mínima del repositorio
# ```
# ├── data/
# │   └── dataset.csv
# ├── notebooks/
# │   └── eda.ipynb
# ├── README.md
# └── requirements.txt (opcional)
# ```
#
# ### 4.2 Contenido obligatorio
# - Notebook completo con el proceso.
# - Dataset en la carpeta `data/`.
# - README con explicación del análisis.
#
# ### 4.3 Criterios de evaluación
# - Claridad del análisis.
# - Coherencia del proceso de limpieza.
# - Calidad de las visualizaciones.
# - Orden del repositorio.
# - Explicaciones adecuadas.
#
# ---
#
# ## 5. Recomendaciones
# - Comentar el código cuando sea necesario.
# - Mantener el notebook limpio y sin celdas duplicadas.
# - Evitar análisis avanzados no requeridos.
# - Asegurar que las visualizaciones sean legibles y útiles.
# - Hacer commits frecuentes.
#
# ---
#
# ## 6. Entrega
# La entrega se realizará exclusivamente por **Google Classroom**, adjuntando el enlace público al repositorio de GitHub.
#
# **Fin del enunciado del ejercicio**

# %%
# !pip install cloudpickle
# Out:
# Requirement already satisfied: cloudpickle in c:\users\oscar\onedrive - fm4\escritorio\evolve\data science\.venv2\lib\site-packages (3.1.2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cloudpickle #Mismas funciones de pickle de guardar modelos + funciones de guardado de las funciones específicasimport seaborn as sns
# %matplotlib inline
# %config IPCompleter.greedy = True
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Definimos la ruta donde ubicamos los datasets para no tener que estar poniéndola en cada ocasión

# %%
ruta_datasets = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/001_crime_from_2020/000_datasets/'

# %% [markdown]
# Definimos el dataset que vamos a usar.
#
# A continuación, aplicaremos los cambios de manera individual sobre el df pero, después, generaremos una función que aglutine todos los pasos individuales y la aplicaremos directamente

# %%
dataset_df = 'Crime_Data_from_2020_to_Present.csv'

# %% [markdown]
# Cargamos el dataset df

# %%
ruta_completa = ruta_datasets + dataset_df
df = pd.read_csv(ruta_completa,sep=',').sample(frac = 0.5)
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 504909  221317764  09/16/2022 12:00:00 AM  09/16/2022 12:00:00 AM       320
# 888948  240613264  11/12/2024 12:00:00 AM  11/12/2024 12:00:00 AM      1220
# 380355  210117314  09/22/2021 12:00:00 AM  09/22/2021 12:00:00 AM       600
# 592078  222019602  12/23/2022 12:00:00 AM  12/22/2022 12:00:00 AM      1800
# 909821  241306293  02/18/2024 12:00:00 AM  02/18/2024 12:00:00 AM      1445
# ...           ...                     ...                     ...       ...
# 653301  230221477  11/24/2023 12:00:00 AM  11/23/2023 12:00:00 AM      1530
# 377447  210907524  03/30/2021 12:00:00 AM  03/16/2021 12:00:00 AM      1216
# 596506  221204790  01/15/2022 12:00:00 AM  01/15/2022 12:00:00 AM      1715
# 828998  230817266  11/25/2023 12:00:00 AM  11/25/2023 12:00:00 AM       745
# 176496  201219561  08/28/2020 12:00:00 AM  08/28/2020 12:00:00 AM      1200
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 504909    13       Newton         1307         2     626
# 888948     6    Hollywood          643         2     354
# 380355     1      Central          174         1     210
# 592078    20      Olympic         2046         1     330
# 909821    13       Newton         1313         1     230
# ...      ...          ...          ...       ...     ...
# 653301     2      Rampart          221         1     236
# 377447     9     Van Nuys          935         1     440
# 596506    12  77th Street         1218         1     210
# 828998     8      West LA          855         2     626
# 176496    12  77th Street         1253         2     745
#
#                                            Crm Cd Desc  ... Status  \
# 504909               INTIMATE PARTNER - SIMPLE ASSAULT  ...     IC
# 888948                               THEFT OF IDENTITY  ...     IC
# 380355                                         ROBBERY  ...     IC
# 592078                           BURGLARY FROM VEHICLE  ...     IC
# 909821  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# ...                                                ...  ...    ...
# 653301           INTIMATE PARTNER - AGGRAVATED ASSAULT  ...     AO
# 377447              THEFT PLAIN - PETTY ($950 & UNDER)  ...     IC
# 596506                                         ROBBERY  ...     IC
# 828998               INTIMATE PARTNER - SIMPLE ASSAULT  ...     AO
# 176496        VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#         Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 504909  Invest Cont    626.0      NaN       NaN      NaN
# 888948  Invest Cont    354.0      NaN       NaN      NaN
# 380355  Invest Cont    210.0    480.0       NaN      NaN
# 592078  Invest Cont    330.0      NaN       NaN      NaN
# 909821  Invest Cont    230.0      NaN       NaN      NaN
# ...             ...      ...      ...       ...      ...
# 653301  Adult Other    236.0      NaN       NaN      NaN
# 377447  Invest Cont    440.0      NaN       NaN      NaN
# 596506  Invest Cont    210.0      NaN       NaN      NaN
# 828998  Adult Other    626.0      NaN       NaN      NaN
# 176496  Invest Cont    745.0      NaN       NaN      NaN
#
#                                         LOCATION  \
# 504909   1200 E  7TH                          ST
# 888948   1700 N  FULLER                       AV
# 380355    700 S  MAIN                         ST
# 592078                                   BERENDO
# 909821                                    MYRTLE
# ...                                          ...
# 653301    300 N  BERENDO                      ST
# 377447  14400    SYLVAN                       ST
# 596506           SLAUSON                      AV
# 828998   1600    MALCOLM                      AV
# 176496   7400 S  WESTERN                      AV
#
#                            Cross Street      LAT       LON
# 504909                              NaN  34.0376 -118.2423
# 888948                              NaN  34.1016 -118.3489
# 380355                              NaN  34.0437 -118.2518
# 592078                       SAN MARINO  34.0545 -118.2941
# 909821                             WALL  34.0286 -118.2545
# ...                                 ...      ...       ...
# 653301                              NaN  34.0770 -118.2944
# 377447                              NaN  34.1847 -118.4480
# 596506  VERMONT                      AV  33.9891 -118.2915
# 828998                              NaN  34.0543 -118.4376
# 176496                              NaN  33.9718 -118.3090
#
# [502496 rows x 28 columns]

# %% [markdown]
# Comprobamos que el dataset tiene nulos y nos sirve para trabajar

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Crm Cd 4          502470
# Crm Cd 3          501349
# Crm Cd 2          468133
# Cross Street      425790
# Weapon Used Cd    339155
# Weapon Desc       339155
# Mocodes            75910
# Vict Descent       72424
# Vict Sex           72417
# Premis Desc          304
# Premis Cd              8
# Crm Cd 1               4
# Status                 1
# Vict Age               0
# Crm Cd                 0
# Crm Cd Desc            0
# AREA NAME              0
# Rpt Dist No            0
# AREA                   0
# TIME OCC               0
# Date Rptd              0
# DATE OCC               0
# DR_NO                  0
# Part 1-2               0
# Status Desc            0
# LOCATION               0
# LAT                    0
# LON                    0
# dtype: int64

# %% [markdown]
# Comprobamos las dimensiones de la tabla y los valores únicos de DR_NO ya que sospecho que debe ser el índice

# %%
dimensiones_df = df.shape
print(f'Dimensiones df: ', dimensiones_df)
# Out:
# Dimensiones df:  (502496, 28)

# %%
DR_NO = df.DR_NO.nunique()
print(f'Valores únicos de DR_NO: ', DR_NO)
# Out:
# Valores únicos de DR_NO:  502496

# %% [markdown]
# Aplicaciones:
# - Transformamos a minúsculas los nombres de las columnas
# - Ponemos 'dr_no' como index ya que es el identificador del reporte

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.columns = df.columns.str.replace('-','_')
df = df.set_index('dr_no')
df
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 221317764  09/16/2022 12:00:00 AM  09/16/2022 12:00:00 AM       320    13
# 240613264  11/12/2024 12:00:00 AM  11/12/2024 12:00:00 AM      1220     6
# 210117314  09/22/2021 12:00:00 AM  09/22/2021 12:00:00 AM       600     1
# 222019602  12/23/2022 12:00:00 AM  12/22/2022 12:00:00 AM      1800    20
# 241306293  02/18/2024 12:00:00 AM  02/18/2024 12:00:00 AM      1445    13
# ...                           ...                     ...       ...   ...
# 230221477  11/24/2023 12:00:00 AM  11/23/2023 12:00:00 AM      1530     2
# 210907524  03/30/2021 12:00:00 AM  03/16/2021 12:00:00 AM      1216     9
# 221204790  01/15/2022 12:00:00 AM  01/15/2022 12:00:00 AM      1715    12
# 230817266  11/25/2023 12:00:00 AM  11/25/2023 12:00:00 AM       745     8
# 201219561  08/28/2020 12:00:00 AM  08/28/2020 12:00:00 AM      1200    12
#
#              area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 221317764       Newton         1307         2     626
# 240613264    Hollywood          643         2     354
# 210117314      Central          174         1     210
# 222019602      Olympic         2046         1     330
# 241306293       Newton         1313         1     230
# ...                ...          ...       ...     ...
# 230221477      Rampart          221         1     236
# 210907524     Van Nuys          935         1     440
# 221204790  77th Street         1218         1     210
# 230817266      West LA          855         2     626
# 201219561  77th Street         1253         2     745
#
#                                               crm_cd_desc  \
# dr_no
# 221317764               INTIMATE PARTNER - SIMPLE ASSAULT
# 240613264                               THEFT OF IDENTITY
# 210117314                                         ROBBERY
# 222019602                           BURGLARY FROM VEHICLE
# 241306293  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# ...                                                   ...
# 230221477           INTIMATE PARTNER - AGGRAVATED ASSAULT
# 210907524              THEFT PLAIN - PETTY ($950 & UNDER)
# 221204790                                         ROBBERY
# 230817266               INTIMATE PARTNER - SIMPLE ASSAULT
# 201219561        VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#                                                      mocodes  ...  status  \
# dr_no                                                         ...
# 221317764                                2000 0400 0916 1813  ...      IC
# 240613264                                          1501 1822  ...      IC
# 210117314                      1414 1420 0334 0411 0344 0913  ...      IC
# 222019602                                0386 0344 1822 0216  ...      IC
# 241306293                                0400 1822 1217 0342  ...      IC
# ...                                                      ...  ...     ...
# 230221477                      2000 0913 1814 0445 0401 0447  ...      AO
# 210907524                                     0394 0344 1822  ...      IC
# 221204790  1822 0302 0371 0906 0432 0345 0337 0316 0344 0216  ...      IC
# 230817266                                               2000  ...      AO
# 201219561                                     0329 0397 1236  ...      IC
#
#            status_desc crm_cd_1  crm_cd_2 crm_cd_3  crm_cd_4  \
# dr_no
# 221317764  Invest Cont    626.0       NaN      NaN       NaN
# 240613264  Invest Cont    354.0       NaN      NaN       NaN
# 210117314  Invest Cont    210.0     480.0      NaN       NaN
# 222019602  Invest Cont    330.0       NaN      NaN       NaN
# 241306293  Invest Cont    230.0       NaN      NaN       NaN
# ...                ...      ...       ...      ...       ...
# 230221477  Adult Other    236.0       NaN      NaN       NaN
# 210907524  Invest Cont    440.0       NaN      NaN       NaN
# 221204790  Invest Cont    210.0       NaN      NaN       NaN
# 230817266  Adult Other    626.0       NaN      NaN       NaN
# 201219561  Invest Cont    745.0       NaN      NaN       NaN
#
#                                            location  \
# dr_no
# 221317764   1200 E  7TH                          ST
# 240613264   1700 N  FULLER                       AV
# 210117314    700 S  MAIN                         ST
# 222019602                                   BERENDO
# 241306293                                    MYRTLE
# ...                                             ...
# 230221477    300 N  BERENDO                      ST
# 210907524  14400    SYLVAN                       ST
# 221204790           SLAUSON                      AV
# 230817266   1600    MALCOLM                      AV
# 201219561   7400 S  WESTERN                      AV
#
#                               cross_street      lat       lon
# dr_no
# 221317764                              NaN  34.0376 -118.2423
# 240613264                              NaN  34.1016 -118.3489
# 210117314                              NaN  34.0437 -118.2518
# 222019602                       SAN MARINO  34.0545 -118.2941
# 241306293                             WALL  34.0286 -118.2545
# ...                                    ...      ...       ...
# 230221477                              NaN  34.0770 -118.2944
# 210907524                              NaN  34.1847 -118.4480
# 221204790  VERMONT                      AV  33.9891 -118.2915
# 230817266                              NaN  34.0543 -118.4376
# 201219561                              NaN  33.9718 -118.3090
#
# [502496 rows x 27 columns]

# %% [markdown]
# Ya sabemos que podemos trabajar con el dataset y lo tenemos cargado con los nombre de las columnas en su formato correto
#
# Significado de las columnas:
# - dr_no: Número de expediente oficial compuesto por un año de 2 dígitos, un ID de área y 5 dígitos.
# - date_rptd: Fecha de Reporte. Indica el día en que el crimen o incidente fue oficialmente reportado (MM/DD/AAAA)
# - date_occ: Fecha de Ocurrencia. Indica el día real en que el crimen tuvo lugar (MM/DD/AAAA)
# - time_occ: En horario militar de 24 horas.
# - area: Áreas Geográficas o Divisiones de Patrulla numeradas secuencialmente del 1 al 21.
# - area_name: Nombre de las áreas Geográficas o Divisiones de Patrulla
# - rpt_dist_no: Número de distrito de la patrulla del oficial que informó el incidente.
# - part_1_2: Indica si el incidente es un crimen de la Parte 1 (crímenes más graves) o de la Parte 2 (crímenes menos graves).
# - crm_cd: Código de delito de 3 dígitos del crimen cometido.
# - crm_cd_desc: Descripción del delito del crimen cometido.
# - mocodes: Modus Operandi o la manera distintiva o característica en que una persona lleva a cabo una actividad criminal.
# - vict_age: Edad de la víctima
# - vict_sex: Sexo de la víctima.
# - vict_descent: Código de descendencia de la víctima
# - premis_cd: El Código de Instalación es un código de 3 dígitos que identifica el tipo de lugar donde ocurrió el incidente
# - premis_desc: Descripción de la Instalación.
# - weapon_used_cd: El Código de Arma es un código de 3 dígitos que identifica el tipo de arma utilizada en el incidente
# - weapon_desc: Descripción del Arma.
# - status: Estado del caso. (IC es el valor predeterminado)
# - status_desc: Define el Código de Estado proporcionado.
# - crm_cd_1: Indica el crimen cometido. El Código de Crimen 1 es el principal y el más grave. Los Códigos de Crimen 2, 3 y 4 son, respectivamente, delitos menos graves. Los números de clase de crimen más bajos son más graves.
# - crm_cd_2: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_3: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_4: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - location: Dirección postal del incidente del crimen redondeada al centenar de la cuadra más cercana para mantener el anonimato.
# - cross_street: El nombre de la calle que se cruza con la calle principal donde ocurrió el incidente.
# - lat: Latitud.
# - lon: Longitud.
#
# Códigos de descendencia:
# - A: Otros Asiáticos
# - B: Afroamericano
# - C: Chino
# - D: Camboyano
# - F: Filipino
# - G: Guamés
# - H: Hispano/Latino/Mexicano
# - I: Indio Americano/Nativo de Alaska
# - J: Japonés
# - K: Coreano
# - L: Laosiano
# - O: Otro
# - P: Isleño del Pacífico
# - S: Samoano
# - U: Hawaiano
# - V: Vietnamita
# - W: Blanco
# - X: Desconocido
# - Z: Hindú Asiático

# %% [markdown]
# Revisamos los tipos de datos de cada variable observando entre el .info() y la viasualización de la propia tabla y no se requieren cambios
#
# También observamos en el count que hay nulos en varias columnas que trataremos posteriormente

# %%
pd.set_option('display.max_columns', None)
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 200310785  05/03/2020 12:00:00 AM  05/03/2020 12:00:00 AM      1300     3
#
#            area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 200310785  Southwest          361         2     901
#
#                               crm_cd_desc         mocodes  vict_age vict_sex  \
# dr_no
# 200310785  VIOLATION OF RESTRAINING ORDER  0561 2038 2004        55        F
#
#           vict_descent  premis_cd  \
# dr_no
# 200310785            H      502.0
#
#                                             premis_desc  weapon_used_cd  \
# dr_no
# 200310785  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
#
#           weapon_desc status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  \
# dr_no
# 200310785         NaN     IC  Invest Cont     901.0       NaN       NaN
#
#            crm_cd_4                         location  \
# dr_no
# 200310785       NaN  NICOLET                      ST
#
#                               cross_street      lat       lon
# dr_no
# 200310785  COLISEUM                     AV  34.0183 -118.3504

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 502496 entries, 221317764 to 201219561
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       502496 non-null  object
#  1   date_occ        502496 non-null  object
#  2   time_occ        502496 non-null  int64
#  3   area            502496 non-null  int64
#  4   area_name       502496 non-null  object
#  5   rpt_dist_no     502496 non-null  int64
#  6   part_1_2        502496 non-null  int64
#  7   crm_cd          502496 non-null  int64
#  8   crm_cd_desc     502496 non-null  object
#  9   mocodes         426586 non-null  object
#  10  vict_age        502496 non-null  int64
#  11  vict_sex        430079 non-null  object
#  12  vict_descent    430072 non-null  object
#  13  premis_cd       502488 non-null  float64
#  14  premis_desc     502192 non-null  object
#  15  weapon_used_cd  163341 non-null  float64
#  16  weapon_desc     163341 non-null  object
#  17  status          502495 non-null  object
#  18  status_desc     502496 non-null  object
#  19  crm_cd_1        502492 non-null  float64
#  20  crm_cd_2        34363 non-null   float64
#  21  crm_cd_3        1147 non-null    float64
#  22  crm_cd_4        26 non-null      float64
#  23  location        502496 non-null  object
#  24  cross_street    76706 non-null   object
#  25  lat             502496 non-null  float64
#  26  lon             502496 non-null  float64
# dtypes: float64(8), int64(6), object(13)
# memory usage: 107.3+ MB

# %% [markdown]
# Las columnas 'date_rptd' y 'date_occ' vamos a eliminar la hora porque en todos los registros nos dicen que ha sido a las '12:00:00 AM'. Esta información es errónea según la columna 'time_occ' y además no nos aporta información como variable porque es una constante en todos los registros

# %%
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 241004431  01/11/2024 12:00:00 AM  01/11/2024 12:00:00 AM      1315    10
#
#              area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 241004431  West Valley         1025         2     624
#
#                         crm_cd_desc                             mocodes  \
# dr_no
# 241004431  BATTERY - SIMPLE ASSAULT  0319 2004 0400 0416 1822 0345 1202
#
#            vict_age vict_sex vict_descent  premis_cd  premis_desc  \
# dr_no
# 241004431        78        M            O      108.0  PARKING LOT
#
#            weapon_used_cd                                     weapon_desc  \
# dr_no
# 241004431           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 241004431     IC  Invest Cont     624.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 241004431  7100    DARBY                        AV          NaN  34.1993
#
#                 lon
# dr_no
# 241004431 -118.5335

# %% [markdown]
# Eliminamos la parte de la hora

# %%
df['date_rptd'] = df['date_rptd'].str.split(' ').str[0]
df['date_occ'] = df['date_occ'].str.split(' ').str[0]

# %% [markdown]
# Hacemos un datetime de las columnas de fechas

# %%
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 221504546  01/14/2022  01/13/2022      1740    15  N Hollywood         1549
#
#            part_1_2  crm_cd                         crm_cd_desc    mocodes  \
# dr_no
# 221504546         1     440  THEFT PLAIN - PETTY ($950 & UNDER)  0344 0352
#
#            vict_age vict_sex vict_descent  premis_cd premis_desc  \
# dr_no
# 221504546        57        F            W      102.0    SIDEWALK
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 221504546             NaN         NaN     IC  Invest Cont     440.0       NaN
#
#            crm_cd_3  crm_cd_4                         location  \
# dr_no
# 221504546       NaN       NaN  CUMPSTON                     ST
#
#                               cross_street    lat       lon
# dr_no
# 221504546  LANKERSHIM                   BL  34.17 -118.3777

# %%
df['date_rptd'] = pd.to_datetime(df['date_rptd'], format='%m/%d/%Y')
df['date_occ'] = pd.to_datetime(df['date_occ'], format='%m/%d/%Y')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 502496 entries, 221317764 to 201219561
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       502496 non-null  datetime64[ns]
#  1   date_occ        502496 non-null  datetime64[ns]
#  2   time_occ        502496 non-null  int64
#  3   area            502496 non-null  int64
#  4   area_name       502496 non-null  object
#  5   rpt_dist_no     502496 non-null  int64
#  6   part_1_2        502496 non-null  int64
#  7   crm_cd          502496 non-null  int64
#  8   crm_cd_desc     502496 non-null  object
#  9   mocodes         426586 non-null  object
#  10  vict_age        502496 non-null  int64
#  11  vict_sex        430079 non-null  object
#  12  vict_descent    430072 non-null  object
#  13  premis_cd       502488 non-null  float64
#  14  premis_desc     502192 non-null  object
#  15  weapon_used_cd  163341 non-null  float64
#  16  weapon_desc     163341 non-null  object
#  17  status          502495 non-null  object
#  18  status_desc     502496 non-null  object
#  19  crm_cd_1        502492 non-null  float64
#  20  crm_cd_2        34363 non-null   float64
#  21  crm_cd_3        1147 non-null    float64
#  22  crm_cd_4        26 non-null      float64
#  23  location        502496 non-null  object
#  24  cross_street    76706 non-null   object
#  25  lat             502496 non-null  float64
#  26  lon             502496 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(6), object(11)
# memory usage: 107.3+ MB

# %%
df.sample()
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 231317844 2023-09-25 2023-09-25       400    13    Newton         1383
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 231317844         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd premis_desc  weapon_used_cd weapon_desc  \
# dr_no
# 231317844          NaN      101.0      STREET             NaN         NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 231317844     IC  Invest Cont     510.0       NaN       NaN       NaN
#
#                                          location cross_street      lat  \
# dr_no
# 231317844  200 E  60TH                         ST          NaN  33.9852
#
#                 lon
# dr_no
# 231317844 -118.2718

# %% [markdown]
# Comprobamos los duplicados

# %%
duplicados = df.duplicated().sum()
print(f'Recuento de duplicados en df: ', duplicados)
# Out:
# Recuento de duplicados en df:  849

# %% [markdown]
# Nos salen 2966 duplicados de las 27 columnas y que solamente es diferente el índice. Hacemos unas visualizaciones para comprobar que son realmente duplicados y vemos que es cierto, por lo que borramos todos los duplicados

# %%
df.loc[df.duplicated()].head()
# Out:
#            date_rptd   date_occ  time_occ  area   area_name  rpt_dist_no  \
# dr_no
# 230507918 2023-04-19 2022-11-01      1000     5      Harbor          519
# 210415821 2021-12-13 2021-12-11       700     4  Hollenbeck          424
# 200710075 2020-06-05 2020-05-30      2145     7    Wilshire          702
# 202109705 2020-05-24 2020-05-17      1700    21     Topanga         2157
# 230805459 2023-02-03 2023-02-03      2115     8     West LA          842
#
#            part_1_2  crm_cd                                   crm_cd_desc  \
# dr_no
# 230507918         1     510                              VEHICLE - STOLEN
# 210415821         1     510                              VEHICLE - STOLEN
# 200710075         1     231  ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER
# 202109705         1     510                              VEHICLE - STOLEN
# 230805459         2     624                      BATTERY - SIMPLE ASSAULT
#
#                   mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 230507918             NaN         0      NaN          NaN      710.0
# 210415821             NaN         0      NaN          NaN      108.0
# 200710075  1822 1212 0447         0        M            W      101.0
# 202109705             NaN         0      NaN          NaN      108.0
# 230805459  1815 0416 1251        19        F            B      108.0
#
#              premis_desc  weapon_used_cd  \
# dr_no
# 230507918  OTHER PREMISE             NaN
# 210415821    PARKING LOT             NaN
# 200710075         STREET           500.0
# 202109705    PARKING LOT             NaN
# 230805459    PARKING LOT           400.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 230507918                                             NaN     IC  Invest Cont
# 210415821                                             NaN     IC  Invest Cont
# 200710075                     UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont
# 202109705                                             NaN     IC  Invest Cont
# 230805459  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 230507918     510.0       NaN       NaN       NaN
# 210415821     510.0       NaN       NaN       NaN
# 200710075     231.0       NaN       NaN       NaN
# 202109705     510.0       NaN       NaN       NaN
# 230805459     624.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 230507918   1700    ALAMEDA                      ST          NaN  33.7976
# 210415821   2100 N  SOTO                         ST          NaN  34.0700
# 200710075   7500 W  MELROSE                      AV          NaN  34.0837
# 202109705   6800    DE SOTO                      AV          NaN  34.1938
# 230805459  11800    TEXAS                        AV          NaN  34.0458
#
#                 lon
# dr_no
# 230507918 -118.2385
# 210415821 -118.1998
# 200710075 -118.3532
# 202109705 -118.5884
# 230805459 -118.4614

# %%
df.loc[(df.mocodes == '0400 2004 1822 0356 1212')]
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 242000713 2024-08-27 2024-08-27      1900    20   Olympic         2069
#
#            part_1_2  crm_cd              crm_cd_desc  \
# dr_no
# 242000713         2     623  BATTERY POLICE (SIMPLE)
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 242000713  0400 2004 1822 0356 1212         0        X            X
#
#            premis_cd      premis_desc  weapon_used_cd  \
# dr_no
# 242000713      726.0  POLICE FACILITY           400.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 242000713  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 242000713     623.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 242000713  1100 S  VERMONT                      AV          NaN  34.0509
#
#                 lon
# dr_no
# 242000713 -118.2916

# %% [markdown]
# Eliminamos los duplicados

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (501647, 27)

# %%
# Al cargar el df tenia 1004991 filas
1004991 - 1002025
# Out:
# 2966

# %% [markdown]
# Comprobamos los valores únicos en la tabla para desestimar variables. En este caso, no hay constantes

# %%
df.nunique().sort_values(ascending=True)

# Si hubiera alguna columna que eliminar haríamos df.drop(columns = '...', inplace=True)
# Out:
# part_1_2               2
# vict_sex               4
# crm_cd_4               4
# status                 6
# status_desc            6
# vict_descent          19
# area_name             21
# area                  21
# crm_cd_3              32
# weapon_used_cd        78
# weapon_desc           78
# vict_age             104
# crm_cd_2             115
# crm_cd               139
# crm_cd_desc          139
# crm_cd_1             141
# premis_desc          305
# premis_cd            312
# rpt_dist_no         1177
# time_occ            1439
# date_occ            1853
# date_rptd           1874
# lon                 4913
# lat                 5283
# cross_street        7920
# location           56974
# mocodes           168939
# dtype: int64

# %% [markdown]
# Comprobamos los nulos que existen según el tipo de columna: Categórica y numérica
#
# Primero haremos las comprobaciones, después expondré las conclusiones y a continuación realizaré los cambios

# %%
df.select_dtypes(include='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_4          501621
# crm_cd_3          500500
# crm_cd_2          467309
# weapon_used_cd    338605
# premis_cd              8
# crm_cd_1               4
# vict_age               0
# crm_cd                 0
# part_1_2               0
# rpt_dist_no            0
# area                   0
# time_occ               0
# lat                    0
# lon                    0
# dtype: int64

# %%
df.select_dtypes(exclude='number').isna().sum().sort_values(ascending=False)
# Out:
# cross_street    425080
# weapon_desc     338605
# mocodes          75585
# vict_descent     72115
# vict_sex         72108
# premis_desc        304
# status               1
# date_occ             0
# date_rptd            0
# crm_cd_desc          0
# area_name            0
# status_desc          0
# location             0
# dtype: int64

# %%
df.vict_descent.unique()
# Out:
# array(['H', 'B', nan, 'W', 'O', 'X', 'K', 'A', 'P', 'C', 'F', 'U', 'V',
#        'J', 'I', 'Z', 'G', 'S', 'L', 'D'], dtype=object)

# %%
df.loc[df.vict_descent=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon]
# Index: []

# %%
df.vict_sex.unique()
# Out:
# array(['M', 'F', nan, 'X', 'H'], dtype=object)

# %%
df.loc[df.vict_sex=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon]
# Index: []

# %%
df.loc[(df.premis_cd.notna())&(df.premis_desc.isna())].premis_cd.value_counts()
# Out:
# premis_cd
# 418.0    198
# 256.0     79
# 972.0      9
# 974.0      5
# 973.0      4
# 976.0      1
# Name: count, dtype: int64

# %%
df.loc[(df.crm_cd_1.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 200112035 2020-05-21 2020-05-21       525     1   Central          163
# 220805565 2022-02-09 2022-02-09       245     8   West LA          842
# 200116522 2020-08-17 2020-08-17       545     1   Central          176
# 230114706 2023-06-22 2023-06-22      1550     1   Central          155
#
#            part_1_2  crm_cd  \
# dr_no
# 200112035         2     740
# 220805565         2     888
# 200116522         2     745
# 230114706         2     623
#
#                                                  crm_cd_desc  \
# dr_no
# 200112035  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 220805565                                        TRESPASSING
# 200116522           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 230114706                            BATTERY POLICE (SIMPLE)
#
#                        mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 200112035       0329 0910 0447         0      NaN          NaN      801.0
# 220805565                 1501        21        F            H      502.0
# 200116522       0329 2004 1601         0        X            X      203.0
# 230114706  1212 0917 0447 2004         0        M            H      726.0
#
#                                             premis_desc  weapon_used_cd  \
# dr_no
# 200112035                                       MTA BUS           306.0
# 220805565  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 200116522                                OTHER BUSINESS           400.0
# 230114706                               POLICE FACILITY           500.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 200112035                              ROCK/THROWN OBJECT     IC  Invest Cont
# 220805565                                             NaN     IC  Invest Cont
# 200116522  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 230114706                     UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 200112035       NaN     740.0       NaN       NaN
# 220805565       NaN     888.0       NaN       NaN
# 200116522       NaN     745.0       NaN       NaN
# 230114706       NaN     623.0       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 200112035                                       9TH       SPRING  34.0420
# 220805565  11700    WILSHIRE                     BL          NaN  34.0495
# 200116522    800    SANTEE                       ST          NaN  34.0401
# 230114706    200 E  6TH                          ST          NaN  34.0448
#
#                 lon
# dr_no
# 200112035 -118.2555
# 220805565 -118.4609
# 200116522 -118.2533
# 230114706 -118.2474

# %%
df.loc[(df.status.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 241810568 2024-06-08 2024-05-24      1900    18  Southeast         1871
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 241810568         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd premis_desc  weapon_used_cd weapon_desc  \
# dr_no
# 241810568          NaN        NaN         NaN             NaN         NaN
#
#           status status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 241810568    NaN         UNK     510.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 241810568  13500 S  FIGUEROA                     ST          NaN  33.9092
#
#                 lon
# dr_no
# 241810568 -118.2827

# %%
df.loc[(df.crm_cd_1== 510.0)]
# Out:
#            date_rptd   date_occ  time_occ  area   area_name  rpt_dist_no  \
# dr_no
# 240613953 2024-12-13 2024-12-13      1715     6   Hollywood          628
# 240910310 2024-07-13 2024-06-30      1930     9    Van Nuys          919
# 230714913 2023-09-21 2023-09-21      1410     7    Wilshire          701
# 201407940 2020-03-09 2020-01-18      1505    14     Pacific         1488
# 221105406 2022-02-08 2022-02-06       900    11   Northeast         1107
# ...              ...        ...       ...   ...         ...          ...
# 220407988 2022-04-27 2022-04-27       545     4  Hollenbeck          417
# 200517338 2020-12-02 2020-12-02         1     5      Harbor          532
# 200312367 2020-06-06 2020-06-04      1500     3   Southwest          396
# 231412338 2023-06-14 2023-06-12       500    14     Pacific         1444
# 230814035 2023-09-02 2023-09-01      1400     8     West LA          885
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 240613953         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 240910310         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 230714913         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201407940         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 221105406         1     510  VEHICLE - STOLEN     NaN         0      NaN
# ...             ...     ...               ...     ...       ...      ...
# 220407988         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 200517338         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 200312367         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 231412338         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 230814035         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd                   premis_desc  \
# dr_no
# 240613953          NaN      101.0                        STREET
# 240910310          NaN      101.0                        STREET
# 230714913          NaN      101.0                        STREET
# 201407940          NaN      203.0                OTHER BUSINESS
# 221105406          NaN      101.0                        STREET
# ...                ...        ...                           ...
# 220407988          NaN      101.0                        STREET
# 200517338          NaN      123.0  PARKING UNDERGROUND/BUILDING
# 200312367          NaN      101.0                        STREET
# 231412338          NaN      108.0                   PARKING LOT
# 230814035          NaN      101.0                        STREET
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 240613953             NaN         NaN     IC  Invest Cont     510.0       NaN
# 240910310             NaN         NaN     IC  Invest Cont     510.0       NaN
# 230714913             NaN         NaN     IC  Invest Cont     510.0       NaN
# 201407940             NaN         NaN     IC  Invest Cont     510.0       NaN
# 221105406             NaN         NaN     IC  Invest Cont     510.0       NaN
# ...                   ...         ...    ...          ...       ...       ...
# 220407988             NaN         NaN     IC  Invest Cont     510.0       NaN
# 200517338             NaN         NaN     IC  Invest Cont     510.0       NaN
# 200312367             NaN         NaN     IC  Invest Cont     510.0       NaN
# 231412338             NaN         NaN     IC  Invest Cont     510.0       NaN
# 230814035             NaN         NaN     IC  Invest Cont     510.0       NaN
#
#            crm_cd_3  crm_cd_4                                  location  \
# dr_no
# 240613953       NaN       NaN   1900    TAMARIND                     AV
# 240910310       NaN       NaN  13400    VANOWEN                      ST
# 230714913       NaN       NaN   8400    MELROSE                      PL
# 201407940       NaN       NaN   9000    AIRPORT                      BL
# 221105406       NaN       NaN   6000    LA PRADA                     ST
# ...             ...       ...                                       ...
# 220407988       NaN       NaN   4300    MERCURY                      AV
# 200517338       NaN       NaN   1100 N  WILMINGTON                   BL
# 200312367       NaN       NaN   4300 S  HOOVER                       ST
# 231412338       NaN       NaN   4000    LINCOLN                      BL
# 230814035       NaN       NaN  10200    MONTE MAR                    DR
#
#           cross_street      lat       lon
# dr_no
# 240613953          NaN  34.1052 -118.3192
# 240910310          NaN  34.1939 -118.4246
# 230714913          NaN  34.0835 -118.3734
# 201407940          NaN  33.9553 -118.3857
# 221105406          NaN  34.1249 -118.1884
# ...                ...      ...       ...
# 220407988          NaN  34.0856 -118.1941
# 200517338          NaN  33.7843 -118.2746
# 200312367          NaN  34.0073 -118.2894
# 231412338          NaN  33.9905 -118.4478
# 230814035          NaN  34.0415 -118.4084
#
# [57546 rows x 27 columns]

# %% [markdown]
# Observamos lo siguiente sobre las variables categóricas y numéricas:
# - En ambos casos hay variables con muchos nulos pero tiene sentido que sean nulos porque son datos que no era necesario rellenarlos por lo que los imputaremos por 'NULO'
#     - crm_cd_4, crm_cd_3 y crm_cd_2 son los códigos de los crímenes secundarios. Entiendo que no hubo crímenes secundarios
#     - weapon_used_cd y weapon_desc: Habla de las armas usadas. Entiendo que no hubo armas
#     - cross_street: Identifica si el crimen se cometió en un cruce. Entiendo que no fue en un cruce
#     - mocodes: Habla del modus operandi específico del crimen. Entiendo que no encontraron un patrón identificable
#
# - En el caso de vict_descent vamos a completar los nulos según la distribución de los datos que si están identificados y vamos a borrar los 2 registros que hay con '-'
# - En el caso de vict_sex, aparecen registros con ['M', 'F', nan, 'X', 'H', '-']. Vamos a dejar solamente M: Male, F: Female y U: Unknown y borraremos el registro con '-'
# - premis_cd y premis_desc contienen información sobre las instalaciones donde se produjo el crimen (código y descripción). Desconocemos el significado de los códigos, pero observamos que los registros de (df.premis_cd.notna())&(df.premis_desc.isna()) se concentran en unos cuantos códigos y habría que investigarlos con una persona de dentro de la organización para obtener mas información. De momento
#     - premis_cd lo imputaremos por la moda
#     - premis_desc lo imputaremos como 'NULO'
# - En el caso de status, los vamos a borrar porque no hay información en casi ninguna variable y solamente es un caso
# - Por último, crm_cd_1. Este es el código del delito principal que siempre debe ser un código mas bajo (mas bajo = mas grave) que los códigos de crm_cd_1, 2 3 y 4. Así que vamos a ponerles el mismo código por practicar entendiendo que se equivocaron al rellenar el campo y pusieron la información en el crm_cd_2 en vez de el crm_cd_1

# %% [markdown]
# Imputaciones por 'NULO'

# %%
list(df.columns)
# Out:
# ['date_rptd',
#  'date_occ',
#  'time_occ',
#  'area',
#  'area_name',
#  'rpt_dist_no',
#  'part_1_2',
#  'crm_cd',
#  'crm_cd_desc',
#  'mocodes',
#  'vict_age',
#  'vict_sex',
#  'vict_descent',
#  'premis_cd',
#  'premis_desc',
#  'weapon_used_cd',
#  'weapon_desc',
#  'status',
#  'status_desc',
#  'crm_cd_1',
#  'crm_cd_2',
#  'crm_cd_3',
#  'crm_cd_4',
#  'location',
#  'cross_street',
#  'lat',
#  'lon']

# %%
var_imputar_valor = ['crm_cd_2',
                    'crm_cd_3',
                    'crm_cd_4',
                    'weapon_used_cd',
                    'weapon_desc',
                    'cross_street',
                    'premis_desc']
valor = 'NULO'
df[var_imputar_valor] = df[var_imputar_valor].fillna(valor)
df.isna().sum().sort_values(ascending=False)
# Out:
# mocodes           75585
# vict_descent      72115
# vict_sex          72108
# premis_cd             8
# crm_cd_1              4
# status                1
# rpt_dist_no           0
# time_occ              0
# area                  0
# date_occ              0
# date_rptd             0
# vict_age              0
# crm_cd_desc           0
# crm_cd                0
# part_1_2              0
# area_name             0
# premis_desc           0
# weapon_desc           0
# weapon_used_cd        0
# status_desc           0
# crm_cd_2              0
# crm_cd_3              0
# crm_cd_4              0
# location              0
# cross_street          0
# lat                   0
# lon                   0
# dtype: int64

# %% [markdown]
# Imputamos los nulos de 'mocodes' por 9999 para tenerlos identificados pero que sea un valor numérico de 4 dígitos

# %%
var_imputar_numero = ['mocodes']
numero = 9999
df[var_imputar_numero] = df[var_imputar_numero].fillna(numero)
df.isna().sum().sort_values(ascending=False)
# Out:
# vict_descent      72115
# vict_sex          72108
# premis_cd             8
# crm_cd_1              4
# status                1
# rpt_dist_no           0
# area_name             0
# area                  0
# date_rptd             0
# date_occ              0
# time_occ              0
# vict_age              0
# mocodes               0
# crm_cd_desc           0
# crm_cd                0
# part_1_2              0
# premis_desc           0
# weapon_desc           0
# weapon_used_cd        0
# status_desc           0
# crm_cd_2              0
# crm_cd_3              0
# crm_cd_4              0
# location              0
# cross_street          0
# lat                   0
# lon                   0
# dtype: int64

# %% [markdown]
# Borramos el registro de status

# %%
df.loc[(df.status.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 241810568 2024-06-08 2024-05-24      1900    18  Southeast         1871
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 241810568         1     510  VEHICLE - STOLEN    9999         0      NaN
#
#           vict_descent  premis_cd premis_desc weapon_used_cd weapon_desc  \
# dr_no
# 241810568          NaN        NaN        NULO           NULO        NULO
#
#           status status_desc  crm_cd_1 crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 241810568    NaN         UNK     510.0     NULO     NULO     NULO
#
#                                            location cross_street      lat  \
# dr_no
# 241810568  13500 S  FIGUEROA                     ST         NULO  33.9092
#
#                 lon
# dr_no
# 241810568 -118.2827

# %%
df = df.loc[df.status.notna()]
df.isna().sum().sort_values(ascending=False)
# Out:
# vict_descent      72114
# vict_sex          72107
# premis_cd             7
# crm_cd_1              4
# area_name             0
# rpt_dist_no           0
# part_1_2              0
# area                  0
# date_rptd             0
# date_occ              0
# time_occ              0
# vict_age              0
# mocodes               0
# crm_cd_desc           0
# crm_cd                0
# weapon_used_cd        0
# weapon_desc           0
# status                0
# premis_desc           0
# status_desc           0
# crm_cd_2              0
# crm_cd_3              0
# crm_cd_4              0
# location              0
# cross_street          0
# lat                   0
# lon                   0
# dtype: int64

# %% [markdown]
# Borramos los dos registros con '-' e imputamos los registros de vict_descent según la distribución de los datos

# %%
df = df.loc[~(df.vict_descent=='-')]

# %%
# Paso 1: calcular la distribución de frecuencias sin contar los nulos
frequencies = df['vict_descent'].value_counts(normalize=True)

# Paso 2: contar cuántos nulos hay
n_nulos = df['vict_descent'].isna().sum()

# Paso 3: calcular cuántos nulos asignar a cada categoría según la frecuencia
nuevos_valores = (frequencies * n_nulos).round().astype(int)

# Ajustar en caso de que no sumen exactamente la cantidad de nulos (por redondeo)
diferencia = n_nulos - nuevos_valores.sum()
if diferencia != 0:
    # Ordenar por residuo de la multiplicación original para decidir a quién sumar/restar
    residuos = (frequencies * n_nulos) - (frequencies * n_nulos).round()
    ajustes = residuos.abs().sort_values(ascending=False).index[:abs(diferencia)]
    
    for i in range(abs(diferencia)):
        categoria = ajustes[i % len(ajustes)]
        nuevos_valores[categoria] += 1 if diferencia > 0 else -1

# Paso 4: crear una lista con los nuevos valores imputados
imputaciones = []
for categoria, cantidad in nuevos_valores.items():
    imputaciones.extend([categoria] * cantidad)

# Mezclar los valores imputados para que no haya sesgo de orden
np.random.shuffle(imputaciones)

# Paso 5: asignar los valores imputados a las filas con NaN
df.loc[df['vict_descent'].isna(), 'vict_descent'] = imputaciones

df.isna().sum().sort_values(ascending=False)
# Out:
# vict_sex          72107
# premis_cd             7
# crm_cd_1              4
# area                  0
# area_name             0
# rpt_dist_no           0
# part_1_2              0
# crm_cd                0
# date_rptd             0
# date_occ              0
# time_occ              0
# vict_age              0
# mocodes               0
# crm_cd_desc           0
# vict_descent          0
# weapon_used_cd        0
# weapon_desc           0
# status                0
# premis_desc           0
# status_desc           0
# crm_cd_2              0
# crm_cd_3              0
# crm_cd_4              0
# location              0
# cross_street          0
# lat                   0
# lon                   0
# dtype: int64

# %% [markdown]
# Imputamos los valores de crm_cd_1 que son nulos por los de crm_cd_2

# %%
df['crm_cd_1'] = df['crm_cd_1'].fillna(df['crm_cd_2'])
df.isna().sum().sort_values(ascending=False)
# Out:
# vict_sex          72107
# premis_cd             7
# date_rptd             0
# area                  0
# area_name             0
# rpt_dist_no           0
# part_1_2              0
# crm_cd                0
# crm_cd_desc           0
# date_occ              0
# time_occ              0
# vict_age              0
# mocodes               0
# vict_descent          0
# premis_desc           0
# weapon_used_cd        0
# weapon_desc           0
# status                0
# status_desc           0
# crm_cd_1              0
# crm_cd_2              0
# crm_cd_3              0
# crm_cd_4              0
# location              0
# cross_street          0
# lat                   0
# lon                   0
# dtype: int64

# %% [markdown]
# Usaremos el SimpleImputer para aplicar sobre la variable 'vict_sex' que vamos a sustituir los nulos por 'U' y sobre 'premis_cd' imputaremos por la moda

# %%
#['M', 'F', nan, 'X', 'H', '-']

#Cargamos e instanciamos SimpleImputer
from sklearn.impute import SimpleImputer

#Reenplaza todos los 'unknown' de df y los hace NaN de Numpy para que después los identifique bien.
#El valor a reemplazar hay que mirarlo en cada caso
df.vict_sex.replace(['nan'], np.nan, inplace = True)

#Instanciamos el nuevo imputer
#Variables CATEGÓRICAS
nulos_var = SimpleImputer(strategy='constant', fill_value='Unknwon') #Reenplazamos por un valor constante
mode_var = SimpleImputer(strategy='most_frequent') #Reenplazamos por la moda

#Entrenamos el imputer
#Es importante que si hacemos una sola variable la pongamos con doble corchete. Si no, nos dará un error de dimensiones
nulos_var.fit(df[['vict_sex']])
mode_var.fit(df[['premis_cd']])

#Ejecutamos el imputer
df[['vict_sex']] = nulos_var.transform(df[['vict_sex']])
df[['premis_cd']] = mode_var.transform(df[['premis_cd']])
df.isna().sum().sort_values(ascending=False)
# Out:
# date_rptd         0
# date_occ          0
# time_occ          0
# area              0
# area_name         0
# rpt_dist_no       0
# part_1_2          0
# crm_cd            0
# crm_cd_desc       0
# mocodes           0
# vict_age          0
# vict_sex          0
# vict_descent      0
# premis_cd         0
# premis_desc       0
# weapon_used_cd    0
# weapon_desc       0
# status            0
# status_desc       0
# crm_cd_1          0
# crm_cd_2          0
# crm_cd_3          0
# crm_cd_4          0
# location          0
# cross_street      0
# lat               0
# lon               0
# dtype: int64

# %% [markdown]
# Eliminamos el registro de vict_sex = '-'

# %%
df = df.loc[~(df.vict_sex=='-')]

# %% [markdown]
# Estandarización de los valores de vict_sex para que solamente haya 'Male', 'Female' y 'Unknown'

# %%
df.vict_sex.unique()
# Out:
# array(['M', 'F', 'Unknwon', 'X', 'H'], dtype=object)

# %%
df.vict_sex.replace({'M':'Female',
                     'F':'Female',
                     'H':'Male',
                     'X':'Male'}, inplace=True)

# %%
df.vict_sex.unique()
# Out:
# array(['Female', 'Unknwon', 'Male'], dtype=object)

# %% [markdown]
# Localizamos los valores atípicos

# %%
for variable in df:
    print(variable + '\n')
    print(df[variable].value_counts(dropna = False))
    print('\n\n')
# Out:
# date_rptd
#
# date_rptd
# 2022-05-02    469
# 2023-02-02    463
# 2023-02-03    462
# 2023-01-03    448
# 2022-08-01    442
#              ...
# 2025-01-16      1
# 2025-01-31      1
# 2025-02-20      1
# 2025-01-28      1
# 2025-01-08      1
# Name: count, Length: 1874, dtype: int64
#
#
#
# date_occ
#
# date_occ
# 2020-01-01    567
# 2022-12-02    565
# 2022-10-01    556
# 2023-01-01    553
# 2022-06-01    552
#              ...
# 2025-05-29      1
# 2025-01-31      1
# 2025-03-18      1
# 2025-02-18      1
# 2025-03-11      1
# Name: count, Length: 1853, dtype: int64
#
#
#
# time_occ
#
# time_occ
# 1200    17736
# 1800    13375
# 1700    12649
# 2000    12466
# 1900    11459
#         ...
# 741        11
# 2331       11
# 51         10
# 2332       10
# 531         6
# Name: count, Length: 1439, dtype: int64
#
#
#
# area
#
# area
# 1     34474
# 12    30688
# 14    29729
# 3     28688
# 6     26281
# 15    25430
# 20    25029
# 18    24833
# 13    24569
# 7     24134
# 2     23468
# 8     23010
# 11    21469
# 9     21283
# 10    21038
# 17    20720
# 5     20708
# 21    20680
# 19    20105
# 4     18650
# 16    16660
# Name: count, dtype: int64
#
#
#
# area_name
#
# area_name
# Central        34474
# 77th Street    30688
# Pacific        29729
# Southwest      28688
# Hollywood      26281
# N Hollywood    25430
# Olympic        25029
# Southeast      24833
# Newton         24569
# Wilshire       24134
# Rampart        23468
# West LA        23010
# Northeast      21469
# Van Nuys       21283
# West Valley    21038
# Devonshire     20720
# Harbor         20708
# Topanga        20680
# Mission        20105
# Hollenbeck     18650
# Foothill       16660
# Name: count, dtype: int64
#
#
#
# rpt_dist_no
#
# rpt_dist_no
# 162     2717
# 1494    2707
# 645     2595
# 182     2373
# 646     2197
#         ...
# 226        1
# 700        1
# 1013       1
# 1200       1
# 1100       1
# Name: count, Length: 1177, dtype: int64
#
#
#
# part_1_2
#
# part_1_2
# 1    300618
# 2    201028
# Name: count, dtype: int64
#
#
#
# crm_cd
#
# crm_cd
# 510    57548
# 624    37336
# 330    31793
# 354    31423
# 740    30530
#        ...
# 830        2
# 948        2
# 906        2
# 445        2
# 926        1
# Name: count, Length: 139, dtype: int64
#
#
#
# crm_cd_desc
#
# crm_cd_desc
# VEHICLE - STOLEN                                           57548
# BATTERY - SIMPLE ASSAULT                                   37336
# BURGLARY FROM VEHICLE                                      31793
# THEFT OF IDENTITY                                          31423
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    30530
#                                                            ...
# INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)                   2
# BIGAMY                                                         2
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                       2
# DISHONEST EMPLOYEE ATTEMPTED THEFT                             2
# TRAIN WRECKING                                                 1
# Name: count, Length: 139, dtype: int64
#
#
#
# mocodes
#
# mocodes
# 9999                             75584
# 0344                             21211
# 0329                             10761
# 1822 0344                         7099
# 0325                              5129
#                                  ...
# 0913 0561 0602 1701 1202 0416        1
# 1822 0344 1236 2100 0385             1
# 1251 1822 0416                       1
# 2000 1814 0444 2004 1218 0416        1
# 0344 0209 0216 0349 1501             1
# Name: count, Length: 168940, dtype: int64
#
#
#
# vict_age
#
# vict_age
#  0      134073
#  30      11105
#  31      10866
#  35      10844
#  29      10672
#          ...
#  98         30
# -2          13
# -3           4
# -4           2
#  120         1
# Name: count, Length: 104, dtype: int64
#
#
#
# vict_sex
#
# vict_sex
# Female     380854
# Unknwon     72107
# Male        48685
# Name: count, dtype: int64
#
#
#
# vict_descent
#
# vict_descent
# H    172475
# W    117532
# B     79371
# X     62035
# O     45663
# A     12471
# K      3539
# F      2837
# C      2683
# J       920
# V       682
# I       590
# Z       346
# P       189
# U       124
# G        52
# D        51
# L        48
# S        38
# Name: count, dtype: int64
#
#
#
# premis_cd
#
# premis_cd
# 101.0    130411
# 501.0     81876
# 502.0     59556
# 108.0     34192
# 203.0     23761
#           ...
# 976.0         1
# 898.0         1
# 715.0         1
# 878.0         1
# 891.0         1
# Name: count, Length: 312, dtype: int64
#
#
#
# premis_desc
#
# premis_desc
# STREET                                          130404
# SINGLE FAMILY DWELLING                           81876
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     59556
# PARKING LOT                                      34192
# OTHER BUSINESS                                   23761
#                                                  ...
# SEWAGE FACILITY/PIPE                                 1
# MTA - SILVER LINE - PACIFIC COAST HWY                1
# HORSE RACING/SANTA ANITA PARK*                       1
# MTA - ORANGE LINE - PIERCE COLLEGE                   1
# MTA - SILVER LINE - DOWNTOWN STREET STOPS            1
# Name: count, Length: 306, dtype: int64
#
#
#
# weapon_used_cd
#
# weapon_used_cd
# NULO     338604
# 400.0     87206
# 500.0     18037
# 511.0     11889
# 102.0     10042
#           ...
# 300.0         5
# 120.0         1
# 119.0         1
# 124.0         1
# 123.0         1
# Name: count, Length: 79, dtype: int64
#
#
#
# weapon_desc
#
# weapon_desc
# NULO                                              338604
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     87206
# UNKNOWN WEAPON/OTHER WEAPON                        18037
# VERBAL THREAT                                      11889
# HAND GUN                                           10042
#                                                    ...
# BLACKJACK                                              5
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    1
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    1
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       1
# Name: count, Length: 79, dtype: int64
#
#
#
# status
#
# status
# IC    401092
# AO     54659
# AA     43287
# JA      1652
# JO       950
# CC         6
# Name: count, dtype: int64
#
#
#
# status_desc
#
# status_desc
# Invest Cont     401092
# Adult Other      54659
# Adult Arrest     43287
# Juv Arrest        1652
# Juv Other          950
# UNK                  6
# Name: count, dtype: int64
#
#
#
# crm_cd_1
#
# crm_cd_1
# 510.0    57545
# 624.0    37510
# 330.0    31821
# 354.0    31428
# 740.0    30583
#          ...
# 830.0        2
# 948.0        2
# 445.0        2
# 430.0        1
# 926.0        1
# Name: count, Length: 141, dtype: int64
#
#
#
# crm_cd_2
#
# crm_cd_2
# NULO     467308
# 998.0     27423
# 930.0      1929
# 860.0       678
# 946.0       481
#           ...
# 979.0         1
# 954.0         1
# 421.0         1
# 471.0         1
# 931.0         1
# Name: count, Length: 116, dtype: int64
#
#
#
# crm_cd_3
#
# crm_cd_3
# NULO     500499
# 998.0      1017
# 930.0        37
# 946.0        16
# 910.0        11
# 761.0        10
# 740.0         6
# 901.0         5
# 860.0         5
# 999.0         5
# 821.0         4
# 653.0         4
# 956.0         3
# 745.0         3
# 993.0         3
# 820.0         1
# 903.0         1
# 815.0         1
# 813.0         1
# 940.0         1
# 997.0         1
# 626.0         1
# 902.0         1
# 310.0         1
# 763.0         1
# 888.0         1
# 649.0         1
# 900.0         1
# 830.0         1
# 943.0         1
# 753.0         1
# 933.0         1
# 648.0         1
# Name: count, dtype: int64
#
#
#
# crm_cd_4
#
# crm_cd_4
# NULO     501620
# 998.0        22
# 946.0         2
# 930.0         1
# 910.0         1
# Name: count, dtype: int64
#
#
#
# location
#
# location
# 800 N  ALAMEDA                      ST      1249
# 100    THE GROVE                    DR       873
# 10200    SANTA MONICA                 BL     855
# 700 S  FIGUEROA                     ST       854
# 6TH                          ST              800
#                                             ...
# 11100 S  LA CIENEGA                   BL       1
# 11700    CHIVERS                      AV       1
# 12700    JIMENO                       AV       1
# FARNSWORTH                   AV                1
# E  47TH                         PL             1
# Name: count, Length: 56974, dtype: int64
#
#
#
# cross_street
#
# cross_street
# NULO                               425079
# BROADWAY                             1212
# FIGUEROA                     ST      1008
# FIGUEROA                              829
# VERMONT                      AV       808
#                                     ...
# ELM                          ST         1
# STEARNS                      ST         1
# FLEET                                   1
# BROMLEY                                 1
# SPROULE                      AV         1
# Name: count, Length: 7921, dtype: int64
#
#
#
# lat
#
# lat
# 34.1016    2929
# 34.2012    2307
# 34.0980    2147
# 34.1939    1728
# 34.1867    1647
#            ...
# 33.7473       1
# 33.8754       1
# 34.3169       1
# 34.3282       1
# 34.3136       1
# Name: count, Length: 5283, dtype: int64
#
#
#
# lon
#
# lon
# -118.2739    3754
# -118.2827    3234
# -118.2652    2204
# -118.2915    2093
# -118.2871    1919
#              ...
# -118.6578       1
# -118.6043       1
# -118.6433       1
# -118.6562       1
# -118.6606       1
# Name: count, Length: 4913, dtype: int64

# %%
# Función de agrupacion de variables raras
def agrupar_cat_raras(variable, criterio = 0.05):
    #Calcula las frecuencias
    frecuencias = variable.value_counts(normalize=True)
    #Identifica las que están por debajo del criterio
    temp = [cada for cada in frecuencias.loc[frecuencias < criterio].index.values]
    #Las recodifica en 'OTROS'
    temp2 = np.where(variable.isin(temp),'OTROS',variable)
    #Devuelve el resultado
    return(temp2)

# Variables a agrupar
var_imputar_cat_raras = ['weapon_used_cd','premis_cd','premis_desc','weapon_used_cd','weapon_desc','crm_cd_1','crm_cd_2','crm_cd_3','crm_cd_4','cross_street','location']

# Aplicación
for variable in var_imputar_cat_raras:
    df[variable] = agrupar_cat_raras(df[variable],criterio = 0.02)

# %% [markdown]
# Hacemos un describe sobre las variables numéricas a ver que vemos y observamos que, aunque hay varias variabees numéricas, no podríamos hacer ningún estadísticos sobre ellas, exceptopsobre 'vict_age' donde vemos que la media de edad es de 29 años y la mediana está en 22 años pero observamos que el mínimo es -4 y máximo 120 años. Esto lo solucionaremos una media winsorizada (0,100)

# %%
df.select_dtypes(include='number').describe().T
# Out:
#                 count         mean         std       min       25%        50%  \
# time_occ     501646.0  1339.976721  650.104656    1.0000  900.0000  1420.0000
# area         501646.0    10.689534    6.108206    1.0000    5.0000    11.0000
# rpt_dist_no  501646.0  1115.466773  610.994628  101.0000  587.0000  1139.0000
# part_1_2     501646.0     1.400737    0.490048    1.0000    1.0000     1.0000
# crm_cd       501646.0   500.136505  205.083501  110.0000  331.0000   442.0000
# vict_age     501646.0    28.960789   21.999339   -4.0000    0.0000    30.0000
# lat          501646.0    33.999107    1.600585    0.0000   34.0148    34.0589
# lon          501646.0  -118.094173    5.547150 -118.6676 -118.4301  -118.3226
#
#                    75%        max
# time_occ     1900.0000  2359.0000
# area           16.0000    21.0000
# rpt_dist_no  1613.0000  2199.0000
# part_1_2        2.0000     2.0000
# crm_cd        626.0000   956.0000
# vict_age       44.0000   120.0000
# lat            34.1649    34.3343
# lon          -118.2739     0.0000

# %%
df.vict_age.value_counts().sort_index(ascending=True)
# Out:
# vict_age
# -4           2
# -3           4
# -2          13
# -1          49
#  0      134073
#          ...
#  96         52
#  97         34
#  98         30
#  99        179
#  120         1
# Name: count, Length: 104, dtype: int64

# %% [markdown]
# Realizamos una imputacion de los valores de la edad tras realizar una media winsorizada manualmente (0, 100)

# %%
variable = 'vict_age'
df[variable].describe().loc[['min','max']]
# Out:
# min     -4.0
# max    120.0
# Name: vict_age, dtype: float64

# %%
minimo = 0
maximo = 100
df[variable] = df[variable].clip(minimo, maximo)
df[variable].describe()
# Out:
# count    501646.000000
# mean         28.960939
# std          21.998935
# min           0.000000
# 25%           0.000000
# 50%          30.000000
# 75%          44.000000
# max         100.000000
# Name: vict_age, dtype: float64

# %%
num = df.select_dtypes(include='number')
num
# Out:
#            time_occ  area  rpt_dist_no  part_1_2  crm_cd  vict_age      lat  \
# dr_no
# 221317764       320    13         1307         2     626        38  34.0376
# 240613264      1220     6          643         2     354        42  34.1016
# 210117314       600     1          174         1     210        42  34.0437
# 222019602      1800    20         2046         1     330        27  34.0545
# 241306293      1445    13         1313         1     230        31  34.0286
# ...             ...   ...          ...       ...     ...       ...      ...
# 230221477      1530     2          221         1     236        38  34.0770
# 210907524      1216     9          935         1     440        38  34.1847
# 221204790      1715    12         1218         1     210        25  33.9891
# 230817266       745     8          855         2     626        31  34.0543
# 201219561      1200    12         1253         2     745        51  33.9718
#
#                 lon
# dr_no
# 221317764 -118.2423
# 240613264 -118.3489
# 210117314 -118.2518
# 222019602 -118.2941
# 241306293 -118.2545
# ...             ...
# 230221477 -118.2944
# 210907524 -118.4480
# 221204790 -118.2915
# 230817266 -118.4376
# 201219561 -118.3090
#
# [501646 rows x 8 columns]

# %%
cat = df.select_dtypes(exclude='number')
cat
# Out:
#            date_rptd   date_occ    area_name  \
# dr_no
# 221317764 2022-09-16 2022-09-16       Newton
# 240613264 2024-11-12 2024-11-12    Hollywood
# 210117314 2021-09-22 2021-09-22      Central
# 222019602 2022-12-23 2022-12-22      Olympic
# 241306293 2024-02-18 2024-02-18       Newton
# ...              ...        ...          ...
# 230221477 2023-11-24 2023-11-23      Rampart
# 210907524 2021-03-30 2021-03-16     Van Nuys
# 221204790 2022-01-15 2022-01-15  77th Street
# 230817266 2023-11-25 2023-11-25      West LA
# 201219561 2020-08-28 2020-08-28  77th Street
#
#                                               crm_cd_desc  \
# dr_no
# 221317764               INTIMATE PARTNER - SIMPLE ASSAULT
# 240613264                               THEFT OF IDENTITY
# 210117314                                         ROBBERY
# 222019602                           BURGLARY FROM VEHICLE
# 241306293  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# ...                                                   ...
# 230221477           INTIMATE PARTNER - AGGRAVATED ASSAULT
# 210907524              THEFT PLAIN - PETTY ($950 & UNDER)
# 221204790                                         ROBBERY
# 230817266               INTIMATE PARTNER - SIMPLE ASSAULT
# 201219561        VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#                                                      mocodes vict_sex  \
# dr_no
# 221317764                                2000 0400 0916 1813   Female
# 240613264                                          1501 1822   Female
# 210117314                      1414 1420 0334 0411 0344 0913   Female
# 222019602                                0386 0344 1822 0216   Female
# 241306293                                0400 1822 1217 0342   Female
# ...                                                      ...      ...
# 230221477                      2000 0913 1814 0445 0401 0447   Female
# 210907524                                     0394 0344 1822   Female
# 221204790  1822 0302 0371 0906 0432 0345 0337 0316 0344 0216   Female
# 230817266                                               2000   Female
# 201219561                                     0329 0397 1236   Female
#
#           vict_descent premis_cd  \
# dr_no
# 221317764            H     501.0
# 240613264            B     502.0
# 210117314            H     502.0
# 222019602            B     101.0
# 241306293            H     101.0
# ...                ...       ...
# 230221477            H     502.0
# 210907524            H     203.0
# 221204790            H     102.0
# 230817266            W     501.0
# 201219561            O     502.0
#
#                                             premis_desc weapon_used_cd  \
# dr_no
# 221317764                        SINGLE FAMILY DWELLING          400.0
# 240613264  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)           NULO
# 210117314  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)          OTROS
# 222019602                                        STREET           NULO
# 241306293                                        STREET          OTROS
# ...                                                 ...            ...
# 230221477  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)          400.0
# 210907524                                OTHER BUSINESS           NULO
# 221204790                                      SIDEWALK          102.0
# 230817266                        SINGLE FAMILY DWELLING           NULO
# 201219561  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)           NULO
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 221317764  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 240613264                                            NULO     IC  Invest Cont
# 210117314                                           OTROS     IC  Invest Cont
# 222019602                                            NULO     IC  Invest Cont
# 241306293                                           OTROS     IC  Invest Cont
# ...                                                   ...    ...          ...
# 230221477  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO  Adult Other
# 210907524                                            NULO     IC  Invest Cont
# 221204790                                        HAND GUN     IC  Invest Cont
# 230817266                                            NULO     AO  Adult Other
# 201219561                                            NULO     IC  Invest Cont
#
#           crm_cd_1 crm_cd_2 crm_cd_3 crm_cd_4 location cross_street
# dr_no
# 221317764    626.0     NULO     NULO     NULO    OTROS         NULO
# 240613264    354.0     NULO     NULO     NULO    OTROS         NULO
# 210117314    210.0    OTROS     NULO     NULO    OTROS         NULO
# 222019602    330.0     NULO     NULO     NULO    OTROS        OTROS
# 241306293    230.0     NULO     NULO     NULO    OTROS        OTROS
# ...            ...      ...      ...      ...      ...          ...
# 230221477    OTROS     NULO     NULO     NULO    OTROS         NULO
# 210907524    440.0     NULO     NULO     NULO    OTROS         NULO
# 221204790    210.0     NULO     NULO     NULO    OTROS        OTROS
# 230817266    626.0     NULO     NULO     NULO    OTROS         NULO
# 201219561    745.0     NULO     NULO     NULO    OTROS         NULO
#
# [501646 rows x 19 columns]

# %% [markdown]
# Guardado de datasets

# %%
ruta_calidad = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/001_crime_from_2020/001_calidad_de_datos/'

# %%
ruta_trabajo = ruta_calidad + 'trabajo_resultado_calidad.pickle'
ruta_cat = ruta_calidad + 'cat_resultado_calidad.pickle'
ruta_num = ruta_calidad + 'num_resultado_calidad.pickle'

# %% [markdown]
# Guardar los archivos

# %%
df.to_pickle(ruta_trabajo)
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
