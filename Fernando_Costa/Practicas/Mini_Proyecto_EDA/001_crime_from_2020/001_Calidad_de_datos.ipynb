# %% [markdown]
# # Mini_proyecto_EDA
#
# # Ejercicio Práctico: Carga, Exploración, Limpieza y Visualización Básica de un Dataset
#
# ## 1. Objetivo del ejercicio
# El propósito de este ejercicio es aprender a realizar un flujo completo y ordenado de análisis exploratorio inicial (EDA) sobre un dataset real. El objetivo no es realizar análisis estadísticos avanzados, sino dominar las fases fundamentales que permiten comprender y describir datos antes de cualquier modelado.
#
# Al finalizar el ejercicio, el alumno deberá ser capaz de:
#
# ### 1.1 Exploración
# - Identificar la estructura del dataset: dimensiones, columnas, tipos de datos.
# - Evaluar la calidad del dataset respondiendo preguntas como:
#   - ¿Qué tipos de datos tengo? (numéricos, categóricos, fechas, texto libre...)
#       - Tenemos datos int, float y object
#   - ¿Cuál es el dominio del dataset? ¿Conozco el contexto de las variables?
#       - Los datasets proceden de https://archive.ics.uci.edu/ y el significado de las variables está explicado antes de comenzar el análisis
#   - ¿La fuente de datos es fiable y completa?
#   - ¿Los datos están agregados o son individuales (nivel de granularidad)?
#       - Los datos no están agregados
#   - ¿Hay valores perdidos? ¿Cuál es su proporción?
#       - Hay valores nulos
#   - ¿Existen duplicados o registros anómalos?
#       - No
#   - ¿Las variables tienen una distribución razonable? ¿Existen outliers?
#     - Aproximadamente lógica la distribución
#   - ¿Los formatos (fechas, categorías) están normalizados?
#       - No estaban normalizadas pero yo he generado una columna fecha para generar una columna 'datetime
#   - ¿Existen incoherencias entre columnas?
#       - No
#
#       https://catalog.data.gov/dataset/crime-data-from-2020-to-present
#
# ### 1.2 Limpieza
# - Corregir tipos de datos.
# - Gestionar valores nulos de forma justificada.
# - Eliminar o tratar duplicados.
# - Normalizar formatos y categorías.
# - Corregir incoherencias detectadas.
#
# ### 1.3 Visualización básica
# Generar visualizaciones sencillas que ayuden a explicar el dataset, respondiendo a preguntas como:
# - ¿Cómo se distribuye una variable numérica relevante?
# - ¿Cuáles son las categorías más frecuentes?
# - ¿Existen diferencias visuales entre grupos?
# - ¿Cómo varían los valores a lo largo del tiempo (si aplica)?
# - ¿Qué patrones básicos se detectan tras la limpieza?
#
# ### 1.4 Documentación y repositorio
# - Explicar con claridad el trabajo realizado.
# - Organizar un repositorio en GitHub con estructura ordenada.
# - Entregar el enlace a través de **Google Classroom**.
#
# ---
#
# ## 2. Descripción general del ejercicio
# El alumno trabajará con un dataset **elegido libremente** de una fuente fiable (Kaggle, datos públicos, open data, repositorios gubernamentales, etc.).
#
# El trabajo consistirá en cargar los datos, explorarlos, limpiarlos y generar visualizaciones básicas que permitan entender sus características principales.
#
# El foco está en:
# - Calidad del proceso.
# - Claridad del análisis.
# - Documentación.
# - Organización del repositorio.
#
# ---
#
# ## 3. Tareas obligatorias
#
# ### 3.1 Carga del dataset
# - Importar el dataset.
# - Revisar dimensiones y primeras filas.
# - Inspeccionar tipos de datos.
#
# ### 3.2 Exploración del dataset
# - Valores nulos.
# - Duplicados.
# - Rango de las variables.
# - Incoherencias.
# - Distribución inicial de columnas.
#
# ### 3.3 Limpieza y normalización
# - Corrección de tipos.
# - Tratamiento de nulos.
# - Eliminación o tratamiento de duplicados.
# - Normalización de categorías y fechas.
# - Justificación de cada decisión.
#
# ### 3.4 Visualizaciones básicas
# Debe incluir, como mínimo:
# - Un histograma.
# - Una gráfica de barras.
# - Una visualización adicional que aporte información relevante.
#
# ### 3.5 Conclusiones exploratorias
# - Resumen claro de las características del dataset.
# - Principales hallazgos.
# - Cambios aplicados durante la limpieza.
#
# ---
#
# ## 4. Entregables
# La entrega se realizará por **Google Classroom**, incluyendo un enlace a un repositorio público de GitHub.
#
# ### 4.1 Estructura mínima del repositorio
# ```
# ├── data/
# │   └── dataset.csv
# ├── notebooks/
# │   └── eda.ipynb
# ├── README.md
# └── requirements.txt (opcional)
# ```
#
# ### 4.2 Contenido obligatorio
# - Notebook completo con el proceso.
# - Dataset en la carpeta `data/`.
# - README con explicación del análisis.
#
# ### 4.3 Criterios de evaluación
# - Claridad del análisis.
# - Coherencia del proceso de limpieza.
# - Calidad de las visualizaciones.
# - Orden del repositorio.
# - Explicaciones adecuadas.
#
# ---
#
# ## 5. Recomendaciones
# - Comentar el código cuando sea necesario.
# - Mantener el notebook limpio y sin celdas duplicadas.
# - Evitar análisis avanzados no requeridos.
# - Asegurar que las visualizaciones sean legibles y útiles.
# - Hacer commits frecuentes.
#
# ---
#
# ## 6. Entrega
# La entrega se realizará exclusivamente por **Google Classroom**, adjuntando el enlace público al repositorio de GitHub.
#
# **Fin del enunciado del ejercicio**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
# %matplotlib inline
# %config IPCompleter.greedy = True
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Definimos la ruta donde ubicamos los datasets para no tener que estar poniéndola en cada ocasión

# %%
ruta_datasets = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/001_crime_from_2020/datasets/'

# %% [markdown]
# Definimos el dataset que vamos a usar.
#
# A continuación, aplicaremos los cambios de manera individual sobre el df pero, después, generaremos una función que aglutine todos los pasos individuales y la aplicaremos directamente

# %%
dataset_df = 'Crime_Data_from_2020_to_Present.csv'

# %% [markdown]
# Cargamos el dataset df

# %%
ruta_completa = ruta_datasets + dataset_df
df = pd.read_csv(ruta_completa,sep=',')
df
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240
# 3        210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830
# ...            ...                     ...                     ...       ...
# 1004986  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130
# 1004987  250404100  02/18/2025 12:00:00 AM  02/18/2025 12:00:00 AM      1000
# 1004988  251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM      1554
# 1004989  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1600
# 1004990  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235
#
#          AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          15  N Hollywood         1502         2     354
# 1          15  N Hollywood         1521         1     230
# 2           9     Van Nuys          933         2     354
# 3           7     Wilshire          782         1     331
# 4          14      Pacific         1454         1     420
# ...       ...          ...          ...       ...     ...
# 1004986    21      Topanga         2103         2     946
# 1004987     4   Hollenbeck          479         2     237
# 1004988    13       Newton         1372         2     850
# 1004989    17   Devonshire         1774         2     624
# 1004990    19      Mission         1944         2     850
#
#                                                Crm Cd Desc  ... Status  \
# 0                                        THEFT OF IDENTITY  ...     IC
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 2                                        THEFT OF IDENTITY  ...     IC
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC
# ...                                                    ...  ...    ...
# 1004986                          OTHER MISCELLANEOUS CRIME  ...     IC
# 1004987                     CHILD NEGLECT (SEE 300 W.I.C.)  ...     IC
# 1004988                                  INDECENT EXPOSURE  ...     IC
# 1004989                           BATTERY - SIMPLE ASSAULT  ...     IC
# 1004990                                  INDECENT EXPOSURE  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Invest Cont    354.0      NaN       NaN      NaN
# 1        Invest Cont    230.0      NaN       NaN      NaN
# 2        Invest Cont    354.0      NaN       NaN      NaN
# 3        Invest Cont    331.0      NaN       NaN      NaN
# 4        Invest Cont    420.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 1004986  Invest Cont    946.0      NaN       NaN      NaN
# 1004987  Invest Cont    237.0      NaN       NaN      NaN
# 1004988  Invest Cont    850.0      NaN       NaN      NaN
# 1004989  Invest Cont    624.0      NaN       NaN      NaN
# 1004990  Invest Cont    850.0      NaN       NaN      NaN
#
#                                          LOCATION Cross Street      LAT  \
# 0         7800    BEEMAN                       AV          NaN  34.2124
# 1                 ATOLL                        AV     N  GAULT  34.1993
# 2        14600    SYLVAN                       ST          NaN  34.1847
# 3         6000    COMEY                        AV          NaN  34.0339
# 4                         4700    LA VILLA MARINA          NaN  33.9813
# ...                                           ...          ...      ...
# 1004986  22100    ROSCOE                       BL          NaN  34.2259
# 1004987   3500    PERCY                        ST          NaN  34.0277
# 1004988    300 E  53RD                         ST          NaN  33.9942
# 1004989   9600    ZELZAH                       AV          NaN  34.2450
# 1004990  11100    OMELVENY                     AV          NaN  34.2722
#
#               LON
# 0       -118.4092
# 1       -118.4203
# 2       -118.4509
# 3       -118.3747
# 4       -118.4350
# ...           ...
# 1004986 -118.6126
# 1004987 -118.1979
# 1004988 -118.2701
# 1004989 -118.5233
# 1004990 -118.4417
#
# [1004991 rows x 28 columns]

# %% [markdown]
# Comprobamos que el dataset tiene nulos y nos sirve para trabajar

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Crm Cd 4          1004927
# Crm Cd 3          1002677
# Crm Cd 2           935831
# Cross Street       850755
# Weapon Used Cd     677744
# Weapon Desc        677744
# Mocodes            151619
# Vict Descent       144656
# Vict Sex           144644
# Premis Desc           588
# Premis Cd              16
# Crm Cd 1               11
# Status                  1
# Vict Age                0
# Crm Cd                  0
# Crm Cd Desc             0
# AREA NAME               0
# Rpt Dist No             0
# AREA                    0
# TIME OCC                0
# Date Rptd               0
# DATE OCC                0
# DR_NO                   0
# Part 1-2                0
# Status Desc             0
# LOCATION                0
# LAT                     0
# LON                     0
# dtype: int64

# %% [markdown]
# Comprobamos las dimensiones de la tabla y los valores únicos de DR_NO ya que sospecho que debe ser el índice

# %%
dimensiones_df = df.shape
print(f'Dimensiones df: ', dimensiones_df)
# Out:
# Dimensiones df:  (1004991, 28)

# %%
DR_NO = df.DR_NO.nunique()
print(f'Valores únicos de DR_NO: ', DR_NO)
# Out:
# Valores únicos de DR_NO:  1004991

# %% [markdown]
# Aplicaciones:
# - Transformamos a minúsculas los nombres de las columnas
# - Ponemos 'dr_no' como index ya que es el identificador del reporte

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.columns = df.columns.str.replace('-','_')
df = df.set_index('dr_no')
df
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
# ...                           ...                     ...       ...   ...
# 252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130    21
# 250404100  02/18/2025 12:00:00 AM  02/18/2025 12:00:00 AM      1000     4
# 251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM      1554    13
# 251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1600    17
# 251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235    19
#
#              area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 211507896  N Hollywood         1502         2     354
# 201516622  N Hollywood         1521         1     230
# 240913563     Van Nuys          933         2     354
# 210704711     Wilshire          782         1     331
# 201418201      Pacific         1454         1     420
# ...                ...          ...       ...     ...
# 252104112      Topanga         2103         2     946
# 250404100   Hollenbeck          479         2     237
# 251304095       Newton         1372         2     850
# 251704066   Devonshire         1774         2     624
# 251904210      Mission         1944         2     850
#
#                                                  crm_cd_desc  \
# dr_no
# 211507896                                  THEFT OF IDENTITY
# 201516622     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 240913563                                  THEFT OF IDENTITY
# 210704711  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 201418201    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...                                                      ...
# 252104112                          OTHER MISCELLANEOUS CRIME
# 250404100                     CHILD NEGLECT (SEE 300 W.I.C.)
# 251304095                                  INDECENT EXPOSURE
# 251704066                           BATTERY - SIMPLE ASSAULT
# 251904210                                  INDECENT EXPOSURE
#
#                                            mocodes  ...  status  status_desc  \
# dr_no                                               ...
# 211507896                                     0377  ...      IC  Invest Cont
# 201516622  0416 0334 2004 1822 1414 0305 0319 0400  ...      IC  Invest Cont
# 240913563                                     0377  ...      IC  Invest Cont
# 210704711                                     0344  ...      IC  Invest Cont
# 201418201                      1300 0344 1606 2032  ...      IC  Invest Cont
# ...                                            ...  ...     ...          ...
# 252104112                                      NaN  ...      IC  Invest Cont
# 250404100                           1258 0553 0602  ...      IC  Invest Cont
# 251304095                                      NaN  ...      IC  Invest Cont
# 251704066                      0400 1259 1822 0356  ...      IC  Invest Cont
# 251904210                      0529 2024 1815 0913  ...      IC  Invest Cont
#
#           crm_cd_1  crm_cd_2 crm_cd_3  crm_cd_4  \
# dr_no
# 211507896    354.0       NaN      NaN       NaN
# 201516622    230.0       NaN      NaN       NaN
# 240913563    354.0       NaN      NaN       NaN
# 210704711    331.0       NaN      NaN       NaN
# 201418201    420.0       NaN      NaN       NaN
# ...            ...       ...      ...       ...
# 252104112    946.0       NaN      NaN       NaN
# 250404100    237.0       NaN      NaN       NaN
# 251304095    850.0       NaN      NaN       NaN
# 251704066    624.0       NaN      NaN       NaN
# 251904210    850.0       NaN      NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 211507896   7800    BEEMAN                       AV          NaN  34.2124
# 201516622           ATOLL                        AV     N  GAULT  34.1993
# 240913563  14600    SYLVAN                       ST          NaN  34.1847
# 210704711   6000    COMEY                        AV          NaN  34.0339
# 201418201                   4700    LA VILLA MARINA          NaN  33.9813
# ...                                             ...          ...      ...
# 252104112  22100    ROSCOE                       BL          NaN  34.2259
# 250404100   3500    PERCY                        ST          NaN  34.0277
# 251304095    300 E  53RD                         ST          NaN  33.9942
# 251704066   9600    ZELZAH                       AV          NaN  34.2450
# 251904210  11100    OMELVENY                     AV          NaN  34.2722
#
#                 lon
# dr_no
# 211507896 -118.4092
# 201516622 -118.4203
# 240913563 -118.4509
# 210704711 -118.3747
# 201418201 -118.4350
# ...             ...
# 252104112 -118.6126
# 250404100 -118.1979
# 251304095 -118.2701
# 251704066 -118.5233
# 251904210 -118.4417
#
# [1004991 rows x 27 columns]

# %% [markdown]
# Ya sabemos que podemos trabajar con el dataset y lo tenemos cargado con los nombre de las columnas en su formato correto
#
# Significado de las columnas:
# - dr_no: Número de expediente oficial compuesto por un año de 2 dígitos, un ID de área y 5 dígitos.
# - date_rptd: Fecha de Reporte. Indica el día en que el crimen o incidente fue oficialmente reportado (MM/DD/AAAA)
# - date_occ: Fecha de Ocurrencia. Indica el día real en que el crimen tuvo lugar (MM/DD/AAAA)
# - time_occ: En horario militar de 24 horas.
# - area: Áreas Geográficas o Divisiones de Patrulla numeradas secuencialmente del 1 al 21.
# - area_name: Nombre de las áreas Geográficas o Divisiones de Patrulla
# - rpt_dist_no: Número de distrito de la patrulla del oficial que informó el incidente.
# - part_1_2: Indica si el incidente es un crimen de la Parte 1 (crímenes más graves) o de la Parte 2 (crímenes menos graves).
# - crm_cd: Código de delito de 3 dígitos del crimen cometido.
# - crm_cd_desc: Descripción del delito del crimen cometido.
# - mocodes: Modus Operandi o la manera distintiva o característica en que una persona lleva a cabo una actividad criminal.
# - vict_age: Edad de la víctima
# - vict_sex: Sexo de la víctima.
# - vict_descent: Código de descendencia de la víctima
# - premis_cd: El Código de Instalación es un código de 3 dígitos que identifica el tipo de lugar donde ocurrió el incidente
# - premis_desc: Descripción de la Instalación.
# - weapon_used_cd: El Código de Arma es un código de 3 dígitos que identifica el tipo de arma utilizada en el incidente
# - weapon_desc: Descripción del Arma.
# - status: Estado del caso. (IC es el valor predeterminado)
# - status_desc: Define el Código de Estado proporcionado.
# - crm_cd_1: Indica el crimen cometido. El Código de Crimen 1 es el principal y el más grave. Los Códigos de Crimen 2, 3 y 4 son, respectivamente, delitos menos graves. Los números de clase de crimen más bajos son más graves.
# - crm_cd_2: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_3: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_4: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - location: Dirección postal del incidente del crimen redondeada al centenar de la cuadra más cercana para mantener el anonimato.
# - cross_street: El nombre de la calle que se cruza con la calle principal donde ocurrió el incidente.
# - lat: Latitud.
# - lon: Longitud.
#
# Códigos de descendencia:
# - A: Otros Asiáticos
# - B: Afroamericano
# - C: Chino
# - D: Camboyano
# - F: Filipino
# - G: Guamés
# - H: Hispano/Latino/Mexicano
# - I: Indio Americano/Nativo de Alaska
# - J: Japonés
# - K: Coreano
# - L: Laosiano
# - O: Otro
# - P: Isleño del Pacífico
# - S: Samoano
# - U: Hawaiano
# - V: Vietnamita
# - W: Blanco
# - X: Desconocido
# - Z: Hindú Asiático

# %% [markdown]
# Revisamos los tipos de datos de cada variable observando entre el .info() y la viasualización de la propia tabla y no se requieren cambios
#
# También observamos en el count que hay nulos en varias columnas que trataremos posteriormente

# %%
pd.set_option('display.max_columns', None)
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 200708209  04/12/2020 12:00:00 AM  04/10/2020 12:00:00 AM      2210     7
#
#           area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 200708209  Wilshire          715         2     901
#
#                               crm_cd_desc         mocodes  vict_age vict_sex  \
# dr_no
# 200708209  VIOLATION OF RESTRAINING ORDER  1501 1813 2038        35        F
#
#           vict_descent  premis_cd             premis_desc  weapon_used_cd  \
# dr_no
# 200708209            W      501.0  SINGLE FAMILY DWELLING             NaN
#
#           weapon_desc status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  \
# dr_no
# 200708209         NaN     AO  Adult Other     901.0       NaN       NaN
#
#            crm_cd_4                                 location cross_street  \
# dr_no
# 200708209       NaN  7200    ROSEWOOD                     AV          NaN
#
#                lat       lon
# dr_no
# 200708209  34.0803 -118.3474

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1004991 entries, 211507896 to 251904210
# Data columns (total 27 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   date_rptd       1004991 non-null  object
#  1   date_occ        1004991 non-null  object
#  2   time_occ        1004991 non-null  int64
#  3   area            1004991 non-null  int64
#  4   area_name       1004991 non-null  object
#  5   rpt_dist_no     1004991 non-null  int64
#  6   part_1_2        1004991 non-null  int64
#  7   crm_cd          1004991 non-null  int64
#  8   crm_cd_desc     1004991 non-null  object
#  9   mocodes         853372 non-null   object
#  10  vict_age        1004991 non-null  int64
#  11  vict_sex        860347 non-null   object
#  12  vict_descent    860335 non-null   object
#  13  premis_cd       1004975 non-null  float64
#  14  premis_desc     1004403 non-null  object
#  15  weapon_used_cd  327247 non-null   float64
#  16  weapon_desc     327247 non-null   object
#  17  status          1004990 non-null  object
#  18  status_desc     1004991 non-null  object
#  19  crm_cd_1        1004980 non-null  float64
#  20  crm_cd_2        69160 non-null    float64
#  21  crm_cd_3        2314 non-null     float64
#  22  crm_cd_4        64 non-null       float64
#  23  location        1004991 non-null  object
#  24  cross_street    154236 non-null   object
#  25  lat             1004991 non-null  float64
#  26  lon             1004991 non-null  float64
# dtypes: float64(8), int64(6), object(13)
# memory usage: 214.7+ MB

# %% [markdown]
# Las columnas 'date_rptd' y 'date_occ' vamos a eliminar la hora porque en todos los registros nos dicen que ha sido a las '12:00:00 AM'. Esta información es errónea según la columna 'time_occ' y además no nos aporta información como variable porque es una constante en todos los registros

# %%
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 231414910  07/27/2023 12:00:00 AM  07/27/2023 12:00:00 AM      1800    14
#
#           area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 231414910   Pacific         1431         1     341
#
#                                                  crm_cd_desc         mocodes  \
# dr_no
# 231414910  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  0344 0380 1501
#
#            vict_age vict_sex vict_descent  premis_cd    premis_desc  \
# dr_no
# 231414910        29        M            B      116.0  OTHER/OUTSIDE
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 231414910             NaN         NaN     IC  Invest Cont     341.0       NaN
#
#            crm_cd_3  crm_cd_4                                 location  \
# dr_no
# 231414910       NaN       NaN  1800    OCEAN FRONT                  WK
#
#           cross_street      lat       lon
# dr_no
# 231414910          NaN  33.9858 -118.4728

# %% [markdown]
# Eliminamos la parte de la hora

# %%
df['date_rptd'] = df['date_rptd'].str.split(' ').str[0]
df['date_occ'] = df['date_occ'].str.split(' ').str[0]

# %% [markdown]
# Hacemos un datetime de las columnas de fechas

# %%
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 221513593  08/16/2022  08/16/2022       740    15  N Hollywood         1547
#
#            part_1_2  crm_cd                                     crm_cd_desc  \
# dr_no
# 221513593         1     230  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
#
#              mocodes  vict_age vict_sex vict_descent  premis_cd premis_desc  \
# dr_no
# 221513593  1402 2004         0        X            X      101.0      STREET
#
#            weapon_used_cd                  weapon_desc status   status_desc  \
# dr_no
# 221513593           500.0  UNKNOWN WEAPON/OTHER WEAPON     AA  Adult Arrest
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4 location cross_street  \
# dr_no
# 221513593     230.0     998.0       NaN       NaN  TUJUNGA     CHANDLER
#
#                lat      lon
# dr_no
# 221513593  34.1689 -118.379

# %%
df['date_rptd'] = pd.to_datetime(df['date_rptd'], format='%m/%d/%Y')
df['date_occ'] = pd.to_datetime(df['date_occ'], format='%m/%d/%Y')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1004991 entries, 211507896 to 251904210
# Data columns (total 27 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   date_rptd       1004991 non-null  datetime64[ns]
#  1   date_occ        1004991 non-null  datetime64[ns]
#  2   time_occ        1004991 non-null  int64
#  3   area            1004991 non-null  int64
#  4   area_name       1004991 non-null  object
#  5   rpt_dist_no     1004991 non-null  int64
#  6   part_1_2        1004991 non-null  int64
#  7   crm_cd          1004991 non-null  int64
#  8   crm_cd_desc     1004991 non-null  object
#  9   mocodes         853372 non-null   object
#  10  vict_age        1004991 non-null  int64
#  11  vict_sex        860347 non-null   object
#  12  vict_descent    860335 non-null   object
#  13  premis_cd       1004975 non-null  float64
#  14  premis_desc     1004403 non-null  object
#  15  weapon_used_cd  327247 non-null   float64
#  16  weapon_desc     327247 non-null   object
#  17  status          1004990 non-null  object
#  18  status_desc     1004991 non-null  object
#  19  crm_cd_1        1004980 non-null  float64
#  20  crm_cd_2        69160 non-null    float64
#  21  crm_cd_3        2314 non-null     float64
#  22  crm_cd_4        64 non-null       float64
#  23  location        1004991 non-null  object
#  24  cross_street    154236 non-null   object
#  25  lat             1004991 non-null  float64
#  26  lon             1004991 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(6), object(11)
# memory usage: 214.7+ MB

# %%
df.sample()
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 211914983 2021-10-30 2021-10-30        45    19   Mission         1962
#
#            part_1_2  crm_cd    crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 211914983         2     625  OTHER ASSAULT    0447        50        M
#
#           vict_descent  premis_cd premis_desc  weapon_used_cd  \
# dr_no
# 211914983            O      401.0   MINI-MART           302.0
#
#                 weapon_desc status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  \
# dr_no
# 211914983  BLUNT INSTRUMENT     IC  Invest Cont     625.0       NaN       NaN
#
#            crm_cd_4                                 location cross_street  \
# dr_no
# 211914983       NaN  9500 N  SEPULVEDA                    BL          NaN
#
#                lat       lon
# dr_no
# 211914983  34.2428 -118.4674

# %% [markdown]
# Comprobamos los duplicados

# %%
duplicados = df.duplicated().sum()
print(f'Recuento de duplicados en df: ', duplicados)
# Out:
# Recuento de duplicados en df:  2966

# %% [markdown]
# Nos salen 2966 duplicados de las 27 columnas y que solamente es diferente el índice. Hacemos unas visualizaciones para comprobar que son realmente duplicados y vemos que es cierto, por lo que borramos todos los duplicados

# %%
df.loc[df.duplicated()].head()
# Out:
#            date_rptd   date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 201512986 2020-07-23 2020-07-22      2100    15  N Hollywood         1504
# 201916688 2020-11-08 2020-11-08       155    19      Mission         1935
# 201711318 2020-07-20 2020-07-20      1800    17   Devonshire         1764
# 201615215 2020-11-30 2020-11-27      1700    16     Foothill         1675
# 201509694 2020-05-07 2020-05-04      1530    15  N Hollywood         1532
#
#            part_1_2  crm_cd                                      crm_cd_desc  \
# dr_no
# 201512986         1     510                                 VEHICLE - STOLEN
# 201916688         1     310                                         BURGLARY
# 201711318         1     442         SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 201615215         1     420  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 201509694         1     510                                 VEHICLE - STOLEN
#
#                        mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 201512986                  NaN         0      NaN          NaN      101.0
# 201916688  1607 0344 0216 0209         0        M            W      221.0
# 201711318            0325 0378         0        X            X      404.0
# 201615215                  NaN         0      NaN          NaN      101.0
# 201509694                  NaN         0      NaN          NaN      108.0
#
#                 premis_desc  weapon_used_cd weapon_desc status  status_desc  \
# dr_no
# 201512986            STREET             NaN         NaN     IC  Invest Cont
# 201916688    PUBLIC STORAGE             NaN         NaN     IC  Invest Cont
# 201711318  DEPARTMENT STORE             NaN         NaN     IC  Invest Cont
# 201615215            STREET             NaN         NaN     IC  Invest Cont
# 201509694       PARKING LOT             NaN         NaN     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 201512986     510.0       NaN       NaN       NaN
# 201916688     310.0       NaN       NaN       NaN
# 201711318     442.0       NaN       NaN       NaN
# 201615215     420.0       NaN       NaN       NaN
# 201509694     510.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 201512986   7400    LAUREL CANYON                BL          NaN  34.2048
# 201916688  15200    BRAND                        BL          NaN  34.2719
# 201711318   9300    TAMPA                        AV          NaN  34.2440
# 201615215  11000    TUXFORD                      ST          NaN  34.2364
# 201509694   5800    WHITSETT                     AV          NaN  34.1758
#
#                 lon
# dr_no
# 201512986 -118.3965
# 201916688 -118.4592
# 201711318 -118.5583
# 201615215 -118.3687
# 201509694 -118.4052

# %%
df.loc[(df.mocodes == '0400 2004 1822 0356 1212')]
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 242000716 2024-08-27 2024-08-27      1900    20   Olympic         2069
# 242000713 2024-08-27 2024-08-27      1900    20   Olympic         2069
#
#            part_1_2  crm_cd              crm_cd_desc  \
# dr_no
# 242000716         2     623  BATTERY POLICE (SIMPLE)
# 242000713         2     623  BATTERY POLICE (SIMPLE)
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 242000716  0400 2004 1822 0356 1212         0        X            X
# 242000713  0400 2004 1822 0356 1212         0        X            X
#
#            premis_cd      premis_desc  weapon_used_cd  \
# dr_no
# 242000716      726.0  POLICE FACILITY           400.0
# 242000713      726.0  POLICE FACILITY           400.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 242000716  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 242000713  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 242000716     623.0       NaN       NaN       NaN
# 242000713     623.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 242000716  1100 S  VERMONT                      AV          NaN  34.0509
# 242000713  1100 S  VERMONT                      AV          NaN  34.0509
#
#                 lon
# dr_no
# 242000716 -118.2916
# 242000713 -118.2916

# %% [markdown]
# Eliminamos los duplicados

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (1002025, 27)

# %%
# Al cargar el df tenia 1004991 filas
1004991 - 1002025
# Out:
# 2966

# %% [markdown]
# Comprobamos los valores únicos en la tabla para desestimar variables. En este caso, no hay constantes

# %%
df.nunique().sort_values(ascending=True)

# Si hubiera alguna columna que eliminar haríamos df.drop(columns = '...', inplace=True)
# Out:
# part_1_2               2
# vict_sex               5
# status_desc            6
# status                 6
# crm_cd_4               6
# vict_descent          20
# area_name             21
# area                  21
# crm_cd_3              38
# weapon_used_cd        79
# weapon_desc           79
# vict_age             104
# crm_cd_2             126
# crm_cd               140
# crm_cd_desc          140
# crm_cd_1             142
# premis_desc          306
# premis_cd            314
# rpt_dist_no         1210
# time_occ            1439
# date_occ            1879
# date_rptd           1896
# lon                 4982
# lat                 5426
# cross_street       10413
# location           66566
# mocodes           310940
# dtype: int64

# %% [markdown]
# Comprobamos los nulos que existen según el tipo de columna: Categórica y numérica
#
# Primero haremos las comprobaciones, después expondré las conclusiones y a continuación realizaré los cambios

# %%
df.select_dtypes(include='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_4          1001961
# crm_cd_3           999713
# crm_cd_2           932941
# weapon_used_cd     675725
# premis_cd              16
# crm_cd_1               11
# vict_age                0
# crm_cd                  0
# part_1_2                0
# rpt_dist_no             0
# area                    0
# time_occ                0
# lat                     0
# lon                     0
# dtype: int64

# %%
df.select_dtypes(exclude='number').isna().sum().sort_values(ascending=False)
# Out:
# cross_street    848225
# weapon_desc     675725
# mocodes         150369
# vict_descent    143441
# vict_sex        143429
# premis_desc        587
# status               1
# date_occ             0
# date_rptd            0
# crm_cd_desc          0
# area_name            0
# status_desc          0
# location             0
# dtype: int64

# %%
df.vict_descent.unique()
# Out:
# array(['H', 'W', 'A', 'B', nan, 'X', 'O', 'C', 'J', 'V', 'K', 'F', 'I',
#        'Z', 'L', 'G', 'P', 'D', 'U', 'S', '-'], dtype=object)

# %%
df.loc[df.vict_descent=='-']
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 230908075 2023-04-12 2023-03-30      1200     9  Van Nuys          952
# 232012240 2023-06-29 2023-06-29      2115    20   Olympic         2091
#
#            part_1_2  crm_cd  \
# dr_no
# 230908075         2     649
# 232012240         2     740
#
#                                                  crm_cd_desc  \
# dr_no
# 230908075                   DOCUMENT FORGERY / STOLEN FELONY
# 232012240  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 230908075            1822 0924 1501        38        M            -
# 232012240  0329 1822 2002 0601 1309         0        -            -
#
#            premis_cd         premis_desc  weapon_used_cd weapon_desc status  \
# dr_no
# 230908075      203.0      OTHER BUSINESS             NaN         NaN     IC
# 232012240      408.0  AUTO SUPPLY STORE*             NaN         NaN     IC
#
#            status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 230908075  Invest Cont     649.0       NaN       NaN       NaN
# 232012240  Invest Cont     740.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 230908075  15300    MAGNOLIA                     BL          NaN  34.1684
# 232012240   1900 S  WESTERN                      AV          NaN  34.0385
#
#                 lon
# dr_no
# 230908075 -118.4586
# 232012240 -118.3135

# %%
df.vict_sex.unique()
# Out:
# array(['M', 'F', nan, 'X', 'H', '-'], dtype=object)

# %%
df.loc[df.vict_sex=='-']
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 232012240 2023-06-29 2023-06-29      2115    20   Olympic         2091
#
#            part_1_2  crm_cd  \
# dr_no
# 232012240         2     740
#
#                                                  crm_cd_desc  \
# dr_no
# 232012240  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 232012240  0329 1822 2002 0601 1309         0        -            -
#
#            premis_cd         premis_desc  weapon_used_cd weapon_desc status  \
# dr_no
# 232012240      408.0  AUTO SUPPLY STORE*             NaN         NaN     IC
#
#            status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 232012240  Invest Cont     740.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 232012240  1900 S  WESTERN                      AV          NaN  34.0385
#
#                 lon
# dr_no
# 232012240 -118.3135

# %%
df.loc[(df.premis_cd.notna())&(df.premis_desc.isna())].premis_cd.value_counts()
# Out:
# premis_cd
# 418.0    371
# 256.0    164
# 972.0     15
# 974.0     11
# 973.0      7
# 976.0      2
# 975.0      1
# Name: count, dtype: int64

# %%
df.loc[(df.crm_cd_1.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 200112035 2020-05-21 2020-05-21       525     1      Central          163
# 200116522 2020-08-17 2020-08-17       545     1      Central          176
# 211016055 2021-12-26 2021-12-25      2000    10  West Valley         1023
# 210118616 2021-10-13 2021-10-13      1840     1      Central          162
# 221701255 2022-12-08 2022-12-08      2138    17   Devonshire         1799
# 220509912 2022-06-06 2022-06-06      2000     5       Harbor          526
# 220805565 2022-02-09 2022-02-09       245     8      West LA          842
# 230114704 2023-06-22 2023-06-22      1801     1      Central          162
# 230123939 2023-11-13 2023-11-12      2300     1      Central          162
# 230106125 2023-02-01 2023-02-01      1855     1      Central          129
# 230114706 2023-06-22 2023-06-22      1550     1      Central          155
#
#            part_1_2  crm_cd  \
# dr_no
# 200112035         2     740
# 200116522         2     745
# 211016055         1     520
# 210118616         1     442
# 221701255         2     890
# 220509912         2     888
# 220805565         2     888
# 230114704         1     442
# 230123939         1     330
# 230106125         1     330
# 230114706         2     623
#
#                                                  crm_cd_desc  \
# dr_no
# 200112035  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 200116522           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 211016055                           VEHICLE - ATTEMPT STOLEN
# 210118616           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 221701255                                   FAILURE TO YIELD
# 220509912                                        TRESPASSING
# 220805565                                        TRESPASSING
# 230114704           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 230123939                              BURGLARY FROM VEHICLE
# 230106125                              BURGLARY FROM VEHICLE
# 230114706                            BATTERY POLICE (SIMPLE)
#
#                        mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 200112035       0329 0910 0447         0      NaN          NaN      801.0
# 200116522       0329 2004 1601         0        X            X      203.0
# 211016055            1822 1300        59        M            O      101.0
# 210118616            2004 0325         0        X            X      404.0
# 221701255            1300 1501         0        X            X      101.0
# 220509912            2004 0561        42        F            H      502.0
# 220805565                 1501        21        F            H      502.0
# 230114704                 0325        25        M            H      404.0
# 230123939            0344 1307        47        M            B      108.0
# 230106125            0344 1609        32        M            B      101.0
# 230114706  1212 0917 0447 2004         0        M            H      726.0
#
#                                             premis_desc  weapon_used_cd  \
# dr_no
# 200112035                                       MTA BUS           306.0
# 200116522                                OTHER BUSINESS           400.0
# 211016055                                        STREET             NaN
# 210118616                              DEPARTMENT STORE             NaN
# 221701255                                        STREET             NaN
# 220509912  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 220805565  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 230114704                              DEPARTMENT STORE             NaN
# 230123939                                   PARKING LOT             NaN
# 230106125                                        STREET             NaN
# 230114706                               POLICE FACILITY           500.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 200112035                              ROCK/THROWN OBJECT     IC  Invest Cont
# 200116522  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 211016055                                             NaN     IC  Invest Cont
# 210118616                                             NaN     IC  Invest Cont
# 221701255                                             NaN     IC  Invest Cont
# 220509912                                             NaN     IC  Invest Cont
# 220805565                                             NaN     IC  Invest Cont
# 230114704                                             NaN     IC  Invest Cont
# 230123939                                             NaN     IC  Invest Cont
# 230106125                                             NaN     IC  Invest Cont
# 230114706                     UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 200112035       NaN     740.0       NaN       NaN
# 200116522       NaN     745.0       NaN       NaN
# 211016055       NaN     520.0       NaN       NaN
# 210118616       NaN     442.0       NaN       NaN
# 221701255       NaN     890.0       NaN       NaN
# 220509912       NaN     888.0       NaN       NaN
# 220805565       NaN     888.0       NaN       NaN
# 230114704       NaN     442.0       NaN       NaN
# 230123939       NaN     330.0       NaN       NaN
# 230106125       NaN     330.0       NaN       NaN
# 230114706       NaN     623.0       NaN       NaN
#
#                                            location  \
# dr_no
# 200112035                                       9TH
# 200116522    800    SANTEE                       ST
# 211016055           ARCHWOOD                     ST
# 210118616    700 W  7TH                          ST
# 221701255           AQUEDUCT                     AV
# 220509912    900 N  FRIES                        AV
# 220805565  11700    WILSHIRE                     BL
# 230114704    700 S  FLOWER                       ST
# 230123939    800 S  HILL                         ST
# 230106125                                     GAREY
# 230114706    200 E  6TH                          ST
#
#                               cross_street      lat       lon
# dr_no
# 200112035                           SPRING  34.0420 -118.2555
# 200116522                              NaN  34.0401 -118.2533
# 211016055  WILBUR                       AV  34.1921 -118.5447
# 210118616                              NaN  34.0480 -118.2577
# 221701255  NORDHOFF                     ST  34.2249 -118.4792
# 220509912                              NaN  33.7815 -118.2650
# 220805565                              NaN  34.0495 -118.4609
# 230114704                              NaN  34.0487 -118.2588
# 230123939                              NaN  34.0462 -118.2585
# 230106125                          JACKSON  34.0513 -118.2344
# 230114706                              NaN  34.0448 -118.2474

# %%
df.loc[(df.status.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 241810568 2024-06-08 2024-05-24      1900    18  Southeast         1871
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 241810568         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd premis_desc  weapon_used_cd weapon_desc  \
# dr_no
# 241810568          NaN        NaN         NaN             NaN         NaN
#
#           status status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 241810568    NaN         UNK     510.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 241810568  13500 S  FIGUEROA                     ST          NaN  33.9092
#
#                 lon
# dr_no
# 241810568 -118.2827

# %%
df.loc[(df.crm_cd_1== 510.0)]
# Out:
#            date_rptd   date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 202113531 2020-09-06 2020-09-05      1500    21      Topanga         2149
# 201811813 2020-05-28 2020-05-25       200    18    Southeast         1851
# 201416348 2020-08-30 2020-08-28      1200    14      Pacific         1453
# 201904694 2020-01-16 2020-01-15      2130    19      Mission         1901
# 201513536 2020-08-05 2020-08-04       730    15  N Hollywood         1557
# ...              ...        ...       ...   ...          ...          ...
# 250400004 2025-02-26 2025-02-26       915     4   Hollenbeck          477
# 251204103 2025-01-22 2025-01-21       500    12  77th Street         1259
# 250300002 2025-02-26 2025-02-25      2315     3    Southwest          358
# 2503      2025-03-10 2025-03-06      1700     3    Southwest          358
# 250304291 2025-04-29 2025-04-29       425     3    Southwest          325
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 202113531         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201811813         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201416348         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201904694         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201513536         1     510  VEHICLE - STOLEN     NaN         0      NaN
# ...             ...     ...               ...     ...       ...      ...
# 250400004         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 251204103         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 250300002         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 2503              1     510  VEHICLE - STOLEN     NaN         0      NaN
# 250304291         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd                  premis_desc  \
# dr_no
# 202113531          NaN      108.0                  PARKING LOT
# 201811813          NaN      101.0                       STREET
# 201416348          NaN      108.0                  PARKING LOT
# 201904694          NaN      101.0                       STREET
# 201513536          NaN      101.0                       STREET
# ...                ...        ...                          ...
# 250400004          NaN      101.0                       STREET
# 251204103          NaN      101.0                       STREET
# 250300002          NaN      101.0                       STREET
# 2503               NaN      101.0                       STREET
# 250304291          NaN      121.0  YARD (RESIDENTIAL/BUSINESS)
#
#            weapon_used_cd weapon_desc status   status_desc  crm_cd_1  \
# dr_no
# 202113531             NaN         NaN     AA  Adult Arrest     510.0
# 201811813             NaN         NaN     IC   Invest Cont     510.0
# 201416348             NaN         NaN     IC   Invest Cont     510.0
# 201904694             NaN         NaN     IC   Invest Cont     510.0
# 201513536             NaN         NaN     IC   Invest Cont     510.0
# ...                   ...         ...    ...           ...       ...
# 250400004             NaN         NaN     IC   Invest Cont     510.0
# 251204103             NaN         NaN     IC   Invest Cont     510.0
# 250300002             NaN         NaN     IC   Invest Cont     510.0
# 2503                  NaN         NaN     IC   Invest Cont     510.0
# 250304291             NaN         NaN     IC   Invest Cont     510.0
#
#            crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 202113531       NaN       NaN       NaN
# 201811813       NaN       NaN       NaN
# 201416348       NaN       NaN       NaN
# 201904694       NaN       NaN       NaN
# 201513536       NaN       NaN       NaN
# ...             ...       ...       ...
# 250400004       NaN       NaN       NaN
# 251204103       NaN       NaN       NaN
# 250300002       NaN       NaN       NaN
# 2503            NaN       NaN       NaN
# 250304291       NaN       NaN       NaN
#
#                                            location  \
# dr_no
# 202113531  19700    VANOWEN                      ST
# 201811813           MENLO                        AV
# 201416348   4000    GLENCOE                      AV
# 201904694                                  FOOTHILL
# 201513536   4900    CARTWRIGHT                   AV
# ...                                             ...
# 250400004    800    EUCLID                       AV
# 251204103   7800    MCKINLEY                     AV
# 250300002   1000 W  34TH                         ST
# 2503         600    CHILDS                       WY
# 250304291   2700    ELLENDALE                    PL
#
#                               cross_street      lat       lon
# dr_no
# 202113531                              NaN  34.1938 -118.5631
# 201811813  130TH                        ST  33.9144 -118.2894
# 201416348                              NaN  33.9918 -118.4446
# 201904694                           BALBOA  34.3193 -118.4871
# 201513536                              NaN  34.1595 -118.3637
# ...                                    ...      ...       ...
# 250400004                              NaN  34.0322 -118.2117
# 251204103                              NaN  33.9685 -118.2608
# 250300002                              NaN  34.0243 -118.2876
# 2503                                   NaN  34.0189 -118.2819
# 250304291                              NaN  34.0307 -118.2923
#
# [114256 rows x 27 columns]

# %% [markdown]
# Observamos lo siguiente sobre las variables categóricas y numéricas:
# - En ambos casos hay variables con muchos nulos pero tiene sentido que sean nulos porque son datos que no era necesario rellenarlos por lo que los imputaremos por 'NULO'
#     - crm_cd_4, crm_cd_3 y crm_cd_2 son los códigos de los crímenes secundarios. Entiendo que no hubo crímenes secundarios
#     - weapon_used_cd y weapon_desc: Habla de las armas usadas. Entiendo que no hubo armas
#     - cross_street: Identifica si el crimen se cometió en un cruce. Entiendo que no fue en un cruce
#     - mocodes: Habla del modus operandi específico del crimen. Entiendo que no encontraron un patrón identificable
#
# - En el caso de vict_descent vamos a completar los nulos según la distribución de los datos que si están identificados y vamos a borrar los 2 registros que hay con '-'
# - En el caso de vict_sex, aparecen registros con ['M', 'F', nan, 'X', 'H', '-']. Vamos a dejar solamente M: Male, F: Female y U: Unknown y borraremos el registro con '-'
# - premis_cd y premis_desc contienen información sobre las instalaciones donde se produjo el crimen (código y descripción). Desconocemos el significado de los códigos, pero observamos que los registros de (df.premis_cd.notna())&(df.premis_desc.isna()) se concentran en unos cuantos códigos y habría que investigarlos con una persona de dentro de la organización para obtener mas información. De momento
#     - premis_cd lo imputaremos por la moda
#     - premis_desc lo imputaremos como 'NULO'
# - En el caso de status, los vamos a borrar porque no hay información en casi ninguna variable y solamente es un caso
# - Por último, crm_cd_1. Este es el código del delito principal que siempre debe ser un código mas bajo (mas bajo = mas grave) que los códigos de crm_cd_1, 2 3 y 4. Así que vamos a ponerles el mismo código por practicar entendiendo que se equivocaron al rellenar el campo y pusieron la información en el crm_cd_2 en vez de el crm_cd_1

# %% [markdown]
# Imputaciones por 'NULO'

# %%
list(df.columns)
# Out:
# ['date_rptd',
#  'date_occ',
#  'time_occ',
#  'area',
#  'area_name',
#  'rpt_dist_no',
#  'part_1_2',
#  'crm_cd',
#  'crm_cd_desc',
#  'mocodes',
#  'vict_age',
#  'vict_sex',
#  'vict_descent',
#  'premis_cd',
#  'premis_desc',
#  'weapon_used_cd',
#  'weapon_desc',
#  'status',
#  'status_desc',
#  'crm_cd_1',
#  'crm_cd_2',
#  'crm_cd_3',
#  'crm_cd_4',
#  'location',
#  'cross_street',
#  'lat',
#  'lon']

# %%
var_imputar_valor = ['crm_cd_2',
                    'crm_cd_3',
                    'crm_cd_4',
                    'weapon_used_cd',
                    'weapon_desc',
                    'cross_street',
                    'premis_desc']
valor = 'NULO'
df[var_imputar_valor] = df[var_imputar_valor].fillna(valor)
df.isna().sum().sort_values(ascending=False)
# Out:
# mocodes           150369
# vict_descent      143441
# vict_sex          143429
# premis_cd             16
# crm_cd_1              11
# status                 1
# rpt_dist_no            0
# time_occ               0
# area                   0
# date_occ               0
# date_rptd              0
# vict_age               0
# crm_cd_desc            0
# crm_cd                 0
# part_1_2               0
# area_name              0
# premis_desc            0
# weapon_desc            0
# weapon_used_cd         0
# status_desc            0
# crm_cd_2               0
# crm_cd_3               0
# crm_cd_4               0
# location               0
# cross_street           0
# lat                    0
# lon                    0
# dtype: int64

# %% [markdown]
# Imputamos los nulos de 'mocodes' por 9999 para tenerlos identificados pero que sea un valor numérico de 4 dígitos

# %%
var_imputar_numero = ['mocodes']
numero = 9999
df[var_imputar_numero] = df[var_imputar_numero].fillna(numero)
df.isna().sum().sort_values(ascending=False)
# Out:
# vict_descent      143441
# vict_sex          143429
# premis_cd             16
# crm_cd_1              11
# status                 1
# rpt_dist_no            0
# area_name              0
# area                   0
# date_rptd              0
# date_occ               0
# time_occ               0
# vict_age               0
# mocodes                0
# crm_cd_desc            0
# crm_cd                 0
# part_1_2               0
# premis_desc            0
# weapon_desc            0
# weapon_used_cd         0
# status_desc            0
# crm_cd_2               0
# crm_cd_3               0
# crm_cd_4               0
# location               0
# cross_street           0
# lat                    0
# lon                    0
# dtype: int64

# %% [markdown]
# Borramos el registro de status

# %%
df.loc[(df.status.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 241810568 2024-06-08 2024-05-24      1900    18  Southeast         1871
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 241810568         1     510  VEHICLE - STOLEN    9999         0      NaN
#
#           vict_descent  premis_cd premis_desc weapon_used_cd weapon_desc  \
# dr_no
# 241810568          NaN        NaN        NULO           NULO        NULO
#
#           status status_desc  crm_cd_1 crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 241810568    NaN         UNK     510.0     NULO     NULO     NULO
#
#                                            location cross_street      lat  \
# dr_no
# 241810568  13500 S  FIGUEROA                     ST         NULO  33.9092
#
#                 lon
# dr_no
# 241810568 -118.2827

# %%
df = df.loc[df.status.notna()]
df.isna().sum().sort_values(ascending=False)
# Out:
# vict_descent      143440
# vict_sex          143428
# premis_cd             15
# crm_cd_1              11
# area_name              0
# rpt_dist_no            0
# part_1_2               0
# area                   0
# date_rptd              0
# date_occ               0
# time_occ               0
# vict_age               0
# mocodes                0
# crm_cd_desc            0
# crm_cd                 0
# weapon_used_cd         0
# weapon_desc            0
# status                 0
# premis_desc            0
# status_desc            0
# crm_cd_2               0
# crm_cd_3               0
# crm_cd_4               0
# location               0
# cross_street           0
# lat                    0
# lon                    0
# dtype: int64

# %% [markdown]
# Borramos los dos registros con '-' e imputamos los registros de vict_descent según la distribución de los datos

# %%
df = df.loc[~(df.vict_descent=='-')]

# %%
# Paso 1: calcular la distribución de frecuencias sin contar los nulos
frequencies = df['vict_descent'].value_counts(normalize=True)

# Paso 2: contar cuántos nulos hay
n_nulos = df['vict_descent'].isna().sum()

# Paso 3: calcular cuántos nulos asignar a cada categoría según la frecuencia
nuevos_valores = (frequencies * n_nulos).round().astype(int)

# Ajustar en caso de que no sumen exactamente la cantidad de nulos (por redondeo)
diferencia = n_nulos - nuevos_valores.sum()
if diferencia != 0:
    # Ordenar por residuo de la multiplicación original para decidir a quién sumar/restar
    residuos = (frequencies * n_nulos) - (frequencies * n_nulos).round()
    ajustes = residuos.abs().sort_values(ascending=False).index[:abs(diferencia)]
    
    for i in range(abs(diferencia)):
        categoria = ajustes[i % len(ajustes)]
        nuevos_valores[categoria] += 1 if diferencia > 0 else -1

# Paso 4: crear una lista con los nuevos valores imputados
imputaciones = []
for categoria, cantidad in nuevos_valores.items():
    imputaciones.extend([categoria] * cantidad)

# Mezclar los valores imputados para que no haya sesgo de orden
np.random.shuffle(imputaciones)

# Paso 5: asignar los valores imputados a las filas con NaN
df.loc[df['vict_descent'].isna(), 'vict_descent'] = imputaciones

df.isna().sum().sort_values(ascending=False)
# Out:
# vict_sex          143428
# premis_cd             15
# crm_cd_1              11
# area                   0
# area_name              0
# rpt_dist_no            0
# part_1_2               0
# crm_cd                 0
# date_rptd              0
# date_occ               0
# time_occ               0
# vict_age               0
# mocodes                0
# crm_cd_desc            0
# vict_descent           0
# weapon_used_cd         0
# weapon_desc            0
# status                 0
# premis_desc            0
# status_desc            0
# crm_cd_2               0
# crm_cd_3               0
# crm_cd_4               0
# location               0
# cross_street           0
# lat                    0
# lon                    0
# dtype: int64

# %% [markdown]
# Imputamos los valores de crm_cd_1 que son nulos por los de crm_cd_2

# %%
df['crm_cd_1'] = df['crm_cd_1'].fillna(df['crm_cd_2'])
df.isna().sum().sort_values(ascending=False)
# Out:
# vict_sex          143428
# premis_cd             15
# date_rptd              0
# area                   0
# area_name              0
# rpt_dist_no            0
# part_1_2               0
# crm_cd                 0
# crm_cd_desc            0
# date_occ               0
# time_occ               0
# vict_age               0
# mocodes                0
# vict_descent           0
# premis_desc            0
# weapon_used_cd         0
# weapon_desc            0
# status                 0
# status_desc            0
# crm_cd_1               0
# crm_cd_2               0
# crm_cd_3               0
# crm_cd_4               0
# location               0
# cross_street           0
# lat                    0
# lon                    0
# dtype: int64

# %% [markdown]
# Usaremos el SimpleImputer para aplicar sobre la variable 'vict_sex' que vamos a sustituir los nulos por 'U' y sobre 'premis_cd' imputaremos por la moda

# %%
#['M', 'F', nan, 'X', 'H', '-']

#Cargamos e instanciamos SimpleImputer
from sklearn.impute import SimpleImputer

#Reenplaza todos los 'unknown' de df y los hace NaN de Numpy para que después los identifique bien.
#El valor a reemplazar hay que mirarlo en cada caso
df.vict_sex.replace(['nan'], np.nan, inplace = True)

#Instanciamos el nuevo imputer
#Variables CATEGÓRICAS
nulos_var = SimpleImputer(strategy='constant', fill_value='Unknwon') #Reenplazamos por un valor constante
mode_var = SimpleImputer(strategy='most_frequent') #Reenplazamos por la moda

#Entrenamos el imputer
#Es importante que si hacemos una sola variable la pongamos con doble corchete. Si no, nos dará un error de dimensiones
nulos_var.fit(df[['vict_sex']])
mode_var.fit(df[['premis_cd']])

#Ejecutamos el imputer
df[['vict_sex']] = nulos_var.transform(df[['vict_sex']])
df[['premis_cd']] = mode_var.transform(df[['premis_cd']])
df.isna().sum().sort_values(ascending=False)
# Out:
# date_rptd         0
# date_occ          0
# time_occ          0
# area              0
# area_name         0
# rpt_dist_no       0
# part_1_2          0
# crm_cd            0
# crm_cd_desc       0
# mocodes           0
# vict_age          0
# vict_sex          0
# vict_descent      0
# premis_cd         0
# premis_desc       0
# weapon_used_cd    0
# weapon_desc       0
# status            0
# status_desc       0
# crm_cd_1          0
# crm_cd_2          0
# crm_cd_3          0
# crm_cd_4          0
# location          0
# cross_street      0
# lat               0
# lon               0
# dtype: int64

# %% [markdown]
# Eliminamos el registro de vict_sex = '-'

# %%
df = df.loc[~(df.vict_sex=='-')]

# %% [markdown]
# Estandarización de los valores de vict_sex para que solamente haya 'Male', 'Female' y 'Unknown'

# %%
df.vict_sex.unique()
# Out:
# array(['M', 'F', 'Unknwon', 'X', 'H'], dtype=object)

# %%
df.vict_sex.replace({'M':'Female',
                     'F':'Female',
                     'H':'Male',
                     'X':'Male'}, inplace=True)

# %%
df.vict_sex.unique()
# Out:
# array(['Female', 'Unknwon', 'Male'], dtype=object)

# %% [markdown]
# Localizamos los valores atípicos

# %%
for variable in df:
    print(variable + '\n')
    print(df[variable].value_counts(dropna = False))
    print('\n\n')
# Out:
# date_rptd
#
# date_rptd
# 2023-02-02    927
# 2023-02-03    923
# 2023-01-03    911
# 2022-05-02    908
# 2022-04-04    882
#              ...
# 2025-03-10      1
# 2025-02-22      1
# 2025-02-07      1
# 2025-04-29      1
# 2025-03-25      1
# Name: count, Length: 1896, dtype: int64
#
#
#
# date_occ
#
# date_occ
# 2020-01-01    1159
# 2023-01-01    1158
# 2022-12-02    1131
# 2023-02-01    1091
# 2022-10-01    1078
#               ...
# 2025-05-29       1
# 2025-02-27       1
# 2025-04-29       1
# 2025-02-18       1
# 2025-01-17       1
# Name: count, Length: 1879, dtype: int64
#
#
#
# time_occ
#
# time_occ
# 1200    35092
# 1800    26500
# 1700    25107
# 2000    24685
# 1900    22990
#         ...
# 741        29
# 534        26
# 2332       26
# 559        23
# 531        19
# Name: count, Length: 1439, dtype: int64
#
#
#
# area
#
# area
# 1     69372
# 12    61584
# 14    59261
# 3     57292
# 6     52311
# 15    50999
# 20    49977
# 18    49779
# 13    49014
# 7     48091
# 2     46690
# 8     45635
# 11    42855
# 9     42787
# 10    42072
# 17    41618
# 21    41292
# 5     41208
# 19    40202
# 4     36969
# 16    33014
# Name: count, dtype: int64
#
#
#
# area_name
#
# area_name
# Central        69372
# 77th Street    61584
# Pacific        59261
# Southwest      57292
# Hollywood      52311
# N Hollywood    50999
# Olympic        49977
# Southeast      49779
# Newton         49014
# Wilshire       48091
# Rampart        46690
# West LA        45635
# Northeast      42855
# Van Nuys       42787
# West Valley    42072
# Devonshire     41618
# Topanga        41292
# Harbor         41208
# Mission        40202
# Hollenbeck     36969
# Foothill       33014
# Name: count, dtype: int64
#
#
#
# rpt_dist_no
#
# rpt_dist_no
# 162     5395
# 1494    5327
# 645     5015
# 182     4877
# 646     4409
#         ...
# 995        1
# 1100       1
# 672        1
# 709        1
# 902        1
# Name: count, Length: 1210, dtype: int64
#
#
#
# part_1_2
#
# part_1_2
# 1    600659
# 2    401363
# Name: count, dtype: int64
#
#
#
# crm_cd
#
# crm_cd
# 510    114271
# 624     74738
# 330     63506
# 354     62514
# 740     61046
#         ...
# 906         4
# 884         4
# 445         4
# 926         1
# 453         1
# Name: count, Length: 140, dtype: int64
#
#
#
# crm_cd_desc
#
# crm_cd_desc
# VEHICLE - STOLEN                                           114271
# BATTERY - SIMPLE ASSAULT                                    74738
# BURGLARY FROM VEHICLE                                       63506
# THEFT OF IDENTITY                                           62514
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     61046
#                                                             ...
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# FAILURE TO DISPERSE                                             4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# DRUNK ROLL - ATTEMPT                                            1
# Name: count, Length: 140, dtype: int64
#
#
#
# mocodes
#
# mocodes
# 9999                        150368
# 0344                         42132
# 0329                         21602
# 1822 0344                    14231
# 0325                         10235
#                              ...
# 1822 0311 0329 0327 1300         1
# 1601 0448 1402                   1
# 1258 0553 0602                   1
# 0400 1259 1822 0356              1
# 0377 1822 1202 0929 0930         1
# Name: count, Length: 310940, dtype: int64
#
#
#
# vict_age
#
# vict_age
#  0      266855
#  30      22269
#  35      21794
#  31      21408
#  29      21334
#          ...
#  98         71
# -2          28
# -3           6
# -4           3
#  120         1
# Name: count, Length: 104, dtype: int64
#
#
#
# vict_sex
#
# vict_sex
# Female     761487
# Unknwon    143428
# Male        97107
# Name: count, dtype: int64
#
#
#
# vict_descent
#
# vict_descent
# H    345561
# W    234850
# B    158351
# X    123480
# O     90801
# A     24895
# K      6991
# F      5645
# C      5403
# J      1849
# V      1395
# I      1185
# Z       673
# P       336
# U       257
# D       106
# L        90
# G        86
# S        68
# Name: count, dtype: int64
#
#
#
# premis_cd
#
# premis_cd
# 101.0    260224
# 501.0    163526
# 502.0    118913
# 108.0     68763
# 203.0     47506
#           ...
# 889.0         2
# 976.0         2
# 240.0         2
# 137.0         1
# 975.0         1
# Name: count, Length: 314, dtype: int64
#
#
#
# premis_desc
#
# premis_desc
# STREET                                          260209
# SINGLE FAMILY DWELLING                          163526
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)    118913
# PARKING LOT                                      68763
# OTHER BUSINESS                                   47506
#                                                  ...
# HORSE RACING/SANTA ANITA PARK*                       2
# MTA - SILVER LINE - DOWNTOWN STREET STOPS            2
# DEPT OF DEFENSE FACILITY                             2
# MTA - SILVER LINE - LAC/USC MEDICAL CENTER           2
# TRAM/STREETCAR(BOXLIKE WAG ON RAILS)*                1
# Name: count, Length: 307, dtype: int64
#
#
#
# weapon_used_cd
#
# weapon_used_cd
# NULO     675722
# 400.0    174397
# 500.0     36239
# 511.0     23789
# 102.0     20098
#           ...
# 120.0         3
# 121.0         2
# 119.0         2
# 124.0         2
# 123.0         1
# Name: count, Length: 80, dtype: int64
#
#
#
# weapon_desc
#
# weapon_desc
# NULO                                              675722
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    174397
# UNKNOWN WEAPON/OTHER WEAPON                        36239
# VERBAL THREAT                                      23789
# HAND GUN                                           20098
#                                                    ...
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    3
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          2
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    2
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       2
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       1
# Name: count, Length: 80, dtype: int64
#
#
#
# status
#
# status
# IC    800431
# AO    109653
# AA     86792
# JA      3268
# JO      1872
# CC         6
# Name: count, dtype: int64
#
#
#
# status_desc
#
# status_desc
# Invest Cont     800431
# Adult Other     109653
# Adult Arrest     86792
# Juv Arrest        3268
# Juv Other         1872
# UNK                  6
# Name: count, dtype: int64
#
#
#
# crm_cd_1
#
# crm_cd_1
# 510.0    114255
# 624.0     75073
# 330.0     63560
# 354.0     62527
# 740.0     61151
#           ...
# 430.0         4
# 884.0         4
# 445.0         4
# 926.0         1
# 453.0         1
# Name: count, Length: 142, dtype: int64
#
#
#
# crm_cd_2
#
# crm_cd_2
# NULO     932938
# 998.0     55273
# 930.0      3862
# 860.0      1367
# 761.0       973
#           ...
# 450.0         1
# 470.0         1
# 438.0         1
# 924.0         1
# 846.0         1
# Name: count, Length: 127, dtype: int64
#
#
#
# crm_cd_3
#
# crm_cd_3
# NULO     999710
# 998.0      2040
# 930.0        85
# 946.0        31
# 910.0        27
# 761.0        23
# 999.0        18
# 740.0        13
# 860.0         7
# 901.0         6
# 626.0         6
# 821.0         5
# 745.0         5
# 956.0         5
# 653.0         5
# 815.0         3
# 888.0         3
# 820.0         3
# 997.0         3
# 993.0         3
# 900.0         2
# 753.0         2
# 933.0         1
# 763.0         1
# 902.0         1
# 990.0         1
# 810.0         1
# 648.0         1
# 434.0         1
# 940.0         1
# 830.0         1
# 813.0         1
# 943.0         1
# 649.0         1
# 906.0         1
# 310.0         1
# 903.0         1
# 850.0         1
# 520.0         1
# Name: count, dtype: int64
#
#
#
# crm_cd_4
#
# crm_cd_4
# NULO     1001958
# 998.0         56
# 999.0          3
# 946.0          2
# 930.0          1
# 910.0          1
# 821.0          1
# Name: count, dtype: int64
#
#
#
# location
#
# location
# 800 N  ALAMEDA                      ST      2537
# 700 S  FIGUEROA                     ST      1706
# 100    THE GROVE                    DR      1682
# 10200    SANTA MONICA                 BL    1656
# 6TH                          ST             1584
#                                             ...
# 9100 W  3RD                          ST        1
# ECCLES                                         1
# 3100    FOND                         DR        1
# 5400    CHANDLER                     DR        1
# 9500    CHEROKEE                     LN        1
# Name: count, Length: 66566, dtype: int64
#
#
#
# cross_street
#
# cross_street
# NULO                               848222
# BROADWAY                             2480
# FIGUEROA                     ST      1927
# FIGUEROA                             1636
# VERMONT                      AV      1632
#                                     ...
# ELEVADO                                 1
# LAUREN                       ST         1
# MILLRACE                     ST         1
# FERMOSA                                 1
# CASABA                       AV         1
# Name: count, Length: 10414, dtype: int64
#
#
#
# lat
#
# lat
# 34.1016    5684
# 34.2012    4501
# 34.0980    4256
# 34.1939    3538
# 34.1867    3294
#            ...
# 33.7996       1
# 33.7710       1
# 33.7139       1
# 33.8518       1
# 33.7675       1
# Name: count, Length: 5426, dtype: int64
#
#
#
# lon
#
# lon
# -118.2739    7526
# -118.2827    6407
# -118.2915    4280
# -118.2652    4245
# -118.2871    3909
#              ...
# -118.6666       1
# -118.6317       1
# -118.6607       1
# -118.6552       1
# -118.6323       1
# Name: count, Length: 4982, dtype: int64

# %%
# Función de agrupacion de variables raras
def agrupar_cat_raras(variable, criterio = 0.05):
    #Calcula las frecuencias
    frecuencias = variable.value_counts(normalize=True)
    #Identifica las que están por debajo del criterio
    temp = [cada for cada in frecuencias.loc[frecuencias < criterio].index.values]
    #Las recodifica en 'OTROS'
    temp2 = np.where(variable.isin(temp),'OTROS',variable)
    #Devuelve el resultado
    return(temp2)

# Variables a agrupar
var_imputar_cat_raras = ['weapon_used_cd','premis_cd','premis_desc','weapon_used_cd','weapon_desc','crm_cd_1','crm_cd_2','crm_cd_3','crm_cd_4','cross_street','location']

# Aplicación
for variable in var_imputar_cat_raras:
    df[variable] = agrupar_cat_raras(df[variable],criterio = 0.02)

# %%
df
# Out:
#            date_rptd   date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 211507896 2021-04-11 2020-11-07       845    15  N Hollywood         1502
# 201516622 2020-10-21 2020-10-18      1845    15  N Hollywood         1521
# 240913563 2024-12-10 2020-10-30      1240     9     Van Nuys          933
# 210704711 2020-12-24 2020-12-24      1310     7     Wilshire          782
# 201418201 2020-10-03 2020-09-29      1830    14      Pacific         1454
# ...              ...        ...       ...   ...          ...          ...
# 252104112 2025-02-02 2025-02-02       130    21      Topanga         2103
# 250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck          479
# 251304095 2025-01-31 2025-01-30      1554    13       Newton         1372
# 251704066 2025-01-17 2025-01-17      1600    17   Devonshire         1774
# 251904210 2025-03-25 2025-03-25      1235    19      Mission         1944
#
#            part_1_2  crm_cd  \
# dr_no
# 211507896         2     354
# 201516622         1     230
# 240913563         2     354
# 210704711         1     331
# 201418201         1     420
# ...             ...     ...
# 252104112         2     946
# 250404100         2     237
# 251304095         2     850
# 251704066         2     624
# 251904210         2     850
#
#                                                  crm_cd_desc  \
# dr_no
# 211507896                                  THEFT OF IDENTITY
# 201516622     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 240913563                                  THEFT OF IDENTITY
# 210704711  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 201418201    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...                                                      ...
# 252104112                          OTHER MISCELLANEOUS CRIME
# 250404100                     CHILD NEGLECT (SEE 300 W.I.C.)
# 251304095                                  INDECENT EXPOSURE
# 251704066                           BATTERY - SIMPLE ASSAULT
# 251904210                                  INDECENT EXPOSURE
#
#                                            mocodes  vict_age vict_sex  \
# dr_no
# 211507896                                     0377        31   Female
# 201516622  0416 0334 2004 1822 1414 0305 0319 0400        32   Female
# 240913563                                     0377        30   Female
# 210704711                                     0344        47   Female
# 201418201                      1300 0344 1606 2032        63   Female
# ...                                            ...       ...      ...
# 252104112                                     9999        35   Female
# 250404100                           1258 0553 0602        11   Female
# 251304095                                     9999        16   Female
# 251704066                      0400 1259 1822 0356        17   Female
# 251904210                      0529 2024 1815 0913        35   Female
#
#           vict_descent premis_cd             premis_desc weapon_used_cd  \
# dr_no
# 211507896            H     501.0  SINGLE FAMILY DWELLING           NULO
# 201516622            H     102.0                SIDEWALK          OTROS
# 240913563            W     501.0  SINGLE FAMILY DWELLING           NULO
# 210704711            A     101.0                  STREET           NULO
# 201418201            H     OTROS                   OTROS           NULO
# ...                ...       ...                     ...            ...
# 252104112            X     101.0                  STREET           NULO
# 250404100            B     501.0  SINGLE FAMILY DWELLING           NULO
# 251304095            H     101.0                  STREET           NULO
# 251704066            H     OTROS                   OTROS          400.0
# 251904210            H     OTROS                   OTROS           NULO
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 211507896                                            NULO     IC  Invest Cont
# 201516622                                           OTROS     IC  Invest Cont
# 240913563                                            NULO     IC  Invest Cont
# 210704711                                            NULO     IC  Invest Cont
# 201418201                                            NULO     IC  Invest Cont
# ...                                                   ...    ...          ...
# 252104112                                            NULO     IC  Invest Cont
# 250404100                                            NULO     IC  Invest Cont
# 251304095                                            NULO     IC  Invest Cont
# 251704066  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 251904210                                            NULO     IC  Invest Cont
#
#           crm_cd_1 crm_cd_2 crm_cd_3 crm_cd_4 location cross_street      lat  \
# dr_no
# 211507896    354.0     NULO     NULO     NULO    OTROS         NULO  34.2124
# 201516622    230.0     NULO     NULO     NULO    OTROS        OTROS  34.1993
# 240913563    354.0     NULO     NULO     NULO    OTROS         NULO  34.1847
# 210704711    331.0     NULO     NULO     NULO    OTROS         NULO  34.0339
# 201418201    420.0     NULO     NULO     NULO    OTROS         NULO  33.9813
# ...            ...      ...      ...      ...      ...          ...      ...
# 252104112    OTROS     NULO     NULO     NULO    OTROS         NULO  34.2259
# 250404100    OTROS     NULO     NULO     NULO    OTROS         NULO  34.0277
# 251304095    OTROS     NULO     NULO     NULO    OTROS         NULO  33.9942
# 251704066    624.0     NULO     NULO     NULO    OTROS         NULO  34.2450
# 251904210    OTROS     NULO     NULO     NULO    OTROS         NULO  34.2722
#
#                 lon
# dr_no
# 211507896 -118.4092
# 201516622 -118.4203
# 240913563 -118.4509
# 210704711 -118.3747
# 201418201 -118.4350
# ...             ...
# 252104112 -118.6126
# 250404100 -118.1979
# 251304095 -118.2701
# 251704066 -118.5233
# 251904210 -118.4417
#
# [1002022 rows x 27 columns]

# %% [markdown]
# Hacemos un describe sobre las variables numéricas a ver que vemos y observamos que, aunque hay varias variabees numéricas, no podríamos hacer ningún estadísticos sobre ellas, exceptopsobre 'vict_age' donde vemos que la media de edad es de 29 años y la mediana está en 22 años pero observamos que el mínimo es -4 y máximo 120 años. Esto lo solucionaremos una media winsorizada (0,100)

# %%
df.select_dtypes(include='number').describe().T
# Out:
#                  count         mean         std       min       25%  \
# time_occ     1002022.0  1339.985157  650.949821    1.0000  900.0000
# area         1002022.0    10.692805    6.109985    1.0000    5.0000
# rpt_dist_no  1002022.0  1115.737503  611.124789  101.0000  587.0000
# part_1_2     1002022.0     1.400553    0.490011    1.0000    1.0000
# crm_cd       1002022.0   500.072772  205.287494  110.0000  331.0000
# vict_age     1002022.0    28.985425   21.977709   -4.0000    0.0000
# lat          1002022.0    33.998122    1.612007    0.0000   34.0148
# lon          1002022.0  -118.090472    5.586895 -118.6676 -118.4305
#
#                    50%        75%        max
# time_occ     1420.0000  1900.0000  2359.0000
# area           11.0000    16.0000    21.0000
# rpt_dist_no  1139.0000  1613.0000  2199.0000
# part_1_2        1.0000     2.0000     2.0000
# crm_cd        442.0000   626.0000   956.0000
# vict_age       30.0000    44.0000   120.0000
# lat            34.0590    34.1649    34.3343
# lon          -118.3225  -118.2739     0.0000

# %%
df.vict_age.value_counts().sort_index(ascending=True)
# Out:
# vict_age
# 0      266990
# 2         429
# 3         498
# 4         518
# 5         571
#         ...
# 96         94
# 97         72
# 98         71
# 99        354
# 100         1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# Realizamos una imputacion de los valores de la edad tras realizar una media winsorizada manualmente (0, 100)

# %%
variable = 'vict_age'
num[variable].describe().loc[['min','max']]
# Out:
# min     -4.0
# max    120.0
# Name: vict_age, dtype: float64

# %%
minimo = 0
maximo = 100
df[variable] = df[variable].clip(minimo, maximo)
df[variable].describe()
# Out:
# count    1.002022e+06
# mean     2.898559e+01
# std      2.197739e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      3.000000e+01
# 75%      4.400000e+01
# max      1.000000e+02
# Name: vict_age, dtype: float64
