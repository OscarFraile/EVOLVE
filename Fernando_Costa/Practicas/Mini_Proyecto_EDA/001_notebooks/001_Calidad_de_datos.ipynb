# %% [markdown]
# # CALIDAD DE DATOS

# %% [markdown]
# ## 1. IMPORTAMOS PAQUETES Y DATOS

# %%
import pandas as pd
import zipfile
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
# %config IPCompleter.greedy = True
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Definimos la ruta donde ubicamos los datasets para no tener que estar poniéndola en cada ocasión

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '999_data/'

# %% [markdown]
# Definimos el dataset que vamos a usar

# %%
zip_name = 'Crime_Data_from_2020_to_Present.zip'
csv_filename = 'Crime_Data_from_2020_to_Present.csv'

# %%
zip_path = ruta_principal + carpeta + zip_name

# %% [markdown]
# Cargamos el dataset df

# %%
frac = 0.33
chunksize = 100_000  # ajusta según memoria

rows = []

with zipfile.ZipFile(zip_path) as z:
    with z.open(csv_filename) as f:
        for chunk in pd.read_csv(f, chunksize=chunksize):
            rows.append(chunk.sample(frac=frac))
            
df = pd.concat(rows, ignore_index=True)
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  201319771  11/08/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1541    13
# 1  200611211  05/29/2020 12:00:00 AM  05/29/2020 12:00:00 AM      1855     6
# 2  201501048  10/30/2020 12:00:00 AM  06/30/2020 12:00:00 AM      1800    15
# 3  201416637  09/04/2020 12:00:00 AM  09/03/2020 12:00:00 AM      1200    14
# 4  201712106  08/11/2020 12:00:00 AM  08/11/2020 12:00:00 AM      1000    17
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0       Newton         1363         1     331
# 1    Hollywood          666         2     740
# 2  N Hollywood         1538         1     210
# 3      Pacific         1494         1     420
# 4   Devonshire         1723         1     310
#
#                                          Crm Cd Desc  \
# 0  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 2                                            ROBBERY
# 3    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 4                                           BURGLARY
#
#                               Mocodes  Vict Age Vict Sex Vict Descent  \
# 0                           1202 0344        76        M            B
# 1                           0329 1822        40        F            W
# 2  1402 0344 0400 0387 0334 1414 1822        43        M            H
# 3                                 NaN         0      NaN          NaN
# 4                 1402 0913 0603 0344        42        M            H
#
#    Premis Cd             Premis Desc  Weapon Used Cd  \
# 0      218.0      BEAUTY/BARBER SHOP             NaN
# 1      101.0                  STREET             NaN
# 2      501.0  SINGLE FAMILY DWELLING           114.0
# 3      101.0                  STREET             NaN
# 4      501.0  SINGLE FAMILY DWELLING             NaN
#
#                         Weapon Desc Status   Status Desc  Crm Cd 1  Crm Cd 2  \
# 0                               NaN     IC   Invest Cont     331.0       NaN
# 1                               NaN     IC   Invest Cont     740.0       NaN
# 2  AIR PISTOL/REVOLVER/RIFLE/BB GUN     AA  Adult Arrest     210.0     998.0
# 3                               NaN     IC   Invest Cont     420.0       NaN
# 4                               NaN     IC   Invest Cont     310.0     998.0
#
#    Crm Cd 3  Crm Cd 4                                  LOCATION  \
# 0       NaN       NaN    700 E  49TH                         ST
# 1       NaN       NaN   1100    VINE                         ST
# 2       NaN       NaN           ERWIN                        ST
# 3       NaN       NaN                         7200    WORLD WAY
# 4       NaN       NaN  20400    GERMAIN                      ST
#
#                       Cross Street      LAT       LON
# 0                              NaN  33.9986 -118.2632
# 1                              NaN  34.0908 -118.3266
# 2  FULCHER                      ST  34.1758 -118.3746
# 3                              NaN  33.9419 -118.4217
# 4                              NaN  34.2622 -118.5790

# %% [markdown]
# ## 2. COMPROBAMOS LAS CARACTERÍSTICAS DEL DATASET

# %%
df.shape
# Out:
# (331647, 28)

# %% [markdown]
# Comprobamos que el dataset tiene nulos y nos sirve para trabajar

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Crm Cd 4          331627
# Crm Cd 3          330888
# Crm Cd 2          308801
# Cross Street      280649
# Weapon Used Cd    223461
# Weapon Desc       223461
# Mocodes            49801
# Vict Descent       47511
# Vict Sex           47508
# Premis Desc          223
# Premis Cd              6
# Crm Cd 1               2
# Vict Age               0
# Crm Cd Desc            0
# Crm Cd                 0
# Part 1-2               0
# AREA NAME              0
# Rpt Dist No            0
# AREA                   0
# TIME OCC               0
# Date Rptd              0
# DATE OCC               0
# DR_NO                  0
# Status                 0
# Status Desc            0
# LOCATION               0
# LAT                    0
# LON                    0
# dtype: int64

# %% [markdown]
# Comprobamos las dimensiones de la tabla y los valores únicos de DR_NO ya que sospecho que debe ser el índice

# %%
dimensiones_df = df.shape
print(f'Dimensiones df: ', dimensiones_df)
# Out:
# Dimensiones df:  (331647, 28)

# %%
DR_NO = df.DR_NO.nunique()
print(f'Valores únicos de DR_NO: ', DR_NO)
# Out:
# Valores únicos de DR_NO:  331647

# %% [markdown]
# CAMBIOS EN NOMBRES E ÍNDICE:
# - Transformamos a minúsculas los nombres de las columnas
# - Ponemos 'dr_no' como index ya que es el identificador del reporte

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.columns = df.columns.str.replace('-','_')
df = df.set_index('dr_no')
df
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 201319771  11/08/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1541    13
# 200611211  05/29/2020 12:00:00 AM  05/29/2020 12:00:00 AM      1855     6
# 201501048  10/30/2020 12:00:00 AM  06/30/2020 12:00:00 AM      1800    15
# 201416637  09/04/2020 12:00:00 AM  09/03/2020 12:00:00 AM      1200    14
# 201712106  08/11/2020 12:00:00 AM  08/11/2020 12:00:00 AM      1000    17
# ...                           ...                     ...       ...   ...
# 240711752  10/02/2024 12:00:00 AM  10/01/2024 12:00:00 AM      1800     7
# 240505317  02/03/2024 12:00:00 AM  02/03/2024 12:00:00 AM      2220     5
# 240804529  01/15/2024 12:00:00 AM  01/11/2024 12:00:00 AM      1659     8
# 241309619  05/22/2024 12:00:00 AM  05/20/2024 12:00:00 AM      2300    13
# 242111298  08/24/2024 12:00:00 AM  08/23/2024 12:00:00 AM       200    21
#
#              area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 201319771       Newton         1363         1     331
# 200611211    Hollywood          666         2     740
# 201501048  N Hollywood         1538         1     210
# 201416637      Pacific         1494         1     420
# 201712106   Devonshire         1723         1     310
# ...                ...          ...       ...     ...
# 240711752     Wilshire          759         1     420
# 240505317       Harbor          564         2     850
# 240804529      West LA          882         1     440
# 241309619       Newton         1361         2     740
# 242111298      Topanga         2185         1     330
#
#                                                  crm_cd_desc  \
# dr_no
# 201319771  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 200611211  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 201501048                                            ROBBERY
# 201416637    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 201712106                                           BURGLARY
# ...                                                      ...
# 240711752    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 240505317                                  INDECENT EXPOSURE
# 240804529                 THEFT PLAIN - PETTY ($950 & UNDER)
# 241309619  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 242111298                              BURGLARY FROM VEHICLE
#
#                                       mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 201319771                           1202 0344        76        M            B
# 200611211                           0329 1822        40        F            W
# 201501048  1402 0344 0400 0387 0334 1414 1822        43        M            H
# 201416637                                 NaN         0      NaN          NaN
# 201712106                 1402 0913 0603 0344        42        M            H
# ...                                       ...       ...      ...          ...
# 240711752                                 NaN         0      NaN          NaN
# 240505317                      1822 0529 2004        29        F            B
# 240804529                           1822 0344        58        M            J
# 241309619                           0329 1307        45        F            H
# 242111298                      1202 1307 0344        29        M            W
#
#            premis_cd                                   premis_desc  \
# dr_no
# 201319771      218.0                            BEAUTY/BARBER SHOP
# 200611211      101.0                                        STREET
# 201501048      501.0                        SINGLE FAMILY DWELLING
# 201416637      101.0                                        STREET
# 201712106      501.0                        SINGLE FAMILY DWELLING
# ...              ...                                           ...
# 240711752      101.0                                        STREET
# 240505317      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 240804529      203.0                                OTHER BUSINESS
# 241309619      122.0                      VEHICLE, PASSENGER/TRUCK
# 242111298      101.0                                        STREET
#
#            weapon_used_cd                       weapon_desc status  \
# dr_no
# 201319771             NaN                               NaN     IC
# 200611211             NaN                               NaN     IC
# 201501048           114.0  AIR PISTOL/REVOLVER/RIFLE/BB GUN     AA
# 201416637             NaN                               NaN     IC
# 201712106             NaN                               NaN     IC
# ...                   ...                               ...    ...
# 240711752             NaN                               NaN     IC
# 240505317             NaN                               NaN     IC
# 240804529             NaN                               NaN     IC
# 241309619             NaN                               NaN     IC
# 242111298             NaN                               NaN     IC
#
#             status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 201319771   Invest Cont     331.0       NaN       NaN       NaN
# 200611211   Invest Cont     740.0       NaN       NaN       NaN
# 201501048  Adult Arrest     210.0     998.0       NaN       NaN
# 201416637   Invest Cont     420.0       NaN       NaN       NaN
# 201712106   Invest Cont     310.0     998.0       NaN       NaN
# ...                 ...       ...       ...       ...       ...
# 240711752   Invest Cont     420.0       NaN       NaN       NaN
# 240505317   Invest Cont     850.0       NaN       NaN       NaN
# 240804529   Invest Cont     440.0       NaN       NaN       NaN
# 241309619   Invest Cont     740.0       NaN       NaN       NaN
# 242111298   Invest Cont     330.0       NaN       NaN       NaN
#
#                                            location  \
# dr_no
# 201319771    700 E  49TH                         ST
# 200611211   1100    VINE                         ST
# 201501048           ERWIN                        ST
# 201416637                         7200    WORLD WAY
# 201712106  20400    GERMAIN                      ST
# ...                                             ...
# 240711752   1100    CRENSHAW                     BL
# 240505317    400 W  3RD                          ST
# 240804529   2100    SAWTELLE                     BL
# 241309619    100 W  47TH                         ST
# 242111298   4900    LLANO                        DR
#
#                               cross_street      lat       lon
# dr_no
# 201319771                              NaN  33.9986 -118.2632
# 200611211                              NaN  34.0908 -118.3266
# 201501048  FULCHER                      ST  34.1758 -118.3746
# 201416637                              NaN  33.9419 -118.4217
# 201712106                              NaN  34.2622 -118.5790
# ...                                    ...      ...       ...
# 240711752                              NaN  34.0531 -118.3239
# 240505317                              NaN  33.7415 -118.2857
# 240804529                              NaN  34.0396 -118.4425
# 241309619                              NaN  34.0010 -118.2740
# 242111298                              NaN  34.1567 -118.6108
#
# [331647 rows x 27 columns]

# %% [markdown]
# ## 3. SIGNIFICADO Y FORMATO DE LAS COLUMNAS

# %% [markdown]
# Ya sabemos que podemos trabajar con el dataset y lo tenemos cargado con los nombre de las columnas en su formato correto
#
# Significado de las columnas:
# - dr_no: Número de expediente oficial compuesto por un año de 2 dígitos, un ID de área y 5 dígitos.
# - date_rptd: Fecha de Reporte. Indica el día en que el crimen o incidente fue oficialmente reportado (MM/DD/AAAA)
# - date_occ: Fecha de Ocurrencia. Indica el día real en que el crimen tuvo lugar (MM/DD/AAAA)
# - time_occ: En horario militar de 24 horas.
# - area: Áreas Geográficas o Divisiones de Patrulla numeradas secuencialmente del 1 al 21.
# - area_name: Nombre de las áreas Geográficas o Divisiones de Patrulla
# - rpt_dist_no: Número de distrito de la patrulla del oficial que informó el incidente.
# - part_1_2: Indica si el incidente es un crimen de la Parte 1 (crímenes más graves) o de la Parte 2 (crímenes menos graves).
# - crm_cd: Código de delito de 3 dígitos del crimen cometido.
# - crm_cd_desc: Descripción del delito del crimen cometido.
# - mocodes: Modus Operandi o la manera distintiva o característica en que una persona lleva a cabo una actividad criminal.
# - vict_age: Edad de la víctima
# - vict_sex: Sexo de la víctima.
# - vict_descent: Código de descendencia de la víctima
# - premis_cd: El Código de Instalación es un código de 3 dígitos que identifica el tipo de lugar donde ocurrió el incidente
# - premis_desc: Descripción de la Instalación.
# - weapon_used_cd: El Código de Arma es un código de 3 dígitos que identifica el tipo de arma utilizada en el incidente
# - weapon_desc: Descripción del Arma.
# - status: Estado del caso. (IC es el valor predeterminado)
# - status_desc: Define el Código de Estado proporcionado.
# - crm_cd_1: Indica el crimen cometido. El Código de Crimen 1 es el principal y el más grave. Los Códigos de Crimen 2, 3 y 4 son, respectivamente, delitos menos graves. Los números de clase de crimen más bajos son más graves.
# - crm_cd_2: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_3: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_4: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - location: Dirección postal del incidente del crimen redondeada al centenar de la cuadra más cercana para mantener el anonimato.
# - cross_street: El nombre de la calle que se cruza con la calle principal donde ocurrió el incidente.
# - lat: Latitud.
# - lon: Longitud.
#
# Códigos de descendencia:
# - A: Otros Asiáticos
# - B: Afroamericano
# - C: Chino
# - D: Camboyano
# - F: Filipino
# - G: Guamés
# - H: Hispano/Latino/Mexicano
# - I: Indio Americano/Nativo de Alaska
# - J: Japonés
# - K: Coreano
# - L: Laosiano
# - O: Otro
# - P: Isleño del Pacífico
# - S: Samoano
# - U: Hawaiano
# - V: Vietnamita
# - W: Blanco
# - X: Desconocido
# - Z: Hindú Asiático

# %% [markdown]
# Revisamos los tipos de datos de cada variable observando entre el .info() y la viasualización de la propia tabla y no se requieren cambios
#
# También observamos en el count que hay nulos en varias columnas que trataremos posteriormente

# %%
pd.set_option('display.max_columns', None)
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 211206686  02/11/2021 12:00:00 AM  02/10/2021 12:00:00 AM      2300    12
#
#              area_name  rpt_dist_no  part_1_2  crm_cd       crm_cd_desc  \
# dr_no
# 211206686  77th Street         1268         1     510  VEHICLE - STOLEN
#
#           mocodes  vict_age vict_sex vict_descent  premis_cd premis_desc  \
# dr_no
# 211206686     NaN         0      NaN          NaN      101.0      STREET
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 211206686             NaN         NaN     IC  Invest Cont     510.0       NaN
#
#            crm_cd_3  crm_cd_4                                location  \
# dr_no
# 211206686       NaN       NaN  200 E  80TH                         ST
#
#           cross_street     lat       lon
# dr_no
# 211206686          NaN  33.967 -118.2717

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 201319771 to 242111298
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  object
#  1   date_occ        331647 non-null  object
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  int64
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  int64
#  6   part_1_2        331647 non-null  int64
#  7   crm_cd          331647 non-null  int64
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281846 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        284139 non-null  object
#  12  vict_descent    284136 non-null  object
#  13  premis_cd       331641 non-null  float64
#  14  premis_desc     331424 non-null  object
#  15  weapon_used_cd  108186 non-null  float64
#  16  weapon_desc     108186 non-null  object
#  17  status          331647 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331645 non-null  float64
#  20  crm_cd_2        22846 non-null   float64
#  21  crm_cd_3        759 non-null     float64
#  22  crm_cd_4        20 non-null      float64
#  23  location        331647 non-null  object
#  24  cross_street    50998 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
# dtypes: float64(8), int64(6), object(13)
# memory usage: 70.8+ MB

# %% [markdown]
# ## 4. TRATAMIENTO DE VARIABLES
#
# ### FORMATO DE VARIABLES

# %% [markdown]
# Las columnas 'date_rptd' y 'date_occ' vamos a eliminar la hora porque en todos los registros nos dicen que ha sido a las '12:00:00 AM'. Esta información es errónea según la columna 'time_occ' y además no nos aporta información como variable porque es una constante en todos los registros

# %%
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 200909062  04/28/2020 12:00:00 AM  04/17/2020 12:00:00 AM      1200     9
#
#           area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 200909062  Van Nuys          909         1     420
#
#                                                crm_cd_desc    mocodes  \
# dr_no
# 200909062  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  0385 0344
#
#            vict_age vict_sex vict_descent  premis_cd premis_desc  \
# dr_no
# 200909062        33        M            O      103.0       ALLEY
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 200909062             NaN         NaN     IC  Invest Cont     420.0       NaN
#
#            crm_cd_3  crm_cd_4                                  location  \
# dr_no
# 200909062       NaN       NaN  13600    VALERIO                      ST
#
#           cross_street      lat       lon
# dr_no
# 200909062          NaN  34.2049 -118.4291

# %% [markdown]
# Eliminamos la parte de la hora

# %%
df['date_rptd'] = df['date_rptd'].str.split(' ').str[0]
df['date_occ'] = df['date_occ'].str.split(' ').str[0]

# %% [markdown]
# Hacemos un datetime de las columnas de fechas

# %%
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 241807082  03/06/2024  03/04/2024      1900    18  Southeast         1822
#
#            part_1_2  crm_cd                                      crm_cd_desc  \
# dr_no
# 241807082         1     420  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#           mocodes  vict_age vict_sex vict_descent  premis_cd premis_desc  \
# dr_no
# 241807082     NaN         0      NaN          NaN      104.0    DRIVEWAY
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 241807082             NaN         NaN     IC  Invest Cont     420.0       NaN
#
#            crm_cd_3  crm_cd_4                                location  \
# dr_no
# 241807082       NaN       NaN  100 E  COLDEN                       AV
#
#           cross_street      lat       lon
# dr_no
# 241807082          NaN  33.9492 -118.2739

# %%
df['date_rptd'] = pd.to_datetime(df['date_rptd'], format='%m/%d/%Y')
df['date_occ'] = pd.to_datetime(df['date_occ'], format='%m/%d/%Y')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 201319771 to 242111298
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  datetime64[ns]
#  1   date_occ        331647 non-null  datetime64[ns]
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  int64
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  int64
#  6   part_1_2        331647 non-null  int64
#  7   crm_cd          331647 non-null  int64
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281846 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        284139 non-null  object
#  12  vict_descent    284136 non-null  object
#  13  premis_cd       331641 non-null  float64
#  14  premis_desc     331424 non-null  object
#  15  weapon_used_cd  108186 non-null  float64
#  16  weapon_desc     108186 non-null  object
#  17  status          331647 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331645 non-null  float64
#  20  crm_cd_2        22846 non-null   float64
#  21  crm_cd_3        759 non-null     float64
#  22  crm_cd_4        20 non-null      float64
#  23  location        331647 non-null  object
#  24  cross_street    50998 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(6), object(11)
# memory usage: 70.8+ MB

# %%
df.sample()
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 241406397 2024-02-22 2024-02-21      2200    14   Pacific         1454
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 241406397         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd premis_desc  weapon_used_cd weapon_desc  \
# dr_no
# 241406397          NaN      101.0      STREET             NaN         NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 241406397     IC  Invest Cont     510.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 241406397  13100    MAXELLA                      AV          NaN  33.9893
#
#                 lon
# dr_no
# 241406397 -118.4363

# %% [markdown]
# ### DUPLICADOS
#
# Comprobamos si hay duplicados y hacemos comparaciones para asegurarnos

# %%
duplicados = df.duplicated().sum()
print(f'Recuento de duplicados en df: ', duplicados)
# Out:
# Recuento de duplicados en df:  355

# %% [markdown]
# Nos salen que hay duplicados de las 27 columnas y que solamente es diferente el índice. Hacemos unas visualizaciones para comprobar que son realmente duplicados y vemos que es cierto, por lo que borramos todos los duplicados

# %%
lineas_original = len(df)
lineas_original
# Out:
# 331647

# %%
df.loc[df.duplicated()].head(2)
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 201614391 2020-11-02 2020-10-12      1100    16  Foothill         1664
# 202017850 2020-12-01 2020-12-01      1427    20   Olympic         2076
#
#            part_1_2  crm_cd               crm_cd_desc  \
# dr_no
# 201614391         1     510          VEHICLE - STOLEN
# 202017850         2     624  BATTERY - SIMPLE ASSAULT
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 201614391                       NaN         0      NaN          NaN
# 202017850  0913 0445 0447 1309 0319        51        F            H
#
#            premis_cd             premis_desc  weapon_used_cd  \
# dr_no
# 201614391      108.0             PARKING LOT             NaN
# 202017850      719.0  MEDICAL/DENTAL OFFICES           500.0
#
#                            weapon_desc status  status_desc  crm_cd_1  \
# dr_no
# 201614391                          NaN     IC  Invest Cont     510.0
# 202017850  UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont     624.0
#
#            crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 201614391       NaN       NaN       NaN
# 202017850       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 201614391  9200    TUJUNGA                      AV          NaN  34.2363
# 202017850  1400 S  VERMONT                      AV          NaN  34.0436
#
#                 lon
# dr_no
# 201614391 -118.3804
# 202017850 -118.2960

# %%
# Buscamos una en concreto por hacer la comprobación
df.loc[(df.mocodes == '0421 1528 1822 0903 2053')]
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 220706170 2022-02-26 2022-02-26      1200     7  Wilshire          752
# 220706178 2022-02-26 2022-02-26      1200     7  Wilshire          752
#
#            part_1_2  crm_cd                             crm_cd_desc  \
# dr_no
# 220706170         2     930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706178         2     930  CRIMINAL THREATS - NO WEAPON DISPLAYED
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 220706170  0421 1528 1822 0903 2053         0        M            O
# 220706178  0421 1528 1822 0903 2053         0        M            O
#
#            premis_cd             premis_desc  weapon_used_cd    weapon_desc  \
# dr_no
# 220706170      501.0  SINGLE FAMILY DWELLING           511.0  VERBAL THREAT
# 220706178      501.0  SINGLE FAMILY DWELLING           511.0  VERBAL THREAT
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 220706170     IC  Invest Cont     930.0     946.0       NaN       NaN
# 220706178     IC  Invest Cont     930.0     946.0       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 220706170  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706178  1100 S  ORLANDO                      AV          NaN  34.0572
#
#                 lon
# dr_no
# 220706170 -118.3739
# 220706178 -118.3739

# %% [markdown]
# Eliminamos los duplicados

# %%
df.drop_duplicates(inplace=True)

# %%
lineas_despues = len(df)

diff = lineas_original - lineas_despues

print("Filas antes:", lineas_original)
print("Filas después:", lineas_despues)
print("Diferencia:", diff)
# Out:
# Filas antes: 331647
# Filas después: 331292
# Diferencia: 355

# %% [markdown]
# ### VALORES ÚNICOS
#
# Comprobamos los valores únicos en la tabla para desestimar variables. En este caso, no hay constantes

# %%
df.nunique().sort_values(ascending=True)

# Si hubiera alguna columna que eliminar haríamos df.drop(columns = '...', inplace=True)
# Out:
# part_1_2               2
# crm_cd_4               3
# vict_sex               4
# status                 6
# status_desc            6
# vict_descent          19
# area_name             21
# area                  21
# crm_cd_3              22
# weapon_used_cd        79
# weapon_desc           79
# crm_cd_2             103
# vict_age             103
# crm_cd               137
# crm_cd_desc          137
# crm_cd_1             138
# premis_desc          303
# premis_cd            310
# rpt_dist_no         1166
# time_occ            1439
# date_occ            1856
# date_rptd           1871
# lon                 4870
# lat                 5169
# cross_street        6593
# location           50606
# mocodes           117498
# dtype: int64

# %% [markdown]
# ### VALORES NULOS
#
# Comprobamos los nulos que existen según el tipo de columna: Categórica y numérica
#
# Primero haremos las comprobaciones, después expondré las conclusiones y a continuación realizaré los cambios

# %%
df.select_dtypes(include='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_4          331272
# crm_cd_3          330533
# crm_cd_2          308456
# weapon_used_cd    223241
# premis_cd              6
# crm_cd_1               2
# vict_age               0
# crm_cd                 0
# part_1_2               0
# rpt_dist_no            0
# area                   0
# time_occ               0
# lat                    0
# lon                    0
# dtype: int64

# %%
df.select_dtypes(exclude='number').isna().sum().sort_values(ascending=False)
# Out:
# cross_street    280359
# weapon_desc     223241
# mocodes          49664
# vict_descent     47375
# vict_sex         47372
# premis_desc        223
# area_name            0
# date_occ             0
# date_rptd            0
# crm_cd_desc          0
# status               0
# status_desc          0
# location             0
# dtype: int64

# %%
df.vict_descent.unique()
# Out:
# array(['B', 'W', 'H', nan, 'X', 'O', 'A', 'P', 'K', 'C', 'F', 'V', 'J',
#        'Z', 'I', 'S', 'U', 'D', 'G', 'L'], dtype=object)

# %%
df.loc[df.vict_descent=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon]
# Index: []

# %%
df.vict_sex.unique()
# Out:
# array(['M', 'F', nan, 'X', 'H'], dtype=object)

# %%
df.loc[df.vict_sex=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon]
# Index: []

# %%
df.loc[(df.premis_cd.notna())&(df.premis_desc.isna())].premis_cd.value_counts()
# Out:
# premis_cd
# 418.0    137
# 256.0     64
# 972.0      7
# 973.0      4
# 974.0      4
# 976.0      1
# Name: count, dtype: int64

# %%
df.loc[(df.crm_cd_1.isna())]
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 230114704 2023-06-22 2023-06-22      1801     1   Central          162
# 230106125 2023-02-01 2023-02-01      1855     1   Central          129
#
#            part_1_2  crm_cd                               crm_cd_desc  \
# dr_no
# 230114704         1     442  SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 230106125         1     330                     BURGLARY FROM VEHICLE
#
#              mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 230114704       0325        25        M            H      404.0
# 230106125  0344 1609        32        M            B      101.0
#
#                 premis_desc  weapon_used_cd weapon_desc status  status_desc  \
# dr_no
# 230114704  DEPARTMENT STORE             NaN         NaN     IC  Invest Cont
# 230106125            STREET             NaN         NaN     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 230114704       NaN     442.0       NaN       NaN
# 230106125       NaN     330.0       NaN       NaN
#
#                                          location cross_street      lat  \
# dr_no
# 230114704  700 S  FLOWER                       ST          NaN  34.0487
# 230106125                                   GAREY      JACKSON  34.0513
#
#                 lon
# dr_no
# 230114704 -118.2588
# 230106125 -118.2344

# %%
df.loc[(df.status.isna())]
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon]
# Index: []

# %%
df.loc[(df.crm_cd_1 == 510.0)]
# Out:
#            date_rptd   date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 200317116 2020-09-10 2020-09-10      1351     3    Southwest          329
# 201916864 2020-11-13 2020-11-13      1830    19      Mission         1984
# 201318949 2020-10-24 2020-10-23      2200    13       Newton         1362
# 201910635 2020-06-07 2020-06-07       550    19      Mission         1907
# 202106989 2020-03-06 2020-03-05      1830    21      Topanga         2118
# ...              ...        ...       ...   ...          ...          ...
# 240511143 2024-09-06 2024-09-03       100     5       Harbor          566
# 241011254 2024-09-25 2024-09-10      1100    10  West Valley         1007
# 241813573 2024-10-02 2024-10-02         1    18    Southeast         1822
# 241105695 2024-02-14 2024-02-13      2300    11    Northeast         1183
# 240410970 2024-10-22 2024-10-17      2000     4   Hollenbeck          477
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 200317116         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201916864         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201318949         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 201910635         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 202106989         1     510  VEHICLE - STOLEN     NaN         0      NaN
# ...             ...     ...               ...     ...       ...      ...
# 240511143         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 241011254         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 241813573         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 241105695         1     510  VEHICLE - STOLEN     NaN         0      NaN
# 240410970         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd                   premis_desc  \
# dr_no
# 200317116          NaN      108.0                   PARKING LOT
# 201916864          NaN      123.0  PARKING UNDERGROUND/BUILDING
# 201318949          NaN      101.0                        STREET
# 201910635          NaN      104.0                      DRIVEWAY
# 202106989          NaN      101.0                        STREET
# ...                ...        ...                           ...
# 240511143          NaN      101.0                        STREET
# 241011254          NaN      104.0                      DRIVEWAY
# 241813573          NaN      108.0                   PARKING LOT
# 241105695          NaN      101.0                        STREET
# 240410970          NaN      101.0                        STREET
#
#            weapon_used_cd weapon_desc status   status_desc  crm_cd_1  \
# dr_no
# 200317116             NaN         NaN     IC   Invest Cont     510.0
# 201916864             NaN         NaN     IC   Invest Cont     510.0
# 201318949             NaN         NaN     IC   Invest Cont     510.0
# 201910635             NaN         NaN     AA  Adult Arrest     510.0
# 202106989             NaN         NaN     IC   Invest Cont     510.0
# ...                   ...         ...    ...           ...       ...
# 240511143             NaN         NaN     IC   Invest Cont     510.0
# 241011254             NaN         NaN     IC   Invest Cont     510.0
# 241813573             NaN         NaN     IC   Invest Cont     510.0
# 241105695             NaN         NaN     IC   Invest Cont     510.0
# 240410970             NaN         NaN     IC   Invest Cont     510.0
#
#            crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 200317116       NaN       NaN       NaN
# 201916864       NaN       NaN       NaN
# 201318949       NaN       NaN       NaN
# 201910635       NaN       NaN       NaN
# 202106989       NaN       NaN       NaN
# ...             ...       ...       ...
# 240511143       NaN       NaN       NaN
# 241011254       NaN       NaN       NaN
# 241813573       NaN       NaN       NaN
# 241105695       NaN       NaN       NaN
# 240410970       NaN       NaN       NaN
#
#                                            location  \
# dr_no
# 200317116   3300 S  FIGUEROA                     ST
# 201916864  14900    ROSCOE                       BL
# 201318949           48TH                         ST
# 201910635  12800    FENTON                       AV
# 202106989   8200    DELCO                        AV
# ...                                             ...
# 240511143    300 W  9TH                          ST
# 241011254   7800    AMESTOY                      AV
# 241813573    100 W  104TH                        ST
# 241105695   1600    LUCRETIA                     AV
# 240410970           6TH                          ST
#
#                               cross_street      lat       lon
# dr_no
# 200317116                              NaN  34.0225 -118.2796
# 201916864                              NaN  34.2265 -118.4565
# 201318949  AVALON                       BL  33.9998 -118.2652
# 201910635                              NaN  34.3062 -118.4222
# 202106989                              NaN  34.2182 -118.5787
# ...                                    ...      ...       ...
# 240511143                              NaN  33.7360 -118.2836
# 241011254                              NaN  34.2121 -118.5055
# 241813573                              NaN  33.9469 -118.2772
# 241105695                              NaN  34.0824 -118.2555
# 240410970  SOTO                         ST  34.0372 -118.2132
#
# [37778 rows x 27 columns]

# %% [markdown]
# ## 5. GUARDADO DE RESULTADOS

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '002_archivos/'

# %%
ruta_trabajo = ruta_principal + carpeta + 'trabajo_resultado_calidad.pickle'

# %% [markdown]
# Guardar los archivos

# %%
df.to_pickle(ruta_trabajo)
