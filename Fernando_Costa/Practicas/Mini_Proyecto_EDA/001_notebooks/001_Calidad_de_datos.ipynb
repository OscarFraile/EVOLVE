# %% [markdown]
# # CALIDAD DE DATOS

# %% [markdown]
# ## 1. IMPORTAMOS PAQUETES Y DATOS

# %%
import pandas as pd
import zipfile
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
# %config IPCompleter.greedy = True
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Definimos la ruta donde ubicamos los datasets para no tener que estar poniéndola en cada ocasión

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '999_data/'

# %% [markdown]
# Definimos el dataset que vamos a usar

# %%
zip_name = 'Crime_Data_from_2020_to_Present.zip'
csv_filename = 'Crime_Data_from_2020_to_Present.csv'

# %%
zip_path = ruta_principal + carpeta + zip_name

# %% [markdown]
# Cargamos el dataset df

# %%
frac = 0.33
chunksize = 100_000  # ajusta según memoria

rows = []

with zipfile.ZipFile(zip_path) as z:
    with z.open(csv_filename) as f:
        for chunk in pd.read_csv(f, chunksize=chunksize):
            rows.append(chunk.sample(frac=frac))
            
df = pd.concat(rows, ignore_index=True)
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  201812425  06/11/2020 12:00:00 AM  06/07/2020 12:00:00 AM      2300    18
# 1  200705197  01/23/2020 12:00:00 AM  01/13/2020 12:00:00 AM      1130     7
# 2  201912165  07/15/2020 12:00:00 AM  07/14/2020 12:00:00 AM      2200    19
# 3  201317843  10/02/2020 12:00:00 AM  10/02/2020 12:00:00 AM      1130    13
# 4  201608441  04/21/2020 12:00:00 AM  04/21/2020 12:00:00 AM       139    16
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  Southeast         1829         1     420
# 1   Wilshire          777         2     930
# 2    Mission         1985         1     510
# 3     Newton         1371         1     236
# 4   Foothill         1619         1     648
#
#                                        Crm Cd Desc                   Mocodes  \
# 0  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)       1822 1300 0344 1202
# 1           CRIMINAL THREATS - NO WEAPON DISPLAYED                 0601 0443
# 2                                 VEHICLE - STOLEN                       NaN
# 3            INTIMATE PARTNER - AGGRAVATED ASSAULT  0913 1813 2000 0408 0448
# 4                                            ARSON                       NaN
#
#    Vict Age Vict Sex Vict Descent  Premis Cd             Premis Desc  \
# 0        66        F            H      108.0             PARKING LOT
# 1        53        F            B      501.0  SINGLE FAMILY DWELLING
# 2         0      NaN          NaN      101.0                  STREET
# 3        21        F            B      501.0  SINGLE FAMILY DWELLING
# 4        71        F            X      501.0  SINGLE FAMILY DWELLING
#
#    Weapon Used Cd                                     Weapon Desc Status  \
# 0           500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
# 1           511.0                                   VERBAL THREAT     AO
# 2             NaN                                             NaN     IC
# 3           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC
# 4             NaN                                             NaN     IC
#
#    Status Desc  Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  \
# 0  Invest Cont     420.0       NaN       NaN       NaN
# 1  Adult Other     930.0       NaN       NaN       NaN
# 2  Invest Cont     510.0       NaN       NaN       NaN
# 3  Invest Cont     236.0       NaN       NaN       NaN
# 4  Invest Cont     648.0       NaN       NaN       NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   2100 E  102ND                        ST          NaN  33.9439 -118.2346
# 1   1600    WEST                         BL          NaN  34.0452 -118.3351
# 2   8800    TOBIAS                       AV          NaN  34.2299 -118.4517
# 3    100 W  57TH                         ST          NaN  33.9906 -118.2745
# 4  10700    LAS LUNITAS                  AV          NaN  34.2629 -118.2913

# %% [markdown]
# ## 2. COMPROBAMOS LAS CARACTERÍSTICAS DEL DATASET

# %%
df.shape
# Out:
# (331647, 28)

# %% [markdown]
# Comprobamos que el dataset tiene nulos y nos sirve para trabajar

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Crm Cd 4          331620
# Crm Cd 3          330882
# Crm Cd 2          308932
# Cross Street      280652
# Weapon Used Cd    223784
# Weapon Desc       223784
# Mocodes            50534
# Vict Descent       48264
# Vict Sex           48263
# Premis Desc          179
# Premis Cd              4
# Crm Cd 1               3
# Vict Age               0
# Crm Cd Desc            0
# Crm Cd                 0
# Part 1-2               0
# AREA NAME              0
# Rpt Dist No            0
# AREA                   0
# TIME OCC               0
# Date Rptd              0
# DATE OCC               0
# DR_NO                  0
# Status                 0
# Status Desc            0
# LOCATION               0
# LAT                    0
# LON                    0
# dtype: int64

# %% [markdown]
# Comprobamos las dimensiones de la tabla y los valores únicos de DR_NO ya que sospecho que debe ser el índice

# %%
dimensiones_df = df.shape
print(f'Dimensiones df: ', dimensiones_df)
# Out:
# Dimensiones df:  (331647, 28)

# %%
DR_NO = df.DR_NO.nunique()
print(f'Valores únicos de DR_NO: ', DR_NO)
# Out:
# Valores únicos de DR_NO:  331647

# %% [markdown]
# CAMBIOS EN NOMBRES E ÍNDICE:
# - Transformamos a minúsculas los nombres de las columnas
# - Ponemos 'dr_no' como index ya que es el identificador del reporte

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.columns = df.columns.str.replace('-','_')
df = df.set_index('dr_no')
df
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 201812425  06/11/2020 12:00:00 AM  06/07/2020 12:00:00 AM      2300    18
# 200705197  01/23/2020 12:00:00 AM  01/13/2020 12:00:00 AM      1130     7
# 201912165  07/15/2020 12:00:00 AM  07/14/2020 12:00:00 AM      2200    19
# 201317843  10/02/2020 12:00:00 AM  10/02/2020 12:00:00 AM      1130    13
# 201608441  04/21/2020 12:00:00 AM  04/21/2020 12:00:00 AM       139    16
# ...                           ...                     ...       ...   ...
# 240806981  03/15/2024 12:00:00 AM  03/15/2024 12:00:00 AM      1500     8
# 240510863  08/23/2024 12:00:00 AM  08/22/2024 12:00:00 AM       100     5
# 241411186  06/06/2024 12:00:00 AM  06/06/2024 12:00:00 AM      1531    14
# 241907340  04/01/2024 12:00:00 AM  03/31/2024 12:00:00 AM       200    19
# 240113008  06/18/2024 12:00:00 AM  06/17/2024 12:00:00 AM      1855     1
#
#            area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 201812425  Southeast         1829         1     420
# 200705197   Wilshire          777         2     930
# 201912165    Mission         1985         1     510
# 201317843     Newton         1371         1     236
# 201608441   Foothill         1619         1     648
# ...              ...          ...       ...     ...
# 240806981    West LA          841         1     230
# 240510863     Harbor          505         2     745
# 241411186    Pacific         1485         1     442
# 241907340    Mission         1906         1     230
# 240113008    Central          161         1     442
#
#                                                crm_cd_desc  \
# dr_no
# 201812425  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 200705197           CRIMINAL THREATS - NO WEAPON DISPLAYED
# 201912165                                 VEHICLE - STOLEN
# 201317843            INTIMATE PARTNER - AGGRAVATED ASSAULT
# 201608441                                            ARSON
# ...                                                    ...
# 240806981   ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 240510863         VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 241411186         SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 241907340   ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 240113008         SHOPLIFTING - PETTY THEFT ($950 & UNDER)
#
#                             mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 201812425       1822 1300 0344 1202        66        F            H
# 200705197                 0601 0443        53        F            B
# 201912165                       NaN         0      NaN          NaN
# 201317843  0913 1813 2000 0408 0448        21        F            B
# 201608441                       NaN        71        F            X
# ...                             ...       ...      ...          ...
# 240806981            0416 0334 1822        31        M            W
# 240510863                      0329         0        M            O
# 241411186                      0325         0        X            X
# 241907340       0445 0561 0913 1817        28        M            H
# 240113008                      0325        27        M            B
#
#            premis_cd             premis_desc  weapon_used_cd  \
# dr_no
# 201812425      108.0             PARKING LOT           500.0
# 200705197      501.0  SINGLE FAMILY DWELLING           511.0
# 201912165      101.0                  STREET             NaN
# 201317843      501.0  SINGLE FAMILY DWELLING           400.0
# 201608441      501.0  SINGLE FAMILY DWELLING             NaN
# ...              ...                     ...             ...
# 240806981      102.0                SIDEWALK           312.0
# 240510863      702.0  OFFICE BUILDING/OFFICE             NaN
# 241411186      405.0          CLOTHING STORE             NaN
# 241907340      501.0  SINGLE FAMILY DWELLING           207.0
# 240113008      404.0        DEPARTMENT STORE             NaN
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 201812425                     UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont
# 200705197                                   VERBAL THREAT     AO  Adult Other
# 201912165                                             NaN     IC  Invest Cont
# 201317843  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 201608441                                             NaN     IC  Invest Cont
# ...                                                   ...    ...          ...
# 240806981                                 PIPE/METAL PIPE     IC  Invest Cont
# 240510863                                             NaN     IC  Invest Cont
# 241411186                                             NaN     IC  Invest Cont
# 241907340                                     OTHER KNIFE     AO  Adult Other
# 240113008                                             NaN     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 201812425     420.0       NaN       NaN       NaN
# 200705197     930.0       NaN       NaN       NaN
# 201912165     510.0       NaN       NaN       NaN
# 201317843     236.0       NaN       NaN       NaN
# 201608441     648.0       NaN       NaN       NaN
# ...             ...       ...       ...       ...
# 240806981     230.0       NaN       NaN       NaN
# 240510863     745.0       NaN       NaN       NaN
# 241411186     442.0       NaN       NaN       NaN
# 241907340     230.0       NaN       NaN       NaN
# 240113008     442.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 201812425   2100 E  102ND                        ST          NaN  33.9439
# 200705197   1600    WEST                         BL          NaN  34.0452
# 201912165   8800    TOBIAS                       AV          NaN  34.2299
# 201317843    100 W  57TH                         ST          NaN  33.9906
# 201608441  10700    LAS LUNITAS                  AV          NaN  34.2629
# ...                                             ...          ...      ...
# 240806981  11900    SANTA MONICA                 BL          NaN  34.0423
# 240510863    900    KNOX                         ST          NaN  33.8542
# 241411186   8600 S  SEPULVEDA                    BL          NaN  33.9579
# 241907340  13600    ELDRIDGE                     AV          NaN  34.3188
# 240113008    700 S  FIGUEROA                     ST          NaN  34.0483
#
#                 lon
# dr_no
# 201812425 -118.2346
# 200705197 -118.3351
# 201912165 -118.4517
# 201317843 -118.2745
# 201608441 -118.2913
# ...             ...
# 240806981 -118.4656
# 240510863 -118.2905
# 241411186 -118.4020
# 241907340 -118.4257
# 240113008 -118.2631
#
# [331647 rows x 27 columns]

# %% [markdown]
# ## 3. SIGNIFICADO Y FORMATO DE LAS COLUMNAS

# %% [markdown]
# Ya sabemos que podemos trabajar con el dataset y lo tenemos cargado con los nombre de las columnas en su formato correto
#
# Significado de las columnas:
# - dr_no: Número de expediente oficial compuesto por un año de 2 dígitos, un ID de área y 5 dígitos.
# - date_rptd: Fecha de Reporte. Indica el día en que el crimen o incidente fue oficialmente reportado (MM/DD/AAAA)
# - date_occ: Fecha de Ocurrencia. Indica el día real en que el crimen tuvo lugar (MM/DD/AAAA)
# - time_occ: Hora de Ocurrencia en horario militar de 24 horas.
# - area: Áreas Geográficas o Divisiones de Patrulla numeradas secuencialmente del 1 al 21.
# - area_name: Nombre de las áreas Geográficas o Divisiones de Patrulla
# - rpt_dist_no: Número de distrito de la patrulla del oficial que informó el incidente.
# - part_1_2: Indica si el incidente es un crimen de la Parte 1 (crímenes más graves) o de la Parte 2 (crímenes menos graves).
# - crm_cd: Código de delito de 3 dígitos del crimen cometido.
# - crm_cd_desc: Descripción del delito del crimen cometido.
# - mocodes: Modus Operandi o la manera distintiva o característica en que una persona lleva a cabo una actividad criminal.
# - vict_age: Edad de la víctima
# - vict_sex: Sexo de la víctima.
# - vict_descent: Código de descendencia de la víctima
# - premis_cd: El Código de Instalación es un código de 3 dígitos que identifica el tipo de lugar donde ocurrió el incidente
# - premis_desc: Descripción de la Instalación.
# - weapon_used_cd: El Código de Arma es un código de 3 dígitos que identifica el tipo de arma utilizada en el incidente
# - weapon_desc: Descripción del Arma.
# - status: Estado del caso. (IC es el valor predeterminado)
# - status_desc: Define el Código de Estado proporcionado.
# - crm_cd_1: Indica el crimen cometido. El Código de Crimen 1 es el principal y el más grave. Los Códigos de Crimen 2, 3 y 4 son, respectivamente, delitos menos graves. Los números de clase de crimen más bajos son más graves.
# - crm_cd_2: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_3: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_4: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - location: Dirección postal del incidente del crimen redondeada al centenar de la cuadra más cercana para mantener el anonimato.
# - cross_street: El nombre de la calle que se cruza con la calle principal donde ocurrió el incidente.
# - lat: Latitud.
# - lon: Longitud.
#
# Códigos de descendencia:
# - A: Otros Asiáticos
# - B: Afroamericano
# - C: Chino
# - D: Camboyano
# - F: Filipino
# - G: Guamés
# - H: Hispano/Latino/Mexicano
# - I: Indio Americano/Nativo de Alaska
# - J: Japonés
# - K: Coreano
# - L: Laosiano
# - O: Otro
# - P: Isleño del Pacífico
# - S: Samoano
# - U: Hawaiano
# - V: Vietnamita
# - W: Blanco
# - X: Desconocido
# - Z: Hindú Asiático

# %% [markdown]
# Revisamos los tipos de datos de cada variable observando entre el .info() y la viasualización de la propia tabla y no se requieren cambios
#
# También observamos en el count que hay nulos en varias columnas que trataremos posteriormente

# %%
pd.set_option('display.max_columns', None)
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 242008097  04/06/2024 12:00:00 AM  04/06/2024 12:00:00 AM       415    20
#
#           area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 242008097   Olympic         2033         1     331
#
#                                                  crm_cd_desc  \
# dr_no
# 242008097  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
#
#                        mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 242008097  1602 0344 0385 1822        22        M            H      101.0
#
#           premis_desc  weapon_used_cd weapon_desc status  status_desc  \
# dr_no
# 242008097      STREET             NaN         NaN     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 242008097     331.0       NaN       NaN       NaN
#
#                                          location cross_street      lat  \
# dr_no
# 242008097  900 S  HOBART                       BL          NaN  34.0559
#
#                 lon
# dr_no
# 242008097 -118.3053

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 201812425 to 240113008
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  object
#  1   date_occ        331647 non-null  object
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  int64
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  int64
#  6   part_1_2        331647 non-null  int64
#  7   crm_cd          331647 non-null  int64
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281113 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        283384 non-null  object
#  12  vict_descent    283383 non-null  object
#  13  premis_cd       331643 non-null  float64
#  14  premis_desc     331468 non-null  object
#  15  weapon_used_cd  107863 non-null  float64
#  16  weapon_desc     107863 non-null  object
#  17  status          331647 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331644 non-null  float64
#  20  crm_cd_2        22715 non-null   float64
#  21  crm_cd_3        765 non-null     float64
#  22  crm_cd_4        27 non-null      float64
#  23  location        331647 non-null  object
#  24  cross_street    50995 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
# dtypes: float64(8), int64(6), object(13)
# memory usage: 70.8+ MB

# %% [markdown]
# ## 4. TRATAMIENTO DE VARIABLES
#
# ### FORMATO DE VARIABLES

# %% [markdown]
# Las columnas 'date_rptd' y 'date_occ' vamos a eliminar la hora porque en todos los registros nos dicen que ha sido a las '12:00:00 AM'. Esta información es errónea según la columna 'time_occ' y además no nos aporta información como variable porque es una constante en todos los registros

# %%
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 221808598  04/04/2022 12:00:00 AM  04/02/2022 12:00:00 AM         1    18
#
#            area_name  rpt_dist_no  part_1_2  crm_cd        crm_cd_desc  \
# dr_no
# 221808598  Southeast         1846         2     354  THEFT OF IDENTITY
#
#                   mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 221808598  0100 1822 0935        54        F            H      501.0
#
#                       premis_desc  weapon_used_cd weapon_desc status  \
# dr_no
# 221808598  SINGLE FAMILY DWELLING             NaN         NaN     IC
#
#            status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 221808598  Invest Cont     354.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 221808598  1300 E  115TH                        ST          NaN  33.9303
#
#                 lon
# dr_no
# 221808598 -118.2518

# %% [markdown]
# Eliminamos la parte de la hora

# %%
df['date_rptd'] = df['date_rptd'].str.split(' ').str[0]
df['date_occ'] = df['date_occ'].str.split(' ').str[0]

# %%
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area   area_name  rpt_dist_no  \
# dr_no
# 241714063  11/06/2024  11/06/2024      1200    17  Devonshire         1754
#
#            part_1_2  crm_cd                                      crm_cd_desc  \
# dr_no
# 241714063         1     420  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#           mocodes  vict_age vict_sex vict_descent  premis_cd  premis_desc  \
# dr_no
# 241714063     NaN         0      NaN          NaN      108.0  PARKING LOT
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 241714063             NaN         NaN     IC  Invest Cont     420.0       NaN
#
#            crm_cd_3  crm_cd_4                                  location  \
# dr_no
# 241714063       NaN       NaN  10100    RESEDA                       BL
#
#           cross_street      lat       lon
# dr_no
# 241714063          NaN  34.2533 -118.5361

# %% [markdown]
# Separamos la composición de las fechas con formato '%m/%d/%Y' de las columnas 'date_rptd' y 'date_occ' en una columna para los años, otra para meses y otra para días

# %%
df['year_rptd'] = df['date_rptd'].str.split('/').str[2]
df['month_rptd'] = df['date_rptd'].str.split('/').str[0]
df['day_rptd'] = df['date_rptd'].str.split('/').str[1]
df['year_occ'] = df['date_occ'].str.split('/').str[2]
df['month_occ'] = df['date_occ'].str.split('/').str[0]
df['day_occ'] = df['date_occ'].str.split('/').str[1]
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area    area_name  rpt_dist_no  \
# dr_no
# 211225568  12/23/2021  12/22/2021      2200    12  77th Street         1232
#
#            part_1_2  crm_cd                         crm_cd_desc  \
# dr_no
# 211225568         1     440  THEFT PLAIN - PETTY ($950 & UNDER)
#
#                   mocodes  vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 211225568  0344 0346 1822        64        F            B      301.0
#
#            premis_desc  weapon_used_cd weapon_desc status  status_desc  \
# dr_no
# 211225568  GAS STATION             NaN         NaN     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 211225568     440.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 211225568  5800    CRENSHAW                     BL          NaN  33.9886
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ
# dr_no
# 211225568 -118.3307      2021         12       23     2021        12      22

# %% [markdown]
# Hacemos un datetime de las columnas de fechas

# %%
df['date_rptd'] = pd.to_datetime(df['date_rptd'], dayfirst=False, format='%m/%d/%Y')
df['date_occ'] = pd.to_datetime(df['date_occ'], dayfirst=False, format='%m/%d/%Y')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 201812425 to 240113008
# Data columns (total 33 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  datetime64[ns]
#  1   date_occ        331647 non-null  datetime64[ns]
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  int64
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  int64
#  6   part_1_2        331647 non-null  int64
#  7   crm_cd          331647 non-null  int64
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281113 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        283384 non-null  object
#  12  vict_descent    283383 non-null  object
#  13  premis_cd       331643 non-null  float64
#  14  premis_desc     331468 non-null  object
#  15  weapon_used_cd  107863 non-null  float64
#  16  weapon_desc     107863 non-null  object
#  17  status          331647 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331644 non-null  float64
#  20  crm_cd_2        22715 non-null   float64
#  21  crm_cd_3        765 non-null     float64
#  22  crm_cd_4        27 non-null      float64
#  23  location        331647 non-null  object
#  24  cross_street    50995 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
#  27  year_rptd       331647 non-null  object
#  28  month_rptd      331647 non-null  object
#  29  day_rptd        331647 non-null  object
#  30  year_occ        331647 non-null  object
#  31  month_occ       331647 non-null  object
#  32  day_occ         331647 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(6), object(17)
# memory usage: 86.0+ MB

# %% [markdown]
# Generamos una columna calculada con la diferencia de tiempo (en días) entre que se comete el delito y se denuncia

# %%
df['time_to_report'] = (df['date_rptd'] - df['date_occ']).dt.days.astype(int)
df.time_to_report.describe()
# Out:
# count    331647.000000
# mean         12.189337
# std          69.333968
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max        1796.000000
# Name: time_to_report, dtype: float64

# %% [markdown]
# Generamos una columna para obtener la hora de ocurrencia de los delitos

# %%
df["hour_occ"] = df["time_occ"] // 100
df.hour_occ.nunique()
# Out:
# 24

# %% [markdown]
# Vamos a mapear los códigos de 'vict_descent' con el significado que nos dieron en la información del dataset para que sea mas visual

# %%
map_vict_descent = {
    "A": "Otros Asiáticos",
    "B": "Afroamericano",
    "C": "Chino",
    "D": "Camboyano",
    "F": "Filipino",
    "G": "Guamés",
    "H": "Hispano/Latino/Mexicano",
    "I": "Indio Americano/Nativo de Alaska",
    "J": "Japonés",
    "K": "Coreano",
    "L": "Laosiano",
    "O": "Otro",
    "P": "Isleño del Pacífico",
    "S": "Samoano",
    "U": "Hawaiano",
    "V": "Vietnamita",
    "W": "Blanco",
    "X": "Desconocido",
    "Z": "Hindú Asiático"
}

df["vict_descent"] = df["vict_descent"].map(map_vict_descent)
df.head()
# Out:
#            date_rptd   date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 201812425 2020-06-11 2020-06-07      2300    18  Southeast         1829
# 200705197 2020-01-23 2020-01-13      1130     7   Wilshire          777
# 201912165 2020-07-15 2020-07-14      2200    19    Mission         1985
# 201317843 2020-10-02 2020-10-02      1130    13     Newton         1371
# 201608441 2020-04-21 2020-04-21       139    16   Foothill         1619
#
#            part_1_2  crm_cd                                      crm_cd_desc  \
# dr_no
# 201812425         1     420  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 200705197         2     930           CRIMINAL THREATS - NO WEAPON DISPLAYED
# 201912165         1     510                                 VEHICLE - STOLEN
# 201317843         1     236            INTIMATE PARTNER - AGGRAVATED ASSAULT
# 201608441         1     648                                            ARSON
#
#                             mocodes  vict_age vict_sex  \
# dr_no
# 201812425       1822 1300 0344 1202        66        F
# 200705197                 0601 0443        53        F
# 201912165                       NaN         0      NaN
# 201317843  0913 1813 2000 0408 0448        21        F
# 201608441                       NaN        71        F
#
#                       vict_descent  premis_cd             premis_desc  \
# dr_no
# 201812425  Hispano/Latino/Mexicano      108.0             PARKING LOT
# 200705197            Afroamericano      501.0  SINGLE FAMILY DWELLING
# 201912165                      NaN      101.0                  STREET
# 201317843            Afroamericano      501.0  SINGLE FAMILY DWELLING
# 201608441              Desconocido      501.0  SINGLE FAMILY DWELLING
#
#            weapon_used_cd                                     weapon_desc  \
# dr_no
# 201812425           500.0                     UNKNOWN WEAPON/OTHER WEAPON
# 200705197           511.0                                   VERBAL THREAT
# 201912165             NaN                                             NaN
# 201317843           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 201608441             NaN                                             NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 201812425     IC  Invest Cont     420.0       NaN       NaN       NaN
# 200705197     AO  Adult Other     930.0       NaN       NaN       NaN
# 201912165     IC  Invest Cont     510.0       NaN       NaN       NaN
# 201317843     IC  Invest Cont     236.0       NaN       NaN       NaN
# 201608441     IC  Invest Cont     648.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 201812425   2100 E  102ND                        ST          NaN  33.9439
# 200705197   1600    WEST                         BL          NaN  34.0452
# 201912165   8800    TOBIAS                       AV          NaN  34.2299
# 201317843    100 W  57TH                         ST          NaN  33.9906
# 201608441  10700    LAS LUNITAS                  AV          NaN  34.2629
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 201812425 -118.2346      2020         06       11     2020        06      07
# 200705197 -118.3351      2020         01       23     2020        01      13
# 201912165 -118.4517      2020         07       15     2020        07      14
# 201317843 -118.2745      2020         10       02     2020        10      02
# 201608441 -118.2913      2020         04       21     2020        04      21
#
#            time_to_report  hour_occ
# dr_no
# 201812425               4        23
# 200705197              10        11
# 201912165               1        22
# 201317843               0        11
# 201608441               0         1

# %%
df["vict_descent"].unique()
# Out:
# array(['Hispano/Latino/Mexicano', 'Afroamericano', nan, 'Desconocido',
#        'Blanco', 'Otros Asiáticos', 'Otro', 'Chino', 'Coreano',
#        'Filipino', 'Japonés', 'Vietnamita',
#        'Indio Americano/Nativo de Alaska', 'Laosiano', 'Hawaiano',
#        'Hindú Asiático', 'Isleño del Pacífico', 'Guamés', 'Samoano',
#        'Camboyano'], dtype=object)

# %% [markdown]
# Cambiamos el formato de ciertas columnas para que nos sirvan para hacer los análisis
#
# Nota. En el EDA hemos detectado que necesitamos dejar 'crm_cd_1' y 'crm_cd_2' como float hasta hacer las transformaciones necesarias y después lo pasaremos a category

# %%
#Cambiar formatos manualmente
df = df.astype({'part_1_2':'category',
                'rpt_dist_no':'object',
                #'crm_cd_1':'category',
                #'crm_cd_2':'category',
                'crm_cd_3':'category',
                'crm_cd_4':'category',
                'crm_cd':'category',
                'area':'category',
                'weapon_used_cd':'category',
                'premis_cd':'category',
                'year_rptd':'object',
                'month_rptd':'object',
                'day_rptd':'object',
                'year_occ':'object',
                'year_occ':'object',
                'year_occ':'object',
                'hour_occ':'object'
                })

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 201812425 to 240113008
# Data columns (total 35 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  datetime64[ns]
#  1   date_occ        331647 non-null  datetime64[ns]
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  category
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  object
#  6   part_1_2        331647 non-null  category
#  7   crm_cd          331647 non-null  category
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281113 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        283384 non-null  object
#  12  vict_descent    283383 non-null  object
#  13  premis_cd       331643 non-null  category
#  14  premis_desc     331468 non-null  object
#  15  weapon_used_cd  107863 non-null  category
#  16  weapon_desc     107863 non-null  object
#  17  status          331647 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331644 non-null  float64
#  20  crm_cd_2        22715 non-null   float64
#  21  crm_cd_3        765 non-null     category
#  22  crm_cd_4        27 non-null      category
#  23  location        331647 non-null  object
#  24  cross_street    50995 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
#  27  year_rptd       331647 non-null  object
#  28  month_rptd      331647 non-null  object
#  29  day_rptd        331647 non-null  object
#  30  year_occ        331647 non-null  object
#  31  month_occ       331647 non-null  object
#  32  day_occ         331647 non-null  object
#  33  time_to_report  331647 non-null  int64
#  34  hour_occ        331647 non-null  object
# dtypes: category(7), datetime64[ns](2), float64(4), int64(3), object(19)
# memory usage: 76.2+ MB

# %% [markdown]
# Camabiamos la posición de las columnas para una visualización mas cómoda

# %%
#Sacamos una lista de todas las columnas
list(df.columns)
# Out:
# ['date_rptd',
#  'date_occ',
#  'time_occ',
#  'area',
#  'area_name',
#  'rpt_dist_no',
#  'part_1_2',
#  'crm_cd',
#  'crm_cd_desc',
#  'mocodes',
#  'vict_age',
#  'vict_sex',
#  'vict_descent',
#  'premis_cd',
#  'premis_desc',
#  'weapon_used_cd',
#  'weapon_desc',
#  'status',
#  'status_desc',
#  'crm_cd_1',
#  'crm_cd_2',
#  'crm_cd_3',
#  'crm_cd_4',
#  'location',
#  'cross_street',
#  'lat',
#  'lon',
#  'year_rptd',
#  'month_rptd',
#  'day_rptd',
#  'year_occ',
#  'month_occ',
#  'day_occ',
#  'time_to_report',
#  'hour_occ']

# %%
#Extraemos las columnas que queremos modificar y las ponemos en el orden que queremos que aparezcan
reorden = ['date_rptd','date_occ','time_to_report']

#Hacemos una lista con el resto de columnas 
resto = df.drop(columns = reorden).columns.to_list()
resto

#Agregamos ambas listas
orden = reorden + resto

df = df[orden]
df.head(5)
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area  area_name  \
# dr_no
# 201812425 2020-06-11 2020-06-07               4      2300   18  Southeast
# 200705197 2020-01-23 2020-01-13              10      1130    7   Wilshire
# 201912165 2020-07-15 2020-07-14               1      2200   19    Mission
# 201317843 2020-10-02 2020-10-02               0      1130   13     Newton
# 201608441 2020-04-21 2020-04-21               0       139   16   Foothill
#
#           rpt_dist_no part_1_2 crm_cd  \
# dr_no
# 201812425        1829        1    420
# 200705197         777        2    930
# 201912165        1985        1    510
# 201317843        1371        1    236
# 201608441        1619        1    648
#
#                                                crm_cd_desc  \
# dr_no
# 201812425  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 200705197           CRIMINAL THREATS - NO WEAPON DISPLAYED
# 201912165                                 VEHICLE - STOLEN
# 201317843            INTIMATE PARTNER - AGGRAVATED ASSAULT
# 201608441                                            ARSON
#
#                             mocodes  vict_age vict_sex  \
# dr_no
# 201812425       1822 1300 0344 1202        66        F
# 200705197                 0601 0443        53        F
# 201912165                       NaN         0      NaN
# 201317843  0913 1813 2000 0408 0448        21        F
# 201608441                       NaN        71        F
#
#                       vict_descent premis_cd             premis_desc  \
# dr_no
# 201812425  Hispano/Latino/Mexicano     108.0             PARKING LOT
# 200705197            Afroamericano     501.0  SINGLE FAMILY DWELLING
# 201912165                      NaN     101.0                  STREET
# 201317843            Afroamericano     501.0  SINGLE FAMILY DWELLING
# 201608441              Desconocido     501.0  SINGLE FAMILY DWELLING
#
#           weapon_used_cd                                     weapon_desc  \
# dr_no
# 201812425          500.0                     UNKNOWN WEAPON/OTHER WEAPON
# 200705197          511.0                                   VERBAL THREAT
# 201912165            NaN                                             NaN
# 201317843          400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 201608441            NaN                                             NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 201812425     IC  Invest Cont     420.0       NaN      NaN      NaN
# 200705197     AO  Adult Other     930.0       NaN      NaN      NaN
# 201912165     IC  Invest Cont     510.0       NaN      NaN      NaN
# 201317843     IC  Invest Cont     236.0       NaN      NaN      NaN
# 201608441     IC  Invest Cont     648.0       NaN      NaN      NaN
#
#                                            location cross_street      lat  \
# dr_no
# 201812425   2100 E  102ND                        ST          NaN  33.9439
# 200705197   1600    WEST                         BL          NaN  34.0452
# 201912165   8800    TOBIAS                       AV          NaN  34.2299
# 201317843    100 W  57TH                         ST          NaN  33.9906
# 201608441  10700    LAS LUNITAS                  AV          NaN  34.2629
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 201812425 -118.2346      2020         06       11     2020        06      07
# 200705197 -118.3351      2020         01       23     2020        01      13
# 201912165 -118.4517      2020         07       15     2020        07      14
# 201317843 -118.2745      2020         10       02     2020        10      02
# 201608441 -118.2913      2020         04       21     2020        04      21
#
#           hour_occ
# dr_no
# 201812425       23
# 200705197       11
# 201912165       22
# 201317843       11
# 201608441        1

# %% [markdown]
# ### DUPLICADOS
#
# Comprobamos si hay duplicados y hacemos comparaciones para asegurarnos

# %%
duplicados = df.duplicated().sum()
print(f'Recuento de duplicados en df: ', duplicados)
# Out:
# Recuento de duplicados en df:  371

# %% [markdown]
# Nos salen que hay duplicados de las 27 columnas y que solamente es diferente el índice. Hacemos unas visualizaciones para comprobar que son realmente duplicados y vemos que es cierto, por lo que borramos todos los duplicados

# %%
lineas_original = len(df)
lineas_original
# Out:
# 331647

# %%
df.loc[df.duplicated()].head(2)
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area area_name  \
# dr_no
# 201916940 2020-11-15 2020-11-14               1      1830   19   Mission
# 201916697 2020-11-08 2020-11-08               0       155   19   Mission
#
#           rpt_dist_no part_1_2 crm_cd       crm_cd_desc              mocodes  \
# dr_no
# 201916940        1944        1    510  VEHICLE - STOLEN                  NaN
# 201916697        1935        1    310          BURGLARY  1607 0344 0216 0209
#
#            vict_age vict_sex vict_descent premis_cd     premis_desc  \
# dr_no
# 201916940         0      NaN          NaN     108.0     PARKING LOT
# 201916697         0        M         Otro     221.0  PUBLIC STORAGE
#
#           weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 201916940            NaN         NaN     IC  Invest Cont     510.0       NaN
# 201916697            NaN         NaN     IC  Invest Cont     310.0       NaN
#
#           crm_cd_3 crm_cd_4                                  location  \
# dr_no
# 201916940      NaN      NaN  11400    SAN FERNANDO                 RD
# 201916697      NaN      NaN  15200    BRAND                        BL
#
#           cross_street      lat       lon year_rptd month_rptd day_rptd  \
# dr_no
# 201916940          NaN  34.2786 -118.4359      2020         11       15
# 201916697          NaN  34.2719 -118.4592      2020         11       08
#
#           year_occ month_occ day_occ hour_occ
# dr_no
# 201916940     2020        11      14       18
# 201916697     2020        11      08        1

# %%
# Buscamos una en concreto por hacer la comprobación
df.loc[(df.mocodes == '0421 1528 1822 0903 2053')]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area area_name  \
# dr_no
# 220706179 2022-02-26 2022-02-26               0      1200    7  Wilshire
# 220706176 2022-02-26 2022-02-26               0      1200    7  Wilshire
# 220706178 2022-02-26 2022-02-26               0      1200    7  Wilshire
#
#           rpt_dist_no part_1_2 crm_cd                             crm_cd_desc  \
# dr_no
# 220706179         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706176         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706178         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
#
#                             mocodes  vict_age vict_sex vict_descent premis_cd  \
# dr_no
# 220706179  0421 1528 1822 0903 2053         0        F         Otro     501.0
# 220706176  0421 1528 1822 0903 2053         0        F         Otro     501.0
# 220706178  0421 1528 1822 0903 2053         0        M         Otro     501.0
#
#                       premis_desc weapon_used_cd    weapon_desc status  \
# dr_no
# 220706179  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
# 220706176  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
# 220706178  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
#
#            status_desc  crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 220706179  Invest Cont     930.0     946.0      NaN      NaN
# 220706176  Invest Cont     930.0     946.0      NaN      NaN
# 220706178  Invest Cont     930.0     946.0      NaN      NaN
#
#                                           location cross_street      lat  \
# dr_no
# 220706179  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706176  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706178  1100 S  ORLANDO                      AV          NaN  34.0572
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 220706179 -118.3739      2022         02       26     2022        02      26
# 220706176 -118.3739      2022         02       26     2022        02      26
# 220706178 -118.3739      2022         02       26     2022        02      26
#
#           hour_occ
# dr_no
# 220706179       12
# 220706176       12
# 220706178       12

# %% [markdown]
# Eliminamos los duplicados

# %%
df.drop_duplicates(inplace=True)

# %%
lineas_despues = len(df)

diff = lineas_original - lineas_despues

print("Filas antes:", lineas_original)
print("Filas después:", lineas_despues)
print("Diferencia:", diff)
# Out:
# Filas antes: 331647
# Filas después: 331276
# Diferencia: 371

# %% [markdown]
# ### VALORES ÚNICOS
#
# Comprobamos los valores únicos en la tabla para desestimar variables. En este caso, no hay constantes

# %%
df.nunique().sort_values(ascending=True)

# Si hubiera alguna columna que eliminar haríamos df.drop(columns = '...', inplace=True)
# Out:
# part_1_2               2
# crm_cd_4               2
# vict_sex               4
# status_desc            6
# year_occ               6
# status                 6
# year_rptd              6
# month_rptd            12
# month_occ             12
# vict_descent          19
# area_name             21
# area                  21
# hour_occ              24
# crm_cd_3              26
# day_rptd              31
# day_occ               31
# weapon_used_cd        76
# weapon_desc           76
# vict_age             103
# crm_cd_2             105
# crm_cd_desc          137
# crm_cd               137
# crm_cd_1             139
# premis_desc          298
# premis_cd            304
# rpt_dist_no         1164
# time_to_report      1180
# time_occ            1439
# date_occ            1856
# date_rptd           1870
# lon                 4875
# lat                 5191
# cross_street        6574
# location           50658
# mocodes           116953
# dtype: int64

# %% [markdown]
# ### VALORES NULOS
#
# Comprobamos los nulos que existen según el tipo de columna: Categórica y numérica
#
# Primero haremos las comprobaciones, después expondré las conclusiones y a continuación realizaré los cambios

# %%
df.select_dtypes(include='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_2          308572
# crm_cd_1               3
# time_to_report         0
# vict_age               0
# time_occ               0
# lat                    0
# lon                    0
# dtype: int64

# %%
df.select_dtypes(exclude='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_4          331249
# crm_cd_3          330511
# cross_street      280342
# weapon_used_cd    223544
# weapon_desc       223544
# mocodes            50386
# vict_descent       48119
# vict_sex           48118
# premis_desc          179
# premis_cd              4
# area_name              0
# area                   0
# rpt_dist_no            0
# part_1_2               0
# crm_cd                 0
# crm_cd_desc            0
# date_rptd              0
# date_occ               0
# status_desc            0
# status                 0
# location               0
# year_rptd              0
# month_rptd             0
# day_rptd               0
# year_occ               0
# month_occ              0
# day_occ                0
# hour_occ               0
# dtype: int64

# %%
df.vict_descent.unique()
# Out:
# array(['Hispano/Latino/Mexicano', 'Afroamericano', nan, 'Desconocido',
#        'Blanco', 'Otros Asiáticos', 'Otro', 'Chino', 'Coreano',
#        'Filipino', 'Japonés', 'Vietnamita',
#        'Indio Americano/Nativo de Alaska', 'Laosiano', 'Hawaiano',
#        'Hindú Asiático', 'Isleño del Pacífico', 'Guamés', 'Samoano',
#        'Camboyano'], dtype=object)

# %%
df.loc[df.vict_descent=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_to_report, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon, year_rptd, month_rptd, day_rptd, year_occ, month_occ, day_occ, hour_occ]
# Index: []

# %%
df.vict_sex.unique()
# Out:
# array(['F', nan, 'M', 'X', 'H'], dtype=object)

# %%
df.loc[df.vict_sex=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_to_report, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon, year_rptd, month_rptd, day_rptd, year_occ, month_occ, day_occ, hour_occ]
# Index: []

# %%
df.loc[(df.premis_cd.notna())&(df.premis_desc.isna())].premis_cd.value_counts()
# Out:
# premis_cd
# 418.0    114
# 256.0     49
# 972.0      8
# 973.0      2
# 975.0      1
#         ...
# 150.0      0
# 151.0      0
# 152.0      0
# 154.0      0
# 106.0      0
# Name: count, Length: 304, dtype: int64

# %%
df.loc[(df.crm_cd_1.isna())]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area area_name  \
# dr_no
# 200116522 2020-08-17 2020-08-17               0       545    1   Central
# 230114704 2023-06-22 2023-06-22               0      1801    1   Central
# 230114706 2023-06-22 2023-06-22               0      1550    1   Central
#
#           rpt_dist_no part_1_2 crm_cd  \
# dr_no
# 200116522         176        2    745
# 230114704         162        1    442
# 230114706         155        2    623
#
#                                         crm_cd_desc              mocodes  \
# dr_no
# 200116522  VANDALISM - MISDEAMEANOR ($399 OR UNDER)       0329 2004 1601
# 230114704  SHOPLIFTING - PETTY THEFT ($950 & UNDER)                 0325
# 230114706                   BATTERY POLICE (SIMPLE)  1212 0917 0447 2004
#
#            vict_age vict_sex             vict_descent premis_cd  \
# dr_no
# 200116522         0        X              Desconocido     203.0
# 230114704        25        M  Hispano/Latino/Mexicano     404.0
# 230114706         0        M  Hispano/Latino/Mexicano     726.0
#
#                 premis_desc weapon_used_cd  \
# dr_no
# 200116522    OTHER BUSINESS          400.0
# 230114704  DEPARTMENT STORE            NaN
# 230114706   POLICE FACILITY          500.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 200116522  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 230114704                                             NaN     IC  Invest Cont
# 230114706                     UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 200116522       NaN     745.0      NaN      NaN
# 230114704       NaN     442.0      NaN      NaN
# 230114706       NaN     623.0      NaN      NaN
#
#                                          location cross_street      lat  \
# dr_no
# 200116522  800    SANTEE                       ST          NaN  34.0401
# 230114704  700 S  FLOWER                       ST          NaN  34.0487
# 230114706  200 E  6TH                          ST          NaN  34.0448
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 200116522 -118.2533      2020         08       17     2020        08      17
# 230114704 -118.2588      2023         06       22     2023        06      22
# 230114706 -118.2474      2023         06       22     2023        06      22
#
#           hour_occ
# dr_no
# 200116522        5
# 230114704       18
# 230114706       15

# %%
df.loc[(df.status.isna())]
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_to_report, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon, year_rptd, month_rptd, day_rptd, year_occ, month_occ, day_occ, hour_occ]
# Index: []

# %%
df.loc[(df.crm_cd_1 == 510.0)]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area   area_name  \
# dr_no
# 201912165 2020-07-15 2020-07-14               1      2200   19     Mission
# 201408986 2020-03-29 2020-03-27               2      1930   14     Pacific
# 201815136 2020-08-06 2020-08-06               0      1030   18   Southeast
# 201915471 2020-10-09 2020-10-09               0      1720   19     Mission
# 201911378 2020-06-25 2020-06-21               4       400   19     Mission
# ...              ...        ...             ...       ...  ...         ...
# 240709186 2024-06-01 2024-06-01               0       530    7    Wilshire
# 240404028 2024-01-02 2024-01-01               1      1600    4  Hollenbeck
# 240511468 2024-09-21 2024-09-21               0       915    5      Harbor
# 241104553 2024-01-15 2024-01-12               3      1430   11   Northeast
# 241408974 2024-04-24 2024-04-22               2      1330   14     Pacific
#
#           rpt_dist_no part_1_2 crm_cd       crm_cd_desc mocodes  vict_age  \
# dr_no
# 201912165        1985        1    510  VEHICLE - STOLEN     NaN         0
# 201408986        1483        1    510  VEHICLE - STOLEN     NaN         0
# 201815136        1823        1    510  VEHICLE - STOLEN     NaN         0
# 201915471        1981        1    510  VEHICLE - STOLEN     NaN         0
# 201911378        1911        1    510  VEHICLE - STOLEN     NaN         0
# ...               ...      ...    ...               ...     ...       ...
# 240709186         764        1    510  VEHICLE - STOLEN     NaN         0
# 240404028         468        1    510  VEHICLE - STOLEN     NaN         0
# 240511468         528        1    510  VEHICLE - STOLEN     NaN         0
# 241104553        1141        1    510  VEHICLE - STOLEN     NaN         0
# 241408974        1464        1    510  VEHICLE - STOLEN     NaN         0
#
#           vict_sex vict_descent premis_cd  premis_desc weapon_used_cd  \
# dr_no
# 201912165      NaN          NaN     101.0       STREET            NaN
# 201408986      NaN          NaN     101.0       STREET            NaN
# 201815136      NaN          NaN     101.0       STREET            NaN
# 201915471      NaN          NaN     108.0  PARKING LOT            NaN
# 201911378      NaN          NaN     108.0  PARKING LOT            NaN
# ...            ...          ...       ...          ...            ...
# 240709186      NaN          NaN     101.0       STREET            NaN
# 240404028      NaN          NaN     101.0       STREET            NaN
# 240511468      NaN          NaN     101.0       STREET            NaN
# 241104553      NaN          NaN     101.0       STREET            NaN
# 241408974      NaN          NaN     101.0       STREET            NaN
#
#           weapon_desc status  status_desc  crm_cd_1  crm_cd_2 crm_cd_3  \
# dr_no
# 201912165         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201408986         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201815136         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201915471         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201911378         NaN     IC  Invest Cont     510.0       NaN      NaN
# ...               ...    ...          ...       ...       ...      ...
# 240709186         NaN     IC  Invest Cont     510.0       NaN      NaN
# 240404028         NaN     IC  Invest Cont     510.0       NaN      NaN
# 240511468         NaN     IC  Invest Cont     510.0       NaN      NaN
# 241104553         NaN     IC  Invest Cont     510.0       NaN      NaN
# 241408974         NaN     IC  Invest Cont     510.0       NaN      NaN
#
#           crm_cd_4                                  location cross_street  \
# dr_no
# 201912165      NaN   8800    TOBIAS                       AV          NaN
# 201408986      NaN   9300    LINCOLN                      BL          NaN
# 201815136      NaN    200 E  95TH                         ST          NaN
# 201915471      NaN   8700 N  SEPULVEDA                    BL          NaN
# 201911378      NaN  13100    TELFAIR                      AV          NaN
# ...            ...                                       ...          ...
# 240709186      NaN   1400 S  DUNSMUIR                     AV          NaN
# 240404028      NaN   3100 E  1ST                          ST          NaN
# 240511468      NaN   1100    SANFORD                      AV          NaN
# 241104553      NaN   1700 N  BERENDO                      ST          NaN
# 241408974      NaN  12000    WATERFRONT                   DR          NaN
#
#                lat       lon year_rptd month_rptd day_rptd year_occ month_occ  \
# dr_no
# 201912165  34.2299 -118.4517      2020         07       15     2020        07
# 201408986  33.9552 -118.4141      2020         03       29     2020        03
# 201815136  33.9502 -118.2717      2020         08       06     2020        08
# 201915471  34.2267 -118.4704      2020         10       09     2020        10
# 201911378  34.3071 -118.4764      2020         06       25     2020        06
# ...            ...       ...       ...        ...      ...      ...       ...
# 240709186  34.0483 -118.3537      2024         06       01     2024        06
# 240404028  34.0395 -118.2003      2024         01       02     2024        01
# 240511468  33.7853 -118.2506      2024         09       21     2024        09
# 241104553  34.1018 -118.2945      2024         01       15     2024        01
# 241408974  33.9829 -118.4032      2024         04       24     2024        04
#
#           day_occ hour_occ
# dr_no
# 201912165      14       22
# 201408986      27       19
# 201815136      06       10
# 201915471      09       17
# 201911378      21        4
# ...           ...      ...
# 240709186      01        5
# 240404028      01       16
# 240511468      21        9
# 241104553      12       14
# 241408974      22       13
#
# [38366 rows x 35 columns]

# %% [markdown]
# ## 5. GUARDADO DE RESULTADOS

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '002_archivos/'

# %%
ruta_trabajo = ruta_principal + carpeta + 'trabajo_resultado_calidad.pickle'

# %% [markdown]
# Guardar los archivos

# %%
df.to_pickle(ruta_trabajo)
