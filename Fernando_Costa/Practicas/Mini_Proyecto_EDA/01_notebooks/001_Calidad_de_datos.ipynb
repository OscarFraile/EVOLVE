# %% [markdown]
# # CALIDAD DE DATOS

# %% [markdown]
# ## 1. IMPORTAMOS PAQUETES Y DATOS

# %%
import pandas as pd
import zipfile
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
# %config IPCompleter.greedy = True
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Definimos la ruta donde ubicamos los datasets para no tener que estar poniéndola en cada ocasión

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '999_data/'

# %% [markdown]
# Definimos el dataset que vamos a usar

# %%
zip_name = 'Crime_Data_from_2020_to_Present.zip'
csv_filename = 'Crime_Data_from_2020_to_Present.csv'

# %%
zip_path = ruta_principal + carpeta + zip_name

# %% [markdown]
# Cargamos el dataset df

# %%
frac = 0.33
chunksize = 100_000  # ajusta según memoria

rows = []

with zipfile.ZipFile(zip_path) as z:
    with z.open(csv_filename) as f:
        for chunk in pd.read_csv(f, chunksize=chunksize):
            rows.append(chunk.sample(frac=frac))
            
df = pd.concat(rows, ignore_index=True)
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  200114944  07/17/2020 12:00:00 AM  07/16/2020 12:00:00 AM      1400     1
# 1  202007973  03/27/2020 12:00:00 AM  03/26/2020 12:00:00 AM      1400    20
# 2  202114730  10/11/2020 12:00:00 AM  10/11/2020 12:00:00 AM      1956    21
# 3  210704099  01/04/2021 12:00:00 AM  12/23/2020 12:00:00 AM      1800     7
# 4  200511531  07/07/2020 12:00:00 AM  06/29/2020 12:00:00 AM      2000     5
#
#   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Central          111         1     330
# 1   Olympic         2002         1     510
# 2   Topanga         2136         2     624
# 3  Wilshire          711         1     330
# 4    Harbor          529         1     420
#
#                                        Crm Cd Desc  \
# 0                            BURGLARY FROM VEHICLE
# 1                                 VEHICLE - STOLEN
# 2                         BATTERY - SIMPLE ASSAULT
# 3                            BURGLARY FROM VEHICLE
# 4  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#                          Mocodes  Vict Age Vict Sex Vict Descent  Premis Cd  \
# 0  1307 1822 0329 0352 1609 0344        27        F            B      103.0
# 1                            NaN         0      NaN          NaN      108.0
# 2                           0400        36        F            H      502.0
# 3                      0344 1601        51        M            O      101.0
# 4                      1300 0344        66        M            W      122.0
#
#                                     Premis Desc  Weapon Used Cd  \
# 0                                         ALLEY             NaN
# 1                                   PARKING LOT             NaN
# 2  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)           400.0
# 3                                        STREET             NaN
# 4                      VEHICLE, PASSENGER/TRUCK             NaN
#
#                                       Weapon Desc Status  Status Desc  \
# 0                                             NaN     IC  Invest Cont
# 1                                             NaN     IC  Invest Cont
# 2  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 3                                             NaN     IC  Invest Cont
# 4                                             NaN     IC  Invest Cont
#
#    Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  \
# 0     330.0       NaN       NaN       NaN
# 1     510.0       NaN       NaN       NaN
# 2     624.0       NaN       NaN       NaN
# 3     330.0       NaN       NaN       NaN
# 4     420.0       NaN       NaN       NaN
#
#                                   LOCATION Cross Street      LAT       LON
# 0   400    BAMBOO                       LN          NaN  34.0658 -118.2366
# 1   500 N  GRAMERCY                     PL          NaN  34.0803 -118.3125
# 2  7300    MILWOOD                      AV          NaN  34.2029 -118.5943
# 3   400 N  ORLANDO                      AV          NaN  34.0781 -118.3732
# 4  1500    ANCHORAGE                    RD          NaN  33.7672 -118.2414

# %% [markdown]
# ## 2. COMPROBAMOS LAS CARACTERÍSTICAS DEL DATASET

# %%
df.shape
# Out:
# (331647, 28)

# %% [markdown]
# Comprobamos que el dataset tiene nulos y nos sirve para trabajar

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Crm Cd 4          331628
# Crm Cd 3          330877
# Crm Cd 2          308670
# Cross Street      280854
# Weapon Used Cd    223492
# Weapon Desc       223492
# Mocodes            50056
# Vict Descent       47725
# Vict Sex           47722
# Premis Desc          208
# Premis Cd              9
# Crm Cd 1               2
# Status                 1
# Vict Age               0
# Crm Cd                 0
# Crm Cd Desc            0
# AREA NAME              0
# Rpt Dist No            0
# AREA                   0
# TIME OCC               0
# Date Rptd              0
# DATE OCC               0
# DR_NO                  0
# Part 1-2               0
# Status Desc            0
# LOCATION               0
# LAT                    0
# LON                    0
# dtype: int64

# %% [markdown]
# Comprobamos las dimensiones de la tabla y los valores únicos de DR_NO ya que sospecho que debe ser el índice

# %%
dimensiones_df = df.shape
print(f'Dimensiones df: ', dimensiones_df)
# Out:
# Dimensiones df:  (331647, 28)

# %%
DR_NO = df.DR_NO.nunique()
print(f'Valores únicos de DR_NO: ', DR_NO)
# Out:
# Valores únicos de DR_NO:  331647

# %% [markdown]
# CAMBIOS EN NOMBRES E ÍNDICE:
# - Transformamos a minúsculas los nombres de las columnas
# - Ponemos 'dr_no' como index ya que es el identificador del reporte

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.columns = df.columns.str.replace('-','_')
df = df.set_index('dr_no')
df
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 200114944  07/17/2020 12:00:00 AM  07/16/2020 12:00:00 AM      1400     1
# 202007973  03/27/2020 12:00:00 AM  03/26/2020 12:00:00 AM      1400    20
# 202114730  10/11/2020 12:00:00 AM  10/11/2020 12:00:00 AM      1956    21
# 210704099  01/04/2021 12:00:00 AM  12/23/2020 12:00:00 AM      1800     7
# 200511531  07/07/2020 12:00:00 AM  06/29/2020 12:00:00 AM      2000     5
# ...                           ...                     ...       ...   ...
# 241209917  04/11/2024 12:00:00 AM  04/11/2024 12:00:00 AM      1430    12
# 241814866  11/23/2024 12:00:00 AM  11/22/2024 12:00:00 AM      2000    18
# 240113722  06/30/2024 12:00:00 AM  06/30/2024 12:00:00 AM       550     1
# 242111676  09/13/2024 12:00:00 AM  09/12/2024 12:00:00 AM      2150    21
# 240710787  08/18/2024 12:00:00 AM  08/17/2024 12:00:00 AM      1900     7
#
#              area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 200114944      Central          111         1     330
# 202007973      Olympic         2002         1     510
# 202114730      Topanga         2136         2     624
# 210704099     Wilshire          711         1     330
# 200511531       Harbor          529         1     420
# ...                ...          ...       ...     ...
# 241209917  77th Street         1245         2     930
# 241814866    Southeast         1838         1     420
# 240113722      Central          119         2     888
# 242111676      Topanga         2185         1     330
# 240710787     Wilshire          765         1     510
#
#                                                crm_cd_desc  \
# dr_no
# 200114944                            BURGLARY FROM VEHICLE
# 202007973                                 VEHICLE - STOLEN
# 202114730                         BATTERY - SIMPLE ASSAULT
# 210704099                            BURGLARY FROM VEHICLE
# 200511531  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...                                                    ...
# 241209917           CRIMINAL THREATS - NO WEAPON DISPLAYED
# 241814866  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 240113722                                      TRESPASSING
# 242111676                            BURGLARY FROM VEHICLE
# 240710787                                 VEHICLE - STOLEN
#
#                                  mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 200114944  1307 1822 0329 0352 1609 0344        27        F            B
# 202007973                            NaN         0      NaN          NaN
# 202114730                           0400        36        F            H
# 210704099                      0344 1601        51        M            O
# 200511531                      1300 0344        66        M            W
# ...                                  ...       ...      ...          ...
# 241209917                 1402 1309 0443        29        M            H
# 241814866                            NaN         0      NaN          NaN
# 240113722                      1501 0910         0        X            X
# 242111676                      0344 1307        38        F            K
# 240710787                            NaN         0      NaN          NaN
#
#            premis_cd                                   premis_desc  \
# dr_no
# 200114944      103.0                                         ALLEY
# 202007973      108.0                                   PARKING LOT
# 202114730      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 210704099      101.0                                        STREET
# 200511531      122.0                      VEHICLE, PASSENGER/TRUCK
# ...              ...                                           ...
# 241209917      108.0                                   PARKING LOT
# 241814866      101.0                                        STREET
# 240113722      900.0                MTA - RED LINE - UNION STATION
# 242111676      101.0                                        STREET
# 240710787      101.0                                        STREET
#
#            weapon_used_cd                                     weapon_desc  \
# dr_no
# 200114944             NaN                                             NaN
# 202007973             NaN                                             NaN
# 202114730           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 210704099             NaN                                             NaN
# 200511531             NaN                                             NaN
# ...                   ...                                             ...
# 241209917           102.0                                        HAND GUN
# 241814866             NaN                                             NaN
# 240113722             NaN                                             NaN
# 242111676             NaN                                             NaN
# 240710787             NaN                                             NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 200114944     IC  Invest Cont     330.0       NaN       NaN       NaN
# 202007973     IC  Invest Cont     510.0       NaN       NaN       NaN
# 202114730     IC  Invest Cont     624.0       NaN       NaN       NaN
# 210704099     IC  Invest Cont     330.0       NaN       NaN       NaN
# 200511531     IC  Invest Cont     420.0       NaN       NaN       NaN
# ...          ...          ...       ...       ...       ...       ...
# 241209917     AO  Adult Other     930.0     998.0       NaN       NaN
# 241814866     IC  Invest Cont     420.0       NaN       NaN       NaN
# 240113722     IC  Invest Cont     888.0       NaN       NaN       NaN
# 242111676     IC  Invest Cont     330.0       NaN       NaN       NaN
# 240710787     IC  Invest Cont     510.0       NaN       NaN       NaN
#
#                                            location cross_street      lat  \
# dr_no
# 200114944    400    BAMBOO                       LN          NaN  34.0658
# 202007973    500 N  GRAMERCY                     PL          NaN  34.0803
# 202114730   7300    MILWOOD                      AV          NaN  34.2029
# 210704099    400 N  ORLANDO                      AV          NaN  34.0781
# 200511531   1500    ANCHORAGE                    RD          NaN  33.7672
# ...                                             ...          ...      ...
# 241209917                                  FLORENCE    NORMANDIE  33.9746
# 241814866  10700    GRAPE                        ST          NaN  33.9389
# 240113722    800 N  ALAMEDA                      ST          NaN  34.0561
# 242111676   4800    REFORMA                      RD          NaN  34.1559
# 240710787   1200 S  TREMAINE                     AV          NaN  34.0531
#
#                 lon
# dr_no
# 200114944 -118.2366
# 202007973 -118.3125
# 202114730 -118.5943
# 210704099 -118.3732
# 200511531 -118.2414
# ...             ...
# 241209917 -118.3003
# 241814866 -118.2370
# 240113722 -118.2375
# 242111676 -118.6158
# 240710787 -118.3391
#
# [331647 rows x 27 columns]

# %% [markdown]
# ## 3. SIGNIFICADO Y FORMATO DE LAS COLUMNAS

# %% [markdown]
# Ya sabemos que podemos trabajar con el dataset y lo tenemos cargado con los nombre de las columnas en su formato correto
#
# Significado de las columnas:
# - dr_no: Número de expediente oficial compuesto por un año de 2 dígitos, un ID de área y 5 dígitos.
# - date_rptd: Fecha de Reporte. Indica el día en que el crimen o incidente fue oficialmente reportado (MM/DD/AAAA)
# - date_occ: Fecha de Ocurrencia. Indica el día real en que el crimen tuvo lugar (MM/DD/AAAA)
# - time_occ: Hora de Ocurrencia en horario militar de 24 horas.
# - area: Áreas Geográficas o Divisiones de Patrulla numeradas secuencialmente del 1 al 21.
# - area_name: Nombre de las áreas Geográficas o Divisiones de Patrulla
# - rpt_dist_no: Número de distrito de la patrulla del oficial que informó el incidente.
# - part_1_2: Indica si el incidente es un crimen de la Parte 1 (crímenes más graves) o de la Parte 2 (crímenes menos graves).
# - crm_cd: Código de delito de 3 dígitos del crimen cometido.
# - crm_cd_desc: Descripción del delito del crimen cometido.
# - mocodes: Modus Operandi o la manera distintiva o característica en que una persona lleva a cabo una actividad criminal.
# - vict_age: Edad de la víctima
# - vict_sex: Sexo de la víctima.
# - vict_descent: Código de descendencia de la víctima
# - premis_cd: El Código de Instalación es un código de 3 dígitos que identifica el tipo de lugar donde ocurrió el incidente
# - premis_desc: Descripción de la Instalación.
# - weapon_used_cd: El Código de Arma es un código de 3 dígitos que identifica el tipo de arma utilizada en el incidente
# - weapon_desc: Descripción del Arma.
# - status: Estado del caso. (IC es el valor predeterminado)
# - status_desc: Define el Código de Estado proporcionado.
# - crm_cd_1: Indica el crimen cometido. El Código de Crimen 1 es el principal y el más grave. Los Códigos de Crimen 2, 3 y 4 son, respectivamente, delitos menos graves. Los números de clase de crimen más bajos son más graves.
# - crm_cd_2: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_3: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - crm_cd_4: Puede contener un código para un crimen adicional, menos grave que el Código de Crimen 1.
# - location: Dirección postal del incidente del crimen redondeada al centenar de la cuadra más cercana para mantener el anonimato.
# - cross_street: El nombre de la calle que se cruza con la calle principal donde ocurrió el incidente.
# - lat: Latitud.
# - lon: Longitud.
#
# Códigos de descendencia:
# - A: Asiáticos
# - B: Afroamericano
# - C: Chino
# - D: Camboyano
# - F: Filipino
# - G: Guamés
# - H: Hispano
# - I: Indio Americano
# - J: Japonés
# - K: Coreano
# - L: Laosiano
# - O: Otro
# - P: Isleño del Pacífico
# - S: Samoano
# - U: Hawaiano
# - V: Vietnamita
# - W: Blanco
# - X: Desconocido
# - Z: Hindú Asiático

# %% [markdown]
# Revisamos los tipos de datos de cada variable observando entre el .info() y la viasualización de la propia tabla y no se requieren cambios
#
# También observamos en el count que hay nulos en varias columnas que trataremos posteriormente

# %%
pd.set_option('display.max_columns', None)
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 230209513  04/24/2023 12:00:00 AM  04/23/2023 12:00:00 AM      2030     2
#
#           area_name  rpt_dist_no  part_1_2  crm_cd       crm_cd_desc mocodes  \
# dr_no
# 230209513   Rampart          218         1     510  VEHICLE - STOLEN     NaN
#
#            vict_age vict_sex vict_descent  premis_cd premis_desc  \
# dr_no
# 230209513         0      NaN          NaN      101.0      STREET
#
#            weapon_used_cd weapon_desc status  status_desc  crm_cd_1  crm_cd_2  \
# dr_no
# 230209513             NaN         NaN     IC  Invest Cont     510.0       NaN
#
#            crm_cd_3  crm_cd_4                                location  \
# dr_no
# 230209513       NaN       NaN  800    LAGUNA                       AV
#
#           cross_street      lat       lon
# dr_no
# 230209513          NaN  34.0727 -118.2597

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 200114944 to 240710787
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  object
#  1   date_occ        331647 non-null  object
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  int64
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  int64
#  6   part_1_2        331647 non-null  int64
#  7   crm_cd          331647 non-null  int64
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281591 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        283925 non-null  object
#  12  vict_descent    283922 non-null  object
#  13  premis_cd       331638 non-null  float64
#  14  premis_desc     331439 non-null  object
#  15  weapon_used_cd  108155 non-null  float64
#  16  weapon_desc     108155 non-null  object
#  17  status          331646 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331645 non-null  float64
#  20  crm_cd_2        22977 non-null   float64
#  21  crm_cd_3        770 non-null     float64
#  22  crm_cd_4        19 non-null      float64
#  23  location        331647 non-null  object
#  24  cross_street    50793 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
# dtypes: float64(8), int64(6), object(13)
# memory usage: 70.8+ MB

# %% [markdown]
# ## 4. TRATAMIENTO DE VARIABLES
#
# ### FORMATO DE VARIABLES

# %% [markdown]
# Las columnas 'date_rptd' y 'date_occ' vamos a eliminar la hora porque en todos los registros nos dicen que ha sido a las '12:00:00 AM'. Esta información es errónea según la columna 'time_occ' y además no nos aporta información como variable porque es una constante en todos los registros

# %%
df.sample()
# Out:
#                         date_rptd                date_occ  time_occ  area  \
# dr_no
# 240912857  11/06/2024 12:00:00 AM  11/04/2024 12:00:00 AM      1430     9
#
#           area_name  rpt_dist_no  part_1_2  crm_cd  \
# dr_no
# 240912857  Van Nuys          989         1     331
#
#                                                  crm_cd_desc    mocodes  \
# dr_no
# 240912857  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  0344 0385
#
#            vict_age vict_sex vict_descent  premis_cd  \
# dr_no
# 240912857        28        M            O      122.0
#
#                         premis_desc  weapon_used_cd weapon_desc status  \
# dr_no
# 240912857  VEHICLE, PASSENGER/TRUCK             NaN         NaN     IC
#
#            status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 240912857  Invest Cont     331.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 240912857  4300    VENTURA CANYON               AV          NaN  34.1478
#
#                 lon
# dr_no
# 240912857 -118.4296

# %% [markdown]
# Eliminamos la parte de la hora

# %%
df['date_rptd'] = df['date_rptd'].str.split(' ').str[0]
df['date_occ'] = df['date_occ'].str.split(' ').str[0]

# %%
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 200612535  07/13/2020  07/13/2020      1010     6  Hollywood          666
#
#            part_1_2  crm_cd               crm_cd_desc  \
# dr_no
# 200612535         2     624  BATTERY - SIMPLE ASSAULT
#
#                                  mocodes  vict_age vict_sex vict_descent  \
# dr_no
# 200612535  0400 0522 0329 1300 0919 1822        54        M            W
#
#            premis_cd               premis_desc  weapon_used_cd  \
# dr_no
# 200612535      122.0  VEHICLE, PASSENGER/TRUCK           400.0
#
#                                               weapon_desc status  status_desc  \
# dr_no
# 200612535  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
#
#            crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  location cross_street  \
# dr_no
# 200612535     624.0     740.0       NaN       NaN  VAN NESS       SUNSET
#
#                lat       lon
# dr_no
# 200612535  34.0944 -118.3277

# %% [markdown]
# Separamos la composición de las fechas con formato '%m/%d/%Y' de las columnas 'date_rptd' y 'date_occ' en una columna para los años, otra para meses y otra para días

# %%
df['year_rptd'] = df['date_rptd'].str.split('/').str[2]
df['month_rptd'] = df['date_rptd'].str.split('/').str[0]
df['day_rptd'] = df['date_rptd'].str.split('/').str[1]
df['year_occ'] = df['date_occ'].str.split('/').str[2]
df['month_occ'] = df['date_occ'].str.split('/').str[0]
df['day_occ'] = df['date_occ'].str.split('/').str[1]
df.sample()
# Out:
#             date_rptd    date_occ  time_occ  area  area_name  rpt_dist_no  \
# dr_no
# 230617753  11/13/2023  11/13/2023        30     6  Hollywood          668
#
#            part_1_2  crm_cd       crm_cd_desc mocodes  vict_age vict_sex  \
# dr_no
# 230617753         1     510  VEHICLE - STOLEN     NaN         0      NaN
#
#           vict_descent  premis_cd premis_desc  weapon_used_cd weapon_desc  \
# dr_no
# 230617753          NaN      101.0      STREET             NaN         NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 230617753     IC  Invest Cont     510.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 230617753  1300 N  ST ANDREWS                   PL          NaN  34.0949
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ
# dr_no
# 230617753 -118.3104      2023         11       13     2023        11      13

# %% [markdown]
# Hacemos un datetime de las columnas de fechas

# %%
df['date_rptd'] = pd.to_datetime(df['date_rptd'], dayfirst=False, format='%m/%d/%Y')
df['date_occ'] = pd.to_datetime(df['date_occ'], dayfirst=False, format='%m/%d/%Y')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 200114944 to 240710787
# Data columns (total 33 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  datetime64[ns]
#  1   date_occ        331647 non-null  datetime64[ns]
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  int64
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  int64
#  6   part_1_2        331647 non-null  int64
#  7   crm_cd          331647 non-null  int64
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281591 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        283925 non-null  object
#  12  vict_descent    283922 non-null  object
#  13  premis_cd       331638 non-null  float64
#  14  premis_desc     331439 non-null  object
#  15  weapon_used_cd  108155 non-null  float64
#  16  weapon_desc     108155 non-null  object
#  17  status          331646 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331645 non-null  float64
#  20  crm_cd_2        22977 non-null   float64
#  21  crm_cd_3        770 non-null     float64
#  22  crm_cd_4        19 non-null      float64
#  23  location        331647 non-null  object
#  24  cross_street    50793 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
#  27  year_rptd       331647 non-null  object
#  28  month_rptd      331647 non-null  object
#  29  day_rptd        331647 non-null  object
#  30  year_occ        331647 non-null  object
#  31  month_occ       331647 non-null  object
#  32  day_occ         331647 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(6), object(17)
# memory usage: 86.0+ MB

# %% [markdown]
# Generamos una columna calculada con la diferencia de tiempo (en días) entre que se comete el delito y se denuncia

# %%
df['time_to_report'] = (df['date_rptd'] - df['date_occ']).dt.days.astype(int)
df.time_to_report.describe()
# Out:
# count    331647.000000
# mean         12.069520
# std          68.199213
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max        1791.000000
# Name: time_to_report, dtype: float64

# %% [markdown]
# Generamos una columna para obtener la hora de ocurrencia de los delitos

# %%
df["hour_occ"] = df["time_occ"] // 100
df.hour_occ.nunique()
# Out:
# 24

# %% [markdown]
# Vamos a mapear los códigos de 'vict_descent' con el significado que nos dieron en la información del dataset para que sea mas visual

# %%
map_vict_descent = {
    "A": "Asiáticos",
    "B": "Afroamericano",
    "C": "Chino",
    "D": "Camboyano",
    "F": "Filipino",
    "G": "Guamés",
    "H": "Hispano",
    "I": "Indio_Americano",
    "J": "Japonés",
    "K": "Coreano",
    "L": "Laosiano",
    "O": "Otro",
    "P": "Isleño_del_Pacífico",
    "S": "Samoano",
    "U": "Hawaiano",
    "V": "Vietnamita",
    "W": "Blanco",
    "X": "Desconocido",
    "Z": "Hindú_Asiático"
}

df["vict_descent"] = df["vict_descent"].map(map_vict_descent)
df.head()
# Out:
#            date_rptd   date_occ  time_occ  area area_name  rpt_dist_no  \
# dr_no
# 200114944 2020-07-17 2020-07-16      1400     1   Central          111
# 202007973 2020-03-27 2020-03-26      1400    20   Olympic         2002
# 202114730 2020-10-11 2020-10-11      1956    21   Topanga         2136
# 210704099 2021-01-04 2020-12-23      1800     7  Wilshire          711
# 200511531 2020-07-07 2020-06-29      2000     5    Harbor          529
#
#            part_1_2  crm_cd                                      crm_cd_desc  \
# dr_no
# 200114944         1     330                            BURGLARY FROM VEHICLE
# 202007973         1     510                                 VEHICLE - STOLEN
# 202114730         2     624                         BATTERY - SIMPLE ASSAULT
# 210704099         1     330                            BURGLARY FROM VEHICLE
# 200511531         1     420  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#                                  mocodes  vict_age vict_sex   vict_descent  \
# dr_no
# 200114944  1307 1822 0329 0352 1609 0344        27        F  Afroamericano
# 202007973                            NaN         0      NaN            NaN
# 202114730                           0400        36        F        Hispano
# 210704099                      0344 1601        51        M           Otro
# 200511531                      1300 0344        66        M         Blanco
#
#            premis_cd                                   premis_desc  \
# dr_no
# 200114944      103.0                                         ALLEY
# 202007973      108.0                                   PARKING LOT
# 202114730      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 210704099      101.0                                        STREET
# 200511531      122.0                      VEHICLE, PASSENGER/TRUCK
#
#            weapon_used_cd                                     weapon_desc  \
# dr_no
# 200114944             NaN                                             NaN
# 202007973             NaN                                             NaN
# 202114730           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 210704099             NaN                                             NaN
# 200511531             NaN                                             NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2  crm_cd_3  crm_cd_4  \
# dr_no
# 200114944     IC  Invest Cont     330.0       NaN       NaN       NaN
# 202007973     IC  Invest Cont     510.0       NaN       NaN       NaN
# 202114730     IC  Invest Cont     624.0       NaN       NaN       NaN
# 210704099     IC  Invest Cont     330.0       NaN       NaN       NaN
# 200511531     IC  Invest Cont     420.0       NaN       NaN       NaN
#
#                                           location cross_street      lat  \
# dr_no
# 200114944   400    BAMBOO                       LN          NaN  34.0658
# 202007973   500 N  GRAMERCY                     PL          NaN  34.0803
# 202114730  7300    MILWOOD                      AV          NaN  34.2029
# 210704099   400 N  ORLANDO                      AV          NaN  34.0781
# 200511531  1500    ANCHORAGE                    RD          NaN  33.7672
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 200114944 -118.2366      2020         07       17     2020        07      16
# 202007973 -118.3125      2020         03       27     2020        03      26
# 202114730 -118.5943      2020         10       11     2020        10      11
# 210704099 -118.3732      2021         01       04     2020        12      23
# 200511531 -118.2414      2020         07       07     2020        06      29
#
#            time_to_report  hour_occ
# dr_no
# 200114944               1        14
# 202007973               1        14
# 202114730               0        19
# 210704099              12        18
# 200511531               8        20

# %%
df["vict_descent"].unique()
# Out:
# array(['Afroamericano', nan, 'Hispano', 'Otro', 'Blanco', 'Desconocido',
#        'Asiáticos', 'Coreano', 'Filipino', 'Camboyano', 'Japonés',
#        'Chino', 'Hawaiano', 'Vietnamita', 'Hindú_Asiático', 'Guamés',
#        'Isleño_del_Pacífico', 'Laosiano', 'Indio_Americano', 'Samoano'],
#       dtype=object)

# %% [markdown]
# Cambiamos el formato de ciertas columnas para que nos sirvan para hacer los análisis
#
# Nota. En el EDA hemos detectado que necesitamos dejar 'crm_cd_1' y 'crm_cd_2' como float hasta hacer las transformaciones necesarias y después lo pasaremos a category

# %%
#Cambiar formatos manualmente
df = df.astype({'part_1_2':'category',
                'rpt_dist_no':'object',
                #'crm_cd_1':'category',
                #'crm_cd_2':'category',
                'crm_cd_3':'category',
                'crm_cd_4':'category',
                'crm_cd':'category',
                'area':'category',
                'weapon_used_cd':'category',
                'premis_cd':'category',
                'year_rptd':'object',
                'month_rptd':'object',
                'day_rptd':'object',
                'year_occ':'object',
                'year_occ':'object',
                'year_occ':'object',
                'hour_occ':'object'
                })

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331647 entries, 200114944 to 240710787
# Data columns (total 35 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date_rptd       331647 non-null  datetime64[ns]
#  1   date_occ        331647 non-null  datetime64[ns]
#  2   time_occ        331647 non-null  int64
#  3   area            331647 non-null  category
#  4   area_name       331647 non-null  object
#  5   rpt_dist_no     331647 non-null  object
#  6   part_1_2        331647 non-null  category
#  7   crm_cd          331647 non-null  category
#  8   crm_cd_desc     331647 non-null  object
#  9   mocodes         281591 non-null  object
#  10  vict_age        331647 non-null  int64
#  11  vict_sex        283925 non-null  object
#  12  vict_descent    283922 non-null  object
#  13  premis_cd       331638 non-null  category
#  14  premis_desc     331439 non-null  object
#  15  weapon_used_cd  108155 non-null  category
#  16  weapon_desc     108155 non-null  object
#  17  status          331646 non-null  object
#  18  status_desc     331647 non-null  object
#  19  crm_cd_1        331645 non-null  float64
#  20  crm_cd_2        22977 non-null   float64
#  21  crm_cd_3        770 non-null     category
#  22  crm_cd_4        19 non-null      category
#  23  location        331647 non-null  object
#  24  cross_street    50793 non-null   object
#  25  lat             331647 non-null  float64
#  26  lon             331647 non-null  float64
#  27  year_rptd       331647 non-null  object
#  28  month_rptd      331647 non-null  object
#  29  day_rptd        331647 non-null  object
#  30  year_occ        331647 non-null  object
#  31  month_occ       331647 non-null  object
#  32  day_occ         331647 non-null  object
#  33  time_to_report  331647 non-null  int64
#  34  hour_occ        331647 non-null  object
# dtypes: category(7), datetime64[ns](2), float64(4), int64(3), object(19)
# memory usage: 76.2+ MB

# %% [markdown]
# Camabiamos la posición de las columnas para una visualización mas cómoda

# %%
#Sacamos una lista de todas las columnas
list(df.columns)
# Out:
# ['date_rptd',
#  'date_occ',
#  'time_occ',
#  'area',
#  'area_name',
#  'rpt_dist_no',
#  'part_1_2',
#  'crm_cd',
#  'crm_cd_desc',
#  'mocodes',
#  'vict_age',
#  'vict_sex',
#  'vict_descent',
#  'premis_cd',
#  'premis_desc',
#  'weapon_used_cd',
#  'weapon_desc',
#  'status',
#  'status_desc',
#  'crm_cd_1',
#  'crm_cd_2',
#  'crm_cd_3',
#  'crm_cd_4',
#  'location',
#  'cross_street',
#  'lat',
#  'lon',
#  'year_rptd',
#  'month_rptd',
#  'day_rptd',
#  'year_occ',
#  'month_occ',
#  'day_occ',
#  'time_to_report',
#  'hour_occ']

# %%
#Extraemos las columnas que queremos modificar y las ponemos en el orden que queremos que aparezcan
reorden = ['date_rptd','date_occ','time_to_report']

#Hacemos una lista con el resto de columnas 
resto = df.drop(columns = reorden).columns.to_list()
resto

#Agregamos ambas listas
orden = reorden + resto

df = df[orden]
df.head(5)
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area area_name  \
# dr_no
# 200114944 2020-07-17 2020-07-16               1      1400    1   Central
# 202007973 2020-03-27 2020-03-26               1      1400   20   Olympic
# 202114730 2020-10-11 2020-10-11               0      1956   21   Topanga
# 210704099 2021-01-04 2020-12-23              12      1800    7  Wilshire
# 200511531 2020-07-07 2020-06-29               8      2000    5    Harbor
#
#           rpt_dist_no part_1_2 crm_cd  \
# dr_no
# 200114944         111        1    330
# 202007973        2002        1    510
# 202114730        2136        2    624
# 210704099         711        1    330
# 200511531         529        1    420
#
#                                                crm_cd_desc  \
# dr_no
# 200114944                            BURGLARY FROM VEHICLE
# 202007973                                 VEHICLE - STOLEN
# 202114730                         BATTERY - SIMPLE ASSAULT
# 210704099                            BURGLARY FROM VEHICLE
# 200511531  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#                                  mocodes  vict_age vict_sex   vict_descent  \
# dr_no
# 200114944  1307 1822 0329 0352 1609 0344        27        F  Afroamericano
# 202007973                            NaN         0      NaN            NaN
# 202114730                           0400        36        F        Hispano
# 210704099                      0344 1601        51        M           Otro
# 200511531                      1300 0344        66        M         Blanco
#
#           premis_cd                                   premis_desc  \
# dr_no
# 200114944     103.0                                         ALLEY
# 202007973     108.0                                   PARKING LOT
# 202114730     502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 210704099     101.0                                        STREET
# 200511531     122.0                      VEHICLE, PASSENGER/TRUCK
#
#           weapon_used_cd                                     weapon_desc  \
# dr_no
# 200114944            NaN                                             NaN
# 202007973            NaN                                             NaN
# 202114730          400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 210704099            NaN                                             NaN
# 200511531            NaN                                             NaN
#
#           status  status_desc  crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 200114944     IC  Invest Cont     330.0       NaN      NaN      NaN
# 202007973     IC  Invest Cont     510.0       NaN      NaN      NaN
# 202114730     IC  Invest Cont     624.0       NaN      NaN      NaN
# 210704099     IC  Invest Cont     330.0       NaN      NaN      NaN
# 200511531     IC  Invest Cont     420.0       NaN      NaN      NaN
#
#                                           location cross_street      lat  \
# dr_no
# 200114944   400    BAMBOO                       LN          NaN  34.0658
# 202007973   500 N  GRAMERCY                     PL          NaN  34.0803
# 202114730  7300    MILWOOD                      AV          NaN  34.2029
# 210704099   400 N  ORLANDO                      AV          NaN  34.0781
# 200511531  1500    ANCHORAGE                    RD          NaN  33.7672
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 200114944 -118.2366      2020         07       17     2020        07      16
# 202007973 -118.3125      2020         03       27     2020        03      26
# 202114730 -118.5943      2020         10       11     2020        10      11
# 210704099 -118.3732      2021         01       04     2020        12      23
# 200511531 -118.2414      2020         07       07     2020        06      29
#
#           hour_occ
# dr_no
# 200114944       14
# 202007973       14
# 202114730       19
# 210704099       18
# 200511531       20

# %% [markdown]
# ### DUPLICADOS
#
# Comprobamos si hay duplicados y hacemos comparaciones para asegurarnos

# %%
duplicados = df.duplicated().sum()
print(f'Recuento de duplicados en df: ', duplicados)
# Out:
# Recuento de duplicados en df:  383

# %% [markdown]
# Nos salen que hay duplicados de las 27 columnas y que solamente es diferente el índice. Hacemos unas visualizaciones para comprobar que son realmente duplicados y vemos que es cierto, por lo que borramos todos los duplicados

# %%
lineas_original = len(df)
lineas_original
# Out:
# 331647

# %%
df.loc[df.duplicated()].head(2)
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area  area_name  \
# dr_no
# 201612241 2020-08-21 2020-08-21               0      1730   16   Foothill
# 210604716 2021-01-20 2020-12-02              49      1200    6  Hollywood
#
#           rpt_dist_no part_1_2 crm_cd  \
# dr_no
# 201612241        1659        1    231
# 210604716         663        1    510
#
#                                             crm_cd_desc         mocodes  \
# dr_no
# 201612241  ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER  0447 1212 1822
# 210604716                              VEHICLE - STOLEN             NaN
#
#            vict_age vict_sex vict_descent premis_cd  premis_desc  \
# dr_no
# 201612241         0        M       Blanco     101.0       STREET
# 210604716         0      NaN          NaN     108.0  PARKING LOT
#
#           weapon_used_cd         weapon_desc status  status_desc  crm_cd_1  \
# dr_no
# 201612241          306.0  ROCK/THROWN OBJECT     IC  Invest Cont     231.0
# 210604716            NaN                 NaN     IC  Invest Cont     510.0
#
#            crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 201612241       NaN      NaN      NaN
# 210604716       NaN      NaN      NaN
#
#                                           location  \
# dr_no
# 201612241          FOOTHILL                     BL
# 210604716  1100 N  SYCAMORE                     AV
#
#                               cross_street      lat       lon year_rptd  \
# dr_no
# 201612241  LOWELL                       AV  34.2407 -118.2661      2020
# 210604716                              NaN  34.0907 -118.3428      2021
#
#           month_rptd day_rptd year_occ month_occ day_occ hour_occ
# dr_no
# 201612241         08       21     2020        08      21       17
# 210604716         01       20     2020        12      02       12

# %%
# Buscamos una en concreto por hacer la comprobación
df.loc[(df.mocodes == '0421 1528 1822 0903 2053')]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area area_name  \
# dr_no
# 220706179 2022-02-26 2022-02-26               0      1200    7  Wilshire
# 220706174 2022-02-26 2022-02-26               0      1200    7  Wilshire
# 220706177 2022-02-26 2022-02-26               0      1200    7  Wilshire
# 220706176 2022-02-26 2022-02-26               0      1200    7  Wilshire
# 220706171 2022-02-26 2022-02-26               0      1200    7  Wilshire
#
#           rpt_dist_no part_1_2 crm_cd                             crm_cd_desc  \
# dr_no
# 220706179         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706174         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706177         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706176         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
# 220706171         752        2    930  CRIMINAL THREATS - NO WEAPON DISPLAYED
#
#                             mocodes  vict_age vict_sex vict_descent premis_cd  \
# dr_no
# 220706179  0421 1528 1822 0903 2053         0        F         Otro     501.0
# 220706174  0421 1528 1822 0903 2053         0        F         Otro     501.0
# 220706177  0421 1528 1822 0903 2053         0        F         Otro     501.0
# 220706176  0421 1528 1822 0903 2053         0        F         Otro     501.0
# 220706171  0421 1528 1822 0903 2053         0        M         Otro     501.0
#
#                       premis_desc weapon_used_cd    weapon_desc status  \
# dr_no
# 220706179  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
# 220706174  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
# 220706177  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
# 220706176  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
# 220706171  SINGLE FAMILY DWELLING          511.0  VERBAL THREAT     IC
#
#            status_desc  crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 220706179  Invest Cont     930.0     946.0      NaN      NaN
# 220706174  Invest Cont     930.0     946.0      NaN      NaN
# 220706177  Invest Cont     930.0     946.0      NaN      NaN
# 220706176  Invest Cont     930.0     946.0      NaN      NaN
# 220706171  Invest Cont     930.0     946.0      NaN      NaN
#
#                                           location cross_street      lat  \
# dr_no
# 220706179  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706174  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706177  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706176  1100 S  ORLANDO                      AV          NaN  34.0572
# 220706171  1100 S  ORLANDO                      AV          NaN  34.0572
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 220706179 -118.3739      2022         02       26     2022        02      26
# 220706174 -118.3739      2022         02       26     2022        02      26
# 220706177 -118.3739      2022         02       26     2022        02      26
# 220706176 -118.3739      2022         02       26     2022        02      26
# 220706171 -118.3739      2022         02       26     2022        02      26
#
#           hour_occ
# dr_no
# 220706179       12
# 220706174       12
# 220706177       12
# 220706176       12
# 220706171       12

# %% [markdown]
# Eliminamos los duplicados

# %%
df.drop_duplicates(inplace=True)

# %%
lineas_despues = len(df)

diff = lineas_original - lineas_despues

print("Filas antes:", lineas_original)
print("Filas después:", lineas_despues)
print("Diferencia:", diff)
# Out:
# Filas antes: 331647
# Filas después: 331264
# Diferencia: 383

# %% [markdown]
# ### VALORES ÚNICOS
#
# Comprobamos los valores únicos en la tabla para desestimar variables. En este caso, no hay constantes

# %%
df.nunique().sort_values(ascending=True)

# Si hubiera alguna columna que eliminar haríamos df.drop(columns = '...', inplace=True)
# Out:
# part_1_2               2
# crm_cd_4               2
# vict_sex               4
# status_desc            6
# year_occ               6
# status                 6
# year_rptd              6
# month_rptd            12
# month_occ             12
# vict_descent          19
# area_name             21
# area                  21
# hour_occ              24
# crm_cd_3              24
# day_rptd              31
# day_occ               31
# weapon_used_cd        78
# weapon_desc           78
# vict_age             104
# crm_cd_2             105
# crm_cd_desc          138
# crm_cd               138
# crm_cd_1             139
# premis_desc          300
# premis_cd            307
# rpt_dist_no         1162
# time_to_report      1164
# time_occ            1439
# date_occ            1853
# date_rptd           1868
# lon                 4872
# lat                 5172
# cross_street        6589
# location           50614
# mocodes           117534
# dtype: int64

# %% [markdown]
# ### VALORES NULOS
#
# Comprobamos los nulos que existen según el tipo de columna: Categórica y numérica
#
# Primero haremos las comprobaciones, después expondré las conclusiones y a continuación realizaré los cambios

# %%
df.select_dtypes(include='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_2          308295
# crm_cd_1               2
# time_to_report         0
# vict_age               0
# time_occ               0
# lat                    0
# lon                    0
# dtype: int64

# %%
df.select_dtypes(exclude='number').isna().sum().sort_values(ascending=False)
# Out:
# crm_cd_4          331245
# crm_cd_3          330494
# cross_street      280530
# weapon_used_cd    223236
# weapon_desc       223236
# mocodes            49901
# vict_descent       47573
# vict_sex           47570
# premis_desc          208
# premis_cd              9
# status                 1
# area_name              0
# rpt_dist_no            0
# part_1_2               0
# crm_cd                 0
# crm_cd_desc            0
# date_rptd              0
# date_occ               0
# area                   0
# status_desc            0
# location               0
# year_rptd              0
# month_rptd             0
# day_rptd               0
# year_occ               0
# month_occ              0
# day_occ                0
# hour_occ               0
# dtype: int64

# %%
df.vict_descent.unique()
# Out:
# array(['Afroamericano', nan, 'Hispano', 'Otro', 'Blanco', 'Desconocido',
#        'Asiáticos', 'Coreano', 'Filipino', 'Camboyano', 'Japonés',
#        'Chino', 'Hawaiano', 'Vietnamita', 'Hindú_Asiático', 'Guamés',
#        'Isleño_del_Pacífico', 'Laosiano', 'Indio_Americano', 'Samoano'],
#       dtype=object)

# %%
df[['vict_descent']].value_counts()
# Out:
# vict_descent
# Hispano                97498
# Blanco                 66350
# Afroamericano          44800
# Desconocido            35385
# Otro                   25696
# Asiáticos               7088
# Coreano                 2025
# Filipino                1629
# Chino                   1534
# Japonés                  534
# Vietnamita               393
# Indio_Americano          334
# Hindú_Asiático           167
# Isleño_del_Pacífico       91
# Hawaiano                  63
# Camboyano                 29
# Guamés                    28
# Samoano                   25
# Laosiano                  22
# Name: count, dtype: int64

# %%
df.vict_sex.unique()
# Out:
# array(['F', nan, 'M', 'X', 'H'], dtype=object)

# %%
df.loc[df.vict_sex=='-']
# Out:
# Empty DataFrame
# Columns: [date_rptd, date_occ, time_to_report, time_occ, area, area_name, rpt_dist_no, part_1_2, crm_cd, crm_cd_desc, mocodes, vict_age, vict_sex, vict_descent, premis_cd, premis_desc, weapon_used_cd, weapon_desc, status, status_desc, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, location, cross_street, lat, lon, year_rptd, month_rptd, day_rptd, year_occ, month_occ, day_occ, hour_occ]
# Index: []

# %%
df.loc[(df.premis_cd.notna())&(df.premis_desc.isna())].premis_cd.value_counts()
# Out:
# premis_cd
# 418.0    130
# 256.0     59
# 972.0      7
# 976.0      1
# 973.0      1
#         ...
# 155.0      0
# 156.0      0
# 157.0      0
# 158.0      0
# 109.0      0
# Name: count, Length: 307, dtype: int64

# %%
df.loc[(df.crm_cd_1.isna())]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area area_name  \
# dr_no
# 230123939 2023-11-13 2023-11-12               1      2300    1   Central
# 230114706 2023-06-22 2023-06-22               0      1550    1   Central
#
#           rpt_dist_no part_1_2 crm_cd              crm_cd_desc  \
# dr_no
# 230123939         162        1    330    BURGLARY FROM VEHICLE
# 230114706         155        2    623  BATTERY POLICE (SIMPLE)
#
#                        mocodes  vict_age vict_sex   vict_descent premis_cd  \
# dr_no
# 230123939            0344 1307        47        M  Afroamericano     108.0
# 230114706  1212 0917 0447 2004         0        M        Hispano     726.0
#
#                premis_desc weapon_used_cd                  weapon_desc status  \
# dr_no
# 230123939      PARKING LOT            NaN                          NaN     IC
# 230114706  POLICE FACILITY          500.0  UNKNOWN WEAPON/OTHER WEAPON     IC
#
#            status_desc  crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4  \
# dr_no
# 230123939  Invest Cont       NaN     330.0      NaN      NaN
# 230114706  Invest Cont       NaN     623.0      NaN      NaN
#
#                                          location cross_street      lat  \
# dr_no
# 230123939  800 S  HILL                         ST          NaN  34.0462
# 230114706  200 E  6TH                          ST          NaN  34.0448
#
#                 lon year_rptd month_rptd day_rptd year_occ month_occ day_occ  \
# dr_no
# 230123939 -118.2585      2023         11       13     2023        11      12
# 230114706 -118.2474      2023         06       22     2023        06      22
#
#           hour_occ
# dr_no
# 230123939       23
# 230114706       15

# %%
df.loc[(df.status.isna())]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area  area_name  \
# dr_no
# 241810568 2024-06-08 2024-05-24              15      1900   18  Southeast
#
#           rpt_dist_no part_1_2 crm_cd       crm_cd_desc mocodes  vict_age  \
# dr_no
# 241810568        1871        1    510  VEHICLE - STOLEN     NaN         0
#
#           vict_sex vict_descent premis_cd premis_desc weapon_used_cd  \
# dr_no
# 241810568      NaN          NaN       NaN         NaN            NaN
#
#           weapon_desc status status_desc  crm_cd_1  crm_cd_2 crm_cd_3  \
# dr_no
# 241810568         NaN    NaN         UNK     510.0       NaN      NaN
#
#           crm_cd_4                                  location cross_street  \
# dr_no
# 241810568      NaN  13500 S  FIGUEROA                     ST          NaN
#
#                lat       lon year_rptd month_rptd day_rptd year_occ month_occ  \
# dr_no
# 241810568  33.9092 -118.2827      2024         06       08     2024        05
#
#           day_occ hour_occ
# dr_no
# 241810568      24       19

# %%
df.loc[(df.crm_cd_1 == 510.0)]
# Out:
#            date_rptd   date_occ  time_to_report  time_occ area    area_name  \
# dr_no
# 202007973 2020-03-27 2020-03-26               1      1400   20      Olympic
# 201821224 2020-11-27 2020-11-25               2       545   18    Southeast
# 201809710 2020-04-17 2020-04-17               0       640   18    Southeast
# 201821561 2020-12-03 2020-11-30               3       700   18    Southeast
# 201117133 2020-12-31 2020-12-29               2      1400   11    Northeast
# ...              ...        ...             ...       ...  ...          ...
# 241611900 2024-12-15 2024-12-15               0       300   16     Foothill
# 240909998 2024-06-26 2024-06-24               2      1600    9     Van Nuys
# 240305327 2024-01-26 2024-01-26               0       100    3    Southwest
# 241509240 2024-04-19 2024-04-18               1       130   15  N Hollywood
# 240710787 2024-08-18 2024-08-17               1      1900    7     Wilshire
#
#           rpt_dist_no part_1_2 crm_cd       crm_cd_desc mocodes  vict_age  \
# dr_no
# 202007973        2002        1    510  VEHICLE - STOLEN     NaN         0
# 201821224        1802        1    510  VEHICLE - STOLEN     NaN         0
# 201809710        1832        1    510  VEHICLE - STOLEN     NaN         0
# 201821561        1842        1    510  VEHICLE - STOLEN     NaN         0
# 201117133        1118        1    510  VEHICLE - STOLEN     NaN         0
# ...               ...      ...    ...               ...     ...       ...
# 241611900        1601        1    510  VEHICLE - STOLEN     NaN         0
# 240909998         914        1    510  VEHICLE - STOLEN     NaN         0
# 240305327         332        1    510  VEHICLE - STOLEN     NaN         0
# 241509240        1502        1    510  VEHICLE - STOLEN     NaN         0
# 240710787         765        1    510  VEHICLE - STOLEN     NaN         0
#
#           vict_sex vict_descent premis_cd  premis_desc weapon_used_cd  \
# dr_no
# 202007973      NaN          NaN     108.0  PARKING LOT            NaN
# 201821224      NaN          NaN     101.0       STREET            NaN
# 201809710      NaN          NaN     101.0       STREET            NaN
# 201821561      NaN          NaN     101.0       STREET            NaN
# 201117133      NaN          NaN     101.0       STREET            NaN
# ...            ...          ...       ...          ...            ...
# 241611900      NaN          NaN     101.0       STREET            NaN
# 240909998      NaN          NaN     101.0       STREET            NaN
# 240305327      NaN          NaN     101.0       STREET            NaN
# 241509240      NaN          NaN     101.0       STREET            NaN
# 240710787      NaN          NaN     101.0       STREET            NaN
#
#           weapon_desc status  status_desc  crm_cd_1  crm_cd_2 crm_cd_3  \
# dr_no
# 202007973         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201821224         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201809710         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201821561         NaN     IC  Invest Cont     510.0       NaN      NaN
# 201117133         NaN     IC  Invest Cont     510.0       NaN      NaN
# ...               ...    ...          ...       ...       ...      ...
# 241611900         NaN     IC  Invest Cont     510.0       NaN      NaN
# 240909998         NaN     IC  Invest Cont     510.0       NaN      NaN
# 240305327         NaN     IC  Invest Cont     510.0       NaN      NaN
# 241509240         NaN     IC  Invest Cont     510.0       NaN      NaN
# 240710787         NaN     IC  Invest Cont     510.0       NaN      NaN
#
#           crm_cd_4                                  location  \
# dr_no
# 202007973      NaN    500 N  GRAMERCY                     PL
# 201821224      NaN    200 W  92ND                         ST
# 201809710      NaN                                   CENTRAL
# 201821561      NaN           111TH                        ST
# 201117133      NaN   5600    IRVINGTON                    PL
# ...            ...                                       ...
# 241611900      NaN  12800    EUSTACE                      ST
# 240909998      NaN   6900    VESPER                       AV
# 240305327      NaN   2800    HILLCREST                    DR
# 241509240      NaN   7700    GOODLAND                     AV
# 240710787      NaN   1200 S  TREMAINE                     AV
#
#                               cross_street      lat       lon year_rptd  \
# dr_no
# 202007973                              NaN  34.0803 -118.3125      2020
# 201821224                              NaN  33.9528 -118.2757      2020
# 201809710  104TH                        ST  33.9401 -118.2761      2020
# 201821561  MAIN                         ST  33.9348 -118.2739      2020
# 201117133                              NaN  34.1152 -118.1962      2020
# ...                                    ...      ...       ...       ...
# 241611900                              NaN  34.2861 -118.4120      2024
# 240909998                              NaN  34.1961 -118.4510      2024
# 240305327                              NaN  34.0311 -118.3429      2024
# 241509240                              NaN  34.2103 -118.4124      2024
# 240710787                              NaN  34.0531 -118.3391      2024
#
#           month_rptd day_rptd year_occ month_occ day_occ hour_occ
# dr_no
# 202007973         03       27     2020        03      26       14
# 201821224         11       27     2020        11      25        5
# 201809710         04       17     2020        04      17        6
# 201821561         12       03     2020        11      30        7
# 201117133         12       31     2020        12      29       14
# ...              ...      ...      ...       ...     ...      ...
# 241611900         12       15     2024        12      15        3
# 240909998         06       26     2024        06      24       16
# 240305327         01       26     2024        01      26        1
# 241509240         04       19     2024        04      18        1
# 240710787         08       18     2024        08      17       19
#
# [37907 rows x 35 columns]

# %% [markdown]
# ## 5. GUARDADO DE RESULTADOS

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '002_archivos/'

# %%
ruta_trabajo = ruta_principal + carpeta + 'trabajo_resultado_calidad.pickle'

# %% [markdown]
# Guardar los archivos

# %%
df.to_pickle(ruta_trabajo)
