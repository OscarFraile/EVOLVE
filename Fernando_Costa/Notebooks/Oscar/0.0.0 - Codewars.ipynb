# %% [markdown]
# ## CODEWARS
#
# Given an array of integers your solution should find the smallest integer.
#
# For example:
#
# - Given [34, 15, 88, 2] your solution will return 2
# - Given [34, -345, -1, 100] your solution will return -345
#
# You can assume, for the purpose of this kata, that the supplied array will not be empty.

# %%
arr = [11, -33, -18446744073709551615, 100]

def find_smallest_int(arr):
    return min(arr)
find_smallest_int(arr)
# Out:
# -18446744073709551615

# %%
lsta = []
[i for i in dir (lsta) if "_" not in i]
# Out:
# ['append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
def di_hola():
    print ('Hola')
di_hola()
# Out:
# Hola

# %%
def di_hola(nombre):
    print('Hola', nombre)
di_hola('Paquito')
# Out:
# Hola Paquito

# %%
def resta(a,b):
    return a-b
resta(5,2)
# Out:
# 3

# %%
def suma(numeros):
    print(type(numeros))
    total = 0
    for n in numeros:
        total += n
    return total
suma([1, 3, 5, 4, 5])
# Out:
# <class 'list'>
# 18

# %%
arr = [34, 15, 88, 200]

def find_smallest_int(arr):
    return min(arr)
find_smallest_int(arr)
# Out:
# 15

# %%
"1234" --> 1234
"605"  --> 605
"1405" --> 1405
"-7" --> -7

# %%
s = ("1234")

def string_to_number(s):
    return int(s)
string_to_number(s)
# Out:
# 1234

# %%
int("1234")
# Out:
# 1234

# %%
sheep = [True,  True,  True,  False,
  True,  True,  True,  True ,
  True,  False, True,  False,
  True,  False, False, True ,
  True,  True,  True,  True ,
  False, False, True,  True]

def count_sheeps(sheep):
    counter = 0
    for cadapal in sheep:
        
        if cadapal is True:
            counter += 1
        else:
            counter += 0
    return counter
count_sheeps(sheep)
# Out:
# 17

# %%
n_eje = 35231
def digitize(n):
    n_invert = str(n)[::-1]
    lista_enteros = []
    for cada in n_invert:
        cada = int(cada)
        lista_enteros.append(cada)
    return lista_enteros
digitize(n_eje)
# Out:
# [1, 3, 2, 5, 3]

# %%
arr = [1, 2, 3, 4]
def grow(arr):

# %%
arr = [1, 2, 3, 4]
arr

# %%
def say_something(name):
    print('Hello world', name)
say_something('Paquito')
# Out:
# Hello world Paquito

# %%
def greet(n):
    return 'hello world!'

# %%
greet('o')
# Out:
# 'hello world!'

# %%
def past(h, m, s):
    # Good Luck!
    milisegs = ((h * 3600) + (m * 60) + s) * 1000
    return milisegs
past(0,1,1)
# Out:
# 61000
