# %% [markdown]
# # Functions

# %% [markdown]
# `On this exercise
# you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    else:
        return b
    
greater(2,1)
# Out:
# 2

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %% [markdown]
# Forbidden built-in functions: `max()` & `sorted()`

# %%
arr = ['cosa', 'cosita', 'palote', 'bicicleta', 'jardi']
arrlen = []

for cadapal in arr:
    arrlen.append(len(cadapal))

arrlen
# Out:
# [4, 6, 6, 9, 5]

# %%
def greatest(arr):
    
    greatest_pal = ''
    maxlen = 0
    
    for cadapal in arr:
        if len(cadapal) > maxlen:
            maxlen = len(cadapal)
            greatest_pal = cadapal
    return greatest_pal
lista = ['cosa', 'cosita', 'palote', 'bicicleta', 'jardi']

greatest(lista)
# Out:
# 'bicicleta'

# %%
def encontrar_palabra_mas_larga(lista_palabras):
  if not lista_palabras:
    return ""
  
  palabra_mas_larga = ""
  longitud_max = 0

  for palabra in lista_palabras:
    if len(palabra) > longitud_max:
      longitud_max = len(palabra)
      palabra_mas_larga = palabra
  
  return palabra_mas_larga

# Ejemplo de uso
mi_lista = ["manzana", "banana", "cereza", "dátil", "uva"]
encontrar_palabra_mas_larga(mi_lista)
# Out:
# 'manzana'

# %%
# Ejemplo de lista con cadenas
mi_lista = ["hola", "mundo", "Python", "ejemplo"]

# Contar la longitud total de todos los caracteres en la lista
longitud_total = sum(len(cadena) for cadena in mi_lista)

print(f"La longitud total de los caracteres en la lista es: {longitud_total}")
# Out:
# La longitud total de los caracteres en la lista es: 22

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %% [markdown]
# Forbidden built-in functions: `sum()`

# %%
arr = ['cosa', 'cosita', 'palote', 'bicicleta', 'jardi']

def sum_all(arr):
    counter = 0
    for cadapal in arr:
        counter += len(cadapal)
    return counter
sum_all(arr)
# Out:
# 30

# %%
arr = [3,4,6,76,8]

def sum_all(arr):
    counter = 0
    for cadanum in arr:
        counter += cadanum
    return counter
sum_all(arr)
# Out:
# 97

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %% [markdown]
# Forbidden built-in functions: `prod()`

# %%
arr = ['cosa', 'cosita', 'palote', 'bicicleta', 'jardi']

def mult_all(arr):
    counter = 1
    for cadapal in arr:
        counter *= len(cadapal)
    return counter
mult_all(arr)
# Out:
# 6480

# %%
arr = [3,4,6,76,8]

def mult_all(arr):
    counter = 1
    for cadanum in arr:
        counter *= cadanum
    return counter
mult_all(arr)
# Out:
# 43776

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    counter = 0
    for cadanum in arr:
        if oper == '+':
            counter += cadanum
        if oper == '*':
            counter *= cadanum
    return counter
    
arr = [3,4,6,76,8]
oper_all(arr, '+')
# Out:
# 97

# %%
def oper_all(arr, oper):
    if oper == '+':
        counter = 0
    elif oper == '*':
        counter = 1
    else:
        print('Solo se aceptan sumas y multiplicaciones')
    for cadanum in arr:
        if oper == '+':
            counter += cadanum
        if oper == '*':
            counter *= cadanum
    return counter
    
arr = [3,4,6,76,8]
oper_all(arr, '*')
# Out:
# 43776

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %% [markdown]
# Forbidden built-in functions: `math.factorial()`

# %%
def factorial(n):
    counter = n
    min = 1
    while counter > 0:
        min *= counter
        counter -= 1
    return min

factorial(5)
# Out:
# 120

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.

# %% [markdown]
# Forbidden built-in functions: `set()`. You can use `lst.append`

# %%
arr
# Out:
# [3, 4, 6, 76, 8]

# %%
def unique(arr):
    unique_list = []

    for cadanum in arr:
        if cadanum not in unique_list:
            unique_list.append(cadanum)
    return unique_list
unique([1,2,2,3,4,4,5,5,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## 8. Write a function that calculates the standard deviation of a list.

# %% [markdown]
# Forbidden built-in functions: `sum()` and no imports oif libraries

# %%
def st_dev(arr):
    pass

# %% [markdown]
# ## 9. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %% [markdown]
# You can use `str.lower()`

# %%
string = ('El bucle termina cuando counter llega a cero y la función devuelve el resultado final')

def pangram(string):
    alphabet = ('abcdefghijklmnopqrstuvwxyz')
    list = []
    for cadapal in string:
        if cadapal.lower() in alphabet and cadapal.lower() not in list:
            list.append(cadapal)
    return list
pangram(string)
# Out:
# ['E',
#  'l',
#  'b',
#  'u',
#  'c',
#  'e',
#  't',
#  'r',
#  'm',
#  'i',
#  'n',
#  'a',
#  'd',
#  'o',
#  'g',
#  'y',
#  'f',
#  'v',
#  's']

# %%
def es_pangrama(texto):
    # 1. Obtener el conjunto (set) de todas las letras minúsculas del alfabeto ('a' a 'z')
    # Usamos set para eliminar automáticamente duplicados y facilitar la comparación.
    alfabeto_completo = set(string_module.ascii_lowercase)
    
    # 2. Obtener el conjunto de letras únicas en la cadena de entrada
    letras_en_texto = set()
    for caracter in texto:
        # 3. Convertir a minúscula y verificar que sea una letra
        caracter_lower = caracter.lower()
        if 'a' <= caracter_lower <= 'z':
            letras_en_texto.add(caracter_lower)
            
    # 4. Comprobar si el conjunto de letras en el texto es igual al conjunto del alfabeto.
    # Si la longitud de las letras encontradas es igual a 26, es un pangrama.
    return len(letras_en_texto) == len(alfabeto_completo)

# --- Pruebas ---
frase_original = 'El bucle termina cuando counter llega a cero y la función devuelve el resultado final'
pangrama_ejemplo = "El veloz murciélago hindú comía feliz cardillo y kiwi. La cigüeña tocaba el saxofón detrás del palenque de paja." # ¡Este contiene las 27 letras del español!

print(f"¿'{frase_original}' es un pangrama? {es_pangrama(frase_original)}")
print(f"¿'{pangrama_ejemplo}' es un pangrama? {es_pangrama(pangrama_ejemplo)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[178], line 22
#      19 frase_original = 'El bucle termina cuando counter llega a cero y la función devuelve el resultado final'
#      20 pangrama_ejemplo = "El veloz murciélago hindú comía feliz cardillo y kiwi. La cigüeña tocaba el saxofón detrás del palenque de paja." # ¡Este contiene las 27 letras del español!
# ---> 22 print(f"¿'{frase_original}' es un pangrama? {es_pangrama(frase_original)}")
#      23 print(f"¿'{pangrama_ejemplo}' es un pangrama? {es_pangrama(pangrama_ejemplo)}")
#
# Cell In[178], line 4, in es_pangrama(texto)
#       1 def es_pangrama(texto):
#       2     # 1. Obtener el conjunto (set) de todas las letras minúsculas del alfabeto ('a' a 'z')
#       3     # Usamos set para eliminar automáticamente duplicados y facilitar la comparación.
# ...

# %% [markdown]
# ## 10. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %% [markdown]
# You can use `len()`

# %%
def check_pass_with_len (string):
    pass

# %% [markdown]
# Forbidden built-in functions: `len()`

# %%
def check_pass_no_len(string):
    pass

# %% [markdown]
# ## BONUS

# %% [markdown]
# ## 11. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    pass

# %% [markdown]
# ## 12. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass
