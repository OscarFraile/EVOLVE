# %% [markdown]
# # Programación orientada a objetos

# %% [markdown]
# ## ¿Qué es OOP (Programación Orientada a Objetos)?

# %% [markdown]
# La programación orientada a objetos es un paradigma de programación, es decir, un estilo y técnica de programación, que va más allá de la propia implementación. Este paradigma se basa en el concepto de “objeto”, que puede contener tanto datos, en forma de campos llamados “atributos”, como código para su manipulación en forma de procedimientos y funciones, llamados “métodos”. Gracias a ello, podemos agrupar todo bajo un único tipo de dato (la “clase” del objeto), lo que facilita la modularidad y reutilización del código.
# Esto tiene una fuerte implicación en el diseño de soluciones informáticas; las metodologías de ingeniería de software se basan en la programación orientada a objetos.

# %% [markdown]
# Puedes imaginar los objetos como un nuevo tipo de datos cuya definición se da en una estructura llamada clase.
# A menudo se comparan las clases con cortadores de galletas y los objetos con las galletas en sí. Si bien todas las galletas hechas con el mismo molde tienen la misma forma, cada una adquiere atributos individuales después de hornearse. Cosas como el color, la textura, el sabor... pueden ser muy diferentes.
# En otras palabras, las galletas comparten un proceso de fabricación y algunos atributos, pero son independientes entre sí y del molde en sí, y eso hace que cada una sea única.
# Extrapolando del ejemplo, una clase es solo un script sobre cómo deben ser los objetos que se crearán con ella.

# %%
"""
OBJETOS/CLASES

- Atributos de algo 
- Acciones: métodos (funciones)
- Puedes crear tus propios tipos de python
- Reciclar/Reutilizar código. Se define una vez y se instancia muchas
    - Se definen una vez y se invocan varias
- Se puede heredar:
    - Los métodos y los atributos de la clase padre se pueden heredar
    - Reutilizar: 
        - Cuando se crean instancias nuevas
        - Cuando creas clases nuevas que comparten cosas con la macrocategoría
            - Staff: vacaiones, correo coporativo, permiso acceso bbdd
                - Marketing
                - Sales: bonus
                ...
            - Se heredan características comunes de la macro-categoría
            - Vehículo > Coche, camión...
"""
# Out:
# '\nOBJETOS/CLASES\n\n- Atributos de algo \n- Acciones: métodos (funciones)\n- Puedes crear tus propios tipos de python\n- Reciclar/Reutilizar código. Se define una vez y se instancia muchas\n    - Se definen una vez y se invocan varias\n- Se puede heredar:\n    - Los métodos y los atributos de la clase padre se pueden heredar\n    - Reutilizar: \n        - Cuando se crean instancias nuevas\n        - Cuando creas clases nuevas que comparten cosas con la macrocategoría\n            - Staff: vacaiones, correo coporativo, permiso acceso bbdd\n                - Marketing\n                - Sales: bonus\n                ...\n            - Se heredan características comunes de la macro-categoría\n            - Vehículo > Coche, camión...\n'

# %% [markdown]
# ### Principios fundamentales

# %% [markdown]
# 1 - **Abstracción de datos**: Algo que hacemos de forma natural en nuestra comprensión del mundo es la abstracción de información concreta en conceptos o clases. Por ejemplo, el concepto de "coche" evoca en nosotros una idea de vehículo con cuatro ruedas, un volante, un motor... Nuestro coche es una "instancia" específica de ese concepto, y diferente de otros coches, pero somos capaces de asociar determinadas propiedades o características a dicho concepto por encima de detalles concretos. Esta capacidad de abstracción de un concepto es esencial para el desarrollo del lenguaje humano y, por supuesto, tan buena idea se ha trasladado al mundo de la programación. En POO, al concepto abstracto lo llamamos "clase" y a la realización de ese concepto "objeto". Tu coche es concreto, lo puedes conducir, es un objeto, una "instancia" de la clase "coche".
#
# 2 - **Encapsulación**: Cada tipo de objeto contiene su propia información y puede ser manipulado de una forma particular. Un coche puede circular y tiene una determinada presión en las ruedas, un color, un determinado nivel de gasolina, etc. Con un GPS podemos obtener nuestras coordenadas de posición y las baterías tendrán una determinada carga. Un perro ladra, tiene un peso, una edad. Todos esos atributos y "métodos" están "encapsulados" dentro del objeto, y son accesibles sólo a través de un objeto dado. La ventaja es que no necesitamos tener, por ejemplo, una lista con nombres, otra con edades, otra con pesos... sino una lista de objetos y cada uno contiene, es decir, encapsula, su propia información.
#
# 3 - **Herencia**: Algunas clases pueden especializar a otras. Para ello, la clase especializada "hereda" las propiedades de la clase más general, llamada "superclase". Por ejemplo, las clases "Coche" y "Camión" pueden heredar de la clase "Vehículo". Esta es una forma de reutilizar código, al poder asumir esas propiedades comunes entre varias clases en una clase superior. Python soporta la "herencia múltiple", por lo que una clase puede definirse como una subclase de varias clases de las que heredaría todas sus propiedades (atributos y métodos) a la vez.
#
# 4 - **Polimorfismo**: Se puede dibujar un cuadrado, un círculo también, al igual que cualquier otra forma. "Cuadrado" y "Círculo" serían subclases de "Forma". La superclase "Forma" implementa un método draw(), y tanto la subclase "Cuadrado" como la subclase "Círculo" sobreescriben este método para su caso particular. Por lo que una función podría aceptar un objeto de tipo "Forma" como parámetro y llamar al método draw() sin saber si el argumento pasado es un círculo o un cuadrado. Cada objeto conoce su nivel de especialización y la implementación concreta de sus métodos. Esta capacidad de usar métodos de superclase en código pero resolverlos en métodos de subclase en tiempo de ejecución se llama "Polimorfismo": la misma variable puede tomar formas diferentes.

# %% [markdown]
# ## Clases e instancias

# %% [markdown]
# Una clase es como un tipo abstracto para objetos que, además de almacenar valores llamados atributos, tiene asociadas una serie de funciones que llamamos métodos. Una instancia de una clase es lo mismo que decir un objeto de esa clase. Instanciar una clase se refiere a crear un objeto que pertenece a esa clase.
# En Python, los tipos de datos son clases, y cualquier literal o variable de uno de estos tipos es un objeto que instancia la clase del tipo. Por ejemplo: a=2222 equivale a instanciar la clase PyLongObject asignando a un atributo interno el valor 2222. Esto es lo que ocurre a bajo nivel, pero podemos considerar que la variable a es de tipo int. Podemos saber el tipo de cualquier variable, es decir, la clase que instancia, con la función type(), y el identificador del objeto instanciado con la función id().

# %% [markdown]
# Para conocer todos los métodos y atributos de una clase podemos utilizar la función dir() tanto sobre un objeto como sobre la clase.

# %%
import pandas as pd
#[i for i in dir(pd.DataFrame()) if "_" not in i]

# %%
df = pd.DataFrame()
df.shape
df.drop()
# Out:
# (0, 0)

# %% [markdown]
# No es necesario que domines esto, solo debes saber qué significa `.__something__`. Es un método tonto/mágico. Pensado para Python internamente.

# %% [markdown]
# ## Definición de una clase

# %% [markdown]
# Podemos definir nuestras propias clases e indicar si heredan de otras, cuáles son sus atributos internos y cuáles son sus métodos. Una vez definida la clase, es posible crear objetos a partir de ella. Para crear una clase, simplemente agrupa atributos y métodos en el cuerpo de un bloque **clase**.
# Imagina que creas un software para gestionar una escuela, y quieres representar a los "profesores" en tu código Python. Los profesores tendrán unos datos asociados (`atributos` en la jerga de las `clases`), y podrán *realizar acciones* a través de funciones que llamaremos `métodos` (de nuevo, jerga de las `clases`).
#
# Podríamos hacerlo uno por uno:

# %%
class Car ():
    def __init__ (self, color, year, puertas): # INICIALIZAR la isntancia:  # double under: cosas para que funcione python
        self.color = color
        self.year = year
        self.puertas = puertas

# %%
coche_luis = Car("rojo", 2020, 5) # instancio -> se tiene que iniciar 
coche_luis

# %%
coche_laura = Car("gris", 2024, 3) # instancio -> se tiene que iniciar

# %%
coche_laura.year
# Out:
# 2024

# %%
df.shape
# Out:
# (0, 0)

# %%
# init: función necesaria para instanciar una clase definida
# el init recibe: SIEMPRE el self, y luego puede o no recibir argumentos
# se guardan los argumentos como atributos cuando se hace self.algo = algo
# sin init: no se instancia. sin init -> plano del coche, pero no salgo ninguno de fábrica

# %%
class Car ():
    def __init__ (self, color, year, puertas):
        self.color = color
        self.year = year
        self.puertas = puertas
    
    def one_more_year (self): # sumar 1 al self.year # por qué este método no lleva __one_more_year__ ?
        self.year += 1
        return self.year
    
coche_elizabeth = Car("rpojo", 2020, 5) 
coche_elizabeth.one_more_year()
# Out:
# 2021

# %%
# Encapsulado: sólo funciona cuando utilizo esta clase
drop(columns=["col1"]) # no
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Encapsulado: sólo funciona cuando utilizo esta clase
# ----> 2 drop(columns=["col1"])
#
# NameError: name 'drop' is not defined

# %%
class Car ():
    def __init__ (self, color):
        self.color = color

elizabeth_coche = Car(color = "rojo")
elizabeth_coche.color
# Out:
# 'rojo'

# %%
# Por qué no sale el atributo 
class Car():

    def __init__(self, velocity=0):
        self.velocity = velocity

coche_enric = Car()


[i for i in dir(Car) if "_" not in i]
[i for i in dir(coche_enric) if "_" not in i]
# Out:
# ['velocity']

# %%
import math

class Car ():

    PI = math.pi
    
    def __init__ (self, color, year, puertas):
        self.color = color
        self.year = year
        self.puertas = puertas
        self.valor = None
    
    def one_more_year (self): # sumar 1 al self.year # por qué este método no lleva __one_more_year__ ?
        self.year += 1
        return self.year
    
    def nuevo_atributo (self, valor):
        self.nuevo = valor
    
coche_elizabeth = Car("rpojo", 2020, 5) 
coche_elizabeth.one_more_year()
coche_elizabeth.nuevo_atributo("hola")
coche_elizabeth.nuevo
# Out:
# 'hola'

# %% [markdown]
# Os dejo [aquí](https://realpython.com/python-pep8/#naming-styles) un artículo de realpython sobre las convenciones para nombrar cosas (por cosas me refiero a variables, clases, funciones... fragmentos de código)
# La comunidad de usuarios de Python ha adoptado una guía de estilo que hace que el código sea más fácil de leer y consistente entre distintos programas de usuario. Esta guía no es obligatoria de seguir, pero es muy recomendable.

# %% [markdown]
# #### Definiendo una función

# %%
def nombrar (nombre): # verbos -> snake_case; escribir_de_esta_forma
    return nombre

# %% [markdown]
# #### Llamar a una función

# %%
nombrar ("Carlos")
# Out:
# 'Carlos'

# %% [markdown]
# #### Definiendo una clase

# %%
class Car (): # CamelCase -> pd.DataFrame()
    pass

# %%
# PI = variable_constante
# esto_es_una_string = # snake_case

# %% [markdown]
# #### Instanciación de una clase

# %%
coche = Car()

# %% [markdown]
# ### Explorando una clase

# %%
"hola" + "sddsdsds" # sin acceder a métodos internos
# Out:
# 'holasddsdsds'

# %%
"hola".__add__("sddsdsds") # double under
# Out:
# 'holasddsdsds'

# %%
[i for i in dir("hola")] # __add__ -> +
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
122345 + "sdsdf"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 122345 + "sdsdf"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Atributos de instancia
# Contienen datos que son exclusivos de cada instancia.

# %% [markdown]
# En lugar de hacerlo una por una, podemos crear estas variables cada vez que se crea una instancia de un objeto con el método especial `__init__`. Esta función define todas las acciones que se deben realizar cuando creamos un nuevo objeto. La razón por la que tenemos dos guiones bajos antes y después del nombre de la función es para indicar que esta función es interna al objeto y no debe llamarse desde fuera del objeto.

# %% [markdown]
# # Self

# %% [markdown]
# ¿Qué hace self? Indica que los datos que estamos ingresando son para el objeto que estamos creando.

# %%
"Hola".upper()

"Hola" # es una isntancia de la clase Str()
        # que ha sido instanciado con el argumento "Hola"
        # sobre el que le puedo aplicar métodos de string

#upper("Hola")
self.upper() # self es la instancia -> ya es el Hola

# %% [markdown]
# #### Atributos por defecto
#
# Podemos inicializar los atributos con un valor por defecto por si más adelante, al crear las instancias, el usuario o nosotros mismos no ponemos nada en ninguno de los atributos

# %%
import datetime
este_anyo = datetime.datetime.today().year
este_anyo
# Out:
# 2025

# %%
class Car ():
    def __init__(self, n_puertas=5):
        self.este_anyo = datetime.datetime.today().year
        self.n_puertas = n_puertas
    
elizabeth_car = Car(n_puertas=5)
elizabeth_car.este_anyo
elizabeth_car.n_puertas
# Out:
# 3

# %%
class Car ():
    def __init__(self, n_puertas=5):
        self.este_anyo = datetime.datetime.today().year
        self.n_puertas = n_puertas
    
elizabeth_car = Car(n_puertas=5)
elizabeth_car.este_anyo = 2024
elizabeth_car.este_anyo
# Out:
# 2024

# %%
class Car ():
    def __init__(self, este_anyo=datetime.datetime.today().year,  n_puertas=5):
        self.este_anyo = este_anyo
        self.n_puertas = n_puertas
    
elizabeth_car = Car(n_puertas=5)
elizabeth_car.este_anyo
elizabeth_car.n_puertas
# Out:
# 5

# %%
class Staff ():
    pass

# %% [markdown]
# ### Métodos de instancia

# %%
class Staff ():

    # 1. Atributos
    def __init__ (self, nombre, apellido, ciudad="Cáceres"):
        self.apellido = apellido
        self.nombre = nombre
        self.ciudad = ciudad
        self.email = f"{nombre}.{apellido}@empresa.com"
     
alvaro = Staff("Álvaro", "González", "Madrid") # al instanciar, se hace de forma posicional
alvaro.email
# Out:
# 'Álvaro.González@empresa.com'

# %%
# 
class Staff ():

    # 1. Atributos
    def __init__ (self, nombre, apellido, ciudad):
        self.nombre = nombre
        self.apellido = apellido.lower()
        self.ciudad = ciudad
        self.email = f"{nombre.lower()}.{self.apellido}@empresa.com" # aquí hace falta self según la lógica 

    def renombrar (self): # aquí si hace el falta el self
        return self.nombre
    
    def saludar (self): # .drop()
        return f"Hola, soy {self.nombre} {self.apellido} y vivo en {self.ciudad}"

     
alvaro = Staff("Álvaro", "González", "Madrid")
alvaro.email # df.shape
alvaro.saludar() # df.drop()
# Out:
# 'Hola, soy Álvaro gonzález y vivo en Madrid'

# %%
# Q: se podría leer la información de la clase como un diccionario?
class Staff ():

    # 1. Atributos
    def __init__ (self, nombre, apellido, ciudad):
        self.nombre = nombre
        self.apellido = apellido.lower()
        self.ciudad = ciudad
        self.email = f"{nombre.lower()}.{self.apellido}@empresa.com" # aquí hace falta self según la lógica 

    def renombrar (self): # aquí si hace el falta el self
        return self.nombre
    
    def salu_dar (self): # .drop()
        return f"Hola, soy {self.nombre} {self.apellido} y vivo en {self.ciudad}"

     
alvaro = Staff("Álvaro", "González", "Madrid")
alvaro.__dict__
# Out:
# {'nombre': 'Álvaro',
#  'apellido': 'gonzález',
#  'ciudad': 'Madrid',
#  'email': 'álvaro.gonzález@empresa.com'}

# %%
[i for i in dir(alvaro)]

method_list = [func for func in dir(alvaro) if callable(getattr(alvaro, func))]
method_list[-1]
# Out:
# 'salu_dar'

# %%
class Staff ():

    # 1. ATRIBUTOS
    def __init__ (self, nombre, apellido, ciudad, vacaciones=30):
        # 1.1. Generales
        self.nombre = nombre
        self.apellido = apellido.lower()
        self.ciudad = ciudad

        # 2. Construidos
        self.email = f"{nombre.lower()}.{self.apellido}@empresa.com" # aquí hace falta self según la lógica 

        # 3. Para modificar luego
        self.vacaciones = vacaciones
    
    # 2. MÉTODOS
    def saludar (self):
        return f"Hola, soy {self.nombre} {self.apellido} y vivo en {self.ciudad}"
    
    def cogervacaciones (self, dias=1):
        if dias < 0:
            raise ValueError("No puedes des-cogerte días")

        if self.vacaciones >= dias:
            self.vacaciones -= dias
            return self.vacaciones
        else:
            return f"No puedes cogerte {dias} de vacaciones porque te quedan {self.vacaciones}"

     
alvaro = Staff("Álvaro", "González", "Madrid")
alvaro.cogervacaciones(5)
alvaro.vacaciones
# Out:
# 25

# %%
class Exception ():
    pass

class ValueError(Exception):
    pass 

class TypeError(Exception):
    pass

# %%
alvaro.cogervacaciones(-2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 alvaro.cogervacaciones(-2)
#
# Cell In[189], line 18, in Staff.cogervacaciones(self, dias)
#      16 def cogervacaciones (self, dias=1):
#      17     if dias < 0:
# ---> 18         raise ValueError("No puedes des-cogerte días")
#      20     if self.vacaciones >= dias:
#      21         self.vacaciones -= dias
#
# ValueError: No puedes des-cogerte días

# %%
alvaro.cogervacaciones()
alvaro.vacaciones
# Out:
# -21

# %%
class Staff ():

    # 1. ATRIBUTOS
    def __init__ (self, nombre, apellido, ciudad, vacaciones=30):
        # 1.1. Generales
        self.nombre = nombre
        self.apellido = apellido.lower()
        self.ciudad = ciudad

        # 2. Construidos
        self.email = f"{nombre.lower()}.{self.apellido}@empresa.com" # aquí hace falta self según la lógica 

        # 3. Para modificar luego
        self.vacaciones = vacaciones
    
    # 2. MÉTODOS
    def saludar (self):
        return f"Hola, soy {self.nombre} {self.apellido} y vivo en {self.ciudad}"
    
    def cogervacaciones (self, dias=1):
        if dias < 0:
            raise ValueError("No puedes des-cogerte días")

        if self.vacaciones >= dias:
            self.vacaciones -= dias
            return self.vacaciones
        else:
            return f"No puedes cogerte {dias} de vacaciones porque te quedan {self.vacaciones}"

     
alvaro = Staff("Álvaro", "González", "Madrid")
alvaro.cogervacaciones(5)
alvaro.vacaciones
# Out:
# 25

# %%
# ejemplo sin self

class Marketing (Staff):
    
    def publicar ():
        return f"He subido algo a instagram"

carlos = Marketing("Carlos", "Martínez", "Álava")
carlos.nombre
carlos.email
carlos.saludar()
carlos.publicar() # ¿qué argumento estoy pasando? 🥴
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[204], line 12
#      10 carlos.email
#      11 carlos.saludar()
# ---> 12 carlos.publicar() # ¿qué argumento estoy pasando? 🥴
#
# TypeError: publicar() takes 0 positional arguments but 1 was given

# %%
alvaro.pulicar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 alvaro.pulicar()
#
# AttributeError: 'Staff' object has no attribute 'pulicar'

# %%
class Marketing (Staff):

    #self.red_social = red_social
    
    def publicar (self):
        return f"He subido algo a instagram"

carlos = Marketing("Carlos", "Martínez", "Álava")
carlos.nombre
carlos.email
carlos.saludar()
carlos.publicar() # ¿qué argumento estoy pasando? 🥴
# Out:
# 'He subido algo a instagram'

# %%
class Marketing (Staff):

    def __init__(self, nombre, apellido, ciudad, red_social):
        super().__init__(nombre, apellido, ciudad) # super.__init__() # elegir las propiedades a heredar
        self.red_social = red_social
    
    def publicar (self):
        return f"He subido algo a {self.red_social}"

carlos = Marketing("Carlos", "Martínez", "Álava", "instagram")
carlos.nombre
carlos.email
carlos.saludar()
carlos.publicar() # ¿qué argumento estoy pasando? 🥴
# Out:
# 'He subido algo a instagram'

# %%
class Marketing (Staff):

    def __init__(self, nombre, apellido, ciudad, red_social, vacaciones=30):
        super().__init__(nombre, apellido, ciudad, vacaciones)
        self.red_social = red_social
    
    def publicar (self):
        return f"He subido algo a {self.red_social}"

carlos = Marketing("Carlos", "Martínez", "Álava", "instagram")
carlos.nombre
carlos.email
carlos.vacaciones
# Out:
# 30

# %%
class Sales (Staff):
    def __init__(self, nombre, apellido, ciudad):
        super().__init__(nombre, apellido, ciudad)
        self.total_ventas = 13
    
    def vender (self, ventas_hechas):
        self.total_ventas += ventas_hechas
        return f"He vendido un total de {self.total_ventas} porque hoy he hecho {ventas_hechas}"

# %%
carmen = Sales(nombre="Carmen", apellido="Gzlz", ciudad="Alicante")
carmen.total_ventas
# Out:
# 13

# %%
carmen.vender(3)
# Out:
# 'He vendido u ntotal de 3 porque hoy he hecho 3'

# %%
carmen.vender(1)
# Out:
# 'He vendido u ntotal de 4 porque hoy he hecho 1'

# %%
class Todo (Marketing, Sales):
    pass

adrian = Todo(nombre="Adrián", apellido="Rodríguez", "Sevilla", "Instagram")
adrian
# Out:
#   Cell In[236], line 4
#     adrian = Todo(nombre="Adrián", apellido="Rodríguez", "Sevilla", "Instagram")
#                                                                                ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# Son funciones dentro de las clases que nos ahorrarán mucho tiempo

# %% [markdown]
# _⚠️: Variables de destino al crear instancias, ¿ignorando valores predeterminados?_

# %% [markdown]
# **Atención** 👀
# Si modificamos una clase y añadimos atributos o métodos, tenemos que volver a crear el objeto para que se inicialice con esos atributos y tenga esos métodos.

# %% [markdown]
# #### Python está construido con objetos
# En Python, los tipos de datos primitivos también son objetos que tienen atributos y métodos asociados.

# %% [markdown]
# Siempre que hacemos algo, es porque estamos llamando a los métodos/atributos de esa clase.

# %% [markdown]
# ### Variables de clase

# %% [markdown]
# En general, no se deben utilizar atributos de clase, excepto para almacenar valores constantes.

# %% [markdown]
# **Hands on 💪**
#
# Crea una clase `Círculo` con:
# - `radio` como variable de instancia
# - `pi` (math.pi) como variable de clase
# - un método `calculate_area(self)` que devuelve el área del objeto "círculo"

# %% [markdown]
# Crea una clase Cliente que almacene nombren, email y saldo. Implementa métodos para agregar saldo y realizar compras, asegurando qeu el saldo sea suficiente

# %% [markdown]
# ## Antes de continuar, tomemos un respiro y repasemos el vocabulario.

# %% [markdown]
# - **Clase**: El cortador de galletas. Con la clase podemos generar instancias u objetos.
# - **Objeto**: La galleta que generamos. Cada objeto tiene características diferentes pero bajo el mismo patrón que la clase.
# - **Instancia**: Lo mismo que objeto, es un sinónimo :) jeje
# - **Atributo**: Los diferentes ingredientes de cada objeto. Se definen como argumentos en la función __init__ pero se guardan como datos cuando instanciamos un objeto llamando a la clase

# %% [markdown]
# * **Atributo de clase**: Variables que pertenecen a la clase y que serán las mismas en todos los objetos.
# * **Atributo de objeto/instancia**: Los atributos explicados anteriormente, específicos de cada objeto.
# * **Método**: Funciones que hacen cosas

# %% [markdown]
# #### Ejercicio fácil
# Kata --> https://www.codewars.com/kata/53f0f358b9cb376eca001079/train/python
#
# Puedes ignorar el "objeto" por ahora

# %% [markdown]
# ## Herencia

# %% [markdown]
# La herencia permite definir nuevas clases a partir de clases existentes. La clase de la que se hereda se denomina "clase padre"/"superclase"/"padre". La clase que hereda se denomina "clase hija" o "subclase".
# La clase hija "hereda" todas las propiedades de la clase padre y nos permite anular métodos y atributos o añadir otros nuevos. La ventaja fundamental que aporta el mecanismo de herencia a la programación es la capacidad de reutilizar código. Así, un conjunto de clases que comparten atributos y métodos pueden heredar de una superclase donde se definen dichos métodos y atributos.

# %% [markdown]
# - Método definido en la clase `parent`, pero no en la `child`
#
# En este caso, el método child heredará el método parent, funcionará exactamente igual y no hay necesidad de sobreescribirlo.
#
# - Método definido en `Child`, pero no en Parent
#
# El método solo pertenece al método child. La herencia es unidireccional.
#
# - Método establecido en "both".
#
# Aquí pueden pasar dos cosas, pero ambas son una variante del mismo hecho. El método escrito en la clase `Child` sobreescribirá el método previamente definido en Parent.
#
# Sin embargo, si queremos usar el método original y solo agregarle algo más, siempre podemos hacer referencia al método original (parent) con `super()`. La función `super()` nos permite llamar a cualquier método de la clase parent. Solo recuerda llamarlo en la nueva definición y asegurarte de obtener todos los atributos que necesita 😉 .

# %% [markdown]
# ### super()

# %% [markdown]
# ## Resumen

# %% [markdown]
# ## Materiales adicionales
#
# - Tutorial de Youtube de [Corey Schafer](https://www.youtube.com/watch?v=ZDa-Z5JzLYM)
# - [Python real](https://docs.hektorprofe.net/python/object-oriented-programming/classes-and-objects/)
# - [Lectura interesante](https://medium.com/@shaistha24/functional-programming-vs-object-oriented-programming-oop-which-is-better-82172e53a526) --> Programación orientada a objetos vs. programación funcional

# %% [markdown]
# ### Métodos **AVANZADOS**
# - @classmethod@staticmethod
# * [Python real - @classmethod/@stathicmethod](https://realpython.com/instance-class-and-static-methods-demystified/).
