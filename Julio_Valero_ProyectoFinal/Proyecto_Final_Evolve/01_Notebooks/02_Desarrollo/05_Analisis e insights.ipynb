# %% [markdown]
# # ANALISIS E INSIGHTS

# %% [markdown]
# Llegamos a la parte más importante, donde vamos a intentar obtener conclusiones relevantes para el objetivo utilizando todo el trabajo de preparación que hemos hecho, las técnicas de Business Analytics que ya conocemos y además vamos a aprender a crear una visualización en mapa.
#
# Para ello empezaremos dando respuesta a las preguntas semilla y es probable que en el proceso nos vayan surgiendo hallazgos interesantes que nos lleven a nuevas preguntas o a la aplicación de ciertas técnicas.

# %% [markdown]
# ## SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa

#Automcompletar rápido
# %config IPCompleter.greedy=True

pd.options.display.max_columns = None

# %% [markdown]
# ## CARGA DE DATOS

# %%
con = sa.create_engine('sqlite:///../../02_Datos/01_Originales/airbnb2025.db')

df = pd.read_sql('df_preparado', con = con)

df.head()
# Out:
#    index     id                                          name  \
# 0      0  21853                          Bright and airy room
# 1      1  30320                   Great Vacational Apartments
# 2      2  30959               Beautiful loft in Madrid Center
# 3      3  40916               Holiday Apartment Madrid Center
# 4      4  62423  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
#
#   host_response_time host_is_superhost  host_verifications  \
# 0        no response                 f  ['email', 'phone']
# 1        no response                 f  ['email', 'phone']
# 2        no response                 f  ['email', 'phone']
# 3        no response                 f  ['email', 'phone']
# 4     within an hour                 f  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                    t                      t               Cármenes
# 1                    t                      f                    Sol
# 2                    t                      f            Embajadores
# 3                    t                      f            Universidad
# 4                    t                      t               Justicia
#
#                  property_type        room_type  \
# 0  Private room in rental unit     Private room
# 1           Entire rental unit  Entire home/apt
# 2                  Entire loft  Entire home/apt
# 3           Entire rental unit  Entire home/apt
# 4  Private room in rental unit     Private room
#
#                                            amenities has_availability license  \
# 0  ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes      no
# 1  ["Heating", "Wifi", "TV with standard cable", ...               no      no
# 2  ["Breakfast", "Heating", "Wifi", "Smoking allo...               no      no
# 3  ["Heating", "Wifi", "Pets allowed", "Kitchen",...               no      no
# 4  ["Books and reading material", "First aid kit"...              yes      no
#
#   instant_bookable neighbourhood_group  host_id host_since  \
# 0                f              Latina    83531 2010-02-21
# 1                f              Centro   130907 2010-05-24
# 2                f              Centro   132883 2010-05-26
# 3                f              Centro   130907 2010-05-24
# 4                f              Centro   303845 2010-11-29
#
#    host_response_rate  host_acceptance_rate  host_listings_count  \
# 0                 0.0                   0.0                  2.0
# 1                 0.0                  93.0                  3.0
# 2                 0.0                  88.0                  1.0
# 3                 0.0                  89.0                  3.0
# 4               100.0                 100.0                  3.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                        2.0  40.40381   -3.74130             1        1.0
# 1                        6.0  40.41476   -3.70418             2        1.0
# 2                        4.0  40.41259   -3.70105             2        1.0
# 3                        6.0  40.42247   -3.70577             3        1.0
# 4                        3.0  40.41884   -3.69655             4        1.5
#
#    bedrooms  beds  price  minimum_nights  maximum_nights  availability_30  \
# 0       1.0   1.0     31               4              40                0
# 1       1.0   1.0    149               5             180                0
# 2       1.0   1.0     92               3             730                0
# 3       1.0   2.0    124               5             180                0
# 4       1.0   2.0     69               1              30               13
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0                0                0               144                 33
# 1                0                0                 0                172
# 2                0                0                 0                  8
# 3                0                0                 0                 49
# 4               37               59               332                219
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                      0                       0   2014-10-10  2018-07-15
# 1                      0                       0   2010-07-06  2022-09-26
# 2                      0                       0   2015-05-12  2017-05-30
# 3                      0                       0   2010-11-01  2021-12-11
# 4                     44                       3   2018-05-10  2024-11-24
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.58                    4.72                       4.56
# 1                  4.63                    4.71                       4.88
# 2                  4.38                    4.14                       4.38
# 3                  4.65                    4.69                       4.90
# 4                  4.64                    4.78                       4.42
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.75                         4.82                    4.21
# 1                   4.82                         4.78                    4.90
# 2                   4.63                         4.63                    4.88
# 3                   4.85                         4.79                    4.88
# 4                   4.79                         4.85                    4.97
#
#    review_scores_value  calculated_host_listings_count  \
# 0                 4.67                               2
# 1                 4.69                               3
# 2                 4.25                               1
# 3                 4.55                               3
# 4                 4.58                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            3
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             2
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  precio_m2  \
# 0                                            0               0.27       2772
# 1                                            0               0.98       6170
# 2                                            0               0.07       6170
# 3                                            0               0.29       6170
# 4                                            0               2.73       6170
#
#    precio_total  ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 0         31.00         60        01_Una               0-3         1
# 1        149.00        100        01_Una               0-3         1
# 2         92.00        100        01_Una               0-3         1
# 3        124.00        100        01_Una               0-3         3
# 4        137.62          9        01_Una                 4         3
#
#   number_of_reviews_disc  m2  precio_compra   pdi_sol  pisos_rentables
# 0                   5-71  50       110880.0  3.521406                1
# 1                71-1136  50       246800.0  0.230175                1
# 2                    1-4  50       246800.0  0.499379                1
# 3                   5-71  50       246800.0  0.671046                1
# 4                71-1136  50       246800.0  0.621024                0

# %% [markdown]
# ## ANALISIS

# %% [markdown]
# ### Analisis sobre el precio

# %% [markdown]
# **¿Cual es el precio medio? ¿y el rango de precios?¿Y por distritos?¿Y por barrios?**
#
# **¿Cual es el ranking de distritos y barrios por precio medio de alquiler?**

# %%
df.precio_total.describe()
# Out:
# count    25913.000000
# mean       137.748630
# std        388.139306
# min         20.000000
# 25%         68.000000
# 50%        100.000000
# 75%        142.000000
# max      21347.000000
# Name: precio_total, dtype: float64

# %% [markdown]
# Vemos que hay al menos un atípico por la parte de arriba que sesga la media, por tanto vamos a usar la mediana como medida de centralización más fiable.

# %%
df.precio_total.median()
# Out:
# 100.0

# %%
df.groupby('neighbourhood_group').precio_total.median().sort_values(ascending = False)
# Out:
# neighbourhood_group
# Salamanca             120.00
# Centro                111.00
# Chamartín             109.00
# Chamberí              104.00
# Moncloa               101.00
# Retiro                 99.00
# Tetuán                 92.00
# San Blas               89.81
# Hortaleza              86.00
# Arganzuela             85.00
# Fuencarral             82.50
# Barajas                79.00
# Ciudad Lineal          78.00
# Latina                 70.00
# Puente de Vallecas     66.00
# Carabanchel            65.00
# Villaverde             60.50
# Villa de Vallecas      60.00
# Usera                  59.00
# Vicálvaro              51.00
# Moratalaz              47.50
# Name: precio_total, dtype: float64

# %% [markdown]
# Nos llama la atención el dato de San Blas, vamos a verlo con más detalle a ver qué está pasando.

# %%
df.loc[df.neighbourhood_group == 'San Blas'].sort_values('precio_total',ascending = False).head(10)
# Out:
#        index                   id  \
# 3307    3307             20842089
# 6365    6365             35155733
# 12046  12046   700011597005161293
# 5774    5774             34569100
# 6171    6171             34970236
# 6313    6313             35137335
# 6036    6036             34796669
# 5878    5878             34614302
# 17751  17751  1029047360999100969
# 11536  11536   668761907769527441
#
#                                                     name  host_response_time  \
# 3307         Mas cerca del Wanda Metropolitano imposible         no response
# 6365           Cosy apartment near Metropolitano Stadium         no response
# 12046                               Habitación reformada         no response
# 5774    Final Champions close of Wanda Stadium.Two Rooms         no response
# 6171   Habitaciones cerca Wanda Metropolitano (Champi...         no response
# 6313                      Bedrooms Champion League Final  a few days or more
# 6036               Bedrooms close to Wanda Metropolitano         no response
# 5878          Wanda Metropolitano Final Champions League         no response
# 17751     Beatifull apartement in the center of the city         no response
# 11536                    Comuna en las afueras de Madrid         no response
#
#       host_is_superhost                host_verifications  \
# 3307                  f                ['email', 'phone']
# 6365                  f                ['email', 'phone']
# 12046                 f                ['email', 'phone']
# 5774                  f                ['email', 'phone']
# 6171                  f                ['email', 'phone']
# 6313                  f                ['email', 'phone']
# 6036                  f                ['email', 'phone']
# 5878                  f                ['email', 'phone']
# 17751                 f                ['email', 'phone']
# 11536                 f  ['email', 'phone', 'work_email']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3307                     t                      f                  Rosas
# 6365                     t                      t                 Hellín
# 12046                    t                      t                  Arcos
# 5774                     t                      t                  Rosas
# 6171                     t                      f                  Arcos
# 6313                     t                      t                  Arcos
# 6036                     t                      f                  Rosas
# 5878                     t                      t                  Rosas
# 17751                    t                      t                  Rejas
# 11536                    t                      t               Simancas
#
#                            property_type        room_type  \
# 3307                Private room in home     Private room
# 6365         Private room in rental unit     Private room
# 12046  Private room in bed and breakfast     Private room
# 5774                Private room in home     Private room
# 6171                Private room in home     Private room
# 6313                Private room in home     Private room
# 6036                Private room in home     Private room
# 5878               Private room in condo     Private room
# 17751                        Entire home  Entire home/apt
# 11536         Shared room in rental unit      Shared room
#
#                                                amenities has_availability  \
# 3307   ["BBQ grill", "Dishwasher", "Pool", "Gym", "Br...              yes
# 6365   ["Private living room", "Hangers", "Heating", ...              yes
# 12046                ["Wifi", "Kitchen", "TV", "Washer"]              yes
# 5774   ["Hangers", "Breakfast", "Heating", "Wifi", "H...              yes
# 6171   ["Exterior security cameras on property", "Bre...               no
# 6313   ["Hangers", "First aid kit", "Heating", "Wifi"...              yes
# 6036   ["Hangers", "Exterior security cameras on prop...              yes
# 5878   ["Hangers", "First aid kit", "Heating", "Wifi"...              yes
# 17751                                           ["Wifi"]              yes
# 11536                                                 []              yes
#
#       license instant_bookable neighbourhood_group    host_id host_since  \
# 3307       no                t            San Blas   11086450 2014-01-07
# 6365       no                t            San Blas   78241549 2016-06-17
# 12046      no                f            San Blas  144457564 2017-08-05
# 5774       no                t            San Blas  231479865 2018-12-19
# 6171       no                f            San Blas  263474389 2019-05-22
# 6313       no                t            San Blas  124425621 2017-04-05
# 6036       no                t            San Blas   49642755 2015-11-22
# 5878       no                t            San Blas  261135831 2019-05-11
# 17751      no                t            San Blas  528957573 2023-07-31
# 11536      no                t            San Blas  369250484 2020-09-25
#
#        host_response_rate  host_acceptance_rate  host_listings_count  \
# 3307                  0.0                  75.0                  1.0
# 6365                  0.0                  86.0                  1.0
# 12046                 0.0                  80.0                  1.0
# 5774                  0.0                  75.0                  1.0
# 6171                  0.0                  80.0                  1.0
# 6313                  0.0                  80.0                  2.0
# 6036                  0.0                  75.0                  2.0
# 5878                  0.0                  75.0                  3.0
# 17751                 0.0                 100.0                  3.0
# 11536                 0.0                  85.0                  1.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 3307                         1.0  40.430030  -3.599750             3
# 6365                         1.0  40.431270  -3.612340             5
# 12046                        1.0  40.423490  -3.620860             3
# 5774                         3.0  40.429030  -3.607640             3
# 6171                         2.0  40.419200  -3.612290            10
# 6313                         3.0  40.426580  -3.611960             3
# 6036                         2.0  40.425620  -3.604900             3
# 5878                         3.0  40.430820  -3.604610             3
# 17751                        6.0  40.446989  -3.596043             1
# 11536                        1.0  40.438370  -3.619480             1
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 3307         1.0       2.0   3.0    700               2              30
# 6365         1.5       2.0   2.0   1050               1               3
# 12046        1.0       1.0   2.0   1000               2               3
# 5774         2.0       2.0   2.0    950               1               3
# 6171         4.0       5.0   4.0    469               1               3
# 6313         2.0       2.0   3.0    500               1               3
# 6036         1.5       2.0   2.0    700               1               4
# 5878         2.0       2.0   2.0    508               1               1
# 17751        1.0       1.0   1.0   1001               1             365
# 11536        0.5       1.0   1.0   1000               1             365
#
#        availability_30  availability_60  availability_90  availability_365  \
# 3307                30               60               90               365
# 6365                30               60               90               365
# 12046               29               59               89                89
# 5774                30               60               90               365
# 6171                 0                0                0                 0
# 6313                30               60               90               365
# 6036                28               58               88                88
# 5878                 0                0                0                 0
# 17751               30               60               90               270
# 11536               30               60               90               365
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 3307                   0                      0                       0
# 6365                   0                      0                       0
# 12046                  1                      0                       0
# 5774                   1                      0                       0
# 6171                   0                      0                       0
# 6313                   0                      0                       0
# 6036                   0                      0                       0
# 5878                   0                      0                       0
# 17751                  0                      0                       0
# 11536                  0                      0                       0
#
#       first_review last_review  review_scores_rating  review_scores_accuracy  \
# 3307    2014-01-07  2014-01-07                   0.0                     0.0
# 6365    2016-06-17  2016-06-17                   0.0                     0.0
# 12046   2022-09-28  2022-09-28                   5.0                     5.0
# 5774    2019-06-02  2019-06-02                   5.0                     5.0
# 6171    2019-05-22  2019-05-22                   0.0                     0.0
# 6313    2017-04-05  2017-04-05                   0.0                     0.0
# 6036    2015-11-22  2015-11-22                   0.0                     0.0
# 5878    2019-05-11  2019-05-11                   0.0                     0.0
# 17751   2023-07-31  2023-07-31                   0.0                     0.0
# 11536   2020-09-25  2020-09-25                   0.0                     0.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 3307                         0.0                    0.0
# 6365                         0.0                    0.0
# 12046                        5.0                    5.0
# 5774                         5.0                    5.0
# 6171                         0.0                    0.0
# 6313                         0.0                    0.0
# 6036                         0.0                    0.0
# 5878                         0.0                    0.0
# 17751                        0.0                    0.0
# 11536                        0.0                    0.0
#
#        review_scores_communication  review_scores_location  \
# 3307                           0.0                     0.0
# 6365                           0.0                     0.0
# 12046                          5.0                     5.0
# 5774                           5.0                     5.0
# 6171                           0.0                     0.0
# 6313                           0.0                     0.0
# 6036                           0.0                     0.0
# 5878                           0.0                     0.0
# 17751                          0.0                     0.0
# 11536                          0.0                     0.0
#
#        review_scores_value  calculated_host_listings_count  \
# 3307                   0.0                               1
# 6365                   0.0                               1
# 12046                  5.0                               1
# 5774                   5.0                               1
# 6171                   0.0                               1
# 6313                   0.0                               1
# 6036                   0.0                               2
# 5878                   0.0                               1
# 17751                  0.0                               1
# 11536                  0.0                               1
#
#        calculated_host_listings_count_entire_homes  \
# 3307                                             0
# 6365                                             0
# 12046                                            0
# 5774                                             0
# 6171                                             0
# 6313                                             0
# 6036                                             0
# 5878                                             0
# 17751                                            1
# 11536                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 3307                                              1
# 6365                                              1
# 12046                                             1
# 5774                                              1
# 6171                                              1
# 6313                                              1
# 6036                                              2
# 5878                                              1
# 17751                                             0
# 11536                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 3307                                             0               0.00
# 6365                                             0               0.00
# 12046                                            0               0.04
# 5774                                             0               0.01
# 6171                                             0               0.00
# 6313                                             0               0.00
# 6036                                             0               0.00
# 5878                                             0               0.00
# 17751                                            0               0.00
# 11536                                            1               0.00
#
#        precio_m2  precio_total  ocupacion    bedrooms_disc accommodates_disc  \
# 3307        2996       2099.62          0           02_Dos               0-3
# 6365        2996       2099.62          0           02_Dos              4-16
# 12046       2996       1999.62         75           01_Una               0-3
# 5774        2996       1899.62          0           02_Dos               0-3
# 6171        2996       1875.62        100  04_Cuatro o mas              4-16
# 6313        2996       1499.62          0           02_Dos               0-3
# 6036        2996       1399.62         75           02_Dos               0-3
# 5878        2996       1015.62        100           02_Dos               0-3
# 17751       2996       1001.00         26           01_Una               0-3
# 11536       2996       1000.00          0           01_Una               0-3
#
#       beds_disc number_of_reviews_disc   m2  precio_compra   pdi_sol  \
# 3307          3                    1-4   70       167776.0  8.895150
# 6365          3                    1-4   70       167776.0  7.873067
# 12046         3                    1-4   50       119840.0  7.024499
# 5774          3                    1-4   70       167776.0  8.217940
# 6171       3-19                    1-4  150       359520.0  7.714952
# 6313          3                    1-4   70       167776.0  7.814783
# 6036          3                    1-4   70       167776.0  8.393914
# 5878          3                    1-4   70       167776.0  8.505350
# 17751         1                    1-4   50       119840.0  9.687539
# 11536         1                    1-4   50       119840.0  7.497144
#
#        pisos_rentables
# 3307                 0
# 6365                 0
# 12046                1
# 5774                 0
# 6171                 1
# 6313                 0
# 6036                 1
# 5878                 1
# 17751                1
# 11536                0

# %% [markdown]
# Vemos que hay precios superiores a 2000 euros que por la zona entendemos que son datos atípicos de alquileres pero, por conocimiento del negocio y de la ciudad, sabemos que el estadio del Atlético de Madrid está allí y esas noches tan caras es muy probable que sean las noches de los partidos importantes como los de la Champions League. Lo cual es un insight interesante:
#
# **Insight 1: pueden existir inmuebles con un valor regular residual pero con alto valor en momentos puntuales por acontenicimientos deportivos o espectáculos**
#
# ¿Tendría sentido generar un producto de alquiler que consista en alquilar de forma "normal" a un precio inferior al mercado con la condición de que el inquilino deje el piso libre para alquilarlo "turísticamente" en fechas señaladas?

# %% [markdown]
# En el resto no hay sorpresas, con distritos como Salamanca, Centro o Chanmartín a la cabeza.
#
# Pero por ejemplo vemos que la diferencia de precio media entre Retiro y Tetuán es muy baja.
#
# Esto nos lleva a comparar el precio medio por distrito con el precio medio de compra también por distrito.

# %%
temp = df.groupby('neighbourhood_group')[['precio_total','precio_compra']].median()
temp
# Out:
#                      precio_total  precio_compra
# neighbourhood_group
# Arganzuela                  85.00       194000.0
# Barajas                     79.00       147440.0
# Carabanchel                 65.00       108480.0
# Centro                     111.00       246800.0
# Chamartín                  109.00       251400.0
# Chamberí                   104.00       266600.0
# Ciudad Lineal               78.00       147040.0
# Fuencarral                  82.50       161520.0
# Hortaleza                   86.00       174720.0
# Latina                      70.00       110880.0
# Moncloa                    101.00       195040.0
# Moratalaz                   47.50       125440.0
# Puente de Vallecas          66.00        94680.0
# Retiro                      99.00       221960.0
# Salamanca                  120.00       313840.0
# San Blas                    89.81       119840.0
# Tetuán                      92.00       181440.0
# Usera                       59.00        99880.0
# Vicálvaro                   51.00       117880.0
# Villa de Vallecas           60.00       113200.0
# Villaverde                  60.50        82800.0

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# Existe una clara correlación entre el precio de compra en cada distrito y el precio que podremos cobrar. Claramente se perciben tres clusters de bajo-bajo, medio-medio y alto-alto, y la excepción de San Blas que ya sabemos por qué es.
#
# Por tanto, como era esperable no hay a priori ningún "chollo" claro a este nivel, así que vamos a repetir el análisis a nivel de barrio a ver si identificamos algo.

# %%
temp = df.groupby('neighbourhood_cleansed')[['precio_total','precio_compra']].median()
temp
# Out:
#                         precio_total  precio_compra
# neighbourhood_cleansed
# Abrantes                       57.00       108480.0
# Acacias                        77.62       194000.0
# Adelfas                        90.00       221960.0
# Aeropuerto                     56.50       147440.0
# Aguilas                        50.00       110880.0
# ...                              ...            ...
# Valverde                       81.00       161520.0
# Ventas                         64.00       147040.0
# Vinateros                      32.50       125440.0
# Vista Alegre                   59.00       108480.0
# Zofío                          54.50        99880.0
#
# [127 rows x 2 columns]

# %%
plt.figure(figsize = (16,20))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# A este nivel ya vemos más cosas:
#
# * 1 barrio que sobresale de San Blas
# * Dentro de cada grupo de bajo-medio-alto sí podemos empezar a separarar
#     * Bajo <150K: Amposta
#     * Medio 150K-250K: Arguelles y Cortés
#     * Medio-alto 250K-350K: Almagro
#     * Alto >350K: Castellana
#
# **Insight 2: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste y además podemos segmentarlo por el tipo calidad del inmueble en el que nos interes invertir**

# %%
df.loc[df.neighbourhood_cleansed.isin(['Amposta']),'neighbourhood_group'].unique()
# Out:
# array(['San Blas'], dtype=object)

# %% [markdown]
# **¿Qué factores (a parte de la localización determinan el precio del alquiler?**

# %% [markdown]
# Para responder a esta pregunta podemos construir un minicubo, ya que hemos discretizado nuestras variables de análisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25913 entries, 0 to 25912
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   index                                         25913 non-null  int64
#  1   id                                            25913 non-null  int64
#  2   name                                          25913 non-null  object
#  3   host_response_time                            25913 non-null  object
#  4   host_is_superhost                             25913 non-null  object
#  5   host_verifications                            25913 non-null  object
#  6   host_has_profile_pic                          25913 non-null  object
#  7   host_identity_verified                        25913 non-null  object
#  8   neighbourhood_cleansed                        25913 non-null  object
#  9   property_type                                 25913 non-null  object
#  10  room_type                                     25913 non-null  object
#  11  amenities                                     25913 non-null  object
#  12  has_availability                              25913 non-null  object
#  13  license                                       25913 non-null  object
#  14  instant_bookable                              25913 non-null  object
#  15  neighbourhood_group                           25913 non-null  object
#  16  host_id                                       25913 non-null  int64
#  17  host_since                                    25913 non-null  datetime64[ns]
#  18  host_response_rate                            25913 non-null  float64
#  19  host_acceptance_rate                          25913 non-null  float64
#  20  host_listings_count                           25913 non-null  float64
#  21  host_total_listings_count                     25913 non-null  float64
#  22  latitude                                      25913 non-null  float64
#  23  longitude                                     25913 non-null  float64
#  24  accommodates                                  25913 non-null  int64
#  25  bathrooms                                     25913 non-null  float64
#  26  bedrooms                                      25913 non-null  float64
#  27  beds                                          25913 non-null  float64
#  28  price                                         25913 non-null  int64
#  29  minimum_nights                                25913 non-null  int64
#  30  maximum_nights                                25913 non-null  int64
#  31  availability_30                               25913 non-null  int64
#  32  availability_60                               25913 non-null  int64
#  33  availability_90                               25913 non-null  int64
#  34  availability_365                              25913 non-null  int64
#  35  number_of_reviews                             25913 non-null  int64
#  36  number_of_reviews_ltm                         25913 non-null  int64
#  37  number_of_reviews_l30d                        25913 non-null  int64
#  38  first_review                                  25913 non-null  datetime64[ns]
#  39  last_review                                   25913 non-null  datetime64[ns]
#  40  review_scores_rating                          25913 non-null  float64
#  41  review_scores_accuracy                        25913 non-null  float64
#  42  review_scores_cleanliness                     25913 non-null  float64
#  43  review_scores_checkin                         25913 non-null  float64
#  44  review_scores_communication                   25913 non-null  float64
#  45  review_scores_location                        25913 non-null  float64
#  46  review_scores_value                           25913 non-null  float64
#  47  calculated_host_listings_count                25913 non-null  int64
#  48  calculated_host_listings_count_entire_homes   25913 non-null  int64
#  49  calculated_host_listings_count_private_rooms  25913 non-null  int64
#  50  calculated_host_listings_count_shared_rooms   25913 non-null  int64
#  51  reviews_per_month                             25913 non-null  float64
#  52  precio_m2                                     25913 non-null  int64
#  53  precio_total                                  25913 non-null  float64
#  54  ocupacion                                     25913 non-null  int64
#  55  bedrooms_disc                                 25913 non-null  object
#  56  accommodates_disc                             25913 non-null  object
#  57  beds_disc                                     25913 non-null  object
#  58  number_of_reviews_disc                        25913 non-null  object
#  59  m2                                            25913 non-null  int64
#  60  precio_compra                                 25913 non-null  float64
#  61  pdi_sol                                       25913 non-null  float64
#  62  pisos_rentables                               25913 non-null  int64
# dtypes: datetime64[ns](3), float64(20), int64(22), object(18)
# memory usage: 12.5+ MB

# %%
#Paso 1: Seleccionar qué variables serán la métricas y cuales las dimensiones
metricas = ['precio_total','precio_compra']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_precio = df[dimensiones + metricas]
minicubo_precio
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_Una               0-3         1                   5-71
# 1            01_Una               0-3         1                71-1136
# 2            01_Una               0-3         1                    1-4
# 3            01_Una               0-3         3                   5-71
# 4            01_Una                 4         3                71-1136
# ...             ...               ...       ...                    ...
# 25908        01_Una               0-3         1                    1-4
# 25909        01_Una                 4         3                    1-4
# 25910        01_Una               0-3         1                    1-4
# 25911        01_Una               0-3         3                    1-4
# 25912        01_Una               0-3         1                    1-4
#
#        precio_total  precio_compra
# 0             31.00       110880.0
# 1            149.00       246800.0
# 2             92.00       246800.0
# 3            124.00       246800.0
# 4            137.62       246800.0
# ...             ...            ...
# 25908         85.00       147040.0
# 25909        258.00       110880.0
# 25910         20.00       246800.0
# 25911        258.00       110880.0
# 25912        161.00       194000.0
#
# [25913 rows x 6 columns]

# %%
#Paso 2: pasar a transaccional las dimensiones
minicubo_precio = minicubo_precio.melt(id_vars=['precio_total','precio_compra'])
minicubo_precio
# Out:
#         precio_total  precio_compra                variable   value
# 0              31.00       110880.0           bedrooms_disc  01_Una
# 1             149.00       246800.0           bedrooms_disc  01_Una
# 2              92.00       246800.0           bedrooms_disc  01_Una
# 3             124.00       246800.0           bedrooms_disc  01_Una
# 4             137.62       246800.0           bedrooms_disc  01_Una
# ...              ...            ...                     ...     ...
# 103647         85.00       147040.0  number_of_reviews_disc     1-4
# 103648        258.00       110880.0  number_of_reviews_disc     1-4
# 103649         20.00       246800.0  number_of_reviews_disc     1-4
# 103650        258.00       110880.0  number_of_reviews_disc     1-4
# 103651        161.00       194000.0  number_of_reviews_disc     1-4
#
# [103652 rows x 4 columns]

# %%
#Paso 3: Agregar las métricas por "variable" y "valor" con las funciones deseadas
minicubo_precio = minicubo_precio.groupby(['variable','value'])[['precio_total','precio_compra']].agg('median')
minicubo_precio
# Out:
#                                         precio_total  precio_compra
# variable               value
# accommodates_disc      0-3                      80.0       201120.0
#                        4                       121.0       246800.0
#                        4-16                    175.0       345520.0
# bedrooms_disc          00_Estudio               82.0       197440.0
#                        01_Una                   86.0       246800.0
#                        02_Dos                  137.0       345520.0
#                        03_Tres                 180.0       444240.0
#                        04_Cuatro o mas         250.0       592320.0
# beds_disc              1                        74.0       197440.0
#                        3                       123.0       246800.0
#                        3-19                    190.0       359520.0
# number_of_reviews_disc 1-4                      99.0       246800.0
#                        5-71                    100.0       246800.0
#                        71-1136                 100.0       246800.0

# %% [markdown]
# Sobre el minicubo vamos analizando cada variable.

# %%
minicubo_precio.loc['bedrooms_disc']
# Out:
#                  precio_total  precio_compra
# value
# 00_Estudio               82.0       197440.0
# 01_Una                   86.0       246800.0
# 02_Dos                  137.0       345520.0
# 03_Tres                 180.0       444240.0
# 04_Cuatro o mas         250.0       592320.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['bedrooms_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['bedrooms_disc'].precio_compra,color = 'green');

# %% [markdown]
# En cuanto al número de habitaciones entre cero y una habitación, el precio_compra casi no varia pero si aumenta el precio_total por lo que sería mas rentable
#
# Parte de este efecto puede ser artificial, ya que usamos el número de habitaciones para calcular el precio total como el precio de compra.

# %%
minicubo_precio.loc['beds_disc']
# Out:
#        precio_total  precio_compra
# value
# 1              74.0       197440.0
# 3             123.0       246800.0
# 3-19          190.0       359520.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['beds_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['beds_disc'].precio_compra,color = 'green');

# %% [markdown]
# En cuanto al número de camas sí hay una conclusión:
#
# **Insight 3: el número de camas a evitar es 2**. O bien ponemos una cama o intentamos meter todas las posibles.
#
# Dado que no había este efecto en el número de habitaciones podría ser que los propietarios estén intentando meter muchas más camas que habitaciones para maximizar el ingreso
#
# Veámoslo por ejemplo con los pisos de una habitación:

# %%
df[df.bedrooms == 1].groupby('beds').precio_total.median().plot();

# %% [markdown]
# Efectivamente aquí hay algo, ya que figura que para pisos de una habitación hay gente que está metiendo hasta doce de camas
#
# Sería un tema a explorar con más detalle y comentar con alguien que conozca el negocio por si hubiera algo que aportar, pero la conclusión es que hay propietarios que buscan maximizar el beneficio metiendo muchas camas por habitación
#
# Vamos a ver unos ejemplos:

# %%
df.loc[(df.bedrooms == 1) & (df.beds > 6)]
# Out:
#        index                   id  \
# 2121    2121             15428073
# 10342  10342   544815531002663097
# 13124  13124   784862856028711383
# 16309  16309   951931255884882441
# 17097  17097   996129561563914923
# 17185  17185   998269085402388662
# 17392  17392  1011554774276353687
# 17904  17904  1033327900604883402
# 21962  21962  1186929367473323308
# 22100  22100  1188554103725517113
# 23570  23570  1241518117004114298
#
#                                                     name host_response_time  \
# 2121          HELLENHOST: Cozy Loft in Gran Vía - Madrid     within an hour
# 10342                 PUERTA DEL SOL PERFECTO PARA GRUPO     within an hour
# 13124  Paseo de la Castellana. 10’ del Santiago Bernabeu     within an hour
# 16309              Cama en habitación compartida 6 camas     within an hour
# 17097              Cama en habitación compartida 6 camas     within an hour
# 17185           2 Camas en habitación compartida 6 camas     within an hour
# 17392  5 Camas en hab. compartida-baño privado, 6 lit...     within an hour
# 17904           2 Camas en habitación compartida 6 camas     within an hour
# 21962              Cama en habitación compartida 6 camas     within an hour
# 22100              Cama en habitación compartida 6 camas     within an hour
# 23570                     11-Hab compartida masculina X8     within an hour
#
#       host_is_superhost       host_verifications host_has_profile_pic  \
# 2121                  f  ['phone', 'work_email']                    t
# 10342                 f       ['email', 'phone']                    f
# 13124                 t       ['email', 'phone']                    t
# 16309                 f       ['email', 'phone']                    t
# 17097                 f       ['email', 'phone']                    t
# 17185                 f       ['email', 'phone']                    t
# 17392                 f       ['email', 'phone']                    t
# 17904                 f       ['email', 'phone']                    t
# 21962                 f       ['email', 'phone']                    t
# 22100                 f       ['email', 'phone']                    t
# 23570                 f       ['email', 'phone']                    t
#
#       host_identity_verified neighbourhood_cleansed  \
# 2121                       t            Universidad
# 10342                      t                 Cortes
# 13124                      t             Berruguete
# 16309                      t            Embajadores
# 17097                      t            Embajadores
# 17185                      t            Embajadores
# 17392                      t            Universidad
# 17904                      t            Embajadores
# 21962                      t            Embajadores
# 22100                      t            Embajadores
# 23570                      t                 Cortes
#
#                           property_type        room_type  \
# 2121                 Entire rental unit  Entire home/apt
# 10342                Entire rental unit  Entire home/apt
# 13124                Entire rental unit  Entire home/apt
# 16309        Shared room in rental unit      Shared room
# 17097        Shared room in rental unit      Shared room
# 17185        Shared room in rental unit      Shared room
# 17392        Shared room in rental unit      Shared room
# 17904       Private room in rental unit     Private room
# 21962        Shared room in rental unit      Shared room
# 22100        Shared room in rental unit      Shared room
# 23570  Shared room in bed and breakfast      Shared room
#
#                                                amenities has_availability  \
# 2121   ["City skyline view", "First aid kit", "Wifi",...              yes
# 10342  ["Bidet", "Wifi", "Clothing storage: closet", ...              yes
# 13124  ["Wifi", "Clothing storage: closet", "AC - spl...              yes
# 16309  ["Smoke alarm", "First aid kit", "Wifi", "Self...              yes
# 17097  ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 17185  ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 17392  ["First aid kit", "Wifi", "Kitchenette", "Esse...              yes
# 17904  ["First aid kit", "Wifi", "Kitchen", "Hot wate...              yes
# 21962  ["Smoke alarm", "First aid kit", "Wifi", "Kitc...              yes
# 22100                          ["Wifi", "Kitchen", "TV"]              yes
# 23570  ["Wifi", "Smoking allowed", "Kitchen", "TV", "...              yes
#
#       license instant_bookable neighbourhood_group    host_id host_since  \
# 2121      yes                t              Centro   32420211 2015-05-02
# 10342      no                t              Centro  441464755 2022-01-21
# 13124      no                t              Tetuán  402837283 2021-05-22
# 16309      no                f              Centro  529015349 2023-07-31
# 17097      no                f              Centro  529015349 2023-07-31
# 17185      no                f              Centro  529015349 2023-07-31
# 17392      no                t              Centro  493916828 2023-01-02
# 17904      no                f              Centro  529015349 2023-07-31
# 21962      no                f              Centro  529015349 2023-07-31
# 22100      no                f              Centro  529015349 2023-07-31
# 23570      no                t              Centro  286514428 2019-08-16
#
#        host_response_rate  host_acceptance_rate  host_listings_count  \
# 2121                100.0                 100.0                  4.0
# 10342                93.0                 100.0                  1.0
# 13124               100.0                 100.0                 11.0
# 16309               100.0                  99.0                 15.0
# 17097               100.0                  99.0                 15.0
# 17185               100.0                  99.0                 15.0
# 17392                93.0                 100.0                 31.0
# 17904               100.0                  99.0                 15.0
# 21962               100.0                  99.0                 15.0
# 22100               100.0                  99.0                 15.0
# 23570               100.0                  83.0                  7.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 2121                         5.0  40.421257  -3.706301             6
# 10342                        1.0  40.415480  -3.700610             8
# 13124                       13.0  40.460340  -3.700470             6
# 16309                       23.0  40.411811  -3.704862             1
# 17097                       23.0  40.411076  -3.705688             1
# 17185                       23.0  40.411811  -3.704862             2
# 17392                       50.0  40.422597  -3.704498             5
# 17904                       23.0  40.411090  -3.704320             2
# 21962                       23.0  40.411059  -3.703784             1
# 22100                       23.0  40.412862  -3.705277             1
# 23570                        9.0  40.416310  -3.695540             1
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 2121         1.0       1.0   7.0    226               1            1125
# 10342        1.0       1.0   8.0    145               2            1125
# 13124        1.0       1.0   7.0     63               1             120
# 16309        3.0       1.0   8.0     24               1             365
# 17097        3.0       1.0   8.0     24               1             365
# 17185        3.0       1.0   8.0     49               1             365
# 17392        2.5       1.0  12.0    137               1             365
# 17904        3.0       1.0   8.0     49               1             365
# 21962        0.5       1.0   8.0     21               1             365
# 22100        0.5       1.0   8.0     26               1             365
# 23570        2.0       1.0   8.0     43               1             365
#
#        availability_30  availability_60  availability_90  availability_365  \
# 2121                20               45               68               259
# 10342                9               20               37               111
# 13124               13               36               36                36
# 16309               13               43               43               289
# 17097                8                8               20               282
# 17185               12               36               66               341
# 17392                0                0                0               266
# 17904                5                5                5               190
# 21962                8               21               46               311
# 22100               13               43               73               348
# 23570               30               60               90               365
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 2121                 100                      2                       0
# 10342                123                     36                       1
# 13124                 72                     37                       3
# 16309                 78                     63                       2
# 17097                 72                     62                       4
# 17185                 46                     41                       5
# 17392                  1                      0                       0
# 17904                 29                     29                       0
# 21962                 27                     27                       8
# 22100                 14                     14                       2
# 23570                  5                      5                       1
#
#       first_review last_review  review_scores_rating  review_scores_accuracy  \
# 2121    2016-11-19  2024-05-26                  4.76                    4.87
# 10342   2022-02-06  2024-11-24                  4.60                    4.66
# 13124   2023-02-19  2024-12-08                  4.85                    4.86
# 16309   2023-08-09  2024-11-16                  4.53                    4.72
# 17097   2023-10-11  2024-12-01                  4.69                    4.81
# 17185   2023-10-29  2024-12-01                  4.54                    4.85
# 17392   2023-11-12  2023-11-12                  4.00                    4.00
# 17904   2024-01-23  2024-10-20                  4.62                    4.45
# 21962   2024-07-04  2024-12-09                  4.70                    4.81
# 22100   2024-06-30  2024-11-24                  4.64                    4.57
# 23570   2024-10-09  2024-12-08                  4.00                    4.20
#
#        review_scores_cleanliness  review_scores_checkin  \
# 2121                        4.92                   4.81
# 10342                       4.59                   4.76
# 13124                       4.79                   4.96
# 16309                       4.61                   4.69
# 17097                       4.68                   4.83
# 17185                       4.52                   4.87
# 17392                       3.00                   5.00
# 17904                       4.69                   4.59
# 21962                       4.85                   4.89
# 22100                       4.50                   4.86
# 23570                       3.80                   4.20
#
#        review_scores_communication  review_scores_location  \
# 2121                          4.88                    4.97
# 10342                         4.69                    4.80
# 13124                         4.96                    4.93
# 16309                         4.79                    4.72
# 17097                         4.83                    4.86
# 17185                         4.85                    4.80
# 17392                         3.00                    5.00
# 17904                         4.79                    4.86
# 21962                         4.85                    4.89
# 22100                         4.93                    4.86
# 23570                         4.20                    4.20
#
#        review_scores_value  calculated_host_listings_count  \
# 2121                  4.74                               4
# 10342                 4.59                               1
# 13124                 4.79                               6
# 16309                 4.67                              15
# 17097                 4.76                              15
# 17185                 4.67                              15
# 17392                 4.00                              31
# 17904                 4.52                              15
# 21962                 4.74                              15
# 22100                 4.50                              15
# 23570                 4.20                               7
#
#        calculated_host_listings_count_entire_homes  \
# 2121                                             4
# 10342                                            1
# 13124                                            6
# 16309                                            0
# 17097                                            0
# 17185                                            0
# 17392                                            0
# 17904                                            0
# 21962                                            0
# 22100                                            0
# 23570                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 2121                                              0
# 10342                                             0
# 13124                                             0
# 16309                                             4
# 17097                                             4
# 17185                                             4
# 17392                                             5
# 17904                                             4
# 21962                                             4
# 22100                                             4
# 23570                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 2121                                             0               1.02
# 10342                                            0               3.54
# 13124                                            0               3.26
# 16309                                           11               4.76
# 17097                                           11               5.03
# 17185                                           11               3.36
# 17392                                           26               0.08
# 17904                                           11               2.68
# 21962                                           11               5.00
# 22100                                           11               2.53
# 23570                                            7               2.31
#
#        precio_m2  precio_total  ocupacion bedrooms_disc accommodates_disc  \
# 2121        6170        226.00         29        01_Una              4-16
# 10342       6170        145.00         69        01_Una              4-16
# 13124       4536         63.00         90        01_Una              4-16
# 16309       6170        191.44         20        01_Una               0-3
# 17097       6170        191.44         22        01_Una               0-3
# 17185       6170        391.44          6        01_Una               0-3
# 17392       6170       1643.44         27        01_Una              4-16
# 17904       6170        391.62         47        01_Una               0-3
# 21962       6170        167.44         14        01_Una               0-3
# 22100       6170        207.44          4        01_Una               0-3
# 23570       6170        343.44          0        01_Una               0-3
#
#       beds_disc number_of_reviews_disc  m2  precio_compra   pdi_sol  \
# 2121       3-19                71-1136  50       246800.0  0.562764
# 10342      3-19                71-1136  50       246800.0  0.269550
# 13124      3-19                71-1136  50       181440.0  4.856901
# 16309      3-19                71-1136  50       246800.0  0.561938
# 17097      3-19                71-1136  50       246800.0  0.659407
# 17185      3-19                   5-71  50       246800.0  0.561938
# 17392      3-19                    1-4  50       246800.0  0.660175
# 17904      3-19                   5-71  50       246800.0  0.632554
# 21962      3-19                   5-71  50       246800.0  0.631630
# 22100      3-19                   5-71  50       246800.0  0.460222
# 23570      3-19                    1-4  50       246800.0  0.662045
#
#        pisos_rentables
# 2121                 1
# 10342                1
# 13124                1
# 16309                1
# 17097                1
# 17185                0
# 17392                1
# 17904                1
# 21962                0
# 22100                0
# 23570                0

# %% [markdown]
# Vamos a analizar ahora por el número de huéspedes que aceptan

# %%
minicubo_precio.loc['accommodates_disc']
# Out:
#        precio_total  precio_compra
# value
# 0-3            80.0       201120.0
# 4             121.0       246800.0
# 4-16          175.0       345520.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['accommodates_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['accommodates_disc'].precio_compra,color = 'green');

# %% [markdown]
# **Insight 4: el número óptimo de huéspedes está en 4, ya el precio de los inmuebles no varia demasiado hasta esos ocupantes pero, a partir de 4 el piso necesita ser mayor y el precio de compra se incrementa bastante**

# %% [markdown]
# Por último vamos a analizar la variable que hemos construído de cercanía a un punto de interés para ver si tiene efecto sobre el precio de las habitaciones.
#
# En este caso como hemos construído la distancia a la Puerta del Sol vamos a evaluar solo los distritos para lo que esto puede ser relevante, es decir los más céntricos pero se podrían construir tantas variables con los puntos de interés como fuera necesario repitiendo el análisis para cada una
#
# Para ello primero vamos a calcular la distancia media por distrito y elegir un punto de corte.

# %%
df.groupby('neighbourhood_group').pdi_sol.median().sort_values()
# Out:
# neighbourhood_group
# Centro                 0.739457
# Arganzuela             1.819477
# Chamberí               2.070151
# Moncloa                2.094686
# Retiro                 2.438053
# Salamanca              2.827520
# Latina                 3.337816
# Carabanchel            3.717970
# Usera                  3.866540
# Puente de Vallecas     4.287319
# Chamartín              4.476647
# Tetuán                 4.639502
# Moratalaz              5.009633
# Ciudad Lineal          5.130979
# Fuencarral             7.528311
# Villaverde             7.588138
# San Blas               8.108111
# Hortaleza              8.119706
# Vicálvaro              8.502931
# Villa de Vallecas      8.754420
# Barajas               11.592324
# Name: pdi_sol, dtype: float64

# %% [markdown]
# Vamos a cortar en Latina incluído.
#
# Y sobre esa selección vamos a visualizar con un scatter.

# %%
df.groupby('neighbourhood_group').pdi_sol.median().sort_values()[0:7].index.to_list()
# Out:
# ['Centro',
#  'Arganzuela',
#  'Chamberí',
#  'Moncloa',
#  'Retiro',
#  'Salamanca',
#  'Latina']

# %%
seleccion = df.groupby('neighbourhood_group').pdi_sol.median().sort_values()[0:7].index.to_list()

plt.figure(figsize = (16,12))
sns.scatterplot(data = df.loc[df.neighbourhood_group.isin(seleccion)], x = 'pdi_sol', y = 'precio_total');

# %% [markdown]
# No parece haber una relación tan directa como sería esperable entre la distancia a la Puerta del Sol y el precio de alquiler.

# %% [markdown]
# **Insight 5: estando dentro del distrito parece que la cercanía a puntos de interés no tiene tanto impacto como sería esperable. Eso abre la puerta a buscar inmuebles que estando en un distrito céntrico no estén justo al lado del PdI y por tanto esperablemente tengan un precio de compra menor**

# %% [markdown]
# ### Analisis sobre la ocupación

# %% [markdown]
# Para este punto podríamos repetir exactamente los mismos análisis que con el precio pero cambiando la variable precio por la de ocupación que habíamos construido.
#
# Dado que sería igual no vamos a desarrollarlo y te lo dejo como tarea para que practiques e intentes obtener tus primeros insights.
#
# En su lugar prefiero el tiempo para enseñarte cómo podemos incluir análisis sobre un mapa, dado que en este caso sería algo muy relevante y es un tipo de análisis que siempre gusta mucho.

# %% [markdown]
# **¿Cual es el ocupación medio? ¿y el rango de ocupación?¿Y por distritos?¿Y por barrios?**
#
# **¿Cual es el ranking de distritos y barrios por ocupación media?**

# %%
df.ocupacion.describe()
# Out:
# count    25913.000000
# mean        54.749547
# std         36.926612
# min          0.000000
# 25%         17.000000
# 50%         56.000000
# 75%         94.000000
# max        100.000000
# Name: ocupacion, dtype: float64

# %% [markdown]
# Vemos que hay al menos un atípico por la parte de arriba que sesga la media, por tanto vamos a usar la mediana como medida de centralización más fiable.

# %%
df.ocupacion.median()
# Out:
# 56.0

# %%
df.groupby('neighbourhood_group').ocupacion.median().sort_values(ascending = False)
# Out:
# neighbourhood_group
# Moratalaz             75.5
# Barajas               75.0
# San Blas              75.0
# Villaverde            72.5
# Retiro                66.0
# Moncloa               65.0
# Latina                63.0
# Fuencarral            62.0
# Arganzuela            61.0
# Hortaleza             57.5
# Centro                57.0
# Salamanca             56.0
# Ciudad Lineal         55.0
# Chamberí              55.0
# Carabanchel           54.5
# Puente de Vallecas    52.0
# Usera                 51.0
# Vicálvaro             50.0
# Chamartín             41.0
# Tetuán                41.0
# Villa de Vallecas     34.0
# Name: ocupacion, dtype: float64

# %% [markdown]
# Nos llama la atención el dato de San Blas, vamos a verlo con más detalle a ver qué está pasando.

# %%
df.loc[df.neighbourhood_group == 'San Blas'].sort_values('ocupacion',ascending = False).head(10)
# Out:
#        index                   id  \
# 6309    6309             35132510
# 6025    6025             34680215
# 6215    6215             34914686
# 6224    6224             34997346
# 6226    6226             34999824
# 6232    6232             34920045
# 6237    6237             34925146
# 6243    6243             35004011
# 6247    6247             35007673
# 21732  21732  1178070221634310360
#
#                                                     name host_response_time  \
# 6309   Se alquila habitacion para la final de la Cham...        no response
# 6025                            Wanda metropolitano Room        no response
# 6215               Alquiler de habitacion a 20 del Wanda        no response
# 6224               Magnífica habitación, CERCA DEL WANDA        no response
# 6226                         Piso final champions league        no response
# 6232           Disfruta la final de la Champions League.        no response
# 6237             EUFA CHAMPIONS LEAGUE FINAL MAY31-JUNE1        no response
# 6243       Bohardilla cerca wanda para final de champios        no response
# 6247       2 bedrooms 4-5 people champions near to wanda        no response
# 21732  靠近市中心，距离马德里机场10分钟车程，地铁口整个房子出租，3个房间3张床，可入住6人，房间有空调     within an hour
#
#       host_is_superhost                host_verifications  \
# 6309                  f                ['email', 'phone']
# 6025                  f                ['email', 'phone']
# 6215                  f                         ['phone']
# 6224                  f                ['email', 'phone']
# 6226                  f                ['email', 'phone']
# 6232                  f                ['email', 'phone']
# 6237                  f  ['email', 'phone', 'work_email']
# 6243                  f                ['email', 'phone']
# 6247                  f                ['email', 'phone']
# 21732                 f                         ['phone']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 6309                     t                      f                 Hellín
# 6025                     t                      f                  Rosas
# 6215                     t                      f                Amposta
# 6224                     t                      f               Simancas
# 6226                     t                      f             Canillejas
# 6232                     t                      f               Simancas
# 6237                     t                      f               Simancas
# 6243                     t                      f                  Rosas
# 6247                     t                      t                  Rosas
# 21732                    t                      t                Amposta
#
#                      property_type        room_type  \
# 6309   Private room in rental unit     Private room
# 6025          Private room in home     Private room
# 6215   Private room in rental unit     Private room
# 6224   Private room in rental unit     Private room
# 6226                   Entire home  Entire home/apt
# 6232   Private room in rental unit     Private room
# 6237   Private room in rental unit     Private room
# 6243        Private room in chalet     Private room
# 6247         Private room in condo     Private room
# 21732           Entire rental unit  Entire home/apt
#
#                                                amenities has_availability  \
# 6309                 ["Hot water", "Wifi", "Essentials"]               no
# 6025   ["Breakfast", "Heating", "Wifi", "Hair dryer",...               no
# 6215   ["Free parking on premises", "Hangers", "First...               no
# 6224   ["Hangers", "First aid kit", "Heating", "Wifi"...               no
# 6226   ["Free parking on premises", "Hangers", "Smoki...               no
# 6232   ["Hangers", "Breakfast", "Wifi", "Hair dryer",...               no
# 6237   ["Private living room", "Smoke alarm", "Privat...               no
# 6243   ["Hangers", "Paid parking on premises", "Exter...               no
# 6247   ["Heating", "Wifi", "Hair dryer", "Smoking all...              yes
# 21732  ["Ethernet connection", "Wifi", "Kitchen", "Es...              yes
#
#       license instant_bookable neighbourhood_group    host_id host_since  \
# 6309       no                f            San Blas  123251555 2017-03-29
# 6025       no                f            San Blas  261609960 2019-05-13
# 6215       no                f            San Blas  263139662 2019-05-21
# 6224       no                f            San Blas  263666045 2019-05-23
# 6226       no                f            San Blas  160767488 2017-11-30
# 6232       no                f            San Blas  263162785 2019-05-21
# 6237       no                f            San Blas  133624002 2017-06-05
# 6243       no                f            San Blas  191769272 2018-05-26
# 6247       no                t            San Blas  250699072 2019-03-23
# 21732      no                f            San Blas   88164282 2016-08-05
#
#        host_response_rate  host_acceptance_rate  host_listings_count  \
# 6309                  0.0                  86.0                  1.0
# 6025                  0.0                  75.0                  1.0
# 6215                  0.0                  74.0                  1.0
# 6224                  0.0                  85.0                  1.0
# 6226                  0.0                  80.0                  1.0
# 6232                  0.0                  85.0                  2.0
# 6237                  0.0                  85.0                  1.0
# 6243                  0.0                  75.0                  1.0
# 6247                  0.0                  75.0                  1.0
# 21732               100.0                  91.0                  5.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 6309                         1.0  40.429390  -3.615350             3
# 6025                         1.0  40.427590  -3.603900             2
# 6215                         1.0  40.423830  -3.624980             2
# 6224                         1.0  40.429430  -3.628570             2
# 6226                         1.0  40.440410  -3.610480             6
# 6232                         2.0  40.429660  -3.624700             3
# 6237                         1.0  40.437290  -3.618140             2
# 6243                         2.0  40.427160  -3.600730             2
# 6247                         1.0  40.425750  -3.605480             4
# 21732                        5.0  40.425955  -3.623808             6
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 6309         1.0       0.0   2.0     91               1            1125
# 6025         1.0       0.0   1.0    173               1               2
# 6215         1.0       2.0   1.0    236               1            1125
# 6224         1.0       0.0   1.0    114               1            1125
# 6226         1.0       4.0   3.0    123               2               2
# 6232         1.0       0.0   2.0     85               1               2
# 6237         1.0       0.0   1.0    114               1               1
# 6243         1.0       0.0   1.0    173               2               2
# 6247         1.0       2.0   2.0    204               1            1125
# 21732        1.0       3.0   3.0    232              30             365
#
#        availability_30  availability_60  availability_90  availability_365  \
# 6309                 0                0                0                 0
# 6025                 0                0                0                 0
# 6215                 0                0                0                 0
# 6224                 0                0                0                 0
# 6226                 0                0                0                 0
# 6232                 0                0                0                 0
# 6237                 0                0                0                 0
# 6243                 0                0                0                 0
# 6247                 0                0                0                 0
# 21732                0                0                0                 0
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 6309                   0                      0                       0
# 6025                   0                      0                       0
# 6215                   0                      0                       0
# 6224                   0                      0                       0
# 6226                   0                      0                       0
# 6232                   0                      0                       0
# 6237                   0                      0                       0
# 6243                   0                      0                       0
# 6247                   0                      0                       0
# 21732                  8                      8                       0
#
#       first_review last_review  review_scores_rating  review_scores_accuracy  \
# 6309    2017-03-29  2017-03-29                   0.0                     0.0
# 6025    2019-05-13  2019-05-13                   0.0                     0.0
# 6215    2019-05-21  2019-05-21                   0.0                     0.0
# 6224    2019-05-23  2019-05-23                   0.0                     0.0
# 6226    2017-11-30  2017-11-30                   0.0                     0.0
# 6232    2019-05-21  2019-05-21                   0.0                     0.0
# 6237    2017-06-05  2017-06-05                   0.0                     0.0
# 6243    2018-05-26  2018-05-26                   0.0                     0.0
# 6247    2019-03-23  2019-03-23                   0.0                     0.0
# 21732   2024-06-23  2024-08-25                   5.0                     5.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 6309                        0.00                   0.00
# 6025                        0.00                   0.00
# 6215                        0.00                   0.00
# 6224                        0.00                   0.00
# 6226                        0.00                   0.00
# 6232                        0.00                   0.00
# 6237                        0.00                   0.00
# 6243                        0.00                   0.00
# 6247                        0.00                   0.00
# 21732                       4.88                   4.75
#
#        review_scores_communication  review_scores_location  \
# 6309                          0.00                    0.00
# 6025                          0.00                    0.00
# 6215                          0.00                    0.00
# 6224                          0.00                    0.00
# 6226                          0.00                    0.00
# 6232                          0.00                    0.00
# 6237                          0.00                    0.00
# 6243                          0.00                    0.00
# 6247                          0.00                    0.00
# 21732                         4.88                    4.63
#
#        review_scores_value  calculated_host_listings_count  \
# 6309                   0.0                               1
# 6025                   0.0                               1
# 6215                   0.0                               1
# 6224                   0.0                               1
# 6226                   0.0                               1
# 6232                   0.0                               1
# 6237                   0.0                               1
# 6243                   0.0                               1
# 6247                   0.0                               1
# 21732                  5.0                               5
#
#        calculated_host_listings_count_entire_homes  \
# 6309                                             0
# 6025                                             0
# 6215                                             0
# 6224                                             0
# 6226                                             1
# 6232                                             0
# 6237                                             0
# 6243                                             0
# 6247                                             0
# 21732                                            2
#
#        calculated_host_listings_count_private_rooms  \
# 6309                                              1
# 6025                                              1
# 6215                                              1
# 6224                                              1
# 6226                                              0
# 6232                                              1
# 6237                                              1
# 6243                                              1
# 6247                                              1
# 21732                                             3
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 6309                                             0               0.00
# 6025                                             0               0.00
# 6215                                             0               0.00
# 6224                                             0               0.00
# 6226                                             0               0.00
# 6232                                             0               0.00
# 6237                                             0               0.00
# 6243                                             0               0.00
# 6247                                             0               0.00
# 21732                                            0               1.39
#
#        precio_m2  precio_total  ocupacion    bedrooms_disc accommodates_disc  \
# 6309        2996        181.62        100       00_Estudio               0-3
# 6025        2996        173.00        100       00_Estudio               0-3
# 6215        2996        236.00        100           02_Dos               0-3
# 6224        2996        114.00        100       00_Estudio               0-3
# 6226        2996        123.00        100  04_Cuatro o mas              4-16
# 6232        2996        169.62        100       00_Estudio               0-3
# 6237        2996        114.00        100       00_Estudio               0-3
# 6243        2996        173.00        100       00_Estudio               0-3
# 6247        2996        407.62        100           02_Dos                 4
# 21732       2996        232.00        100          03_Tres              4-16
#
#       beds_disc number_of_reviews_disc   m2  precio_compra   pdi_sol  \
# 6309          3                    1-4   40        95872.0  7.582310
# 6025          1                    1-4   40        95872.0  8.506231
# 6215          1                    1-4   70       167776.0  6.682085
# 6224          1                    1-4   40        95872.0  6.486697
# 6226          3                    1-4  120       287616.0  8.291607
# 6232          3                    1-4   40        95872.0  6.812238
# 6237          1                    1-4   40        95872.0  7.567569
# 6243          1                    1-4   40        95872.0  8.765582
# 6247          3                    1-4   70       167776.0  8.346864
# 21732         3                    1-4   90       215712.0  6.812142
#
#        pisos_rentables
# 6309                 1
# 6025                 1
# 6215                 1
# 6224                 1
# 6226                 1
# 6232                 1
# 6237                 1
# 6243                 1
# 6247                 1
# 21732                1

# %% [markdown]
# En el resto no hay sorpresas, con distritos como Salamanca, Centro o Chanmartín a la cabeza.
#
# Pero por ejemplo vemos que la diferencia de precio media entre Retiro y Tetuán es muy baja.
#
# Esto nos lleva a comparar el precio medio por distrito con el precio medio de compra también por distrito.

# %%
temp = df.groupby('neighbourhood_group')[['ocupacion','precio_compra','precio_total']].median()
temp
# Out:
#                      ocupacion  precio_compra  precio_total
# neighbourhood_group
# Arganzuela                61.0       194000.0         85.00
# Barajas                   75.0       147440.0         79.00
# Carabanchel               54.5       108480.0         65.00
# Centro                    57.0       246800.0        111.00
# Chamartín                 41.0       251400.0        109.00
# Chamberí                  55.0       266600.0        104.00
# Ciudad Lineal             55.0       147040.0         78.00
# Fuencarral                62.0       161520.0         82.50
# Hortaleza                 57.5       174720.0         86.00
# Latina                    63.0       110880.0         70.00
# Moncloa                   65.0       195040.0        101.00
# Moratalaz                 75.5       125440.0         47.50
# Puente de Vallecas        52.0        94680.0         66.00
# Retiro                    66.0       221960.0         99.00
# Salamanca                 56.0       313840.0        120.00
# San Blas                  75.0       119840.0         89.81
# Tetuán                    41.0       181440.0         92.00
# Usera                     51.0        99880.0         59.00
# Vicálvaro                 50.0       117880.0         51.00
# Villa de Vallecas         34.0       113200.0         60.00
# Villaverde                72.5        82800.0         60.50

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_total', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_total.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %% [markdown]
# Hemos analizado esta relación con dos gráficos diferentes que analizados en conjunto tienen mas sentido porque podemos ver como se relaciona precio_compra y precio_total con la ocupación
#
# No hay una relación directa de la ocupación con el precio_total ni precio_compra, por lo que podríamos encontrar buenas rentabilidades en pisos económicos

# %% [markdown]
# A este nivel ya vemos más cosas:
#
# * 1 barrio que sobresale de San Blas
# * Dentro de cada grupo de bajo-medio-alto sí podemos empezar a separarar
#     * Bajo <150K: Amposta
#     * Medio 150K-250K: Arguelles y Cortés
#     * Medio-alto 250K-350K: Almagro
#     * Alto >350K: Castellana
#
# **Insight 6: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste debido a que tienen una ocupación alta con precios medios y su precio de compra no se dispara**

# %%
temp = df.groupby('neighbourhood_cleansed')[['ocupacion','precio_total','precio_compra']].median()
temp
# Out:
#                         ocupacion  precio_total  precio_compra
# neighbourhood_cleansed
# Abrantes                     45.0         57.00       108480.0
# Acacias                      64.0         77.62       194000.0
# Adelfas                      74.0         90.00       221960.0
# Aeropuerto                    9.0         56.50       147440.0
# Aguilas                      40.0         50.00       110880.0
# ...                           ...           ...            ...
# Valverde                     40.0         81.00       161520.0
# Ventas                       53.0         64.00       147040.0
# Vinateros                    75.5         32.50       125440.0
# Vista Alegre                 56.0         59.00       108480.0
# Zofío                        26.5         54.50        99880.0
#
# [127 rows x 3 columns]

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_total', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_total.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %% [markdown]
# **¿Qué factores (a parte de la localización determinan el precio del alquiler?**

# %% [markdown]
# Para responder a esta pregunta podemos construir un minicubo, ya que hemos discretizado nuestras variables de análisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25913 entries, 0 to 25912
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   index                                         25913 non-null  int64
#  1   id                                            25913 non-null  int64
#  2   name                                          25913 non-null  object
#  3   host_response_time                            25913 non-null  object
#  4   host_is_superhost                             25913 non-null  object
#  5   host_verifications                            25913 non-null  object
#  6   host_has_profile_pic                          25913 non-null  object
#  7   host_identity_verified                        25913 non-null  object
#  8   neighbourhood_cleansed                        25913 non-null  object
#  9   property_type                                 25913 non-null  object
#  10  room_type                                     25913 non-null  object
#  11  amenities                                     25913 non-null  object
#  12  has_availability                              25913 non-null  object
#  13  license                                       25913 non-null  object
#  14  instant_bookable                              25913 non-null  object
#  15  neighbourhood_group                           25913 non-null  object
#  16  host_id                                       25913 non-null  int64
#  17  host_since                                    25913 non-null  datetime64[ns]
#  18  host_response_rate                            25913 non-null  float64
#  19  host_acceptance_rate                          25913 non-null  float64
#  20  host_listings_count                           25913 non-null  float64
#  21  host_total_listings_count                     25913 non-null  float64
#  22  latitude                                      25913 non-null  float64
#  23  longitude                                     25913 non-null  float64
#  24  accommodates                                  25913 non-null  int64
#  25  bathrooms                                     25913 non-null  float64
#  26  bedrooms                                      25913 non-null  float64
#  27  beds                                          25913 non-null  float64
#  28  price                                         25913 non-null  int64
#  29  minimum_nights                                25913 non-null  int64
#  30  maximum_nights                                25913 non-null  int64
#  31  availability_30                               25913 non-null  int64
#  32  availability_60                               25913 non-null  int64
#  33  availability_90                               25913 non-null  int64
#  34  availability_365                              25913 non-null  int64
#  35  number_of_reviews                             25913 non-null  int64
#  36  number_of_reviews_ltm                         25913 non-null  int64
#  37  number_of_reviews_l30d                        25913 non-null  int64
#  38  first_review                                  25913 non-null  datetime64[ns]
#  39  last_review                                   25913 non-null  datetime64[ns]
#  40  review_scores_rating                          25913 non-null  float64
#  41  review_scores_accuracy                        25913 non-null  float64
#  42  review_scores_cleanliness                     25913 non-null  float64
#  43  review_scores_checkin                         25913 non-null  float64
#  44  review_scores_communication                   25913 non-null  float64
#  45  review_scores_location                        25913 non-null  float64
#  46  review_scores_value                           25913 non-null  float64
#  47  calculated_host_listings_count                25913 non-null  int64
#  48  calculated_host_listings_count_entire_homes   25913 non-null  int64
#  49  calculated_host_listings_count_private_rooms  25913 non-null  int64
#  50  calculated_host_listings_count_shared_rooms   25913 non-null  int64
#  51  reviews_per_month                             25913 non-null  float64
#  52  precio_m2                                     25913 non-null  int64
#  53  precio_total                                  25913 non-null  float64
#  54  ocupacion                                     25913 non-null  int64
#  55  bedrooms_disc                                 25913 non-null  object
#  56  accommodates_disc                             25913 non-null  object
#  57  beds_disc                                     25913 non-null  object
#  58  number_of_reviews_disc                        25913 non-null  object
#  59  m2                                            25913 non-null  int64
#  60  precio_compra                                 25913 non-null  float64
#  61  pdi_sol                                       25913 non-null  float64
#  62  pisos_rentables                               25913 non-null  int64
# dtypes: datetime64[ns](3), float64(20), int64(22), object(18)
# memory usage: 12.5+ MB

# %%
#Paso 1: Seleccionar qué variables serán la métricas y cuales las dimensiones
metricas = ['ocupacion']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_ocupacion = df[dimensiones + metricas]
minicubo_ocupacion
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_Una               0-3         1                   5-71
# 1            01_Una               0-3         1                71-1136
# 2            01_Una               0-3         1                    1-4
# 3            01_Una               0-3         3                   5-71
# 4            01_Una                 4         3                71-1136
# ...             ...               ...       ...                    ...
# 25908        01_Una               0-3         1                    1-4
# 25909        01_Una                 4         3                    1-4
# 25910        01_Una               0-3         1                    1-4
# 25911        01_Una               0-3         3                    1-4
# 25912        01_Una               0-3         1                    1-4
#
#        ocupacion
# 0             60
# 1            100
# 2            100
# 3            100
# 4              9
# ...          ...
# 25908          0
# 25909          4
# 25910          0
# 25911          4
# 25912         75
#
# [25913 rows x 5 columns]

# %%
#Paso 2: pasar a transaccional las dimensiones
minicubo_ocupacion = minicubo_ocupacion.melt(id_vars=['ocupacion'])
minicubo_ocupacion
# Out:
#         ocupacion                variable   value
# 0              60           bedrooms_disc  01_Una
# 1             100           bedrooms_disc  01_Una
# 2             100           bedrooms_disc  01_Una
# 3             100           bedrooms_disc  01_Una
# 4               9           bedrooms_disc  01_Una
# ...           ...                     ...     ...
# 103647          0  number_of_reviews_disc     1-4
# 103648          4  number_of_reviews_disc     1-4
# 103649          0  number_of_reviews_disc     1-4
# 103650          4  number_of_reviews_disc     1-4
# 103651         75  number_of_reviews_disc     1-4
#
# [103652 rows x 3 columns]

# %%
#Paso 3: Agregar las métricas por "variable" y "valor" con las funciones deseadas
minicubo_ocupacion = minicubo_ocupacion.groupby(['variable','value'])[['ocupacion']].agg('median')
minicubo_ocupacion
# Out:
#                                         ocupacion
# variable               value
# accommodates_disc      0-3                   63.0
#                        4                     51.0
#                        4-16                  50.0
# bedrooms_disc          00_Estudio           100.0
#                        01_Una                50.0
#                        02_Dos                54.0
#                        03_Tres               53.0
#                        04_Cuatro o mas       53.0
# beds_disc              1                     64.0
#                        3                     54.0
#                        3-19                  42.5
# number_of_reviews_disc 1-4                   58.0
#                        5-71                  54.0
#                        71-1136               58.0

# %% [markdown]
# Sobre el minicubo vamos analizando cada variable.

# %%
minicubo_ocupacion.loc['bedrooms_disc']
# Out:
#                  ocupacion
# value
# 00_Estudio           100.0
# 01_Una                50.0
# 02_Dos                54.0
# 03_Tres               53.0
# 04_Cuatro o mas       53.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_ocupacion.loc['bedrooms_disc'].ocupacion);

# %% [markdown]
# En cuanto al número de habitaciones parece que los estudios son los que mayor ocupación tienen por lo que sería mas rentable

# %%
minicubo_ocupacion.loc['beds_disc']
# Out:
#        ocupacion
# value
# 1           64.0
# 3           54.0
# 3-19        42.5

# %%
f, ax = plt.subplots()
ax.plot(minicubo_ocupacion.loc['beds_disc'].ocupacion);

# %% [markdown]
# En cuanto al número de camas, confirma que hasta 3 camas se ocupa mucho mas
#
# Veámoslo por ejemplo con los pisos de una habitación:

# %%
df[df.bedrooms == 1].groupby('beds').ocupacion.median().plot();

# %% [markdown]
# Vamos a analizar ahora por el número de huéspedes que aceptan

# %%
minicubo_ocupacion.loc['accommodates_disc']
# Out:
#        ocupacion
# value
# 0-3         63.0
# 4           51.0
# 4-16        50.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_ocupacion.loc['accommodates_disc'].ocupacion);

# %% [markdown]
# **Insight 7: el número óptimo de huéspedes es entre 1 y 3**

# %% [markdown]
# ### Analisis geográfico sobre un mapa
#
# Este mismo análisis por colores se podría hacer por cada una de los zonas o incluso barrios

# %%
#conda install -c conda-forge folium
import folium

#Cargamos el mapa de la zona
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

#Hacemos una selección de los datos disponibles para cargarlos en el mapa
datos = df[df.neighbourhood_group == 'San Blas'].copy()

#Definimos la variable por la que segmentaremos por colores y y los quartiles de segmentación
datos['precio_total_disc'] = pd.qcut(datos['precio_total'], q = [0, .25, .5, .75, 1.], 
                              labels=['yellow', 'orange', 'blue', 'red'])

#Generamos un bucle que recorra la tabla datos y que vaya extrayendo latitud y longitud y añadiéndolos al mapa
for piso in range(0,len(datos)):
   folium.CircleMarker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
      fill=True,
      color = datos.iloc[piso]['precio_total_disc'],
      fill_opacity=1,
      radius = 5
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39e9b50086e6bf1c69071da03406cfd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39e9b50086e6bf1c69071da03406cfd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39e9b50086e6bf1c69071da03406cfd2 = L.map(
#                 &quot;map_39e9b50086e6bf1c69071da03406cfd2&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_adf47cdbd8f361c53b41057031081b79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_adf47cdbd8f361c53b41057031081b79.addTo(map_39e9b50086e6bf1c69071da03406cfd2);
#
#
#             var circle_marker_96e6f9bc366ed12058e9e4935ca2b9d4 = L.circleMarker(
#                 [40.43202, -3.60353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e9b50086e6bf1c69071da03406cfd2);
#
#
#         var popup_6cdccd3cfee7abf826ca879b26f2c505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ccea99fac6bd401dcd809989cf67a27 = $(`&lt;div id=&quot;html_7ccea99fac6bd401dcd809989cf67a27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;80.0&lt;/div&gt;`)[0];
#                 popup_6cdccd3cfee7abf826ca879b26f2c505.setContent(html_7ccea99fac6bd401dcd809989cf67a27);
#
#
#
#         circle_marker_96e6f9bc366ed12058e9e4935ca2b9d4.bindPopup(popup_6cdccd3cfee7abf826ca879b26f2c505)
#         ;
#
#
#
#
#             var circle_marker_3a41044a5fb557bdf2f62b13d38270e3 = L.circleMarker(
#                 [40.4267, -3.61631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e9b50086e6bf1c69071da03406cfd2);
#
#
#         var popup_f9b533590c161e94369c5019fe922f31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df64873557f0cb7aa185ff85af3afce6 = $(`&lt;div id=&quot;html_df64873557f0cb7aa185ff85af3afce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;44.0&lt;/div&gt;`)[0];
#                 popup_f9b533590c161e94369c5019fe922f31.setContent(html_df64873557f0cb7aa185ff85af3afce6);
#
#
#
#         circle_marker_3a41044a5fb557bdf2f62b13d38270e3.bindPopup(popup_f9b533590c161e94369c5019fe922f31)
#         ;
#
#
#
#
#             var circle_marker_e8643281cee110e8e9a0a09812ead8ab = L.circleMarker(
#                 [40.43733, -3.6351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e9b50086e6bf1c69071da03406cfd2);
#
#
#         var popup_071fd724e426930d78d7c8b90fbc7ecf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc218de43d963ce891c15e50fbe36a47 = $(`&lt;div id=&quot;html_dc218de43d963ce891c15e50fbe36a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;60.0&lt;/div&gt;`)[0];
#                 popup_071fd724e426930d78d7c8b90fbc7ecf.setContent(html_dc218de43d963ce891c15e50fbe36a47);
#
#
#
#         circle_marker_e8643281cee110e8e9a0a09812ead8ab.bindPopup(popup_071fd724e426930d78d7c8b90fbc7ecf)
#         ;
#
#
#
#
#             var circle_marker_3049b904f5312b96c7a4c8489c7da4f8 = L.circleMarker(
#                 [40.440

# %% [markdown]
# **Insight 8: Existen todavía muchos puntos amarillos y naranjas, lo cual puede indicar que todavía existe potencial para explotar más el factor de los eventos deportivos**

# %% [markdown]
# * Insight 1: pueden existir inmuebles con un valor regular residual pero con alto valor en momentos puntuales por acontenicimientos deportivos o espectáculos
# * Insight 2: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste y además podemos segmentarlo por el tipo calidad del inmueble en el que nos interes invertir
# * Insight 3: el número de camas a evitar es 2
# * Insight 4: el número óptimo de huéspedes está en 4, ya el precio de los inmuebles no varia demasiado hasta esos ocupantes pero, a partir de 4 el piso necesita ser mayor y el precio de compra se incrementa bastante
# * Insight 5: estando dentro del distrito parece que la cercanía a puntos de interés no tiene tanto impacto como sería esperable. Eso abre la puerta a buscar inmuebles que estando en un distrito céntrico no estén justo al lado del PdI y por tanto esperablemente tengan un precio de compra menor
# * Insight 6: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste debido a que tienen una ocupación alta con precios medios y su precio de compra no se dispara
# * Insight 7: el número óptimo de huéspedes es entre 1 y 3
# * Insight 8: Existen todavía muchos puntos amarillos y naranjas, lo cual puede indicar que todavía existe potencial para explotar más el factor de los eventos deportivos
