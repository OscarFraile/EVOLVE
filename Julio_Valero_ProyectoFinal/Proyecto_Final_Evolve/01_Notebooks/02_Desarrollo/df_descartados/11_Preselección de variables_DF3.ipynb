# %% [markdown]
# # PLANTILLA PRESELECCIÓN DE VARIABLES

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## 1. IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.inspection import permutation_importance


#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## 2. IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/Python Data Mastery/EstructuraDirectorio/03_MACHINE_LEARNING/08_CASOS/007_AIRBNB'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)

# %% [markdown]
# ## 3. MÉTODOS SUPERVISADOS

# %% [markdown]
# ### 3.1. Preparar x e y

# %%
target = 'pisos_rentables'
x = df.drop(columns = target).copy()
y =  df[target].copy()

# %% [markdown]
# ### 3.2. Mutual Information

# %% [markdown]
# #### 3.2.1. Crear una función para mostrar el resultado

# %%
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)

# %% [markdown]
# #### 3.2.2. Calcular y revisar

# %%
mutual_selector = mutual_info_classif(x,y)

rank_mi = ranking_mi(mutual_selector, modo = 'grafico')

# %%
#Mostrar el máximo de columnas posibles de una tabla
pd.set_option('display.max_rows', 200) #Número de columnas que deben verse. None = Máx
rank_mi = ranking_mi(mutual_selector)
rank_mi.head(126)
# Out:
#                                               variable  importancia_mi  \
# 89                            availability_365_yeo_mms        0.440286
# 65                                availability_365_yeo        0.439112
# 64                                 availability_90_yeo        0.133235
# 88                             availability_90_yeo_mms        0.132099
# 63                                 availability_60_yeo        0.110033
# 87                             availability_60_yeo_mms        0.107806
# 62                                 availability_30_yeo        0.073040
# 86                             availability_30_yeo_mms        0.070153
# 82                          host_response_rate_yeo_mms        0.033015
# 58                              host_response_rate_yeo        0.031818
# 66                           host_response_time_oe_mms        0.029785
# 60                                  maximum_nights_yeo        0.029509
# 41                               host_response_time_oe        0.028065
# 61                                           price_yeo        0.027687
# 54              calculated_host_listings_count_disc_ds        0.023465
# 79   calculated_host_listings_count_entire_homes_di...        0.023053
# 84                              maximum_nights_yeo_mms        0.022034
# 85                                       price_yeo_mms        0.021673
# 78          calculated_host_listings_count_disc_ds_mms        0.021229
# 53                              maximum_nights_disc_ds        0.019700
# 77                          maximum_nights_disc_ds_mms        0.015985
# 46                                 has_availability_oe        0.013197
# 55   calculated_host_listings_count_entire_homes_di...        0.012080
# 71                             has_availability_oe_mms        0.010293
# 39                                         beds_disc_3        0.009435
# 59                                    accommodates_yeo        0.008599
# 56   calculated_host_listings_count_private_rooms_d...        0.008552
# 38                                         beds_disc_1        0.008519
# 138                                       wifi kitchen        0.008432
# 108                                dedicated workspace        0.007777
# 126                                  microwave hangers        0.007501
# 104                                       conditioning        0.007230
# 121                                               iron        0.006631
# 133                                               soap        0.006564
# 57   calculated_host_listings_count_shared_rooms_di...        0.006435
# 131                                            shampoo        0.006351
# 48                                 instant_bookable_oe        0.006298
# 1                            property_type_Entire loft        0.006086
# 98                                           body soap        0.006021
# 94                                              basics        0.006008
# 31                                bedrooms_disc_01_Una        0.005867
# 137                                         water iron        0.005728
# 43                               host_verifications_oe        0.005515
# 74                       number_of_reviews_disc_oe_mms        0.005391
# 30                            bedrooms_disc_00_Estudio        0.005316
# 102                                             coffee        0.005284
# 139                                          workspace        0.005241
# 23                       neighbourhood_group_Salamanca        0.004978
# 115                                            freezer        0.004974
# 45                           host_identity_verified_oe        0.004873
# 12                          neighbourhood_group_Centro        0.004543
# 125                                          microwave        0.004519
# 105                                            cooking        0.004515
# 10                         neighbourhood_group_Barajas        0.004439
# 17                       neighbourhood_group_Hortaleza        0.004436
# 35                               accommodates_disc_0-3        0.004370
# 97                                                body        0.004235
# 25                          neighbourhood_group_Tetuán        0.004168
# 91                                    air conditioning        0.003880
# 70                       host_identity_verified_oe_mms        0.003879
# 96                                          bed linens        0.003730
# 117                                         hair dryer        0.003723
# 122                                 kitchen essentials        0.003668
# 4                   property_type_Private room in home        0.003633
# 119                                     hot water iron        0.003632
# 92                                             allowed        0.003603
# 116                                               hair        0.003579
# 107                                          dedicated        0.003546
# 67                            host_is_superhost_oe_mms        0.003362
# 9                       neighbourhood_group_Arganzuela        0.003306
# 106                                     cooking basics        0.003282
# 50                                   bathrooms_disc_ds        0.003256
# 130                                               room        0.003158
# 114                                           elevator        0.003127
# 6                            room_type_Entire home/apt        0.002808
# 112                                          dryer bed        0.002807
# 134                                            storage        0.002775
# 0                           property_type_Entire condo        0.002759
# 69                         host_has_profile_pic_oe_mms        0.002673
# 21              neighbourhood_group_Puente de Vallecas        0.002521
# 95                                                 bed        0.002482
# 93                                      and silverware        0.002478
# 111                              dishes and silverware        0.002396
# 80   calculated_host_listings_count_private_rooms_d...        0.002342
# 22                          neighbourhood_group_Retiro        0.002203
# 73                             instant_bookable_oe_mms        0.002143
# 124                                              maker        0.001938
# 76                          minimum_nights_disc_ds_mms        0.001896
# 3                                  property_type_OTROS        0.001876
# 37                              accommodates_disc_4-16        0.001736
# 100                                           clothing        0.001721
# 68                           host_verifications_oe_mms        0.001343
# 8                                room_type_Shared room        0.001143
# 28               neighbourhood_group_Villa de Vallecas        0.001128
# 81   calculated_host_listings_count_shared_rooms_di...        0.001019
# 129                                       refrigerator        0.000639
# 51                                       price_disc_ds        0.000521
# 14                        neighbourhood_group_Chamberí        0.000492
# 135                                              stove        0.000451
# 99                                            cleaning        0.000434
# 123                                             linens        0.000424
# 90                                                 air        0.000271
# 113                                   dryer bed linens        0.000167
# 11                     neighbourhood_group_Carabanchel        0.000127
# 49                           number_of_reviews_disc_oe        0.000000
# 72                                      license_oe_mms        0.000000
# 40                                      beds_disc_3-19        0.000000
# 2                     property_type_Entire rental unit        0.000000
# 7                               room_type_Private room        0.000000
# 128                                            parking        0.000000
# 127                                               oven        0.000000
# 47                                          license_oe        0.000000
# 136                                          tv washer        0.000000
# 120                                                 in        0.000000
# 42                                host_is_superhost_oe        0.000000
# 5            property_type_Private room in rental unit        0.000000
# 132                                         silverware        0.000000
# 44                             host_has_profile_pic_oe        0.000000
# 20                       neighbourhood_group_Moratalaz        0.000000
# 33                               bedrooms_disc_03_Tres        0.000000
# 36                                 accommodates_disc_4        0.000000
# 118                                     hair dryer bed        0.000000
# 24                        neighbourhood_group_San Blas        0.000000
# 19                         neighbourhood_group_Moncloa        0.000000
# 26                           neighbourhood_group_Usera        0.000000
# 27                       neighbourhood_group_Vicálvaro        0.000000
#
#      ranking_mi
# 89            0
# 65            1
# 64            2
# 88            3
# 63            4
# 87            5
# 62            6
# 86            7
# 82            8
# 58            9
# 66           10
# 60           11
# 41           12
# 61           13
# 54           14
# 79           15
# 84           16
# 85           17
# 78           18
# 53           19
# 77           20
# 46           21
# 55           22
# 71           23
# 39           24
# 59           25
# 56           26
# 38           27
# 138          28
# 108          29
# 126          30
# 104          31
# 121          32
# 133          33
# 57           34
# 131          35
# 48           36
# 1            37
# 98           38
# 94           39
# 31           40
# 137          41
# 43           42
# 74           43
# 30           44
# 102          45
# 139          46
# 23           47
# 115          48
# 45           49
# 12           50
# 125          51
# 105          52
# 10           53
# 17           54
# 35           55
# 97           56
# 25           57
# 91           58
# 70           59
# 96           60
# 117          61
# 122          62
# 4            63
# 119          64
# 92           65
# 116          66
# 107          67
# 67           68
# 9            69
# 106          70
# 50           71
# 130          72
# 114          73
# 6            74
# 112          75
# 134          76
# 0            77
# 69           78
# 21           79
# 95           80
# 93           81
# 111          82
# 80           83
# 22           84
# 73           85
# 124          86
# 76           87
# 3            88
# 37           89
# 100          90
# 68           91
# 8            92
# 28           93
# 81           94
# 129          95
# 51           96
# 14           97
# 135          98
# 99           99
# 123         100
# 90          101
# 113         102
# 11          103
# 49          104
# 72          105
# 40          106
# 2           107
# 7           108
# 128         109
# 127         110
# 47          111
# 136         112
# 120         113
# 42          114
# 5           115
# 132         116
# 44          117
# 20          118
# 33          119
# 36          120
# 118         121
# 24          122
# 19          123
# 26          124
# 27          125

# %% [markdown]
# #### 3.2.3. Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 99

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_mi = ranking_mi(mutual_selector).iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_mi = x[entran_mi].copy()

# %% [markdown]
# ### 3.3. Recursive Feature Elimination

# %% [markdown]
# #### 3.3.1. Instanciar

# %%
rfe = RFE(estimator = XGBClassifier( n_jobs = -1, eval_metric='auc'))

# %% [markdown]
# #### 3.3.2. Entrenar

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBClassifier(base_score=None, booster=None, callbacks=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, device=None,
#                             early_stopping_rounds=None,
#                             enable_categorical=False, eval_metric='auc',
#                             feature_types=None, gamma=None, grow_policy=None,
#                             importance_type=None, interaction_constraints=None,
#                             learning_rate=None, max_bin=None,
#                             max_cat_threshold=None, max_cat_to_onehot=None,
#                             max_delta_step=None, max_depth=None,
#                             max_leaves=None, min_child_weight=None, missing=nan,
#                             monotone_constraints=None, multi_strategy=None,
#                             n_estimators=None, n_jobs=-1,
#                             num_parallel_tree=None, random_state=None, ...))

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_rfe = x.columns[rfe.support_]

# %% [markdown]
# #### 3.3.3. Crear el dataframe con la selección

# %%
x_rfe = x[entran_rfe].copy()

# %% [markdown]
# ### 3.4. Permutation Importance

# %% [markdown]
# #### 3.4.1. Crear una función para mostrar el resultado

# %%
def ranking_per(predictoras,permutxacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)

# %% [markdown]
# #### 3.4.2. Instanciar y entrenar

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r'.*Use subset.*of np.ndarray is not recommended')
xgb = XGBClassifier(n_jobs = -1, eval_metric='auc')
xgb.fit(x,y)
permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',
                                     n_repeats=5, n_jobs = -1)

# %% [markdown]
# #### 3.4.3. Revisar la salida

# %%
rank_per = ranking_per(x,permutacion)

rank_per.set_index('variable').importancia_per.sort_values().plot.barh(figsize = (12,19));

# %% [markdown]
# #### 3.4.4. Seleccionar las variables que pasan

# %%
#Formato sin notación científica
pd.options.display.float_format = '{:15.2f}'.format 
rank_per = ranking_per(x,permutacion)
rank_per.head(126)
# Out:
#                                               variable  importancia_per  \
# 65                                availability_365_yeo             0.45
# 61                                           price_yeo             0.05
# 12                          neighbourhood_group_Centro             0.00
# 23                       neighbourhood_group_Salamanca             0.00
# 38                                         beds_disc_1             0.00
# 31                                bedrooms_disc_01_Una             0.00
# 30                            bedrooms_disc_00_Estudio             0.00
# 14                        neighbourhood_group_Chamberí             0.00
# 34                       bedrooms_disc_04_Cuatro o mas             0.00
# 21              neighbourhood_group_Puente de Vallecas             0.00
# 13                       neighbourhood_group_Chamartín             0.00
# 6                            room_type_Entire home/apt             0.00
# 29                      neighbourhood_group_Villaverde             0.00
# 26                           neighbourhood_group_Usera             0.00
# 22                          neighbourhood_group_Retiro             0.00
# 11                     neighbourhood_group_Carabanchel             0.00
# 18                          neighbourhood_group_Latina             0.00
# 28               neighbourhood_group_Villa de Vallecas             0.00
# 24                        neighbourhood_group_San Blas             0.00
# 33                               bedrooms_disc_03_Tres             0.00
# 9                       neighbourhood_group_Arganzuela             0.00
# 40                                      beds_disc_3-19             0.00
# 63                                 availability_60_yeo             0.00
# 32                                bedrooms_disc_02_Dos             0.00
# 5            property_type_Private room in rental unit             0.00
# 59                                    accommodates_yeo             0.00
# 64                                 availability_90_yeo             0.00
# 54              calculated_host_listings_count_disc_ds             0.00
# 62                                 availability_30_yeo             0.00
# 19                         neighbourhood_group_Moncloa             0.00
# 20                       neighbourhood_group_Moratalaz             0.00
# 7                               room_type_Private room             0.00
# 58                              host_response_rate_yeo             0.00
# 51                                       price_disc_ds             0.00
# 128                                            parking             0.00
# 27                       neighbourhood_group_Vicálvaro             0.00
# 101                                   clothing storage             0.00
# 25                          neighbourhood_group_Tetuán             0.00
# 49                           number_of_reviews_disc_oe             0.00
# 126                                  microwave hangers             0.00
# 37                              accommodates_disc_4-16             0.00
# 121                                               iron             0.00
# 122                                 kitchen essentials             0.00
# 60                                  maximum_nights_yeo             0.00
# 35                               accommodates_disc_0-3             0.00
# 94                                              basics             0.00
# 2                     property_type_Entire rental unit             0.00
# 109                                             dishes             0.00
# 107                                          dedicated             0.00
# 108                                dedicated workspace             0.00
# 111                              dishes and silverware             0.00
# 110                                         dishes and             0.00
# 0                           property_type_Entire condo             0.00
# 106                                     cooking basics             0.00
# 105                                            cooking             0.00
# 104                                       conditioning             0.00
# 103                                       coffee maker             0.00
# 102                                             coffee             0.00
# 100                                           clothing             0.00
# 113                                   dryer bed linens             0.00
# 99                                            cleaning             0.00
# 98                                           body soap             0.00
# 97                                                body             0.00
# 96                                          bed linens             0.00
# 95                                                 bed             0.00
# 93                                      and silverware             0.00
# 112                                          dryer bed             0.00
# 125                                          microwave             0.00
# 114                                           elevator             0.00
# 115                                            freezer             0.00
# 138                                       wifi kitchen             0.00
# 137                                         water iron             0.00
# 136                                          tv washer             0.00
# 135                                              stove             0.00
# 134                                            storage             0.00
# 133                                               soap             0.00
# 132                                         silverware             0.00
# 131                                            shampoo             0.00
# 130                                               room             0.00
# 129                                       refrigerator             0.00
# 127                                               oven             0.00
# 91                                    air conditioning             0.00
# 124                                              maker             0.00
# 123                                             linens             0.00
# 120                                                 in             0.00
# 119                                     hot water iron             0.00
# 118                                     hair dryer bed             0.00
# 117                                         hair dryer             0.00
# 116                                               hair             0.00
# 92                                             allowed             0.00
# 70                       host_identity_verified_oe_mms             0.00
# 90                                                 air             0.00
# 57   calculated_host_listings_count_shared_rooms_di...             0.00
# 55   calculated_host_listings_count_entire_homes_di...             0.00
# 53                              maximum_nights_disc_ds             0.00
# 52                              minimum_nights_disc_ds             0.00
# 50                                   bathrooms_disc_ds             0.00
# 48                                 instant_bookable_oe             0.00
# 47                                          license_oe             0.00
# 46                                 has_availability_oe             0.00
# 45                           host_identity_verified_oe             0.00
# 44                             host_has_profile_pic_oe             0.00
# 43                               host_verifications_oe             0.00
# 42                                host_is_superhost_oe             0.00
# 41                               host_response_time_oe             0.00
# 39                                         beds_disc_3             0.00
# 36                                 accommodates_disc_4             0.00
# 17                       neighbourhood_group_Hortaleza             0.00
# 16                      neighbourhood_group_Fuencarral             0.00
# 15                   neighbourhood_group_Ciudad Lineal             0.00
# 10                         neighbourhood_group_Barajas             0.00
# 8                                room_type_Shared room             0.00
# 4                   property_type_Private room in home             0.00
# 3                                  property_type_OTROS             0.00
# 56   calculated_host_listings_count_private_rooms_d...             0.00
# 66                           host_response_time_oe_mms             0.00
# 89                            availability_365_yeo_mms             0.00
# 67                            host_is_superhost_oe_mms             0.00
# 88                             availability_90_yeo_mms             0.00
# 87                             availability_60_yeo_mms             0.00
# 86                             availability_30_yeo_mms             0.00
# 85                                       price_yeo_mms             0.00
# 84                              maximum_nights_yeo_mms             0.00
# 83                                accommodates_yeo_mms             0.00
# 82                          host_response_rate_yeo_mms             0.00
# 81   calculated_host_listings_count_shared_rooms_di...             0.00
#
#      ranking_per
# 65             0
# 61             1
# 12             2
# 23             3
# 38             4
# 31             5
# 30             6
# 14             7
# 34             8
# 21             9
# 13            10
# 6             11
# 29            12
# 26            13
# 22            14
# 11            15
# 18            16
# 28            17
# 24            18
# 33            19
# 9             20
# 40            21
# 63            22
# 32            23
# 5             24
# 59            25
# 64            26
# 54            27
# 62            28
# 19            29
# 20            30
# 7             31
# 58            32
# 51            33
# 128           34
# 27            35
# 101           36
# 25            37
# 49            38
# 126           39
# 37            40
# 121           41
# 122           42
# 60            43
# 35            44
# 94            45
# 2             46
# 109           47
# 107           48
# 108           49
# 111           50
# 110           51
# 0             52
# 106           53
# 105           54
# 104           55
# 103           56
# 102           57
# 100           58
# 113           59
# 99            60
# 98            61
# 97            62
# 96            63
# 95            64
# 93            65
# 112           66
# 125           67
# 114           68
# 115           69
# 138           70
# 137           71
# 136           72
# 135           73
# 134           74
# 133           75
# 132           76
# 131           77
# 130           78
# 129           79
# 127           80
# 91            81
# 124           82
# 123           83
# 120           84
# 119           85
# 118           86
# 117           87
# 116           88
# 92            89
# 70            90
# 90            91
# 57            92
# 55            93
# 53            94
# 52            95
# 50            96
# 48            97
# 47            98
# 46            99
# 45           100
# 44           101
# 43           102
# 42           103
# 41           104
# 39           105
# 36           106
# 17           107
# 16           108
# 15           109
# 10           110
# 8            111
# 4            112
# 3            113
# 56           114
# 66           115
# 89           116
# 67           117
# 88           118
# 87           119
# 86           120
# 85           121
# 84           122
# 83           123
# 82           124
# 81           125

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 2

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_per = rank_per.iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_per = x[entran_per].copy()

# %% [markdown]
# ### 3.5. SUPER RANKING

# %% [markdown]
# Otra forma es hacer los métodos y despues un SUPER RANKING para hacer la selección

# %%
#PASO 1. Preparar x e y. Cuidado si no se ha definido la target previamente
target = 'pisos_rentables'
x = df.drop(columns = target).copy()
y = df[target].copy()

#PASO 2. MÉTODOS PRESELECCION
#Método 1. MUTUAL INFORMATION
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)
mutual_selector = mutual_info_classif(x,y)
x_mi = ranking_mi(mutual_selector)
x_mi

#Método 2. RECURSIVE FEATURE ELIMINATION SIN validación cruzada
rfe = RFE(estimator = XGBClassifier(n_jobs = -1, eval_metric='auc'))
rfe.fit(x,y)
#Ranking. Las 1 son las que él seleccionaría para maximizar la métrica.
rfe.ranking_
#Dataframe de variable y ranking
x_rfe = pd.DataFrame({'variable': x.columns, 'ranking_rfe': rfe.ranking_}).sort_values(by = 'ranking_rfe')

#Método 3. PERMUTATION IMPORTANCE
xgb = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc')
xgb.fit(x,y)
permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',#Metrica regresión o clasificación
                                     n_repeats=5, n_jobs = -1)
#Creamos una función que nos genere un dataframe con la importancia y una columna de ranking.
def ranking_per(predictoras,permutacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)
x_per = ranking_per(x,permutacion)
x_per

#PASO 3. SUPER RANKING
#Función para unir todas los métodos anteriores en un solo dataframe
def ranking_tot(x_mi, x_rfe, x_per):
    ranking_tot = pd.merge(pd.merge(x_mi, x_rfe), x_per)
    ranking_tot['puntos'] = ranking_tot.ranking_mi + ranking_tot.ranking_rfe + ranking_tot.ranking_per
    ranking_tot.sort_values(by = 'puntos', inplace=True)
    ranking_tot['ranking_tot'] = range(0,len(ranking_tot.variable))
    return(ranking_tot)
super_ranking = ranking_tot(x_mi, x_rfe, x_per)
super_ranking
#Seleccionamos el número de las variables con las que queremos trabajar. Ej. [0:20]
x_sr = x[ranking_tot(x_mi, x_rfe, x_per)[0:57].variable].copy()
x_sr

#Gráfico 20 primeras variables según los puntos
#super_ranking.set_index('variable').puntos.sort_values(ascending = False).plot.barh(figsize = (8,10));
#Gráfico 20 primeras variables según el ranking_tot
#super_ranking.set_index('variable').ranking_tot[0:20].sort_values(ascending = False).plot.barh(figsize = (8,10));

#Despues de este proceso haríamos la modelización de ML para predecir resultados
# Out:
#        availability_365_yeo       price_yeo  availability_60_yeo  \
# 0                      0.23           -1.92                -1.39
# 1                     -1.57           -0.01                -1.39
# 2                     -1.57            0.45                -1.39
# 3                      1.04           -0.48                 0.72
# 4                     -1.57            0.09                -1.39
# ...                     ...             ...                  ...
# 18134                  1.15            1.48                 1.27
# 18135                  1.15           -0.14                 1.27
# 18136                  1.10            1.48                 0.93
# 18137                  1.15           -2.79                 1.25
# 18138                 -0.12            0.83                 1.27
#
#        availability_90_yeo  availability_30_yeo  \
# 0                    -1.45                -1.28
# 1                    -1.45                -1.28
# 2                    -1.45                -1.28
# 3                     0.66                 0.64
# 4                    -1.45                -1.28
# ...                    ...                  ...
# 18134                 1.16                 1.45
# 18135                 1.16                 1.45
# 18136                 0.94                 0.77
# 18137                 1.15                 1.42
# 18138                 1.16                 1.45
#
#        calculated_host_listings_count_disc_ds  host_response_rate_yeo  \
# 0                                        0.00                   -1.84
# 1                                        0.00                   -1.84
# 2                                        0.00                   -1.84
# 3                                        0.00                    0.62
# 4                                        0.00                   -1.84
# ...                                       ...                     ...
# 18134                                    0.00                    0.62
# 18135                                    0.00                    0.62
# 18136                                    0.00                    0.62
# 18137                                    0.00                   -1.84
# 18138                                    0.00                    0.62
#
#        bedrooms_disc_01_Una  bedrooms_disc_00_Estudio  \
# 0                      1.00                      0.00
# 1                      1.00                      0.00
# 2                      1.00                      0.00
# 3                      1.00                      0.00
# 4                      1.00                      0.00
# ...                     ...                       ...
# 18134                  1.00                      0.00
# 18135                  1.00                      0.00
# 18136                  1.00                      0.00
# 18137                  1.00                      0.00
# 18138                  1.00                      0.00
#
#        neighbourhood_group_Chamberí  ...  coffee  \
# 0                              0.00  ...       1
# 1                              0.00  ...       0
# 2                              0.00  ...       0
# 3                              0.00  ...       0
# 4                              0.00  ...       1
# ...                             ...  ...     ...
# 18134                          0.00  ...       1
# 18135                          0.00  ...       0
# 18136                          0.00  ...       1
# 18137                          0.00  ...       0
# 18138                          0.00  ...       0
#
#        property_type_Private room in rental unit  has_availability_oe  \
# 0                                           1.00                 0.00
# 1                                           0.00                 1.00
# 2                                           0.00                 1.00
# 3                                           1.00                 0.00
# 4                                           0.00                 0.00
# ...                                          ...                  ...
# 18134                                       0.00                 0.00
# 18135                                       1.00                 0.00
# 18136                                       0.00                 0.00
# 18137                                       1.00                 0.00
# 18138                                       0.00                 0.00
#
#        neighbourhood_group_Villa de Vallecas  cooking  stove  in  bed  \
# 0                                       0.00        1      0   0    1
# 1                                       0.00        0      0   0    0
# 2                                       0.00        0      0   0    0
# 3                                       0.00        1      0   0    0
# 4                                       0.00        1      1   0    1
# ...                                      ...      ...    ...  ..  ...
# 18134                                   0.00        1      0   0    1
# 18135                                   0.00        0      0   0    0
# 18136                                   0.00        1      0   0    1
# 18137                                   0.00        0      0   0    0
# 18138                                   0.00        0      0   0    0
#
#        bathrooms_disc_ds  bedrooms_disc_02_Dos
# 0                   0.00                  0.00
# 1                   0.00                  0.00
# 2                   0.00                  0.00
# 3                   0.00                  0.00
# 4                   0.00                  0.00
# ...                  ...                   ...
# 18134               0.00                  0.00
# 18135               0.00                  0.00
# 18136               0.00                  0.00
# 18137               0.00                  0.00
# 18138               0.00                  0.00
#
# [18139 rows x 57 columns]

# %%
super_ranking.set_index('variable').puntos[0:50].sort_values(ascending = False).plot.barh(figsize = (8,10));

# %% [markdown]
# ## 4. SELECCIONAR EL MÉTODO FINAL

# %% [markdown]
# Descomentar el método de preselección elegido y dejar comentados el resto.

# %%
# x_preseleccionado = x_mi
# x_preseleccionado = x_rfe
# x_preseleccionado = x_per
x_preseleccionado = x_sr

# %%
x_sr
# Out:
#        availability_365_yeo       price_yeo  availability_60_yeo  \
# 0                      0.23           -1.92                -1.39
# 1                     -1.57           -0.01                -1.39
# 2                     -1.57            0.45                -1.39
# 3                      1.04           -0.48                 0.72
# 4                     -1.57            0.09                -1.39
# ...                     ...             ...                  ...
# 18134                  1.15            1.48                 1.27
# 18135                  1.15           -0.14                 1.27
# 18136                  1.10            1.48                 0.93
# 18137                  1.15           -2.79                 1.25
# 18138                 -0.12            0.83                 1.27
#
#        availability_90_yeo  availability_30_yeo  \
# 0                    -1.45                -1.28
# 1                    -1.45                -1.28
# 2                    -1.45                -1.28
# 3                     0.66                 0.64
# 4                    -1.45                -1.28
# ...                    ...                  ...
# 18134                 1.16                 1.45
# 18135                 1.16                 1.45
# 18136                 0.94                 0.77
# 18137                 1.15                 1.42
# 18138                 1.16                 1.45
#
#        calculated_host_listings_count_disc_ds  host_response_rate_yeo  \
# 0                                        0.00                   -1.84
# 1                                        0.00                   -1.84
# 2                                        0.00                   -1.84
# 3                                        0.00                    0.62
# 4                                        0.00                   -1.84
# ...                                       ...                     ...
# 18134                                    0.00                    0.62
# 18135                                    0.00                    0.62
# 18136                                    0.00                    0.62
# 18137                                    0.00                   -1.84
# 18138                                    0.00                    0.62
#
#        bedrooms_disc_01_Una  bedrooms_disc_00_Estudio  \
# 0                      1.00                      0.00
# 1                      1.00                      0.00
# 2                      1.00                      0.00
# 3                      1.00                      0.00
# 4                      1.00                      0.00
# ...                     ...                       ...
# 18134                  1.00                      0.00
# 18135                  1.00                      0.00
# 18136                  1.00                      0.00
# 18137                  1.00                      0.00
# 18138                  1.00                      0.00
#
#        neighbourhood_group_Chamberí  ...  coffee  \
# 0                              0.00  ...       1
# 1                              0.00  ...       0
# 2                              0.00  ...       0
# 3                              0.00  ...       0
# 4                              0.00  ...       1
# ...                             ...  ...     ...
# 18134                          0.00  ...       1
# 18135                          0.00  ...       0
# 18136                          0.00  ...       1
# 18137                          0.00  ...       0
# 18138                          0.00  ...       0
#
#        property_type_Private room in rental unit  has_availability_oe  \
# 0                                           1.00                 0.00
# 1                                           0.00                 1.00
# 2                                           0.00                 1.00
# 3                                           1.00                 0.00
# 4                                           0.00                 0.00
# ...                                          ...                  ...
# 18134                                       0.00                 0.00
# 18135                                       1.00                 0.00
# 18136                                       0.00                 0.00
# 18137                                       1.00                 0.00
# 18138                                       0.00                 0.00
#
#        neighbourhood_group_Villa de Vallecas  cooking  stove  in  bed  \
# 0                                       0.00        1      0   0    1
# 1                                       0.00        0      0   0    0
# 2                                       0.00        0      0   0    0
# 3                                       0.00        1      0   0    0
# 4                                       0.00        1      1   0    1
# ...                                      ...      ...    ...  ..  ...
# 18134                                   0.00        1      0   0    1
# 18135                                   0.00        0      0   0    0
# 18136                                   0.00        1      0   0    1
# 18137                                   0.00        0      0   0    0
# 18138                                   0.00        0      0   0    0
#
#        bathrooms_disc_ds  bedrooms_disc_02_Dos
# 0                   0.00                  0.00
# 1                   0.00                  0.00
# 2                   0.00                  0.00
# 3                   0.00                  0.00
# 4                   0.00                  0.00
# ...                  ...                   ...
# 18134               0.00                  0.00
# 18135               0.00                  0.00
# 18136               0.00                  0.00
# 18137               0.00                  0.00
# 18138               0.00                  0.00
#
# [18139 rows x 57 columns]

# %% [markdown]
# ## 5. MÉTODOS NO SUPERVISADOS

# %% [markdown]
# ### 5.1. Correlación

# %% [markdown]
# #### 5.1.1. Crear una función para mostrar el resultado

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %% [markdown]
# #### 5.1.2. Calcular y revisar

# %% [markdown]
# ##### Calcular

# %%
cor_finales = correlaciones_fuertes(x_preseleccionado)

# %% [markdown]
# ##### Revisar agregado

# %%
#Número de veces que var1 aparece en relacion con diferentes variables. Ej. var1//variacion_tasa_empleo_bin_rs = 6 veces
cor_finales.var1.value_counts()
# Out:
# var1
# coffee                                                 11
# maker                                                  11
# host_response_rate_yeo                                 10
# host_response_time_oe                                   9
# microwave                                               9
# cooking                                                 9
# iron                                                    8
# and silverware                                          8
# dryer bed                                               7
# clothing storage                                        7
# freezer                                                 7
# beds_disc_1                                             6
# stove                                                   6
# hair                                                    6
# number_of_reviews_disc_oe                               6
# in                                                      5
# bed                                                     5
# bedrooms_disc_01_Una                                    4
# room_type_Private room                                  4
# accommodates_yeo                                        4
# availability_90_yeo                                     4
# room_type_Entire home/apt                               4
# price_yeo                                               3
# availability_365_yeo                                    3
# has_availability_oe                                     2
# accommodates_disc_4-16                                  2
# availability_60_yeo                                     2
# room                                                    2
# shampoo                                                 2
# bedrooms_disc_00_Estudio                                2
# property_type_Private room in rental unit               2
# bedrooms_disc_02_Dos                                    1
# availability_30_yeo                                     1
# maximum_nights_disc_ds                                  1
# host_is_superhost_oe                                    1
# bathrooms_disc_ds                                       1
# calculated_host_listings_count_entire_homes_disc_ds     1
# Name: count, dtype: int64

# %% [markdown]
# ##### Revisar detalle

# %%
#Opciones si hay muchas variables con altas correlaciones:
#1. Rehacer el reescalado porque se ha hecho mas de un proceso sobre la misma variable (04_Plantilla Transformacion de datos)
#2. Usar algoritmos como los árboles de decisión o Random Forest que no les afectan las correlaciones entre variables
cor_finales.head(40)
# Out:
#                                                    var1  \
# 2546                             room_type_Private room
# 1943  calculated_host_listings_count_entire_homes_di...
# 2703                                             coffee
# 117                                 availability_60_yeo
# 1488                              host_response_time_oe
# 230                                 availability_30_yeo
# 1618                             maximum_nights_disc_ds
# 175                                 availability_90_yeo
# 2556                             room_type_Private room
# 2774          property_type_Private room in rental unit
# 1479                                          dryer bed
# 171                                 availability_90_yeo
# 2709                                             coffee
# 759                                         beds_disc_1
# 1734                                     and silverware
# 2                                  availability_365_yeo
# 1564                                               hair
# 2253                                          microwave
# 2270                                          microwave
# 1407                                              maker
# 1761                                     and silverware
# 1027                                   accommodates_yeo
# 1043                                   accommodates_yeo
# 2184                          room_type_Entire home/apt
# 4                                  availability_365_yeo
# 2526                             room_type_Private room
# 3117                                                bed
# 2592                                               iron
# 1764                                     and silverware
# 2704                                             coffee
# 2167                          room_type_Entire home/apt
# 1393                                              maker
# 1735                                     and silverware
# 2248                                          microwave
# 2730                                             coffee
# 2095                                   clothing storage
# 455                                bedrooms_disc_01_Una
# 101                                           price_yeo
# 2946                                            cooking
# 1419                                              maker
#
#                                            var2            corr
# 2546                  room_type_Entire home/apt            0.98
# 1943     calculated_host_listings_count_disc_ds            0.98
# 2703                                      maker            0.97
# 117                         availability_90_yeo            0.97
# 1488                     host_response_rate_yeo            0.95
# 230                         availability_60_yeo            0.93
# 1618                         maximum_nights_yeo            0.92
# 175                         availability_30_yeo            0.87
# 2556  property_type_Private room in rental unit            0.85
# 2774                  room_type_Entire home/apt            0.83
# 1479                                        bed            0.79
# 171                        availability_365_yeo            0.78
# 2709                             and silverware            0.74
# 759                            accommodates_yeo            0.73
# 1734                                      maker            0.73
# 2                           availability_60_yeo            0.73
# 1564                                  dryer bed            0.72
# 2253                             and silverware            0.69
# 2270                                     coffee            0.68
# 1407                                  microwave            0.67
# 1761                                    cooking            0.66
# 1027                                  price_yeo            0.66
# 1043                     accommodates_disc_4-16            0.65
# 2184                           accommodates_yeo            0.64
# 4                           availability_30_yeo            0.63
# 2526                           accommodates_yeo            0.62
# 3117                                  microwave            0.60
# 2592                                       hair            0.60
# 1764                                        bed            0.58
# 2704                                  dryer bed            0.57
# 2167                                  price_yeo            0.57
# 1393                                  dryer bed            0.57
# 1735                                  dryer bed            0.56
# 2248                                  dryer bed            0.56
# 2730                                    cooking            0.56
# 2095                                       room            0.56
# 455                        bedrooms_disc_02_Dos            0.56
# 101                      room_type_Private room            0.56
# 2946                                  microwave            0.56
# 1419                                    cooking            0.55

# %%
max_correlacion = 0.96
exceso_correlacion = cor_finales.var1.loc[cor_finales['corr']>=max_correlacion].to_list()
exceso_correlacion
# Out:
# ['room_type_Private room',
#  'calculated_host_listings_count_entire_homes_disc_ds',
#  'coffee',
#  'availability_60_yeo']

# %% [markdown]
# #### 5.1.3. Filtrar variables

# %% [markdown]
# Automáticamente se descartarán las variables que hayan superado la correlación máxima que hayamos definido y se generará una lista con el resto de las variables

# %%
a_eliminar_corr = exceso_correlacion

# %%
x_preseleccionado.drop(columns = a_eliminar_corr, inplace = True)

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['availability_365_yeo',
#  'price_yeo',
#  'availability_90_yeo',
#  'availability_30_yeo',
#  'calculated_host_listings_count_disc_ds',
#  'host_response_rate_yeo',
#  'bedrooms_disc_01_Una',
#  'bedrooms_disc_00_Estudio',
#  'neighbourhood_group_Chamberí',
#  'neighbourhood_group_Centro',
#  'neighbourhood_group_Tetuán',
#  'number_of_reviews_disc_oe',
#  'beds_disc_1',
#  'neighbourhood_group_Chamartín',
#  'parking',
#  'neighbourhood_group_Moncloa',
#  'accommodates_disc_4-16',
#  'accommodates_yeo',
#  'host_is_superhost_oe',
#  'neighbourhood_group_Puente de Vallecas',
#  'shampoo',
#  'maximum_nights_yeo',
#  'neighbourhood_group_Usera',
#  'maker',
#  'dryer bed',
#  'host_response_time_oe',
#  'hair',
#  'maximum_nights_disc_ds',
#  'freezer',
#  'and silverware',
#  'neighbourhood_group_San Blas',
#  'neighbourhood_group_Carabanchel',
#  'neighbourhood_group_Ciudad Lineal',
#  'dedicated workspace',
#  'clothing storage',
#  'bedrooms_disc_04_Cuatro o mas',
#  'room_type_Entire home/apt',
#  'microwave',
#  'neighbourhood_group_Arganzuela',
#  'neighbourhood_group_Villaverde',
#  'instant_bookable_oe',
#  'room',
#  'iron',
#  'neighbourhood_group_Salamanca',
#  'property_type_Private room in rental unit',
#  'has_availability_oe',
#  'neighbourhood_group_Villa de Vallecas',
#  'cooking',
#  'stove',
#  'in',
#  'bed',
#  'bathrooms_disc_ds',
#  'bedrooms_disc_02_Dos']

# %% [markdown]
# ## 6. GUARDAR DATASETS TRAS PRESELECCION DE VARIABLES

# %%
#Definir los nombres de los archivos
nombre_x_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'x_preseleccionado.pickle'
nombre_y_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'y_preseleccionado.pickle'

# %%
#Guardar los archivos
x_preseleccionado.to_pickle(nombre_x_preseleccionado)

y_preseleccionado = y.copy()
y_preseleccionado.to_pickle(nombre_y_preseleccionado)

# %%
#Guardar los nombres de las variables finales
nombre_variables_finales = ruta_proyecto + '/05_Resultados/' + 'variables_finales.pickle'

x_preseleccionado.iloc[0].to_pickle(nombre_variables_finales)

# %%
x_preseleccionado.shape
# Out:
# (18139, 53)
