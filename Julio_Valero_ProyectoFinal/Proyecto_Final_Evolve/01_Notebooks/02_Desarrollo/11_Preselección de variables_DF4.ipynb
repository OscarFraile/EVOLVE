# %% [markdown]
# # PLANTILLA PRESELECCIÓN DE VARIABLES

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## 1. IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.inspection import permutation_importance


#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## 2. IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/Python Data Mastery/EstructuraDirectorio/03_MACHINE_LEARNING/08_CASOS/007_AIRBNB'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)

# %% [markdown]
# ## 3. MÉTODOS SUPERVISADOS

# %% [markdown]
# ### 3.1. Preparar x e y

# %%
target = 'pisos_rentables'
x = df.drop(columns = target).copy()
y =  df[target].copy()

# %%
print("Valores únicos de target:", y.unique())
print("Conteo de clases:", y.value_counts())
# Out:
# Valores únicos de target: [1 0]
# Conteo de clases: pisos_rentables
# 1    12646
# 0     5493
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2. Mutual Information

# %% [markdown]
# #### 3.2.1. Crear una función para mostrar el resultado

# %%
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)

# %% [markdown]
# #### 3.2.2. Calcular y revisar

# %%
mutual_selector = mutual_info_classif(x,y)

rank_mi = ranking_mi(mutual_selector, modo = 'grafico')

# %%
#Mostrar el máximo de columnas posibles de una tabla
pd.set_option('display.max_rows', 200) #Número de columnas que deben verse. None = Máx
rank_mi = ranking_mi(mutual_selector)
rank_mi.head(126)
# Out:
#                                               variable  importancia_mi  \
# 85                            availability_365_yeo_mms        0.440623
# 57                                availability_365_yeo        0.439632
# 56                                 availability_90_yeo        0.135218
# 84                             availability_90_yeo_mms        0.133581
# 55                                 availability_60_yeo        0.109896
# 83                             availability_60_yeo_mms        0.102832
# 54                                 availability_30_yeo        0.071662
# 82                             availability_30_yeo_mms        0.069585
# 58                           host_response_time_oe_mms        0.037506
# 78                          host_response_rate_yeo_mms        0.035864
# 80                              maximum_nights_yeo_mms        0.033132
# 50                              host_response_rate_yeo        0.031428
# 41                              maximum_nights_disc_ds        0.029904
# 30                               host_response_time_oe        0.029419
# 52                                  maximum_nights_yeo        0.026256
# 70          calculated_host_listings_count_disc_ds_mms        0.024416
# 43   calculated_host_listings_count_entire_homes_di...        0.023839
# 81                                       price_yeo_mms        0.022162
# 53                                           price_yeo        0.021804
# 42              calculated_host_listings_count_disc_ds        0.021691
# 71   calculated_host_listings_count_entire_homes_di...        0.018757
# 69                          maximum_nights_disc_ds_mms        0.016052
# 63                             has_availability_oe_mms        0.015183
# 62                       host_identity_verified_oe_mms        0.012614
# 101                                            cooking        0.011244
# 88                                             allowed        0.010755
# 40                              minimum_nights_disc_ds        0.010370
# 35                                 has_availability_oe        0.010249
# 119                                             linens        0.009175
# 6                            room_type_Entire home/apt        0.008357
# 134                                       wifi kitchen        0.007744
# 91                                                 bed        0.007636
# 97                                    clothing storage        0.007316
# 95                                            cleaning        0.006791
# 73   calculated_host_listings_count_shared_rooms_di...        0.006503
# 77                       number_of_reviews_disc_ds_mms        0.006226
# 72   calculated_host_listings_count_private_rooms_d...        0.005876
# 89                                      and silverware        0.005842
# 21              neighbourhood_group_Puente de Vallecas        0.005751
# 115                                     hot water iron        0.005363
# 99                                        coffee maker        0.005255
# 74                            accommodates_disc_ds_mms        0.005147
# 112                                               hair        0.005133
# 118                                 kitchen essentials        0.004886
# 24                        neighbourhood_group_San Blas        0.004589
# 114                                     hair dryer bed        0.004518
# 34                           host_identity_verified_oe        0.004480
# 102                                     cooking basics        0.004382
# 37                                 instant_bookable_oe        0.004323
# 132                                          tv washer        0.004268
# 2                     property_type_Entire rental unit        0.004141
# 90                                              basics        0.004038
# 86                                                 air        0.004031
# 16                      neighbourhood_group_Fuencarral        0.003995
# 125                                       refrigerator        0.003902
# 44   calculated_host_listings_count_private_rooms_d...        0.003881
# 46                                accommodates_disc_ds        0.003822
# 96                                            clothing        0.003682
# 38                                   bathrooms_disc_ds        0.003491
# 108                                          dryer bed        0.003459
# 60                           host_verifications_oe_mms        0.003389
# 7                               room_type_Private room        0.003377
# 29                      neighbourhood_group_Villaverde        0.003368
# 129                                               soap        0.002969
# 117                                               iron        0.002939
# 64                                      license_oe_mms        0.002936
# 116                                                 in        0.002903
# 36                                          license_oe        0.002874
# 17                       neighbourhood_group_Hortaleza        0.002843
# 28               neighbourhood_group_Villa de Vallecas        0.002734
# 20                       neighbourhood_group_Moratalaz        0.002639
# 128                                         silverware        0.002560
# 14                        neighbourhood_group_Chamberí        0.002551
# 124                                            parking        0.002337
# 126                                               room        0.002309
# 98                                              coffee        0.002303
# 79                                accommodates_yeo_mms        0.002274
# 103                                          dedicated        0.002226
# 65                             instant_bookable_oe_mms        0.002093
# 104                                dedicated workspace        0.002089
# 100                                       conditioning        0.001741
# 127                                            shampoo        0.001720
# 109                                   dryer bed linens        0.001692
# 94                                           body soap        0.001593
# 4                   property_type_Private room in home        0.001580
# 51                                    accommodates_yeo        0.001523
# 1                            property_type_Entire loft        0.001446
# 33                             host_has_profile_pic_oe        0.001389
# 122                                  microwave hangers        0.001380
# 135                                          workspace        0.001273
# 39                                       price_disc_ds        0.001191
# 87                                    air conditioning        0.001163
# 12                          neighbourhood_group_Centro        0.001113
# 75                                    beds_disc_ds_mms        0.001075
# 93                                                body        0.001021
# 9                       neighbourhood_group_Arganzuela        0.000651
# 45   calculated_host_listings_count_shared_rooms_di...        0.000636
# 111                                            freezer        0.000582
# 106                                         dishes and        0.000420
# 107                              dishes and silverware        0.000216
# 22                          neighbourhood_group_Retiro        0.000077
# 130                                            storage        0.000000
# 131                                              stove        0.000000
# 121                                          microwave        0.000000
# 113                                         hair dryer        0.000000
# 133                                         water iron        0.000000
# 123                                               oven        0.000000
# 120                                              maker        0.000000
# 110                                           elevator        0.000000
# 0                           property_type_Entire condo        0.000000
# 105                                             dishes        0.000000
# 92                                          bed linens        0.000000
# 3                                  property_type_OTROS        0.000000
# 5            property_type_Private room in rental unit        0.000000
# 8                                room_type_Shared room        0.000000
# 10                         neighbourhood_group_Barajas        0.000000
# 11                     neighbourhood_group_Carabanchel        0.000000
# 13                       neighbourhood_group_Chamartín        0.000000
# 15                   neighbourhood_group_Ciudad Lineal        0.000000
# 18                          neighbourhood_group_Latina        0.000000
# 19                         neighbourhood_group_Moncloa        0.000000
# 23                       neighbourhood_group_Salamanca        0.000000
# 25                          neighbourhood_group_Tetuán        0.000000
# 26                           neighbourhood_group_Usera        0.000000
# 27                       neighbourhood_group_Vicálvaro        0.000000
# 31                                host_is_superhost_oe        0.000000
#
#      ranking_mi
# 85            0
# 57            1
# 56            2
# 84            3
# 55            4
# 83            5
# 54            6
# 82            7
# 58            8
# 78            9
# 80           10
# 50           11
# 41           12
# 30           13
# 52           14
# 70           15
# 43           16
# 81           17
# 53           18
# 42           19
# 71           20
# 69           21
# 63           22
# 62           23
# 101          24
# 88           25
# 40           26
# 35           27
# 119          28
# 6            29
# 134          30
# 91           31
# 97           32
# 95           33
# 73           34
# 77           35
# 72           36
# 89           37
# 21           38
# 115          39
# 99           40
# 74           41
# 112          42
# 118          43
# 24           44
# 114          45
# 34           46
# 102          47
# 37           48
# 132          49
# 2            50
# 90           51
# 86           52
# 16           53
# 125          54
# 44           55
# 46           56
# 96           57
# 38           58
# 108          59
# 60           60
# 7            61
# 29           62
# 129          63
# 117          64
# 64           65
# 116          66
# 36           67
# 17           68
# 28           69
# 20           70
# 128          71
# 14           72
# 124          73
# 126          74
# 98           75
# 79           76
# 103          77
# 65           78
# 104          79
# 100          80
# 127          81
# 109          82
# 94           83
# 4            84
# 51           85
# 1            86
# 33           87
# 122          88
# 135          89
# 39           90
# 87           91
# 12           92
# 75           93
# 93           94
# 9            95
# 45           96
# 111          97
# 106          98
# 107          99
# 22          100
# 130         101
# 131         102
# 121         103
# 113         104
# 133         105
# 123         106
# 120         107
# 110         108
# 0           109
# 105         110
# 92          111
# 3           112
# 5           113
# 8           114
# 10          115
# 11          116
# 13          117
# 15          118
# 18          119
# 19          120
# 23          121
# 25          122
# 26          123
# 27          124
# 31          125

# %% [markdown]
# #### 3.2.3. Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 99

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_mi = ranking_mi(mutual_selector).iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_mi = x[entran_mi].copy()

# %% [markdown]
# ### 3.3. Recursive Feature Elimination

# %% [markdown]
# #### 3.3.1. Instanciar

# %%
rfe = RFE(estimator = XGBClassifier( n_jobs = -1, eval_metric='auc'))

# %% [markdown]
# #### 3.3.2. Entrenar

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBClassifier(base_score=None, booster=None, callbacks=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, device=None,
#                             early_stopping_rounds=None,
#                             enable_categorical=False, eval_metric='auc',
#                             feature_types=None, gamma=None, grow_policy=None,
#                             importance_type=None, interaction_constraints=None,
#                             learning_rate=None, max_bin=None,
#                             max_cat_threshold=None, max_cat_to_onehot=None,
#                             max_delta_step=None, max_depth=None,
#                             max_leaves=None, min_child_weight=None, missing=nan,
#                             monotone_constraints=None, multi_strategy=None,
#                             n_estimators=None, n_jobs=-1,
#                             num_parallel_tree=None, random_state=None, ...))

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_rfe = x.columns[rfe.support_]

# %% [markdown]
# #### 3.3.3. Crear el dataframe con la selección

# %%
x_rfe = x[entran_rfe].copy()

# %% [markdown]
# ### 3.4. Permutation Importance

# %% [markdown]
# #### 3.4.1. Crear una función para mostrar el resultado

# %%
def ranking_per(predictoras,permutxacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)

# %% [markdown]
# #### 3.4.2. Instanciar y entrenar

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r'.*Use subset.*of np.ndarray is not recommended')
xgb = XGBClassifier(n_jobs = -1, eval_metric='auc')
xgb.fit(x,y)
permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',
                                     n_repeats=5, n_jobs = -1)

# %% [markdown]
# #### 3.4.3. Revisar la salida

# %%
rank_per = ranking_per(x,permutacion)

rank_per.set_index('variable').importancia_per.sort_values().plot.barh(figsize = (12,19));

# %% [markdown]
# #### 3.4.4. Seleccionar las variables que pasan

# %%
#Formato sin notación científica
pd.options.display.float_format = '{:15.2f}'.format 
rank_per = ranking_per(x,permutacion)
rank_per.head(126)
# Out:
#                                               variable  importancia_per  \
# 57                                availability_365_yeo             0.45
# 53                                           price_yeo             0.05
# 48                                    bedrooms_disc_ds             0.00
# 23                       neighbourhood_group_Salamanca             0.00
# 12                          neighbourhood_group_Centro             0.00
# 14                        neighbourhood_group_Chamberí             0.00
# 21              neighbourhood_group_Puente de Vallecas             0.00
# 13                       neighbourhood_group_Chamartín             0.00
# 47                                        beds_disc_ds             0.00
# 11                     neighbourhood_group_Carabanchel             0.00
# 51                                    accommodates_yeo             0.00
# 26                           neighbourhood_group_Usera             0.00
# 18                          neighbourhood_group_Latina             0.00
# 29                      neighbourhood_group_Villaverde             0.00
# 22                          neighbourhood_group_Retiro             0.00
# 6                            room_type_Entire home/apt             0.00
# 54                                 availability_30_yeo             0.00
# 55                                 availability_60_yeo             0.00
# 50                              host_response_rate_yeo             0.00
# 56                                 availability_90_yeo             0.00
# 28               neighbourhood_group_Villa de Vallecas             0.00
# 132                                          tv washer             0.00
# 52                                  maximum_nights_yeo             0.00
# 9                       neighbourhood_group_Arganzuela             0.00
# 5            property_type_Private room in rental unit             0.00
# 42              calculated_host_listings_count_disc_ds             0.00
# 24                        neighbourhood_group_San Blas             0.00
# 115                                     hot water iron             0.00
# 88                                             allowed             0.00
# 3                                  property_type_OTROS             0.00
# 37                                 instant_bookable_oe             0.00
# 20                       neighbourhood_group_Moratalaz             0.00
# 124                                            parking             0.00
# 86                                                 air             0.00
# 2                     property_type_Entire rental unit             0.00
# 125                                       refrigerator             0.00
# 95                                            cleaning             0.00
# 19                         neighbourhood_group_Moncloa             0.00
# 122                                  microwave hangers             0.00
# 4                   property_type_Private room in home             0.00
# 90                                              basics             0.00
# 91                                                 bed             0.00
# 30                               host_response_time_oe             0.00
# 99                                        coffee maker             0.00
# 134                                       wifi kitchen             0.00
# 103                                          dedicated             0.00
# 96                                            clothing             0.00
# 36                                          license_oe             0.00
# 131                                              stove             0.00
# 93                                                body             0.00
# 46                                accommodates_disc_ds             0.00
# 121                                          microwave             0.00
# 32                               host_verifications_oe             0.00
# 110                                           elevator             0.00
# 112                                               hair             0.00
# 116                                                 in             0.00
# 27                       neighbourhood_group_Vicálvaro             0.00
# 31                                host_is_superhost_oe             0.00
# 111                                            freezer             0.00
# 16                      neighbourhood_group_Fuencarral             0.00
# 123                                               oven             0.00
# 89                                      and silverware             0.00
# 118                                 kitchen essentials             0.00
# 108                                          dryer bed             0.00
# 43   calculated_host_listings_count_entire_homes_di...             0.00
# 97                                    clothing storage             0.00
# 7                               room_type_Private room             0.00
# 25                          neighbourhood_group_Tetuán             0.00
# 98                                              coffee             0.00
# 120                                              maker             0.00
# 126                                               room             0.00
# 127                                            shampoo             0.00
# 49                           number_of_reviews_disc_ds             0.00
# 41                              maximum_nights_disc_ds             0.00
# 117                                               iron             0.00
# 17                       neighbourhood_group_Hortaleza             0.00
# 33                             host_has_profile_pic_oe             0.00
# 39                                       price_disc_ds             0.00
# 45   calculated_host_listings_count_shared_rooms_di...             0.00
# 0                           property_type_Entire condo             0.00
# 1                            property_type_Entire loft             0.00
# 34                           host_identity_verified_oe             0.00
# 44   calculated_host_listings_count_private_rooms_d...             0.00
# 133                                         water iron             0.00
# 100                                       conditioning             0.00
# 130                                            storage             0.00
# 129                                               soap             0.00
# 114                                     hair dryer bed             0.00
# 101                                            cooking             0.00
# 113                                         hair dryer             0.00
# 104                                dedicated workspace             0.00
# 105                                             dishes             0.00
# 106                                         dishes and             0.00
# 107                              dishes and silverware             0.00
# 128                                         silverware             0.00
# 109                                   dryer bed linens             0.00
# 119                                             linens             0.00
# 102                                     cooking basics             0.00
# 68                          minimum_nights_disc_ds_mms             0.00
# 94                                           body soap             0.00
# 61                         host_has_profile_pic_oe_mms             0.00
# 67                                   price_disc_ds_mms             0.00
# 66                               bathrooms_disc_ds_mms             0.00
# 65                             instant_bookable_oe_mms             0.00
# 64                                      license_oe_mms             0.00
# 63                             has_availability_oe_mms             0.00
# 62                       host_identity_verified_oe_mms             0.00
# 60                           host_verifications_oe_mms             0.00
# 92                                          bed linens             0.00
# 59                            host_is_superhost_oe_mms             0.00
# 58                           host_response_time_oe_mms             0.00
# 40                              minimum_nights_disc_ds             0.00
# 35                                 has_availability_oe             0.00
# 10                         neighbourhood_group_Barajas             0.00
# 8                                room_type_Shared room             0.00
# 69                          maximum_nights_disc_ds_mms             0.00
# 70          calculated_host_listings_count_disc_ds_mms             0.00
# 71   calculated_host_listings_count_entire_homes_di...             0.00
# 72   calculated_host_listings_count_private_rooms_d...             0.00
# 87                                    air conditioning             0.00
# 85                            availability_365_yeo_mms             0.00
# 84                             availability_90_yeo_mms             0.00
# 83                             availability_60_yeo_mms             0.00
# 82                             availability_30_yeo_mms             0.00
# 81                                       price_yeo_mms             0.00
# 80                              maximum_nights_yeo_mms             0.00
#
#      ranking_per
# 57             0
# 53             1
# 48             2
# 23             3
# 12             4
# 14             5
# 21             6
# 13             7
# 47             8
# 11             9
# 51            10
# 26            11
# 18            12
# 29            13
# 22            14
# 6             15
# 54            16
# 55            17
# 50            18
# 56            19
# 28            20
# 132           21
# 52            22
# 9             23
# 5             24
# 42            25
# 24            26
# 115           27
# 88            28
# 3             29
# 37            30
# 20            31
# 124           32
# 86            33
# 2             34
# 125           35
# 95            36
# 19            37
# 122           38
# 4             39
# 90            40
# 91            41
# 30            42
# 99            43
# 134           44
# 103           45
# 96            46
# 36            47
# 131           48
# 93            49
# 46            50
# 121           51
# 32            52
# 110           53
# 112           54
# 116           55
# 27            56
# 31            57
# 111           58
# 16            59
# 123           60
# 89            61
# 118           62
# 108           63
# 43            64
# 97            65
# 7             66
# 25            67
# 98            68
# 120           69
# 126           70
# 127           71
# 49            72
# 41            73
# 117           74
# 17            75
# 33            76
# 39            77
# 45            78
# 0             79
# 1             80
# 34            81
# 44            82
# 133           83
# 100           84
# 130           85
# 129           86
# 114           87
# 101           88
# 113           89
# 104           90
# 105           91
# 106           92
# 107           93
# 128           94
# 109           95
# 119           96
# 102           97
# 68            98
# 94            99
# 61           100
# 67           101
# 66           102
# 65           103
# 64           104
# 63           105
# 62           106
# 60           107
# 92           108
# 59           109
# 58           110
# 40           111
# 35           112
# 10           113
# 8            114
# 69           115
# 70           116
# 71           117
# 72           118
# 87           119
# 85           120
# 84           121
# 83           122
# 82           123
# 81           124
# 80           125

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 1

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_per = rank_per.iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_per = x[entran_per].copy()

# %% [markdown]
# ### 3.5. SUPER RANKING

# %% [markdown]
# Otra forma es hacer los métodos y despues un SUPER RANKING para hacer la selección

# %%
#PASO 1. Preparar x e y. Cuidado si no se ha definido la target previamente
target = 'pisos_rentables'
x = df.drop(columns = target).copy()
y = df[target].copy()

#PASO 2. MÉTODOS PRESELECCION
#Método 1. MUTUAL INFORMATION
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)
mutual_selector = mutual_info_classif(x,y)
x_mi = ranking_mi(mutual_selector)
x_mi

#Método 2. RECURSIVE FEATURE ELIMINATION SIN validación cruzada
rfe = RFE(estimator = XGBClassifier(n_jobs = -1, eval_metric='auc'))
rfe.fit(x,y)
#Ranking. Las 1 son las que él seleccionaría para maximizar la métrica.
rfe.ranking_
#Dataframe de variable y ranking
x_rfe = pd.DataFrame({'variable': x.columns, 'ranking_rfe': rfe.ranking_}).sort_values(by = 'ranking_rfe')

#Método 3. PERMUTATION IMPORTANCE
xgb = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc')
xgb.fit(x,y)
permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',#Metrica regresión o clasificación
                                     n_repeats=5, n_jobs = -1)
#Creamos una función que nos genere un dataframe con la importancia y una columna de ranking.
def ranking_per(predictoras,permutacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)
x_per = ranking_per(x,permutacion)
x_per

#PASO 3. SUPER RANKING
#Función para unir todas los métodos anteriores en un solo dataframe
def ranking_tot(x_mi, x_rfe, x_per):
    ranking_tot = pd.merge(pd.merge(x_mi, x_rfe), x_per)
    ranking_tot['puntos'] = ranking_tot.ranking_mi + ranking_tot.ranking_rfe + ranking_tot.ranking_per
    ranking_tot.sort_values(by = 'puntos', inplace=True)
    ranking_tot['ranking_tot'] = range(0,len(ranking_tot.variable))
    return(ranking_tot)
super_ranking = ranking_tot(x_mi, x_rfe, x_per)
super_ranking
#Seleccionamos el número de las variables con las que queremos trabajar. Ej. [0:20]
x_sr = x[ranking_tot(x_mi, x_rfe, x_per)[0:57].variable].copy()
x_sr

#Gráfico 20 primeras variables según los puntos
#super_ranking.set_index('variable').puntos.sort_values(ascending = False).plot.barh(figsize = (8,10));
#Gráfico 20 primeras variables según el ranking_tot
#super_ranking.set_index('variable').ranking_tot[0:20].sort_values(ascending = False).plot.barh(figsize = (8,10));

#Despues de este proceso haríamos la modelización de ML para predecir resultados
# Out:
#        availability_365_yeo       price_yeo  availability_90_yeo  \
# 0                      0.23           -1.92                -1.45
# 1                     -1.57           -0.01                -1.45
# 2                     -1.57            0.45                -1.45
# 3                      1.04           -0.48                 0.66
# 4                     -1.57            0.09                -1.45
# ...                     ...             ...                  ...
# 18134                  1.15            1.48                 1.16
# 18135                  1.15           -0.14                 1.16
# 18136                  1.10            1.48                 0.94
# 18137                  1.15           -2.79                 1.15
# 18138                 -0.12            0.83                 1.16
#
#        availability_60_yeo  availability_30_yeo  host_response_rate_yeo  \
# 0                    -1.39                -1.28                   -1.84
# 1                    -1.39                -1.28                   -1.84
# 2                    -1.39                -1.28                   -1.84
# 3                     0.72                 0.64                    0.62
# 4                    -1.39                -1.28                   -1.84
# ...                    ...                  ...                     ...
# 18134                 1.27                 1.45                    0.62
# 18135                 1.27                 1.45                    0.62
# 18136                 0.93                 0.77                    0.62
# 18137                 1.25                 1.42                   -1.84
# 18138                 1.27                 1.45                    0.62
#
#        neighbourhood_group_Centro  maximum_nights_yeo  \
# 0                            0.00               -1.38
# 1                            1.00                0.65
# 2                            1.00               -0.64
# 3                            1.00               -1.48
# 4                            1.00               -0.09
# ...                           ...                 ...
# 18134                        0.00               -0.09
# 18135                        0.00               -1.66
# 18136                        0.00               -0.09
# 18137                        1.00               -1.64
# 18138                        0.00               -0.26
#
#        neighbourhood_group_Puente de Vallecas  \
# 0                                        0.00
# 1                                        0.00
# 2                                        0.00
# 3                                        0.00
# 4                                        0.00
# ...                                       ...
# 18134                                    0.00
# 18135                                    0.00
# 18136                                    0.00
# 18137                                    0.00
# 18138                                    0.00
#
#        calculated_host_listings_count_disc_ds  ...  host_verifications_oe  \
# 0                                        0.00  ...                   4.00
# 1                                        0.00  ...                   4.00
# 2                                        0.00  ...                   4.00
# 3                                        0.00  ...                   4.00
# 4                                        0.00  ...                   4.00
# ...                                       ...  ...                    ...
# 18134                                    0.00  ...                   4.00
# 18135                                    0.00  ...                   2.00
# 18136                                    0.00  ...                   4.00
# 18137                                    0.00  ...                   4.00
# 18138                                    0.00  ...                   5.00
#
#        neighbourhood_group_Chamberí  hot water iron  clothing storage  \
# 0                              0.00               1                 0
# 1                              0.00               0                 0
# 2                              0.00               0                 0
# 3                              0.00               1                 0
# 4                              0.00               1                 0
# ...                             ...             ...               ...
# 18134                          0.00               0                 1
# 18135                          0.00               0                 0
# 18136                          0.00               0                 1
# 18137                          0.00               0                 0
# 18138                          0.00               0                 0
#
#        calculated_host_listings_count_private_rooms_disc_ds  \
# 0                                                   0.00
# 1                                                   0.00
# 2                                                   0.00
# 3                                                   0.00
# 4                                                   0.00
# ...                                                  ...
# 18134                                               0.00
# 18135                                               0.00
# 18136                                               0.00
# 18137                                               0.00
# 18138                                               0.00
#
#        neighbourhood_group_Vicálvaro  shampoo  maker  has_availability_oe  \
# 0                               0.00        1      1                 0.00
# 1                               0.00        1      0                 1.00
# 2                               0.00        0      0                 1.00
# 3                               0.00        1      0                 0.00
# 4                               0.00        1      1                 0.00
# ...                              ...      ...    ...                  ...
# 18134                           0.00        1      1                 0.00
# 18135                           0.00        0      0                 0.00
# 18136                           0.00        1      1                 0.00
# 18137                           0.00        0      0                 0.00
# 18138                           0.00        0      0                 0.00
#
#        property_type_OTROS
# 0                     0.00
# 1                     0.00
# 2                     0.00
# 3                     0.00
# 4                     0.00
# ...                    ...
# 18134                 0.00
# 18135                 0.00
# 18136                 0.00
# 18137                 0.00
# 18138                 0.00
#
# [18139 rows x 57 columns]

# %%
super_ranking.set_index('variable').puntos[0:50].sort_values(ascending = False).plot.barh(figsize = (8,10));

# %% [markdown]
# ## 4. SELECCIONAR EL MÉTODO FINAL

# %% [markdown]
# Descomentar el método de preselección elegido y dejar comentados el resto.

# %%
# x_preseleccionado = x_mi
# x_preseleccionado = x_rfe
# x_preseleccionado = x_per
x_preseleccionado = x_sr

# %%
x_sr
# Out:
#        availability_365_yeo       price_yeo  availability_90_yeo  \
# 0                      0.23           -1.92                -1.45
# 1                     -1.57           -0.01                -1.45
# 2                     -1.57            0.45                -1.45
# 3                      1.04           -0.48                 0.66
# 4                     -1.57            0.09                -1.45
# ...                     ...             ...                  ...
# 18134                  1.15            1.48                 1.16
# 18135                  1.15           -0.14                 1.16
# 18136                  1.10            1.48                 0.94
# 18137                  1.15           -2.79                 1.15
# 18138                 -0.12            0.83                 1.16
#
#        availability_60_yeo  availability_30_yeo  host_response_rate_yeo  \
# 0                    -1.39                -1.28                   -1.84
# 1                    -1.39                -1.28                   -1.84
# 2                    -1.39                -1.28                   -1.84
# 3                     0.72                 0.64                    0.62
# 4                    -1.39                -1.28                   -1.84
# ...                    ...                  ...                     ...
# 18134                 1.27                 1.45                    0.62
# 18135                 1.27                 1.45                    0.62
# 18136                 0.93                 0.77                    0.62
# 18137                 1.25                 1.42                   -1.84
# 18138                 1.27                 1.45                    0.62
#
#        neighbourhood_group_Centro  maximum_nights_yeo  \
# 0                            0.00               -1.38
# 1                            1.00                0.65
# 2                            1.00               -0.64
# 3                            1.00               -1.48
# 4                            1.00               -0.09
# ...                           ...                 ...
# 18134                        0.00               -0.09
# 18135                        0.00               -1.66
# 18136                        0.00               -0.09
# 18137                        1.00               -1.64
# 18138                        0.00               -0.26
#
#        neighbourhood_group_Puente de Vallecas  \
# 0                                        0.00
# 1                                        0.00
# 2                                        0.00
# 3                                        0.00
# 4                                        0.00
# ...                                       ...
# 18134                                    0.00
# 18135                                    0.00
# 18136                                    0.00
# 18137                                    0.00
# 18138                                    0.00
#
#        calculated_host_listings_count_disc_ds  ...  host_verifications_oe  \
# 0                                        0.00  ...                   4.00
# 1                                        0.00  ...                   4.00
# 2                                        0.00  ...                   4.00
# 3                                        0.00  ...                   4.00
# 4                                        0.00  ...                   4.00
# ...                                       ...  ...                    ...
# 18134                                    0.00  ...                   4.00
# 18135                                    0.00  ...                   2.00
# 18136                                    0.00  ...                   4.00
# 18137                                    0.00  ...                   4.00
# 18138                                    0.00  ...                   5.00
#
#        neighbourhood_group_Chamberí  hot water iron  clothing storage  \
# 0                              0.00               1                 0
# 1                              0.00               0                 0
# 2                              0.00               0                 0
# 3                              0.00               1                 0
# 4                              0.00               1                 0
# ...                             ...             ...               ...
# 18134                          0.00               0                 1
# 18135                          0.00               0                 0
# 18136                          0.00               0                 1
# 18137                          0.00               0                 0
# 18138                          0.00               0                 0
#
#        calculated_host_listings_count_private_rooms_disc_ds  \
# 0                                                   0.00
# 1                                                   0.00
# 2                                                   0.00
# 3                                                   0.00
# 4                                                   0.00
# ...                                                  ...
# 18134                                               0.00
# 18135                                               0.00
# 18136                                               0.00
# 18137                                               0.00
# 18138                                               0.00
#
#        neighbourhood_group_Vicálvaro  shampoo  maker  has_availability_oe  \
# 0                               0.00        1      1                 0.00
# 1                               0.00        1      0                 1.00
# 2                               0.00        0      0                 1.00
# 3                               0.00        1      0                 0.00
# 4                               0.00        1      1                 0.00
# ...                              ...      ...    ...                  ...
# 18134                           0.00        1      1                 0.00
# 18135                           0.00        0      0                 0.00
# 18136                           0.00        1      1                 0.00
# 18137                           0.00        0      0                 0.00
# 18138                           0.00        0      0                 0.00
#
#        property_type_OTROS
# 0                     0.00
# 1                     0.00
# 2                     0.00
# 3                     0.00
# 4                     0.00
# ...                    ...
# 18134                 0.00
# 18135                 0.00
# 18136                 0.00
# 18137                 0.00
# 18138                 0.00
#
# [18139 rows x 57 columns]

# %% [markdown]
# ## 5. MÉTODOS NO SUPERVISADOS

# %% [markdown]
# ### 5.1. Correlación

# %% [markdown]
# #### 5.1.1. Crear una función para mostrar el resultado

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %% [markdown]
# #### 5.1.2. Calcular y revisar

# %% [markdown]
# ##### Calcular

# %%
cor_finales = correlaciones_fuertes(x_preseleccionado)

# %% [markdown]
# ##### Revisar agregado

# %%
#Número de veces que var1 aparece en relacion con diferentes variables. Ej. var1//variacion_tasa_empleo_bin_rs = 6 veces
cor_finales.var1.value_counts()
# Out:
# var1
# coffee                                       10
# and silverware                                9
# host_response_time_oe                         8
# stove                                         8
# maker                                         8
# microwave                                     8
# basics                                        7
# microwave hangers                             7
# clothing storage                              6
# cleaning                                      6
# dryer bed                                     6
# host_response_rate_yeo                        6
# accommodates_disc_ds                          5
# bed                                           5
# hot water iron                                5
# hair                                          4
# accommodates_yeo                              4
# availability_30_yeo                           4
# availability_365_yeo                          3
# room_type_Entire home/apt                     3
# property_type_Private room in rental unit     3
# has_availability_oe                           2
# allowed                                       2
# availability_90_yeo                           2
# shampoo                                       2
# tv washer                                     1
# bedrooms_disc_ds                              1
# calculated_host_listings_count_disc_ds        1
# beds_disc_ds                                  1
# price_yeo                                     1
# maximum_nights_disc_ds                        1
# availability_60_yeo                           1
# air                                           1
# Name: count, dtype: int64

# %% [markdown]
# ##### Revisar detalle

# %%
#Opciones si hay muchas variables con altas correlaciones:
#1. Rehacer el reescalado porque se ha hecho mas de un proceso sobre la misma variable (04_Plantilla Transformacion de datos)
#2. Usar algoritmos como los árboles de decisión o Random Forest que no les afectan las correlaciones entre variables
cor_finales.head(40)
# Out:
#                                            var1  \
# 548      calculated_host_listings_count_disc_ds
# 2391                                     coffee
# 173                         availability_60_yeo
# 295                      host_response_rate_yeo
# 231                         availability_30_yeo
# 1546                     maximum_nights_disc_ds
# 230                         availability_30_yeo
# 726                            accommodates_yeo
# 1343  property_type_Private room in rental unit
# 2206                                  dryer bed
# 2                          availability_365_yeo
# 2363                                     coffee
# 1536                             and silverware
# 3                          availability_365_yeo
# 2202                                  dryer bed
# 1507                             and silverware
# 2362                                     coffee
# 1479                                  microwave
# 1497                             and silverware
# 685                            accommodates_yeo
# 937                           microwave hangers
# 2428                       accommodates_disc_ds
# 1836                  room_type_Entire home/apt
# 228                         availability_30_yeo
# 1465                                  microwave
# 2831                             hot water iron
# 1522                             and silverware
# 718                            accommodates_yeo
# 2422                       accommodates_disc_ds
# 2207                                  dryer bed
# 2864                           clothing storage
# 89                                    price_yeo
# 2220                                  dryer bed
# 1531                             and silverware
# 2834                             hot water iron
# 1520                             and silverware
# 3127                                      maker
# 2829                             hot water iron
# 2191                                  dryer bed
# 2352                                     coffee
#
#                                                    var2            corr
# 548   calculated_host_listings_count_entire_homes_di...            0.98
# 2391                                              maker            0.97
# 173                                 availability_90_yeo            0.97
# 295                               host_response_time_oe            0.95
# 231                                 availability_60_yeo            0.93
# 1546                                 maximum_nights_yeo            0.92
# 230                                 availability_90_yeo            0.87
# 726                                accommodates_disc_ds            0.86
# 1343                          room_type_Entire home/apt            0.83
# 2206                                                bed            0.79
# 2                                   availability_90_yeo            0.78
# 2363                                     and silverware            0.74
# 1536                                              maker            0.73
# 3                                   availability_60_yeo            0.73
# 2202                                               hair            0.72
# 1507                                          microwave            0.69
# 2362                                          microwave            0.68
# 1479                                              maker            0.67
# 1497                                             basics            0.66
# 685                                           price_yeo            0.66
# 937                                           microwave            0.65
# 2428                                   bedrooms_disc_ds            0.65
# 1836                                   accommodates_yeo            0.64
# 228                                availability_365_yeo            0.63
# 1465                                                bed            0.60
# 2831                                          dryer bed            0.58
# 1522                                                bed            0.58
# 718                                    bedrooms_disc_ds            0.58
# 2422                                       beds_disc_ds            0.58
# 2207                                             coffee            0.57
# 2864                                           cleaning            0.57
# 89                            room_type_Entire home/apt            0.57
# 2220                                              maker            0.57
# 1531                                     hot water iron            0.57
# 2834                                             coffee            0.57
# 1520                                          dryer bed            0.56
# 3127                                     hot water iron            0.56
# 2829                                               hair            0.56
# 2191                                          microwave            0.56
# 2352                                             basics            0.56

# %%
max_correlacion = 0.96
exceso_correlacion = cor_finales.var1.loc[cor_finales['corr']>=max_correlacion].to_list()
exceso_correlacion
# Out:
# ['calculated_host_listings_count_disc_ds', 'coffee', 'availability_60_yeo']

# %% [markdown]
# #### 5.1.3. Filtrar variables

# %% [markdown]
# Automáticamente se descartarán las variables que hayan superado la correlación máxima que hayamos definido y se generará una lista con el resto de las variables

# %%
a_eliminar_corr = exceso_correlacion

# %%
x_preseleccionado.drop(columns = a_eliminar_corr, inplace = True)

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['availability_365_yeo',
#  'price_yeo',
#  'availability_90_yeo',
#  'availability_30_yeo',
#  'host_response_rate_yeo',
#  'neighbourhood_group_Centro',
#  'maximum_nights_yeo',
#  'neighbourhood_group_Puente de Vallecas',
#  'host_response_time_oe',
#  'neighbourhood_group_Retiro',
#  'accommodates_yeo',
#  'tv washer',
#  'cleaning',
#  'basics',
#  'microwave hangers',
#  'instant_bookable_oe',
#  'neighbourhood_group_Carabanchel',
#  'neighbourhood_group_Villa de Vallecas',
#  'neighbourhood_group_Salamanca',
#  'air',
#  'host_is_superhost_oe',
#  'property_type_Private room in rental unit',
#  'allowed',
#  'microwave',
#  'and silverware',
#  'maximum_nights_disc_ds',
#  'beds_disc_ds',
#  'wifi kitchen',
#  'neighbourhood_group_Moratalaz',
#  'neighbourhood_group_Arganzuela',
#  'room_type_Entire home/apt',
#  'neighbourhood_group_Usera',
#  'bedrooms_disc_ds',
#  'calculated_host_listings_count_entire_homes_disc_ds',
#  'hair',
#  'neighbourhood_group_Villaverde',
#  'dryer bed',
#  'neighbourhood_group_Tetuán',
#  'bed',
#  'accommodates_disc_ds',
#  'stove',
#  'neighbourhood_group_San Blas',
#  'neighbourhood_group_Latina',
#  'neighbourhood_group_Chamartín',
#  'host_verifications_oe',
#  'neighbourhood_group_Chamberí',
#  'hot water iron',
#  'clothing storage',
#  'calculated_host_listings_count_private_rooms_disc_ds',
#  'neighbourhood_group_Vicálvaro',
#  'shampoo',
#  'maker',
#  'has_availability_oe',
#  'property_type_OTROS']

# %% [markdown]
# ## 6. GUARDAR DATASETS TRAS PRESELECCION DE VARIABLES

# %%
#Definir los nombres de los archivos
nombre_x_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'x_preseleccionado.pickle'
nombre_y_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'y_preseleccionado.pickle'

# %%
#Guardar los archivos
x_preseleccionado.to_pickle(nombre_x_preseleccionado)

y_preseleccionado = y.copy()
y_preseleccionado.to_pickle(nombre_y_preseleccionado)

# %%
print("Valores únicos de target:", y_preseleccionado.unique())
print("Conteo de clases:", y_preseleccionado.value_counts())
# Out:
# Valores únicos de target: [1 0]
# Conteo de clases: pisos_rentables
# 1    12646
# 0     5493
# Name: count, dtype: int64

# %%
#Guardar los nombres de las variables finales
nombre_variables_finales = ruta_proyecto + '/05_Resultados/' + 'variables_finales.pickle'

x_preseleccionado.iloc[0].to_pickle(nombre_variables_finales)

# %%
x_preseleccionado.shape
