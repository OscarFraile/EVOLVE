# %%
'''Eleccion y preparacion de los datos
    Eleccion de la fuente de datos
    Scraping de los datos
    EDA
    Calidad
    Generacion de pipelines

Modelado
    Preseleccion de variables
    Construccion de un modelo
    Evaluar resultados
    Seleccionar y testear los modelos

Visualizacion
    Diseño de la visualizacion: Power BI, Streamlitt. Hay que decidir cual se va a usar
    Crear y conectar con la visualizacion
    Generacion de usuarios

Integración de todos los datos y código

Presentacion de proyecto

De cada tarea:
    Tiempo necesario
    Dependencias
    Priorizacion de tareas para organizar el orden'''
