# %%
# !pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-genai<2.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.68.0)
# Collecting langchain-core<2.0.0,>=1.2.29 (from langchain-google-genai)
#   Downloading langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (2.12.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Downloading langchain_google_genai-4.2.2-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading langchain_core-1.3.0-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.1/515.1 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: filetype, langchain-core, langchain-google-genai
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.28
#     Uninstalling langchain-core-1.2.28:
#       Successfully uninstalled langchain-core-1.2.28
# Successfully installed filetype-1.2.0 langchain-core-1.3.0 langchain-google-genai-4.2.2

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
API_KEY = userdata.get('GEMINI_API_KEY')

# %%
MODEL = "gemini-2.5-flash-lite"

# %%
llm = ChatGoogleGenerativeAI(model=MODEL, temperature=0.5, google_api_key=API_KEY)

# %%
pregunta = "¿En que año llego el ser humano a la luna por primera vez?"

# %%
print("Pregunta: ", pregunta)
# Out:
# Pregunta:  ¿En que año llego el ser humano a la luna por primera vez?

# %% [markdown]
# # INVOCACION

# %%
respuesta = llm.invoke(pregunta)

# %%
print("Respuesta del modelo: ", respuesta.content)
# Out:
# Respuesta del modelo:  El ser humano llegó a la Luna por primera vez en **1969**.

# %% [markdown]
# # Stream

# %%
for chunk in llm.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# Parrots have colorful feathers for| a variety of fascinating reasons, and it's a combination of **survival, communication|, and reproduction**. Here's a breakdown of the key factors:
#
# **1. Camouflage:**
#
# *   **Blending In:** While many people associate parrots with bright, conspicuous colors, not all of them are. Many species have green| and brown plumage, which helps them blend seamlessly into the leafy canopy of their rainforest habitats. This is crucial for avoiding predators like raptors and snakes.
# *   **Species-Specific Camouflage:** The specific colors and patterns can also help| them blend into particular environments or even specific types of trees.
#
# **2. Communication and Social Signaling:**
#
# *   **Species Recognition:** The vibrant and unique color patterns of a parrot's plumage act like a "uniform" for their| species. This helps them recognize their own kind from a distance, which is important for flocking, mating, and avoiding interbreeding with other species.
# *   **Individual Recognition:** Within a flock, subtle variations in color or the intensity| of certain colors might even help individual parrots recognize each other.
# *   **Mood and Social Status:** While not as dramatic as in some other birds, color intensity can sometimes be influenced by a parrot's mood or social hierarchy. For example, a stressed| or agitated parrot might have duller colors.
# *   **Warning Signals:** In some cases, bright colors can serve as a warning signal to potential predators, indicating that the parrot is poisonous or unpalatable (though this is less common in| parrots than in some other animals).
#
# **3. Sexual Selection and Reproduction:**
#
# *   **Attracting Mates:** This is arguably the most significant driver of vibrant coloration in many parrot species. Brighter, more intense, and varied colors| often indicate a healthier, stronger, and more desirable mate.
# *   **Demonstrating Fitness:** The ability to produce and maintain such vibrant plumage requires good nutrition and a healthy immune system. Therefore, colorful feathers can be a visual advertisement| of a parrot's fitness and genetic quality to potential partners.
# *   **Courtship Displays:** Parrots often use their colorful feathers in elaborate courtship displays, fanning their tails, spreading their wings, and puffing out their chest| feathers to showcase their brilliance.
#
# **4. Pigments and Structural Colors:**
#
# Parrot colors are created by two main mechanisms:
#
# *   **Pigments:** These are chemical compounds that absorb certain wavelengths of light and reflect others.
#     *   **|Melanins:** Produce blacks, browns, and grays.
#     *   **Porphyrins:** Produce reds, oranges, and yellows. These are unique to birds and can degrade in sunlight.
# *   **Structural Colors|:** These are created by the microscopic structure of the feathers themselves. When light hits these structures, it is scattered and reflected in specific ways, producing iridescent blues, greens, and violets. This is similar to how a rainbow appears.
#
# **In| summary, a parrot's colorful feathers are a complex evolutionary adaptation that serves multiple vital functions, from hiding from danger to finding a mate. They are a testament to the power of natural selection in shaping the beauty and diversity of the animal kingdom|.**||

# %% [markdown]
# # Batch

# %%
responses = llm.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?"
])

for response in responses:
  print(response)
# Out:
# content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolution, communication, and survival**. Here's a breakdown of the main factors:\n\n**1. Mating and Sexual Selection:**\n\n* **Attracting a Mate:** This is arguably the most significant reason for vibrant coloration in many parrot species. Brighter, more elaborate plumage can signal a parrot's health, genetic quality, and overall fitness to potential mates. A visually striking bird is more likely to catch the eye of a desirable partner.\n* **Species Recognition:** In areas where multiple parrot species live together, distinct color patterns help individuals recognize members of their own species. This prevents hybridization and ensures that they mate with appropriate partners.\n* **Courtship Displays:** The colors are often used in elaborate courtship rituals. Parrots may puff up their feathers, display specific patches of color, or perform dances to showcase their plumage.\n\n**2. Camouflage and Predator Avoidance:**\n\n* **Blending In:** While some parrots are incredibly vibrant, many also have colors that help them blend into their environment. Greens are common in rainforest species, allowing them to disappear among the foliage. Browns and grays can provide camouflage against tree bark.\n* **Disruptive Coloration:** Some parrots have patches of contrasting colors that can break up their outline, making it harder for predators to spot them against a busy background.\n* **Warning Colors (Aposematism):** In some cases, bright colors might serve as a warning to predators that the parrot is toxic or unpalatable. However, this is less common in parrots compared to insects or amphibians.\n\n**3. Communication and Social Signaling:**\n\n* **Social Status:** Subtle variations in color or the intensity of certain colors might indicate a parrot's social standing within a flock.\n* **Mood and Emotion:** While not as dramatic as in some other animals, some researchers believe that subtle changes in feather appearance or posture can convey information about a parrot's mood.\n* **Territoriality:** In some species, bright colors might be used to signal ownership of a territory to rivals.\n\n**4. Pigments and Structural Colors:**\n\nParrot colors are created through two main mechanisms:\n\n* **Pigments:** These are chemical compounds that absorb certain wavelengths of light and reflect others.\n    * **Melanins:** Produce blacks, browns, grays, and some dull yellows.\n    * **Porphyrins:** Produce reds, oranges, and some greens. These are less common and can fade in sunlight.\n* **Structural Colors:** These are produced by the physical structure of the feathers themselves. Microscopic structures on the barbules of feathers refract and scatter light, creating iridescent blues, greens, and violets. The angle at which you view the feather can change the perceived color.\n\n**In summary, the colorful plumage of parrots is a multifaceted evolutionary adaptation that plays a crucial role in their survival and reproductive success.** It's a testament to the power of natural selection in shaping such striking and diverse forms." additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019db108-183b-7680-bd16-fce52996deb0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 626, 'total_tokens': 634, 'input_token_details': {'cache_read': 0}}
# content="Airplanes fly due to a fascinating interplay of physics, primarily governed by four fundamental forces: **lift, weight, thrust, and drag**.\n\nHere's a breakdown of how these forces work together:\n\n**1. The Role of Wings (Generating Lift):**\n\nThis is the most crucial aspect of flight. Airplane wings are designed with a specific shape called an **airfoil**. This shape is asymmetrical:\n\n*   **Curved Upper Surface:** The top of the wing is more curved than the bottom.\n*   **Flatter Lower Surface:** The bottom of the wing is relatively flatter.\n\nWhen an airplane moves forward, air flows over and under the wings. Due to the airfoil shape:\n\n*   **Faster Airflow Above:** The air traveling over the curved upper surface has to travel a longer distance than the air traveling under the flatter lower surface in the same amount of time. This means the air above the wing moves *faster*.\n*   **Lower Pressure Above:** According to **Bernoulli's Principle**, faster-moving air exerts lower pressure. Therefore, the pressure above the wing is lower than the pressure below the wing.\n*   **Higher Pressure Below:** The slower-moving air under the wing exerts higher pressure.\n\nThis **pressure difference** creates an upward force called **lift**. The higher pressure below pushes the wing up, overcoming the downward force of weight.\n\n**2. The Four Forces of Flight:**\n\n*   **Lift:** The upward force generated by the wings, opposing weight.\n*   **Weight:** The downward force due to gravity acting on the airplane's mass. For an airplane to fly, lift must be greater than or equal to weight.\n*   **Thrust:** The forward force generated by the engines (propellers or jet engines), propelling the airplane through the air. Thrust is needed to create the airflow over the wings to generate lift and to overcome drag.\n*   **Drag:** The backward force resisting the airplane's motion through the air. It's caused by air resistance and friction. Thrust must be greater than or equal to drag for the airplane to move forward.\n\n**3. How These Forces Interact:**\n\n*   **Takeoff:** During takeoff, the engines generate maximum thrust. As the airplane accelerates down the runway, the speed of the air flowing over the wings increases, generating more lift. When lift exceeds weight, the airplane leaves the ground.\n*   **Cruising:** Once at altitude, the pilot adjusts the engine power and wing surfaces (flaps, ailerons) to balance the four forces. Lift equals weight, and thrust equals drag, allowing the airplane to maintain a steady altitude and speed.\n*   **Climbing:** To climb, the pilot increases thrust and/or adjusts the angle of attack (the angle between the wing and the oncoming air) to generate more lift than weight.\n*   **Descending:** To descend, the pilot reduces thrust and/or decreases the angle of attack, allowing weight to become greater than lift.\n*   **Turning:** Turns are achieved by tilting the wings using ailerons. This redirects some of the lift force horizontally, pulling the airplane in the direction of the turn.\n\n**In simpler terms:**\n\nImagine pushing a flat board through water. If you hold it flat, it's hard to move. But if you tilt it slightly, the water pushes it upwards. Airplane wings are like specially shaped boards that are very efficient at using the air to push them upwards. The engines provide the forward motion needed to make this happen.\n\n**Key Concepts to Remember:**\n\n*   **Airfoil Shape:** The crucial design of the wing.\n*   **Bernoulli's Principle:** The relationship between air speed and pressure.\n*   **Angle of Attack:** How the wing is tilted relative to the airflow.\n*   **The Four Forces:** The fundamental balance that allows for flight.\n\nSo, airplanes fly not by magic, but by ingeniously harnessing the principles of physics and aerodynamics through their design and the power of their engines." additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash- ...

# %% [markdown]
# # Herramientas

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)

# %%
from langchain.tools import tool

# %%
@tool
def get_weather(location: str) -> str:
  """Get the weather at a location"""
  return f"It is sunny in {location}"

# %%
model_with_tools = llm.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("What is the weather in Boston?")

# %%
response
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"location": "Boston"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019db110-bb88-7611-9e99-fe56735d1c85-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Boston'}, 'id': '30b0fdcb-a215-4e2f-a312-7584ab8c1206', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 15, 'total_tokens': 61, 'input_token_details': {'cache_read': 0}})

# %%
for tool_call in response.tool_calls:
    # View tool calls made by the model
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
# Out:
# Tool: get_weather
# Args: {'location': 'Boston'}

# %% [markdown]
# # Templates

# %%
# !pip install langchain-core
# Out:
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.4)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)

# %%
from langchain_core.prompts import PromptTemplate

# %%
template = """
Actua como un experto en {domain}.

Explica el siguiente concepto:
{concept}

A un nivel {nivel}

Usa ejemplos.
"""

# %%
promt = PromptTemplate.from_template(template)

# %%
chain = promt | llm

# %%
reponse = chain.invoke({
    "domain": "machine learning",
    "concept": "overfitting",
    "nivel": "principiante"
})

# %%
reponse.content
# Out:
# '¡Absolutamente! Ponte cómodo, porque vamos a desentrañar el concepto de "overfitting" (sobreajuste) de una manera súper sencilla, como si estuviéramos hablando de aprender algo nuevo.\n\nImagina que eres un estudiante y te están preparando para un examen de historia sobre la Segunda Guerra Mundial.\n\n**¿Qué es el Overfitting?**\n\nEl overfitting ocurre cuando un modelo de machine learning se vuelve **demasiado bueno** aprendiendo los datos con los que se entrena, hasta el punto de que **memoriza los detalles específicos y hasta los "ruidos" o errores** de esos datos, en lugar de aprender los patrones generales y las reglas subyacentes.\n\nPiensa en ello como memorizar las respuestas exactas de un examen de práctica, en lugar de entender los conceptos.\n\n**Ejemplo Sencillo: El Examen de Historia**\n\nSupongamos que tu profesor te da un conjunto de preguntas y respuestas para que estudies para el examen de historia sobre la Segunda Guerra Mundial.\n\n*   **Entrenamiento:** Tienes un libro con 100 preguntas y sus respuestas exactas. Te pasas horas memorizando cada pregunta y cada respuesta al pie de la letra.\n    *   Pregunta 1: "¿En qué fecha exacta comenzó la Batalla de Stalingrado?" Respuesta: "23 de agosto de 1942."\n    *   Pregunta 2: "¿Cuál era el nombre del perro del General Patton?" Respuesta: "No se menciona en los materiales de estudio." (¡Este es un detalle irrelevante!)\n\n*   **El Problema del Overfitting:** Ahora, llega el examen real. El profesor, inteligentemente, no te hace exactamente las mismas 100 preguntas. En su lugar, te hace preguntas similares pero con ligeras variaciones, o te pide que apliques lo que aprendiste a situaciones nuevas.\n\n    *   **Pregunta del examen:** "¿En qué mes y año aproximado comenzó la Batalla de Stalingrado?"\n    *   **Tu respuesta (si hiciste overfitting):** Te quedas en blanco porque no memorizaste "agosto de 1942" sino la fecha exacta. O peor aún, dices "23 de agosto de 1942" y el profesor te quita puntos por ser demasiado específico cuando solo pedía una aproximación.\n    *   **Pregunta del examen:** "¿Sabes algo sobre las mascotas de los generales aliados?"\n    *   **Tu respuesta (si hiciste overfitting):** Intentas recordar el nombre del perro del General Patton, pero como solo te lo memorizaste como un dato aislado y no como parte de un patrón más amplio (por ejemplo, que los generales a veces tenían mascotas), no puedes responder.\n\n**¿Qué pasó aquí?**\n\nTu modelo de aprendizaje (tú, el estudiante) se **sobreajustó** a los datos de entrenamiento (las 100 preguntas y respuestas). Memorizaste los detalles específicos y los "ruidos" (como el nombre del perro, que no era relevante para la comprensión general de la guerra) en lugar de aprender los **patrones y conceptos clave** de la Segunda Guerra Mundial.\n\n**En el mundo del Machine Learning:**\n\n*   **Datos de Entrenamiento:** Son las preguntas y respuestas que le das al modelo para que aprenda.\n*   **Modelo de Machine Learning:** Es el programa que intenta aprender.\n*   **Overfitting:** El modelo aprende los datos de entrenamiento tan bien que se vuelve inflexible. Cuando le muestras datos nuevos (el examen real), que son ligeramente diferentes pero siguen la misma lógica, el modelo falla porque está demasiado apegado a los detalles que memorizó.\n\n**¿Por qué es un problema?**\n\nUn modelo con overfitting funciona maravillosamente en los datos que ya ha visto, pero **falla estrepitosamente cuando se enfrenta a datos nuevos y no vistos**. El objetivo del machine learning es crear modelos que puedan **generalizar**, es decir, aplicar lo aprendido a situaciones nuevas.\n\n**Analogía con un Dibujo:**\n\nImagina que te piden dibujar un gato.\n\n*   **Buen aprendizaje (generalización):** Aprendes las características generales de un gato: orejas puntiagudas, cola larga, bigotes, forma del cuerpo. Puedes dibujar muchos gatos diferentes, algunos gordos, otros flacos, de distintos colores, y todos se verán como gatos. ...
