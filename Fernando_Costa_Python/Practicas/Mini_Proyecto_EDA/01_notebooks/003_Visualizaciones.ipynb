# %% [markdown]
# ## 1. IMPORTAMOS PAQUETES Y DATOS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
# %config IPCompleter.greedy = True
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Ruta archivo de calidad de datos

# %%
ruta_principal = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/EVOLVE/Fernando_Costa/Practicas/Mini_Proyecto_EDA/'
carpeta = '002_archivos/'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
df = 'trabajo_resultado_eda.pickle'
cat = 'cat_resultado_eda.pickle'
num = 'num_resultado_eda.pickle'

# %% [markdown]
# Cargamos los datasets

# %%
df = pd.read_pickle(ruta_principal + carpeta + df)
cat = pd.read_pickle(ruta_principal + carpeta + cat)
num = pd.read_pickle(ruta_principal + carpeta + num)

# %% [markdown]
# ## 3. EDA CATEGÓRICAS

# %% [markdown]
# ### 3.1. Análisis estadístico

# %%
list(cat.columns)
# Out:
# ['date_rptd',
#  'date_occ',
#  'area',
#  'area_name',
#  'rpt_dist_no',
#  'part_1_2',
#  'crm_cd',
#  'crm_cd_desc',
#  'mocodes',
#  'vict_sex',
#  'vict_descent',
#  'premis_cd',
#  'premis_desc',
#  'weapon_used_cd',
#  'weapon_desc',
#  'status',
#  'status_desc',
#  'crm_cd_1',
#  'crm_cd_2',
#  'crm_cd_3',
#  'crm_cd_4',
#  'lat',
#  'lon',
#  'year_rptd',
#  'month_rptd',
#  'day_rptd',
#  'year_occ',
#  'month_occ',
#  'day_occ',
#  'hour_occ']

# %%
incluir_cat = cat.columns.to_list()

#Eliminamos las columnas que estén en la siguiente lista
for i in sorted([0, 1, 2, 4, 6, 8, 13, 15, 21, 22], reverse=True):
    del incluir_cat[i]

# %%
def frecuencias_cat(cat):
    # Asegúrate de que todas las columnas son de tipo 'str' para evitar problemas de comparación
    cat = cat[incluir_cat]
    
    resultado = cat.apply(lambda x: x.value_counts(normalize = True))\
                .T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return resultado

# %%
cat[incluir_cat].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331263 entries, 200114944 to 240710787
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   area_name     331263 non-null  object
#  1   part_1_2      331263 non-null  category
#  2   crm_cd_desc   331263 non-null  object
#  3   vict_sex      331263 non-null  object
#  4   vict_descent  283691 non-null  object
#  5   premis_cd     331263 non-null  object
#  6   premis_desc   331056 non-null  object
#  7   weapon_desc   108028 non-null  object
#  8   status_desc   331263 non-null  object
#  9   crm_cd_1      331263 non-null  object
#  10  crm_cd_2      331263 non-null  object
#  11  crm_cd_3      331263 non-null  object
#  12  crm_cd_4      331263 non-null  object
#  13  year_rptd     331263 non-null  object
#  14  month_rptd    331263 non-null  object
#  15  day_rptd      331263 non-null  object
#  16  year_occ      331263 non-null  object
#  17  month_occ     331263 non-null  object
#  18  day_occ       331263 non-null  object
#  19  hour_occ      331263 non-null  object
# dtypes: category(1), object(19)
# memory usage: 50.9+ MB

# %%
pd.set_option('display.max_rows', None)

frecuencias_cat(cat[incluir_cat])
#Aparecerá una lista de todas las variables con su frecuencia asociada
# Out:
#          Variable                                              Valor  \
# 3       area_name                                           Foothill
# 5       area_name                                         Hollenbeck
# 7       area_name                                            Mission
# 16      area_name                                            Topanga
# 4       area_name                                             Harbor
# 2       area_name                                         Devonshire
# 19      area_name                                        West Valley
# 17      area_name                                           Van Nuys
# 10      area_name                                          Northeast
# 18      area_name                                            West LA
# 13      area_name                                            Rampart
# 20      area_name                                           Wilshire
# 9       area_name                                             Newton
# 14      area_name                                          Southeast
# 11      area_name                                            Olympic
# 8       area_name                                        N Hollywood
# 6       area_name                                          Hollywood
# 15      area_name                                          Southwest
# 12      area_name                                            Pacific
# 0       area_name                                        77th Street
# 1       area_name                                            Central
# 227      crm_cd_1                                              745.0
# 222      crm_cd_1                                              442.0
# 213      crm_cd_1                                              210.0
# 218      crm_cd_1                                              341.0
# 217      crm_cd_1                                              331.0
# 220      crm_cd_1                                              420.0
# 225      crm_cd_1                                              626.0
# 214      crm_cd_1                                              230.0
# 221      crm_cd_1                                              440.0
# 215      crm_cd_1                                              310.0
# 226      crm_cd_1                                              740.0
# 219      crm_cd_1                                              354.0
# 216      crm_cd_1                                              330.0
# 224      crm_cd_1                                              624.0
# 223      crm_cd_1                                              510.0
# 228      crm_cd_1                                              OTROS
# 229      crm_cd_2                                              860.0
# 230      crm_cd_2                                              930.0
# 232      crm_cd_2                                              OTROS
# 231      crm_cd_2                                              998.0
# 233      crm_cd_2                                                nan
# 234      crm_cd_3                                              930.0
# 236      crm_cd_3                                              OTROS
# 235      crm_cd_3                                              998.0
# 237      crm_cd_3                                                nan
# 239      crm_cd_4                                              999.0
# 238      crm_cd_4                                              998.0
# 240      crm_cd_4                                                nan
# 69    crm_cd_desc                 DISHONEST EMPLOYEE ATTEMPTED THEFT
# 85    crm_cd_desc  FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS ...
# 103   crm_cd_desc                               LYNCHING - ATTEMPTED
# 104   crm_cd_desc                            MANSLAUGHTER, NEGLIGENT
# 31    crm_cd_desc  BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT...
# 35    crm_cd_desc                     BLOCKING DOOR INDUCTION CENTER
# 81    crm_cd_desc                                FAILURE TO DISPERSE
# 86    crm_cd_desc           FIREARMS RESTRAINING ORDER (FIREARMS RO)
# 92    crm_cd_desc       INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)
# 110   crm_cd_desc                          PETTY THEFT - AUTO REPAIR
# 112   crm_cd_desc                                PICKPOCKET, ATTEMPT
# 116   crm_cd_desc                          PURSE SNATCHING - ATTEMPT
# 120   crm_cd_desc  REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR D...
# 142   crm_cd_desc       THEFT, COIN MACHINE - GRAND ($950.01 & OVER)
# 32    crm_cd_desc                                             BIGAMY
# 33    crm_cd_desc                            BIKE - ATTEMPTED STOLEN
# 141   crm_cd_desc                      THEFT, COIN MACHINE - ATTEMPT
# 70    crm_cd_desc                                     DISRUPT SCHOOL
# 76    crm_cd_desc                                  DRUGS, TO A MINOR
# 87    crm_cd_desc                          GRAND THEFT / AUTO REPAIR
# 88    crm_cd_desc                      GRAND THEFT / INSURANCE FRAUD
# 102   crm_cd_desc                                           LYNCHING
# 133   crm_cd_desc                        TELEPHONE PROPERTY - DAMAGE
# 148   crm_cd_desc            TILL TAP - GRAND THEFT ($950.01 & OVER)
# 39    crm_cd_desc                                            BRIBERY
# 68    crm_cd_desc                   DISHONEST EMPLOYEE - PETTY THEFT
# 73    crm_cd_desc                  DOCUMENT WORTHLESS ($200 & UNDER)
# 93    crm_cd_desc                                    INCITING A RIOT
# 47    crm_cd_desc                                  CHILD ABANDONMENT
# 54    crm_cd_desc                                         CONSPIRACY
# 143   crm_cd_desc         THEFT, COIN MACHINE - PETTY ($950 & UNDER)
# 67    crm_cd_desc                   DISHONEST EMPLOYEE - GRAND THEFT
# 149   crm_cd_desc                    TILL TAP - PETTY ($950 & UNDER)
# 160   crm_cd_desc                         WEAPONS POSSESSION/BOMBING
# 77    crm_cd_desc                                         DRUNK ROLL
# 56    crm_cd_desc                                       CONTRIBUTING
# 137   crm_cd_desc                        THEFT FROM PERSON - ATTEMPT
# 74    crm_cd_desc                DOCUMENT WORTHLESS ($200.01 & OVER)
# 58    crm_cd_desc              CREDIT CARDS, FRAUD USE ($950 & UNDER
# 115   crm_cd_desc                                    PURSE SNATCHING
# 65    crm_cd_desc  DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $...
# 101   crm_cd_desc                    LEWD/LASCIVIOUS ACTS WITH CHILD
# 57    crm_cd_desc                                        COUNTERFEIT
# 91    crm_cd_desc                                    ILLEGAL DUMPING
# 126   crm_cd_desc                              SHOPLIFTING - ATTEMPT
# 59    crm_cd_desc           CREDIT CARDS, FRAUD USE ($950.01 & OVER)
# 90    crm_cd_desc          HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE
# 108   crm_cd_desc                                          PANDERING
# 113   crm_cd_desc                                            PIMPING
# 79    crm_cd_desc           EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)
# 36    crm_cd_desc                                      BOAT - STOLEN
# 84    crm_cd_desc                                FALSE POLICE REPORT
# 75    crm_cd_desc               DRIVING WITHOUT OWNER CONSENT (DWOC)
# 114   crm_cd_desc                                            PROWLER
# 52    crm_cd_desc                                  CHILD PORNOGRAPHY
# 98    crm_cd_desc                         KIDNAPPING - GRAND ATTEMPT
# 119   crm_cd_desc                                   RECKLESS DRIVING
# 63    crm_cd_desc                                 CRUELTY TO ANIMALS
# 28    crm_cd_desc                           BATTERY ON A FIREFIGHTER
# 40    crm_cd_desc                                     BUNCO, ATTEMPT
# 117   crm_cd_desc                                    RAPE, ATTEMPTED
# 83    crm_cd_desc                                 FALSE IMPRISONMENT
# 64    crm_cd_desc  DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 &...
# 109   crm_cd_desc                                        PEEPING TOM
# 146   crm_cd_desc                    THREATENING PHONE CALLS/LETTERS
# 139   crm_cd_desc                              THEFT PLAIN - ATTEMPT
# 89    crm_cd_desc            HUMAN TRAFFICKING - COMMERCIAL SEX ACTS
# 37    crm_cd_desc                                         BOMB SCARE
# 53    crm_cd_desc                                     CHILD STEALING
# 130   crm_cd_desc   SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT
# 131   crm_cd_desc  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...
# 151   crm_cd_desc                       UNAUTHORIZED COMPUTER ACCESS
# 48    crm_cd_desc        CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT
# 132   crm_cd_desc                                           STALKING
# 105   crm_cd_desc                                    ORAL COPULATION
# 45    crm_cd_desc                   BURGLARY FROM VEHICLE, ATTEMPTED
# 100   crm_cd_desc                                       LEWD CONDUCT
# 97    crm_cd_desc                                         KIDNAPPING
# 147   crm_cd_desc                  THROWING OBJECT AT MOVING VEHICLE
# 159   crm_cd_desc           VIOLATION OF TEMPORARY RESTRAINING ORDER
# 134   crm_cd_desc                 THEFT FROM MOTOR VEHICLE - ATTEMPT
# 24    crm_cd_desc       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER
# 50    crm_cd_desc                     CHILD ANNOYING (17YRS & UNDER)
# 123   crm_cd_desc          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 124   crm_cd_desc  SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W...
# 121   crm_cd_desc                                   RESISTING ARREST
# 94    crm_cd_desc                                  INDECENT EXPOSURE
# 51    crm_cd_desc                     CHILD NEGLECT (SEE 300 W.I.C.)
# 125   crm_cd_desc                SEXUAL PENETRATION W/FOREIGN OBJECT
# 71    crm_cd_desc                               DISTURBING THE PEACE
# 60    crm_cd_desc                                  CRIMINAL HOMICIDE
# 129   crm_cd_desc                  SHOTS FIRED AT INHABITED DWELLING
# 82    crm_cd_desc                                   FAILURE TO YIELD
# 62    crm_cd_desc  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...
# 42    crm_cd_desc                                 BUNCO, PETTY THEFT
# 80    crm_cd_desc                                          EXTORTION
# 29    crm_cd_desc                            BATTERY POLICE (SIMPLE)
# 23    crm_cd_desc                                              ARSON
# 55    crm_cd_desc                                  CONTEMPT OF COURT
# 66    crm_cd_desc                     DISCHARGE FIREARMS/SHOTS FIRED
# 156   crm_cd_desc  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...
# 72    crm_cd_desc                   DOCUMENT FORGERY / STOLEN FELONY
# 49    crm_cd_desc            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# 111   crm_cd_desc                                         PICKPOCKET
# 154   crm_cd_desc                           VEHICLE - ATTEMPT STOLEN
# 118   crm_cd_desc                                     RAPE, FORCIBLE
# 78    crm_cd_desc         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 46    crm_cd_desc                                BURGLARY, ATTEMPTED
# 30    crm_cd_desc                        BATTERY WITH SEXUAL CONTACT
# 144   crm_cd_desc                                      THEFT, PERSON
# 106   crm_cd_desc                                      OTHER ASSAULT
# 26    crm_cd_desc                                  ATTEMPTED ROBBERY
# 128   crm_cd_desc           SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 41    crm_cd_desc                                 BUNCO, GRAND THEFT
# 157   crm_cd_desc                           VIOLATION OF COURT ORDER
# 107   crm_cd_desc                          OTHER MISCELLANEOUS CRIME
# 34    crm_cd_desc                                      BIKE - STOLEN
# 99    crm_cd_desc            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 158   crm_cd_desc                     VIOLATION OF RESTRAINING ORDER
# 95    crm_cd_desc              INTIMATE PARTNER - AGGRAVATED ASSAULT
# 38    crm_cd_desc                                    BRANDISH WEAPON
# 150   crm_cd_desc                                        TRESPASSING
# 61    crm_cd_desc             CRIMINAL THREATS - NO WEAPON DISPLAYED
# 153   crm_cd_desc           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 127   crm_cd_desc           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 122   crm_cd_desc                                            ROBBERY
# 145   crm_cd_desc  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 135   crm_cd_desc  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 136   crm_cd_desc    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 96    crm_cd_desc                  INTIMATE PARTNER - SIMPLE ASSAULT
# 25    crm_cd_desc     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 140   crm_cd_desc                 THEFT PLAIN - PETTY ($950 & UNDER)
# 43    crm_cd_desc                                           BURGLARY
# 152   crm_cd_desc  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 138   crm_cd_desc                                  THEFT OF IDENTITY
# 44    crm_cd_desc                              BURGLARY FROM VEHICLE
# 27    crm_cd_desc                           BATTERY - SIMPLE ASSAULT
# 155   crm_cd_desc                                   VEHICLE - STOLEN
# 338       day_occ                                                 31
# 337       day_occ                                                 30
# 336       day_occ                                                 29
# 333       day_occ                                                 26
# 318       day_occ                                                 11
# 332       day_occ                                                 25
# 320       day_occ                                                 13
# 331       day_occ                                                 24
# 324       day_occ                                                 17
# 334       day_occ                                                 27
# 316       day_occ                                                 09
# 335       day_occ                                                 28
# 319       day_occ                                                 12
# 321       day_occ                                                 14
# 326       day_occ                                                 19
# 325       day_occ                                                 18
# 323       day_occ                                                 16
# 314       day_occ                                                 07
# 313       day_occ                                                 06
# 315       day_occ                                                 08
# 328       day_occ                                                 21
# 329       day_occ                                                 22
# 317       day_occ                                                 10
# 330       day_occ                                                 23
# 311       day_occ                                                 04
# 327       day_occ                                                 20
# 312       day_occ                                                 05
# 322       day_occ                                                 15
# 310       day_occ                                                 03
# 309       day_occ                                                 02
# 308       day_occ                                                 01
# 289      day_rptd                                                 31
# 288      day_rptd                                                 30
# 287      day_rptd                                                 29
# 282      day_rptd                                                 24
# 283      day_rptd                                                 25
# 275      day_rptd                                                 17
# 284      day_rptd                                                 26
# 272      day_rptd                                                 14
# 268      day_rptd                                                 10
# 270      day_rptd                                                 12
# 269      day_rptd                                                 11
# 277      day_rptd                                                 19
# 278      day_rptd                                                 20
# 273      day_rptd                                                 15
# 274      day_rptd                                                 16
# 285      day_rptd                                                 27
# 286      day_rptd                                                 28
# 279      day_rptd                                                 21
# 276      day_rptd                                                 18
# 267      day_rptd                                                 09
# 265      day_rptd                                                 07
# 266      day_rptd                                                 08
# 280      day_rptd                                                 22
# 281      day_rptd                                                 23
# 271      day_rptd                                                 13
# 262      day_rptd                                                 04
# 263      day_rptd                                                 05
# 259      day_rptd                                                 01
# 264      day_rptd                                                 06
# 261      day_rptd                                                 03
# 260      day_rptd                                                 02
# 344      hour_occ                                                  5
# 343      hour_occ                                                  4
# 342      hour_occ                                                  3
# 345      hour_occ                                                  6
# 341      hour_occ                                                  2
# 346      hour_occ                                                  7
# 340      hour_occ                                                  1
# 348      hour_occ                                                  9
# 347      hour_occ                                                  8
# 339      hour_occ                                                  0
# 362      hour_occ                                                 23
# 349      hour_occ                                                 10
# 350      hour_occ                                                 11
# 352      hour_occ                                                 13
# 361      hour_occ                                                 22
# 353      hour_occ                                                 14
# 360      hour_occ                                                 21
# 355      hour_occ                                                 16
# 354      hour_occ                                                 15
# 358      hour_occ                                                 19
# 359      hour_occ                                                 20
# 356      hour_occ                                                 17
# 357      hour_occ                                                 18
# 351      hour_occ                                                 12
# 307     month_occ                                                 12
# 306     month_occ                                                 11
# 304     month_occ                                                 09
# 301     month_occ                                                 06
# 300     month_occ                                                 05
# 302     month_occ                                                 07
# 303     month_occ                                                 08
# 299     month_occ                                                 04
# 305     month_occ                                                 10
# 297     month_occ                                                 02
# 298     month_occ                                                 03
# 296     month_occ                                                 01
# 258    month_rptd                                                 12
# 257    month_rptd                                                 11
# 252    month_rptd                                                 06
# 255    month_rptd                                                 09
# 251    month_rptd                                                 05
# 256    month_rptd                                                 10
# 253    month_rptd                                                 07
# 254    month_rptd                                                 08
# 250    month_rptd                                                 04
# 248    month_rptd                                                 02
# 249    month_rptd                                                 03
# 247    month_rptd                                                 01
# 22       part_1_2                                                  2
# 21       part_1_2                                                  1
# 191     premis_cd                                                nan
# 186     premis_cd                                              122.0
# 184     premis_cd                                              102.0
# 187     premis_cd                                              203.0
# 185     premis_cd                                              108.0
# 189     premis_cd                                              502.0
# 188     premis_cd                                              501.0
# 183     premis_cd                                              101.0
# 190     premis_cd                                              OTROS
# 199   premis_desc                           VEHICLE, PASSENGER/TRUCK
# 196   premis_desc                                           SIDEWALK
# 193   premis_desc                                     OTHER BUSINESS
# 195   premis_desc                                        PARKING LOT
# 192   premis_desc       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 197   premis_desc                             SINGLE FAMILY DWELLING
# 198   premis_desc                                             STREET
# 194   premis_desc                                              OTROS
# 212   status_desc                                                UNK
# 211   status_desc                                          Juv Other
# 210   status_desc                                         Juv Arrest
# 207   status_desc                                       Adult Arrest
# 208   status_desc                                        Adult Other
# 209   status_desc                                        Invest Cont
# 179  vict_descent                                           Laosiano
# 181  vict_descent                                            Samoano
# 172  vict_descent                                             Guamés
# 167  vict_descent                                          Camboyano
# 173  vict_descent                                           Hawaiano
# 177  vict_descent                                Isleño_del_Pacífico
# 174  vict_descent                                     Hindú_Asiático
# 176  vict_descent                                    Indio_Americano
# 182  vict_descent                                         Vietnamita
# 178  vict_descent                                            Japonés
# 168  vict_descent                                              Chino
# 171  vict_descent                                           Filipino
# 169  vict_descent                                            Coreano
# 165  vict_descent                                          Asiáticos
# 180  vict_descent                                               Otro
# 170  vict_descent                                        Desconocido
# 164  vict_descent                                      Afroamericano
# 166  vict_descent                                             Blanco
# 175  vict_descent                                            Hispano
# 162      vict_sex                                               Male
# 163      vict_sex                                            Unknwon
# 161      vict_sex                                             Female
# 201   weapon_desc                   KNIFE WITH BLADE 6INCHES OR LESS
# 203   weapon_desc                              SEMI-AUTOMATIC PISTOL
# 200   weapon_desc                                           HAND GUN
# 206   weapon_desc                                      VERBAL THREAT
# 205   weapon_desc                        UNKNOWN WEAPON/OTHER WEAPON
# 202   weapon_desc                                              OTROS
# 204   weapon_desc     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 295      year_occ                                               2025
# 294      year_occ                                               2024
# 290      year_occ                                               2020
# 291      year_occ                                               2021
# 293      year_occ                                               2023
# 292      year_occ                                               2022
# 246     year_rptd                                               2025
# 245     year_rptd                                               2024
# 241     year_rptd                                               2020
# 242     year_rptd                                               2021
# 244     year_rptd                                               2023
# 243     year_rptd                                               2022
#
#      Frecuencia
# 3      0.032823
# 5      0.036696
# 7      0.040267
# 16     0.040771
# 4      0.041185
# 2      0.041674
# 19     0.041882
# 17     0.042558
# 10     0.043259
# 18     0.045616
# 13     0.046305
# 20     0.048179
# 9      0.048901
# 14     0.049366
# 11     0.049882
# 8      0.051603
# 6      0.051627
# 15     0.057543
# 12     0.059107
# 0      0.061582
# 1      0.069175
# 227    0.025361
# 222    0.030794
# 213    0.031978
# 218    0.035126
# 217    0.036488
# 220    0.041028
# 225    0.046936
# 214    0.053411
# 221    0.053728
# 215    0.057311
# 226    0.060710
# 219    0.062440
# 216    0.063016
# 224    0.074817
# 223    0.114429
# 228    0.212429
# 229    0.001395
# 230    0.003795
# 232    0.008649
# 231    0.055500
# 233    0.930662
# 234    0.000072
# 236    0.000181
# 235    0.002071
# 237    0.997676
# 239    0.000009
# 238    0.000048
# 240    0.999943
# 69     0.000003
# 85     0.000003
# 103    0.000003
# 104    0.000003
# 31     0.000006
# 35     0.000006
# 81     0.000006
# 86     0.000006
# 92     0.000006
# 110    0.000006
# 112    0.000006
# 116    0.000006
# 120    0.000006
# 142    0.000006
# 32     0.000009
# 33     0.000009
# 141    0.000009
# 70     0.000012
# 76     0.000012
# 87     0.000012
# 88     0.000012
# 102    0.000012
# 133    0.000012
# 148    0.000012
# 39     0.000015
# 68     0.000015
# 73     0.000015
# 93     0.000015
# 47     0.000024
# 54     0.000024
# 143    0.000024
# 67     0.000033
# 149    0.000033
# 160    0.000036
# 77     0.000039
# 56     0.000045
# 137    0.000075
# 74     0.000078
# 58     0.000085
# 115    0.000088
# 65     0.000091
# 101    0.000091
# 57     0.000103
# 91     0.000106
# 126    0.000115
# 59     0.000130
# 90     0.000133
# 108    0.000136
# 113    0.000136
# 79     0.000139
# 36     0.000148
# 84     0.000160
# 75     0.000190
# 114    0.000208
# 52     0.000238
# 98     0.000257
# 119    0.000257
# 63     0.000275
# 28     0.000296
# 40     0.000305
# 117    0.000308
# 83     0.000311
# 64     0.000377
# 109    0.000401
# 146    0.000435
# 139    0.000438
# 89     0.000444
# 37     0.000447
# 53     0.000468
# 130    0.000474
# 131    0.000516
# 151    0.000574
# 48     0.000601
# 132    0.000676
# 105    0.000706
# 45     0.000724
# 100    0.000755
# 97     0.000788
# 147    0.000788
# 159    0.000894
# 134    0.000918
# 24     0.000927
# 50     0.000930
# 123    0.000945
# 124    0.001020
# 121    0.001063
# 94     0.001120
# 51     0.001304
# 125    0.001316
# 71     0.001497
# 60     0.001636
# 129    0.001651
# 82     0.001700
# 62     0.001832
# 42     0.002044
# 80     0.002161
# 29     0.002445
# 23     0.002593
# 55     0.002865
# 66     0.002883
# 156    0.002976
# 72     0.003155
# 49     0.003559
# 111    0.003710
# 154    0.003819
# 118    0.003879
# 78     0.003997
# 46     0.004072
# 30     0.004090
# 144    0.004090
# 106    0.004281
# 26     0.004990
# 128    0.005796
# 41     0.006007
# 157    0.006267
# 107    0.006871
# 34     0.008145
# 99     0.008757
# 158    0.011888
# 95     0.012612
# 38     0.014366
# 150    0.018523
# 61     0.019148
# 153    0.025333
# 127    0.030788
# 122    0.031972
# 145    0.035087
# 135    0.036473
# 136    0.041019
# 96     0.046616
# 25     0.053405
# 140    0.053722
# 43     0.057317
# 152    0.060616
# 138    0.062431
# 44     0.062980
# 27     0.074503
# 155    0.114426
# 338    0.018448
# 337    0.029511
# 336    0.030251
# 333    0.031141
# 318    0.031289
# 332    0.031326
# 320    0.031410
# 331    0.031446
# 324    0.031546
# 334    0.031682
# 316    0.031742
# 335    0.031781
# 319    0.031836
# 321    0.031881
# 326    0.031938
# 325    0.031960
# 323    0.032011
# 314    0.032135
# 313    0.032331
# 315    0.032376
# 328    0.032458
# 329    0.032542
# 317    0.032566
# 330    0.032581
# 311    0.032699
# 327    0.032874
# 312    0.033200
# 322    0.033291
# 310    0.035884
# 309    0.037514
# 308    0.046350
# 289    0.018620
# 288    0.029545
# 287    0.030767
# 282    0.031597
# 283    0.031630
# 275    0.031821
# 284    0.031839
# 272    0.032186
# 268    0.032213
# 270    0.032243
# 269    0.032273
# 277    0.032295
# 278    0.032307
# 273    0.032470
# 274    0.032669
# 285    0.032738
# 286    0.032844
# 279    0.032886
# 276    0.033025
# 267    0.033064
# 265    0.033158
# 266    0.033185
# 280    0.033203
# 281    0.033255
# 271    0.033315
# 262    0.033565
# 263    0.033578
# 259    0.033765
# 264    0.034027
# 261    0.034622
# 260    0.035295
# 344    0.017089
# 343    0.018680
# 342    0.022167
# 345    0.023151
# 341    0.024874
# 346    0.026456
# 340    0.029454
# 348    0.036231
# 347    0.037001
# 339    0.040177
# 362    0.041903
# 349    0.042945
# 350    0.043603
# 352    0.044726
# 361    0.048771
# 353    0.049006
# 360    0.050624
# 355    0.052798
# 354    0.052916
# 358    0.055279
# 359    0.056146
# 356    0.058609
# 357    0.059237
# 351    0.068157
# 307    0.078291
# 306    0.078871
# 304    0.080516
# 301    0.080755
# 300    0.082671
# 302    0.083281
# 303    0.083372
# 299    0.083640
# 305    0.083794
# 297    0.085473
# 298    0.086985
# 296    0.092350
# 258    0.078820
# 257    0.079505
# 252    0.080800
# 255    0.080866
# 251    0.082850
# 256    0.083248
# 253    0.083284
# 254    0.083423
# 250    0.083565
# 248    0.085802
# 249    0.087329
# 247    0.090508
# 22     0.400733
# 21     0.599267
# 191    0.000024
# 186    0.028889
# 184    0.040152
# 187    0.047705
# 185    0.068740
# 189    0.118673
# 188    0.162551
# 183    0.260047
# 190    0.273218
# 199    0.028907
# 196    0.040177
# 193    0.047735
# 195    0.068783
# 192    0.118747
# 197    0.162652
# 198    0.260210
# 194    0.272788
# 212    0.000006
# 211    0.001971
# 210    0.003248
# 207    0.087245
# 208    0.109224
# 209    0.798305
# 179    0.000078
# 181    0.000088
# 172    0.000099
# 167    0.000102
# 173    0.000222
# 177    0.000321
# 174    0.000589
# 176    0.001177
# 182    0.001385
# 178    0.001882
# 168    0.005407
# 171    0.005742
# 169    0.007138
# 165    0.024985
# 180    0.090577
# 170    0.124731
# 164    0.157918
# 166    0.233881
# 175    0.343677
# 162    0.097940
# 163    0.143599
# 161    0.758461
# 201    0.021189
# 203    0.021948
# 200    0.062687
# 206    0.072685
# 205    0.111749
# 202    0.177584
# 204    0.532158
# 295    0.000115
# 294    0.127008
# 290    0.198812
# 291    0.208849
# 293    0.230974
# 292    0.234243
# 246    0.000202
# 245    0.133640
# 241    0.191751
# 242    0.207180
# 244    0.233075
# 243    0.234152

# %% [markdown]
# ### 3.2. Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
  
    # Filtrar solo columnas numéricas seleccionadas en incluir_num
    cat = cat[incluir_cat]

    # Verificar si hay columnas numéricas
    if cat.shape[1] == 0:
        print("No hay columnas categóricas para graficar.")
        return    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat)

# %% [markdown]
# ## 4. EDA NUMÉRICAS

# %% [markdown]
# ### 4.1. Análisis estadístico

# %%
list(num.columns)
# Out:
# ['time_to_report', 'vict_age']

# %%
incluir_num = num.columns.to_list()

#Eliminamos las columnas que estén en la siguiente lista
for i in sorted([], reverse=True):
    del incluir_num[i]

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
pd.set_option('display.max_rows', None)

estadisticos_cont(num[incluir_num])
#Aparecerá una lista de todas las variables con su frecuencia asociada
# Out:
#                    count       mean  median        std  min  25%   50%   75%  \
# time_to_report  331263.0  12.071732     1.0  68.215594  0.0  0.0   1.0   2.0
# vict_age        331263.0  28.915765    30.0  22.000170  0.0  0.0  30.0  44.0
#
#                    max
# time_to_report  1791.0
# vict_age         100.0

# %%
num[incluir_num].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331263 entries, 200114944 to 240710787
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   time_to_report  331263 non-null  int64
#  1   vict_age        331263 non-null  int64
# dtypes: int64(2)
# memory usage: 7.6 MB

# %% [markdown]
# ### 4.2. Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    # Filtrar solo columnas numéricas seleccionadas en incluir_num
    num = num[incluir_num]

    # Verificar si hay columnas numéricas
    if num.shape[1] == 0:
        print("No hay columnas numéricas para graficar.")
        return
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# ## 5. VISUALIZACIONES ESPECÍFICAS

# %%
resultado = (
    df[df.crm_cd_1 != "OTROS"]                    # Filtramos OTROS
      .groupby(["area_name", "crm_cd_1"])         # Agrupamos por zona y código
      .size()                                     # Contamos
      .reset_index(name="count")                  # Convertimos a columna
      .sort_values(["area_name", "count"], ascending=[True, False])
      .groupby("area_name")                       # Para cada área...
      .head(1)                                    # ...nos quedamos con el top1
      .reset_index(drop=True))

resultado
# Out:
#       area_name crm_cd_1  count
# 0   77th Street    510.0   2911
# 1       Central    330.0   3161
# 2    Devonshire    510.0   1305
# 3      Foothill    510.0   1436
# 4        Harbor    510.0   1990
# 5    Hollenbeck    510.0   2081
# 6     Hollywood    624.0   1499
# 7       Mission    510.0   2058
# 8   N Hollywood    510.0   1698
# 9        Newton    510.0   2760
# 10    Northeast    510.0   1708
# 11      Olympic    510.0   1835
# 12      Pacific    510.0   2141
# 13      Rampart    510.0   1787
# 14    Southeast    510.0   2396
# 15    Southwest    510.0   2158
# 16      Topanga    510.0   1163
# 17     Van Nuys    510.0   1514
# 18      West LA    310.0   1391
# 19  West Valley    510.0   1475
# 20     Wilshire    510.0   1433

# %%
import matplotlib.pyplot as plt

# Ordenamos de mayor a menor
resultado_sorted = resultado.sort_values("count", ascending=False)

plt.figure(figsize=(12, 10))
plt.style.use('ggplot')

bars = plt.barh(
    resultado_sorted["area_name"],
    resultado_sorted["count"],
)

plt.gca().invert_yaxis()  # Para que el mayor quede arriba

# Añadir etiquetas dentro de la barra (crm_cd_1)
for bar, texto in zip(bars, resultado_sorted["crm_cd_1"]):
    plt.text(
        bar.get_width() * 0.02,               # un poco a la derecha del borde
        bar.get_y() + bar.get_height() / 2,   # centrado vertical
        str(texto),
        va='center',
        ha='left',
        color="white",
        fontsize=10,
    )

# Añadir el count al final de la barra
for bar, valor in zip(bars, resultado_sorted["count"]):
    plt.text(
        bar.get_width() + 3,                   # fuera de la barra
        bar.get_y() + bar.get_height() / 2,
        str(valor),
        va='center',
        ha='left',
        fontsize=10
    )

plt.xlabel("Frecuencia")
plt.ylabel("Área")
plt.title("Delito más frecuente por área")
plt.tight_layout()
plt.show()

# %% [markdown]
# En el gráfico podemos observar que el delito mas frecuente que se comete y la zona. Esto ayudaría a destinar recursos específicos
#
# NOTA: En un análisis mas profundo, se podría segmentar por horas, edad, procedencia de la víctima por zona y horario por ejemplo

# %%
tabla = df.groupby(["year_rptd", "part_1_2"]).size().unstack(fill_value=0)
tabla.columns = ['Leve', 'Grave']
tabla
# Out:
#             Leve  Grave
# year_rptd
# 2020       37316  26204
# 2021       40537  28094
# 2022       44660  32906
# 2023       46056  31153
# 2024       29911  14359
# 2025          35     32

# %%
ax = tabla.plot.line(figsize=(10, 6))

ax.set_xlabel("Año")
ax.set_ylabel("Frecuencia")
ax.set_title("Recuento delitos por año")

# Cambiar la leyenda
ax.legend(["Grave", "Leve"])

# Poner la frecuencia sobre cada punto
for line in ax.get_lines():
    for x, y in zip(line.get_xdata(), line.get_ydata()):
        ax.text(x, y, str(int(y)), fontsize=9, ha='center', va='bottom')

plt.show()

# %% [markdown]
# En el gráfico podemos observar el recuento de los tipos de delitos cometidos por año donde vemos que graves y leves siguen el mismo patrón descendente
