# %% [markdown]
# # REGEX IN PANDAS

# %%
import pandas as pd

# %% [markdown]
# # Extracto

# %% [markdown]
# `1. Extraer los enlaces`

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)

# %%
df = pd.DataFrame({'text': ['Visit our website at https://example.com', 'For more information, go to http://www.example.org']})
df
# Out:
#                                                 text
# 0           Visit our website at https://example.com
# 1  For more information, go to http://www.example...

# %% [markdown]
# `patrón_enlace = "?"`

# %%
# https://example.com
# http://www.example.org

# %% [markdown]
# `2. Extraer el número de teléfono`

# %%
df = pd.DataFrame({'text': ['Call me at (123) 456-7890 or 555-5555', 'No phone numbers here']})
df
# Out:
#                                     text
# 0  Call me at (123) 456-7890 or 555-5555
# 1                  No phone numbers here

# %% [markdown]
# `3. Extraer el correo electrónico`

# %% [markdown]
# `patrón_correo electrónico = "?"`

# %% [markdown]
# `4. Extraiga los nombres y expanda las columnas`

# %%
df = pd.DataFrame({'name': ['john Smith', 'Alice Johnson']})
df
# Out:
#             name
# 0     john Smith
# 1  Alice Johnson

# %% [markdown]
# `nombres_de_patrón = "?"`

# %% [markdown]
# # Reemplazar

# %% [markdown]
# `1. Eliminar caracteres no alfanuméricos`

# %% [markdown]
# `patter_non_alphanumeric = "\W+"`
