# %% [markdown]
# <h1>Tabla de contenido<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Cargar-bibliotecas" data-toc-modified-id="Cargar-bibliotecas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cargar bibliotecas</a></span></li><li><span><a href="#Funciones-Principales:" data-toc-modified-id="Funciones-Principales:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Funciones Principales:</a></span><ul class="toc-item"><li><span><a href="#sub()" datos-toc-modificado-id="sub()-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>sub()</a></span></li><li><span><a href="#split()" datos-toc-modificado-id="split()-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>split()</a></span></li><li><span><a href="#findall()" datos-toc-modificado-id="findall()-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>findall()</a></span></li><li><span><a href="#match()" datos-toc-modificado-id="match()-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>match()</a></span></li><li><span><a href="#search()" data-toc-modified-id="search()-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>search()</a></span></li></ul></li><li><span><a href="#¡Manos a la obra!-💪" data-toc-modified-id="¡Manos a la obra!-💪-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>¡Manos a la obra! 💪</a></span></li></ul></div>

# %% [markdown]
# ### Cargar bibliotecas

# %%
import re

# %% [markdown]
# ### Funciones principales:
#
# - **sub** : reemplaza una o varias coincidencias con una cadena.
#
# - **split** : devuelve una lista donde la cadena se ha dividido en cada coincidencia.
#
# - **findall** : devuelve una lista que contiene todas las coincidencias.
#
# - **search** : devuelve un objeto Match si hay una coincidencia en cualquier parte de la cadena.
#
# - **match** : busca el patrón de expresión regular y devuelve la primera ocurrencia.

# %% [markdown]
# #### sub()
# Reemplaza una o varias coincidencias con una cadena

# %%
txt = "Python and C++ are my favorite languages"

# %%
#re.sub(patron, a_sustituir_por, en_que_cadena)

# %%
#re.sub(pattern, substitution, str_)

# %% [markdown]
# #### split()
# Devuelve una lista en la que la cadena se ha dividido en cada coincidencia

# %%
a_string = "3one2twoo3threehttps://www.waedszrfersesrf.comfive666"
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/37/xdj49ptx3wn_fkmn66tjq0ch0000gt/T/ipykernel_1840/2357579002.py:3: SyntaxWarning: invalid escape sequence '\.'
#   re.split("https://www\.[a-zA-Z]+\.com", a_string)
# ['3one2twoo3three', 'five666']

# %% [markdown]
# #### findall()
# Devuelve una lista de cadenas que contienen todas las coincidencias

# %%
a_string = "3one2twoo3three4444five666"

# %%
#re.findall(pattern, text)

# %% [markdown]
# #### match()
# Busca el patrón de expresión regular y devuelve la primera ocurrencia en la **primera línea**.
#
# Pero si se encuentra una coincidencia en alguna otra línea, la función Python RegEx Match devuelve nulo.

# %%
una_string = "Hola! hoy es 26 del 02 en 2025 estamos viendo regex, el ñao pasado fue 2024"
una_string = "2025 Hola! hoy es 26 del 02 en 2025 estamos viendo regex, el ñao pasado fue 2024"

# %% [markdown]
# **Ok, pero... ¿Cómo puedo extraer la información? 🤔**

# %% [markdown]
# #### search()
# Devuelve un objeto de coincidencia si hay una coincidencia en cualquier parte de la cadena
#
# ⚠️Si no se encuentran **coincidencias**, se devuelve el valor `Ninguno`

# %% [markdown]
# 🔴 Entonces... **¿Cuál es la diferencia entre `search`, `match` y `findall`?**
#
# - Tanto `search()` como `match()` devuelven solo la primera ocurrencia de una subcadena en la cadena e ignoran las demás.
#
# - `search()` busca toda la cadena incluso si la cadena contiene varias líneas.
#
# - `match()` busca solo desde el principio de la cadena y devuelve el objeto de coincidencia si lo encuentra.
#
# - `findall` busca toda la cadena y devuelve una lista.
#
# Más información sobre la diferencia entre `findall`, `search` y `match` [aquí](https://www.geeksforgeeks.org/python-re-search-vs-re-match/) y [aquí](https://blog.finxter.com/python-re-findall/#How_Does_the_findall_Method_Work_in_Python)

# %% [markdown]
# | método | lo que encuentra | lo que devuelve |
# |---|---|---|
# |**findall()** | TODAS las coincidencias en todas las cadenas | lista |
# |**search()** | 1.ª coincidencia en todas las cadenas | objeto |
# |**match()** | todas las coincidencias en la 1.ª línea | objeto |

# %% [markdown]
# ### ¡Manos a la obra! 💪
#
# **Regex para validar el código PIN**: https://www.codewars.com/kata/55f8a9c06c018a0d6e000132
#
# **Conceptos básicos de Regexp: ¿es una letra?**: https://www.codewars.com/kata/567de72e8b3621b3c300000b
#
# **Conceptos básicos de Regexp: análisis de precios**: https://www.codewars.com/kata/56833b76371e86f8b6000015/train/python

# %% [markdown]
# [str.extract](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.extract.html)
